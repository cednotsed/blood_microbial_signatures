# %% [markdown]
# # Identication of putative contaminant taxa

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(foreach)
require(tidyverse)
require(ggplot2)
require(data.table)
require(compositions)
require(doParallel)
require(VennDiagram)
registerDoParallel(cores=8)
# Out:
# Loading required package: foreach
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::accumulate() masks foreach::accumulate()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ purrr::when()       masks foreach::when()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: compositions
#
# Welcome to compositions, a package for compositional data analysis.
# Find an intro with "? compositions"
#
#
#
# Attaching package: ‘compositions’
#
#
# The following objects are masked from ‘package:stats’:
#
#     anova, cor, cov, dist, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %*%, norm, scale, scale.default
#
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: VennDiagram
#
# Loading required package: grid
#
# Loading required package: futile.logger

# %% [markdown]
# ### Data pre-processing functions

# %%
load_data <- function(file_path) {
    dat <- as.data.frame(fread(file_path)) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(dat)
}


load_metadata <- function(file_path, dat) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% dat$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}


subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}


retrieve_rows_from_meta <- function(dat, meta) {
    return(dat %>% filter(npm_research_id %in% meta$npm_research_id)) 
}


remove_cols <- function(dat, col_to_exclude) {
    return(dat %>% select(-all_of(col_to_exclude)))
}


remove_low_prev_taxa <- function(dat, frac_presence, read_threshold) {
    n_original <- ncol(dat[, colnames(dat) != "npm_research_id"])
    PA_df <- apply(dat[, 2:ncol(dat)], 2, function(x) {ifelse(x > read_threshold, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    n_new <- length(to_keep) - 1
    print(str_glue("{n_new} / {n_original} taxa are present in {frac_presence} of samples"))
    return(dat %>% select(all_of(to_keep)))
}


otu_to_RA <- function(dat) {
    mat <- as.matrix(dat[, colnames(dat) != "npm_research_id"])
    RA_df <- as.data.frame(mat / rowSums(mat))
    RA_df <- add_column(RA_df, dat$npm_research_id, .before = 1)
    colnames(RA_df)[1] <- "npm_research_id"
    
    return(RA_df)
}


RA_to_clr <- function(dat) {
    mat <- dat[, colnames(dat) != "npm_research_id"]
    clr_df <- clr(mat)
    return(cbind(data.frame(npm_research_id = dat$npm_research_id), as.data.frame(clr_df, check.names = F)))
}


get_metadata_plots <- function(meta, meta_cols) {
    meta <- as.matrix(meta)
    meta <- as_tibble(meta, rownames = "sample")

    plots <- list()
    
    for (column in meta_cols) {
        plt <- meta %>%
            mutate(across(everything(), as.character)) %>%
            select(all_of(column)) %>%
            group_by_at(column) %>%
            summarise(n = n()) %>%
            ggplot(aes_string(x = column, y = "n", fill = column)) +
                geom_bar(stat = "identity") +
                theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
                geom_text(aes_string(label = "n"))
        plots[[column]] <- plt
    }
    
    return(plots)
}


get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id|site_supplying", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


print_group_freqs <- function(meta, meta_cols) {
    for (col in meta_cols) {
        tmp <- tibble(data.frame(meta)) %>%
            group_by(get(col)) %>%
            summarise(n = n())
        print(col)
        print(tmp)
    }
}


get_batch_prevalence <- function(x) {sum(x) / length(x)}


remove_low_sample_levels <- function(dat, metadat, column, min_samples) {
    # Remove levels with < x samples
    tmp <- tibble(data.frame(metadat)) %>%
            group_by(get(column)) %>%
            summarise(n = n())

    # Vector of group levels to keep
    to_keep <- tmp[tmp$n >= min_samples, "get(column)"]$`get(column)`
    to_keep <- to_keep[to_keep != "Unknown"]
    n_levels <- length(to_keep)

    if (n_levels < 2) {
        print(str_glue("After pruning, {column} has < 2 levels"))
    } else {
        print(str_glue("After pruning, {column} has {n_levels} levels"))
    }

    # Remove rows in metadata
    metadat_filt <- metadat %>% filter(get(column) %in% to_keep)

    # Retrieve rows
    dat_filt <- retrieve_rows_from_meta(dat, metadat_filt)
    metadat_filt <- metadat_filt %>% filter(npm_research_id %in% dat_filt$npm_research_id)

    return(list(dat_filt = dat_filt, metadat_filt = metadat_filt))
}


remove_empty_rows <- function(dat) {
    mat <- as.matrix(dat[, colnames(dat) != "npm_research_id"])
    row_sums <- rowSums(mat)
    df_filt <- dat[row_sums != 0, ]
    nrow(df_filt)

    n_original <- nrow(dat)
    n_removed <- n_original - nrow(df_filt)
    
    print(str_glue("{n_removed}/{n_original} samples removed due to having no reads of interest"))
    
    return(df_filt)
}


load_metadata <- function(file_path, dat) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% dat$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}

# %% [markdown]
# #### Params

# %%
human <- "Homo sapiens"
rank <- "S"
max_prev_t <- 0.25
fold_diff_t <- 2

# %% [markdown]
# #### Load and parse data

# %%
to_retain <- fread("data/samples_above_100_microbial_reads.txt")$npm_research_id

prev_df <- fread("results/decontamination/prevalence_RA0.005_read10.csv")

species_df <- load_data(str_glue("data/taxonomic_profiles/07_abundance_matrix/abundance_matrix.S.pipeline2_210322.tsv")) %>% 
    filter(npm_research_id %in% to_retain) %>%
    select(all_of(colnames(prev_df)))

all(colnames(species_df) == colnames(prev_df))

meta_filt <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", species_df)

# Convert to CLR abundances
df_filt <- RA_to_clr(otu_to_RA(species_df))
dim(species_df)
# Out:
# [1] TRUE
# [1] 8828  871

# %% [markdown]
# ### Correlation filter within batches

# %%
corr_decontam <- function(dat, non_contaminants, contaminants, meta_col, level) {
    nc_list <- foreach (non_contaminant_taxon = non_contaminants) %dopar% {
        morsel <- tibble()
        
        for (contaminant_taxon in contaminants) {
            spearman_test <- cor.test(dat[ , contaminant_taxon], dat[, non_contaminant_taxon])
            rho <- spearman_test$estimate
            print(str_glue("Computing correlations for {meta_col}: {level}"))
            morsel <- morsel %>% bind_rows(tibble(meta_col = meta_col, 
                                                  level = level,
                                                  non_contaminant_taxon = non_contaminant_taxon, 
                                                  contaminant_taxon = contaminant_taxon,
                                                  rho = rho))
        }

        return(morsel)
    }

    corr_df <- bind_rows(nc_list)  
    return(corr_df)
}

# %%
# Get non-contaminants/contaminants from diff prev. filter
diff_prev_contams_nc <- read.csv(str_glue("results/decontamination/diff_prev_V3/noncontaminants.RA0.005.read_threshold10.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))$taxa
diff_prev_contams <- read.csv(str_glue("results/decontamination/diff_prev_V3/contaminants.RA0.005.read_threshold10.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))$taxa

diff_prev <- fread("results/decontamination/diff_prev_V3/decon_V3_raw.RA0.005.read_threshold10.csv") %>%
    as_tibble()

diff_filt <- diff_prev %>%
    filter(fold_diff > 2, max_prev > 0.25)

iter_list <- diff_filt %>% 
    distinct(meta_col, max_level)

# %%
# morsels <- foreach(i = seq(nrow(iter_list))) %dopar% {
#     var_name <- iter_list[i, ]$meta_col
#     level_name <- iter_list[i, ]$max_level

#     contams <- (diff_filt %>% filter(meta_col == var_name, max_level == level_name))$taxa

#     noncontams <- colnames(df_filt)
#     noncontams <- noncontams[!(noncontams %in% c("npm_research_id", contams))]

#     batch_dat <- df_filt %>%
#         left_join(meta_filt %>% select(all_of(c("npm_research_id", var_name)))) %>%
#         filter(get(var_name) == level_name)

#     corr_decontam(batch_dat, noncontams, contams, var_name, level_name)
# }

# corr_res <- bind_rows(morsels)
corr_res <- fread("results/decontamination/correlation_decontamination/corr_raw.diff_prev_V3.RA0.005.read_threshold10.max_prev0.25.fold_diff2.corr_t0.7.within_batch.S.n9999.txt")

# %%
corr_res
# Out:
#        meta_col                     level
# 1      site_supplying_sample        MEC
# 2      site_supplying_sample        MEC
# 3      site_supplying_sample        MEC
# 4      site_supplying_sample        MEC
# 5      site_supplying_sample        MEC
# 6      site_supplying_sample        MEC
# 7      site_supplying_sample        MEC
# 8      site_supplying_sample        MEC
# 9      site_supplying_sample        MEC
# 10     site_supplying_sample        MEC
# 11     site_supplying_sample        MEC
# 12     site_supplying_sample        MEC
# 13     site_supplying_sample        MEC
# 14     site_supplying_sample        MEC
# 15     site_supplying_sample        MEC
# 16     site_supplying_sample        MEC
# 17     site_supplying_sample        MEC
# 18     site_supplying_sample        MEC
# 19     site_supplying_sample        MEC
# 20     site_supplying_sample        MEC
# 21     site_supplying_sample        MEC
# 22     site_supplying_sample        MEC
# 23     site_supplying_sample        MEC
# 24     site_supplying_sample        MEC
# 25     site_supplying_sample        MEC
# 26     site_supplying_sample        MEC
# 27     site_supplying_sample        MEC
# 28     site_supplying_sample        MEC
# 29     site_supplying_sample        MEC
# 30     site_supplying_sample        MEC
# ⋮      ⋮                            ⋮
# 726943 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726944 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726945 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726946 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726947 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726948 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726949 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726950 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726951 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726952 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726953 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726954 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726955 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726956 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726957 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726958 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726959 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726960 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726961 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726962 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726963 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726964 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726965 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726966 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726967 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726968 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726969 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726970 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726971 hiseq_xtm_flow_cell_v2_5_lot 20347589
# 726972 hiseq_xtm_flow_cell_v2_5_lot 20347589
#        non_contaminant_taxon
# 1      Sphingobium sp. RAC03
# 2      Sphingobium sp. RAC03
# 3      Sphingobium sp. RAC03
# 4      Sphingobium sp. RAC03
# 5      Sphingobium sp. RAC03
# 6      Sphingobium sp. RAC03
# 7      Sphingobium sp. RAC03
# 8      Sphingobium sp. RAC03
# 9      Sphingobium sp. RAC03
# 10     Sphingobium sp. RAC03
# 11     Sphingobium sp. RAC03
# 12     Sphingobium sp. RAC03
# 13     Sphingobium sp. RAC03
# 14     Sphingobium sp. RAC03
# 15     Sphingobium sp. RAC03
# 16     Sphingobium sp. RAC03
# 17     Sphingobium sp. RAC03
# 18     Sphingobium sp. RAC03
# 19     Sphingobium sp. RAC03
# 20     Sphingobium sp. RAC03
# 21     Sphingobium sp. RAC03
# 22     Sphingobium sp. RAC03
# 23     Sphingobium sp. RAC03
# 24     Sphingobium sp. RAC03
# 25     Sphingobium sp. RAC03
# 26     Sphingobium sp. RAC03
# 27     Sphingobium sp. RAC03
# 28     Sphingobium sp. RAC03
# 29     Sphingobium sp. RAC03
# 30     Sphingobium sp. RAC03
# ⋮      ⋮
# 726943 Rickettsia endosymbiont of Ixodes pacificus
# 726944 Rickettsia endosymbiont of Ixodes pacificus
# 726945 Rickettsia endosymbiont of Ixodes pacificus
# 726946 Woolly monkey hepatitis B virus
# 726947 Woolly monkey hepatitis B virus
# 726948 Woolly monkey hepatitis B virus
# 726949 Human betaherpesvirus 5
# 726950 Human betaherpesvirus 5
# 726951 Human betaherpesvirus 5
# 726952 Human alphaherpesvirus 2
# 726953 Human alphaherpesvirus 2
# 726954 Human alphaherpesvirus 2
# 726955 Streptococcus sp. FDAARGOS_522
# 726956 Streptococcus sp. FDAARGOS_522
# 726957 Streptococcus sp. FDAARGOS_522
# 726958 Torque teno virus 2
# 726959 Torque teno virus 2
# 726960 Torque teno virus 2
# 726961 Bacillus sp. TK-2
# 726962 Bacillus sp. TK-2
# 726963 Bacillus sp. TK-2
# 726964 Rickettsia massiliae
# 726965 Rickettsia massiliae
# 726966 Rickettsia massiliae
# 726967 Lactobacillus phage Lv-1
# 726968 Lactobacillus phage Lv-1
# 726969 Lactobacillus phage Lv-1
# 726970 Capuchin monkey hepatitis B virus
# 726971 Capuchin monkey hepatitis B virus
# 726972 Capuchin monkey hepatitis B virus
#        contaminant_taxon                   rho
# 1      Sphingobium sp. YG1                 0.9289072
# 2      Sphingobium yanoikuyae              0.9367592
# 3      Sphingobium baderi                  0.9574772
# 4      Sphingomonas sp. LM7                0.8393325
# 5      Sphingomonas sp. Cra20              0.8395500
# 6      Sphingomonas sp. CL5.1              0.9118260
# 7      Sphingomonas sp. IC081              0.9681173
# 8      Sphingomonas sp. XS-10              0.8675847
# 9      Sphingomonas sp. FARSPH             0.8638212
# 10     Sphingomonas sp. LK11               0.8976870
# 11     Sphingomonas sp. DH-S5              0.8707972
# 12     Sphingomonas sp. NBWT7              0.8946001
# 13     Sphingomonas sp. MM-1               0.8874182
# 14     Sphingomonas sp. AP4-R1             0.8986929
# 15     Sphingomonas sp. AAP5               0.8814412
# 16     Sphingomonas hengshuiensis          0.8438169
# 17     Sphingomonas koreensis              0.8585692
# 18     Sphingomonas sanxanigenens          0.9215114
# 19     Sphingomonas alpina                 0.8594948
# 20     Sphingomonas paucimobilis           0.8996606
# 21     Sphingomonas taxi                   0.8676601
# 22     Sphingomonas panacisoli             0.8759012
# 23     Sphingomonas panacis                0.8885410
# 24     Novosphingobium sp. ABRDHK2         0.9118342
# 25     Sphingosinithalassobacter sp. zrk23 0.8786016
# 26     Sphingosinithalassobacter sp. CS137 0.8696049
# 27     Bradyrhizobium sp. BTAi1            0.2632180
# 28     Bradyrhizobium sp. PSBB068          0.4630786
# 29     Bradyrhizobium sp. CCBAU 051011     0.2203451
# 30     Bradyrhizobium sp. CCBAU 51753      0.2678297
# ⋮      ⋮                                   ⋮
# 726943 Achromobacter denitrificans         -0.003038504
# 726944 Achromobacter spanius                0.012366081
# 726945 Achromobacter sp. AONIH1            -0.016858115
# 726946 Achromobacter denitrificans                   NA
# 726947 Achromobacter spanius                         NA
# 726948 Achromobacter sp. AONIH1                      NA
# 726949 Achromobacter denitrificans                   NA
# 726950 Achromobacter spanius                         NA
# 726951 Achromobacter sp. AONIH1                      NA
# 726952 Achromobacter denitrificans                   NA
# 726953 Achromobacter spanius                         NA
# 726954 Achromobacter sp. AONIH1                      NA
# 726955 Achromobacter denitrificans          0.037425043
# 726956 Achromobacter spanius                0.089340519
# 726957 Achromobacter sp. AONIH1             0.041405038
# 726958 Achromobacter denitrificans                   NA
# 726959 Achromobacter spanius                         NA
# 726960 Achromobacter sp. AONIH1                      NA
# 726961 Achromobacter denitrificans                   NA
# 726962 Achromobacter spanius                         NA
# 726963 Achromobacter sp. AONIH1                      NA
# 726964 Achromobacter denitrificans                   NA
# 726965 Achromobacter spanius                         NA
# 726966 Achromobacter sp. AONIH1                      NA
# 726967 Achromobacter denitrificans                   NA
# 726968 Achromobacter spanius                         NA
# 726969 Achromobacter sp. AONIH1                      NA
# 726970 Achromobacter denitrificans                   NA
# 726971 Achromobacter spanius                         NA
# 726972 Achromobacter sp. AONIH1                      NA

# %%
corr_c <- corr_res %>% 
    filter(rho > 0.7) %>%
    distinct(non_contaminant_taxon) %>%
    rename(contaminants = non_contaminant_taxon)

corr_nc <- tibble(non_contaminant_taxon = colnames(df_filt)[!(colnames(df_filt) %in% c("npm_research_id", 
                                                                                       corr_c$contaminants, 
                                                                                       diff_prev_contams))])
# Out:
#   [1] "Sphingobium sp. YG1"
#   [2] "Sphingobium yanoikuyae"
#   [3] "Sphingobium baderi"
#   [4] "Sphingomonas sp. LM7"
#   [5] "Sphingomonas sp. Cra20"
#   [6] "Sphingomonas sp. CL5.1"
#   [7] "Sphingomonas sp. IC081"
#   [8] "Sphingomonas sp. XS-10"
#   [9] "Sphingomonas sp. FARSPH"
#  [10] "Sphingomonas sp. LK11"
#  [11] "Sphingomonas sp. DH-S5"
#  [12] "Sphingomonas sp. NBWT7"
#  [13] "Sphingomonas sp. MM-1"
#  [14] "Sphingomonas sp. AP4-R1"
#  [15] "Sphingomonas sp. AAP5"
#  [16] "Sphingomonas hengshuiensis"
#  [17] "Sphingomonas koreensis"
#  [18] "Sphingomonas sanxanigenens"
#  [19] "Sphingomonas alpina"
#  [20] "Sphingomonas melonis"
#  [21] "Sphingomonas paucimobilis"
#  [22] "Sphingomonas taxi"
#  [23] "Sphingomonas panacisoli"
#  [24] "Sphingomonas panacis"
#  [25] "Novosphingobium sp. ABRDHK2"
#  [26] "Sphingosinithalassobacter sp. zrk23"
#  [27] "Sphingosinithalassobacter sp. CS137"
#  [28] "Bradyrhizobium sp. BTAi1"
#  [29] "Bradyrhizobium sp. PSBB068"
#  [30] "Bradyrhizobium sp. CCBAU 051011"
#  [31] "Bradyrhizobium sp. SK17"
#  [32] "Bradyrhizobium sp. CCBAU 51753"
#  [33] "Bradyrhizobium erythrophlei"
#  [34] "Bradyrhizobium diazoefficiens"
#  [35] "Bradyrhizobium lablabi"
#  [36] "Bradyrhizobium betae"
#  [37] "Bradyrhizobium canariense"
#  [38] "Bradyrhizobium icense"
#  [39] "Rhodopseudomonas palustris"
#  [40] "Tardiphaga robiniae"
#  [41] "Afipia carboxidovorans"
#  [42] "Methylobacterium currus"
#  [43] "Methylobacterium sp. 17Sr1-43"
#  [44] "Methylobacterium aquaticum"
#  [45] "Methylobacterium durans"
#  [46] "Caulobacter flavus"
#  [47] "Caulobacter mirabilis"
#  [48] "Caulobacter sp. K31"
#  [49] "Caulobacter soli"
#  [50] "Caulobacter vibrioides"
#  [51] "Caulobacter rhizosphaerae"
#  [52] "Burkholderia contaminans"
#  [53] "Ralstonia solanacearum"
#  [54] "Ralstonia insidiosa"
#  [55] "Ralstonia pickettii"
#  [56] "Kinneretia sp. DAIF2"
#  [57] "Achromobacter xylosoxidans"
#  [58] "Pseudomonas alcaligenes"
#  [59] "Pseudomonas aeruginosa"
#  [60] "Pseudomonas stutzeri"
#  [61] "Caulobacter segnis"
#  [62] "Caulobacter sp. FWC26"
#  [63] "Caulobacter henricii"
#  [64] "Methylobacterium brachiatum"
#  [65] "Alcaligenes sp. SORT26"
#  [66] "Alcaligenes faecalis"
#  [67] "Paraburkholderia fungorum"
#  [68] "Herbaspirillum huttiense"
#  [69] "Acinetobacter johnsonii"
#  [70] "Pseudomonas mendocina"
#  [71] "Pseudomonas sp. phDV1"
#  [72] "Pseudomonas sp. LPH1"
#  [73] "Pseudomonas toyotomiensis"
#  [74] "Pseudomonas sihuiensis"
#  [75] "Pseudomonas sediminis"
#  [76] "Microbacterium sp. BH-3-3-3"
#  [77] "Microbacterium testaceum"
#  [78] "Microbacterium chocolatum"
#  [79] "Brevibacterium casei"
#  [80] "Rhodococcus sp. P-2"
#  [81] "Ralstonia mannitolilytica"
#  [82] "Pseudomonas sp. B11D7D"
#  [83] "Pseudomonas oleovorans"
#  [84] "Pseudomonas sp. MSPm1"
#  [85] "Pseudomonas alcaliphila"
#  [86] "Bordetella genomosp. 13"
#  [87] "Achromobacter deleyi"
#  [88] "Microcella alkaliphila"
#  [89] "Sphingobium sp. RAC03"
#  [90] "Bradyrhizobium sp. ORS 285"
#  [91] "Bradyrhizobium sp. CCBAU 53421"
#  [92] "Bradyrhizobium sp. 6(2017)"
#  [93] "Bradyrhizobium paxllaeri"
#  [94] "Nitrobacter hamburgensis"
#  [95] "Methylorubrum populi"
#  [96] "Brevundimonas sp. CS1"
#  [97] "Sphingomonas sp. LMO-1"
#  [98] "Sphingomonas sp. NIC1"
#  [99] "Sphingomonas sp. HMP6"
# [100] "Sphingomonas sp. HMP9"
# [101] "Sphingomonas wittichii"
# [102] "Sphingomonas insulae"
# [103] "Bradyrhizobium sp. ORS 278"
# [104] "Bradyrhizobium sp. CCGE-LA001"
# [105] "Bradyrhizobium sp. 1(2017)"
# [106] "Bradyrhizobium sp. CCBAU 53338"
# [107] "Bradyrhizobium sp. CCBAU 51765"
# [108] "Bradyrhizobium sp. CCBAU 53351"
# [109] "Bradyrhizobium sp. CCBAU 53340"
# [110] "Bradyrhizobium japonicum"
# [111] "Bradyrhizobium genosp. L"
# [112] "Bradyrhizobium guangzhouense"
# [113] "Bradyrhizobium zhanjiangense"
# [114] "Bradyrhizobium oligotrophicum"
# [115] "Bradyrhizobium vignae"
# [116] "Bradyrhizobium guangdongense"
# [117] "Bradyrhizobium symbiodeficiens"
# [118] "Bradyrhizobium genosp. B"
# [119] "Bradyrhizobium cosmicum"
# [120] "Afipia sp. GAS231"
# [121] "Bosea sp. Tri-49"
# [122] "Nitrobacter winogradskyi"
# [123] "Methylobacterium sp. WL1"
# [124] "Methylobacterium terrae"
# [125] "Methylobacterium indicum"
# [126] "Methylobacterium mesophilicum"
# [127] "Methylorubrum extorquens"
# [128] "Brevundimonas sp. SGAir0440"
# [129] "Microbacterium hominis"
# [130] "Brevundimonas sp. GW460-12-10-14-LB2"
# [131] "Methylobacterium phyllosphaerae"
# [132] "Methylobacterium sp. 4-46"
# [133] "Methylobacterium nodulans"
# [134] "Rhizobium oryzihabitans"
# [135] "Achromobacter denitrificans"
# [136] "Delftia acidovorans"
# [137] "Delftia tsuruhatensis"
# [138] "Massilia oculi"
# [139] "Microbacterium sp. 10M-3C3"
# [140] "Methylobacterium sp. 17Sr1-1"
# [141] "Methylobacterium sp. AMS5"
# [142] "Bosea sp. RAC05"
# [143] "Phreatobacter cathodiphilus"
# [144] "Achromobacter spanius"
# [145] "Achromobacter sp. AONIH1"
# [146] "Leifsonia shinshuensis"
# [147] "Methylobacterium sp. DM1"
# [148] "Massilia sp. LPB0304"
# [149] "Microbacterium lemovicicum"
# [150] "Bradyrhizobium sp."
# [151] "Phreatobacter stygius"
# [152] "Microbacterium oleivorans"
# [153] "Methylobacterium sp. C1"
# [154] "Methylobacterium radiotolerans"
# [155] "Phyllobacterium sp. 628"
# [156] "Stenotrophomonas maltophilia"
# [157] "Methylobacterium sp. XJLW"
# [158] "Methylorubrum zatmanii"
# [159] "Toxoplasma gondii"
# [160] "Prevotella copri"

# %% [markdown]
# ### Parse and save results

# %%
corr_t <- 0.7

fwrite(corr_res,  
       str_glue("results/decontamination/correlation_decontamination/corr_raw.diff_prev_V3.RA0.005.read_threshold10.max_prev{max_prev_t}.fold_diff{fold_diff_t}.corr_t{corr_t}.within_batch.S.n9999.txt"))
fwrite(corr_c, 
       str_glue("results/decontamination/correlation_decontamination/contam.diff_prev_V3.RA0.005.read_threshold10.max_prev{max_prev_t}.fold_diff{fold_diff_t}.corr_t{corr_t}.within_batch.S.n9999.txt"))
fwrite(corr_nc, 
       str_glue("results/decontamination/correlation_decontamination/nc.diff_prev_V3.RA0.005.read_threshold10.max_prev{max_prev_t}.fold_diff{fold_diff_t}.corr_t{corr_t}.within_batch.S.n9999.txt"))

# print(length(corr_nc$non_contaminant_taxon))
print(length(corr_c$contaminants))
print(length(corr_nc$non_contaminant_taxon))
# Out:
# [1] 330
# [1] 535

# %% [markdown]
# ## Plot correlation heatmaps

# %%
plot_heatmap <- function(dat) {
    as.data.frame(cor(dat)) %>%
        rownames_to_column("taxa1") %>%
        pivot_longer(!taxa1, names_to = "taxa2", values_to = "rho") %>%
                mutate(fill_color = case_when(rho <= 0 ~ "<0",
                         rho > 0 & rho <= 0.1 ~ "0-0.1",
                         rho > 0.1 & rho <= 0.2 ~ "0.1-0.2",
                         rho > 0.2 & rho <= 0.3 ~ "0.2-0.3",
                         rho > 0.3 & rho <= 0.5 ~  "0.3-0.5",
                         rho > 0.5 & rho <= 0.7 ~ "0.5-0.7",
                         rho > 0.7 ~ ">0.7")) %>%
        mutate(fill_color = factor(fill_color, levels = c("<0", "0-0.1", "0.1-0.2", "0.2-0.3", "0.3-0.5", "0.5-0.7", ">0.7"))) %>%
        ggplot(aes(x = taxa1, y = taxa2, fill = fill_color)) + 
        geom_tile() +
        scale_fill_manual(values = c("#6699cc", "#ffffcc", "#f39b7fb2", "#e64b35b2", "#d11141", "darkred", "black"), drop = F) +
        theme(axis.text.x = element_text(angle = 45, hjust = 1),
              axis.title = element_blank()) +
    labs(fill = "Rho", title = str_glue("n = {nrow(dat)}"))
}

# %%
plot_iter <- list(c("site_supplying_sample", "MEC"), 
                  c("extraction_kit", "Chemagic DNA Blood Kit (Perkin Elmer, MA)"),
                  c("hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot", "20392972"),
                  c("hiseq_xtm_flow_cell_v2_5_lot", "20367079"))

for (item in plot_iter) {
    var_name <- item[1]
    level_name <- item[2]
    mec_contam <- corr_res %>% 
        filter(level == level_name) %>%
        filter(rho > 0.7)
    mec_contam <- c(mec_contam$contaminant_taxon, mec_contam$non_contaminant_taxon)

    mec_nc <- corr_res %>% 
        filter(level == level_name) %>%
        filter(rho <= 0.7)
    mec_nc <- mec_nc$non_contaminant_taxon

    contam_df <- df_filt %>% 
        left_join(meta_filt) %>%
        filter(get(var_name) == level_name) %>%
        select(all_of(mec_contam))
    nc_df <- df_filt %>% 
        left_join(meta_filt) %>%
        filter(get(var_name) == level_name) %>%
        select(all_of(mec_nc))

    plot_heatmap(contam_df)
    ggsave(str_glue("results/decontamination/correlation_decontamination/correlation_contaminants.{var_name}.{level_name}.png"), 
           dpi = 300, 
           height = 6.67, width = 7.5)
    plot_heatmap(nc_df)
        ggsave(str_glue("results/decontamination/correlation_decontamination/correlation_non_contaminants.{var_name}.{level_name}.png"), 
           dpi = 300, 
           height = 6.67, width = 7.5)
}
# Out:
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
