# %% [markdown]
# # Convert taxa list to a pretty table

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbial_signatures/")
require(tidyverse)
require(data.table)
require(foreach)
require(reactable)
require(htmltools)
require(htmlwidgets)
require(IRdisplay)
require(repr)
require(webshot2)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: reactable
#
# Loading required package: htmltools
#
# Loading required package: htmlwidgets
#
# Loading required package: IRdisplay
#
# Loading required package: repr
#
# Loading required package: webshot2

# %% [markdown]
# ### Load  data and add metadata

# %%
# After parsing
path_prev_max_filt <- fread(str_glue("results/decontamination/curated_n117_global_decontamination_stats.parsed.csv"))

# %%
cov_df_parsed <- fread("results/irep_analysis/coverage_irep_results.parsed.csv") %>%
    select(prefix, taxa)
cov_df <- fread("results/irep_analysis/coverage_irep_results.raw.csv") %>%
    left_join(cov_df_parsed) %>%
    filter(bPTR > 0)

to_display <- path_prev_max_filt %>%
    left_join(cov_df, "taxa") %>%
    filter(bPTR > 0, org_group == "Bacteria") %>%
    mutate(site = ifelse(site == "oral", "mouth", site))

# to_display
to_display_morsels <- foreach(taxon = unique(to_display$taxa)) %do% {
        temp <- to_display %>% filter(taxa == taxon) 
        sites <- temp$site[!(temp$site %in% c("eye", "blood"))]
        sites <- sites[order(sites)]
#         sites <- paste0(sites, collapse = "<br>")
        sites <- paste0(sites, collapse = ", ")
        temp %>% 
            distinct(taxa, .keep_all = T) %>%
            mutate(site = sites)
}

final <- bind_rows(to_display_morsels)
final
# Out:
# Joining, by = "prefix"
#    taxa                        genus.x         max_count overall_prevalence
# 1  Fusobacterium nucleatum     Fusobacterium   194199    0.001124606
# 2  Neisseria subflava          Neisseria        15385    0.001574449
# 3  Haemophilus parainfluenzae  Haemophilus      12183    0.002024291
# 4  Fannyhessea vaginae         Fannyhessea      10395    0.002361673
# 5  Staphylococcus epidermidis  Staphylococcus    9140    0.008547009
# 6  Lactobacillus crispatus     Lactobacillus     7799    0.010571300
# 7  Acinetobacter baumannii     Acinetobacter     7673    0.003148898
# 8  Neisseria flavescens        Neisseria         3787    0.000562303
# 9  Rickettsia sp. Tillamook 23 Rickettsia        2923    0.000224921
# 10 Moraxella osloensis         Moraxella         2402    0.019118309
# 11 Corynebacterium imitans     Corynebacterium   1976    0.000224921
#    n_samples org_group site
# 1   10       Bacteria  genitourinary tract, gut, mouth
# 2   14       Bacteria  gut, mouth
# 3   18       Bacteria  gut, mouth, respiratory tract
# 4   21       Bacteria  genitourinary tract
# 5   76       Bacteria  gut, mouth, respiratory tract, skin
# 6   94       Bacteria  genitourinary tract, gut, mouth
# 7   28       Bacteria  mouth
# 8    5       Bacteria  mouth
# 9    2       Bacteria
# 10 170       Bacteria  skin
# 11   2       Bacteria
#    microbiol_class        prefix
# 1  Obligate anaerobe      Fusobacterium_nucleatum_NZ_LN831027.1
# 2  Aerobic                Neisseria_subflava_NZ_CP039887.1
# 3  Facultative anaerobe   Haemophilus_parainfluenzae_NZ_GL872339.1
# 4  Obligate anaerobe      Fannyhessea_vaginae_NZ_UFSV01000001.1
# 5  Facultative anaerobe   Staphylococcus_epidermidis_NZ_CP035288.1
# 6  Aerotolerant anaerobe  Lactobacillus_crispatus_NZ_CP039266.1
# 7  Aerobic                Acinetobacter_baumannii_NZ_CP043953.1
# 8  Aerobic                Neisseria_flavescens_NZ_CP039886.1
# 9  Obligate intracellular Rickettsia_Tillamook_23_NZ_CP060138.1
# 10 Aerobic                Moraxella_osloensis_NZ_CP014234.1
# 11 Aerobic                Corynebacterium_imitans_NZ_LT906467.1
#    npm_research_id ⋯ file_name
# 1  WHB4594         ⋯ Fusobacterium_nucleatum_NZ_LN831027.1.fasta
# 2  WHB9179         ⋯ Neisseria_subflava_NZ_CP039887.1.fasta
# 3  WHB9179         ⋯ Haemophilus_parainfluenzae_NZ_GL872339.1.fasta
# 4  WHB4035         ⋯ Fannyhessea_vaginae_NZ_UFSV01000001.1.fasta
# 5  WHB6459         ⋯ Staphylococcus_epidermidis_NZ_CP035288.1.fasta
# 6  WHB10710        ⋯ Lactobacillus_crispatus_NZ_CP039266.1.fasta
# 7  0116-0053       ⋯ Acinetobacter_baumannii_NZ_CP043953.1.fasta
# 8  WHB9179         ⋯ Neisseria_flavescens_NZ_CP039886.1.fasta
# 9  WHB9978         ⋯ Rickettsia_Tillamook_23_NZ_CP060138.1.fasta
# 10 WHH1248         ⋯ Moraxella_osloensis_NZ_CP014234.1.fasta
# 11 WHB9812         ⋯ Corynebacterium_imitans_NZ_LT906467.1.fasta
#    genus.y         species        suffix1 suffix2              ORI
# 1  Fusobacterium   nucleatum      NZ      LN831027.1.fasta     201,937
# 2  Neisseria       subflava       NZ      CP039887.1.fasta     1,883,368
# 3  Haemophilus     parainfluenzae NZ      GL872339.1.fasta     492,915
# 4  Fannyhessea     vaginae        NZ      UFSV01000001.1.fasta 613,931
# 5  Staphylococcus  epidermidis    NZ      CP035288.1.fasta     237,449
# 6  Lactobacillus   crispatus      NZ      CP039266.1.fasta     328,627
# 7  Acinetobacter   baumannii      NZ      CP043953.1.fasta     3,869,401
# 8  Neisseria       flavescens     NZ      CP039886.1.fasta     1,737,155
# 9  Rickettsia      Tillamook      23      NZ                   240,832
# 10 Moraxella       osloensis      NZ      CP014234.1.fasta     1,501,499
# 11 Corynebacterium imitans        NZ      LT906467.1.fasta     395,265
#    TER       bPTR     microbe_length microbe_count
# 1  1,345,205 1.675886 2443126        3657.7463
# 2  797,590   1.506405 2195659        1882.0952
# 3  1,443,748 1.172580 2112961         744.5671
# 4  1,264,620 1.876599 1445974         707.5888
# 5  1,347,375 1.566844 2466502         734.9293
# 6  1,239,005 1.571468 2023061         541.4163
# 7  1,967,227 1.896385 3972439         849.0606
# 8  716,802   1.380708 2231882        1721.0496
# 9  888,370   1.346660 1438973        1197.8891
# 10 405,889   1.329333 2434688         138.1334
# 11 1,549,788 1.588094 2565606         182.7148

# %%
fread("results/irep_analysis/coverage_irep_results.raw.csv") %>%
    filter(!grepl("Achromo|Alcali|Pseu|Staphylococcus_haemolyticus|cohnii|Asper", prefix)) %>%
    summarise(range(perc_covered1))
#     distinct(prefix)
# Out:
#   range(perc_covered1)
# 1  0.04072575
# 2 98.75583204

# %% [markdown]
# ## Render table

# %%
# render functions
orange_pal <- function(x) rgb(colorRamp(c("khaki4", "khaki1"))(x), maxColorValue = 255)
green_pal <- function(x) scales::colour_ramp(c("white", "darkolivegreen1"), na.color = "white")(x)

# %%
parsed <- final %>%
    mutate(overall_prevalence = round(overall_prevalence * 100, 2),
           perc_covered1 = round(perc_covered1, 1),
           bPTR = round(bPTR, 2),
           emia = ifelse(taxa == "Rickettsia sp. Tillamook 23", F, T)) %>%
    select(npm_research_id, taxa, site, emia, pairs_assigned, overall_prevalence, bPTR) %>%
    arrange(desc(pairs_assigned))

rtable <- parsed %>%
  reactable(compact = T,
            borderless = F,
            pagination = F,
            style = list(fontFamily = "Arial", fontSize = "16px"),
            width = 1300,
            height = 450,
            columns = list(taxa = colDef(name = "Species",
                                         width = 250,
                                         align = "left",
                                         style = list(fontStyle = "italic")),
                           site = colDef(name = "Possible origin",
                                         width = 200,
                                         align = "center",
                                         html = T),
                           npm_research_id = colDef(name = "ID",
                                                    width = 100,
                                                    align = "center"),
                            
                           overall_prevalence = colDef(name = "Overall prevalence (%)",
                                                       align = "center",
                                                       width = 200,
                                                       style = function(value) {
                                                          normalized <- (value - min(parsed$overall_prevalence)) / (max(parsed$overall_prevalence) - min(parsed$overall_prevalence))
                                                          color <- green_pal(normalized)
                                                          list(background = color)
                                                       }),
                           pairs_assigned = colDef(name = "No. of read pairs assigned",
                                                       align = "center"),
                           bPTR = colDef(name = "PTR",
                                         width = 80,
                                             align = "center",
                                             style = function(value) {
                                                 normalised <- (value - min(parsed$bPTR, na.rm = T)) / 
                                                   (max(parsed$bPTR, na.rm = T) - min(parsed$bPTR, na.rm = T))
                                                 color <- green_pal(normalised)
                                                 list(background = color)
                                             }),                        
                           emia = colDef(name = "Reported in blood",
                                         align = "center",
                                         width = 150,
#                                          style = list(borderRight = "1px solid rgba(0, 0, 0, 0.5)"),
                                         cell = function(value) {
                                             # Render as an X mark or check mark
                                             if (value) "\u2714\ufe0f" else "\u274c"
                                         })
            )
  )

html <- "results/irep_analysis/parsed_irep_results.html"
saveWidget(rtable, html)
