# %% [markdown]
# # Identication of putative contaminant taxa

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(foreach)
require(tidyverse)
require(ggplot2)
require(data.table)
require(doParallel)
require(compositions)
require(VennDiagram)
registerDoParallel(cores=6)

# %% [markdown]
# ### Data processing functions

# %%
load_data <- function(file_path) {
    df <- as.data.frame(fread(file_path)) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}


load_metadata <- function(file_path, df) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% df$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}


subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}


retrieve_rows_from_meta <- function(df, meta) {
    return(df %>% filter(npm_research_id %in% meta$npm_research_id)) 
}


remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}


remove_low_freq_taxa <- function(df, frac_presence) {
    n_original <- ncol(df[, colnames(df) != "npm_research_id"])
    PA_df <- apply(df[, 2:ncol(df)], 2, function(x) {ifelse(x > 0, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    n_new <- length(to_keep) - 1
    print(str_glue("{n_new} / {n_original} taxa are present in {frac_presence} of samples"))
    return(df %>% select(all_of(to_keep)))
}


otu_to_RA <- function(df) {
    mat <- as.matrix(df[, colnames(df) != "npm_research_id"])
    RA_df <- as.data.frame(mat / rowSums(mat))
    RA_df <- add_column(RA_df, df$npm_research_id, .before = 1)
    colnames(RA_df)[1] <- "npm_research_id"
    
    return(RA_df)
}


get_meta_cols <- function(meta, meta_regex, to_exclude) {
    meta_cols <- colnames(meta)[grep(meta_regex, colnames(meta))]
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


otu_to_PA <- function(df, read_threshold) {
    prev_read <- df %>%
        column_to_rownames("npm_research_id")
    
    prev_read[prev_read <= read_threshold] <- 0
    prev_read[prev_read > read_threshold] <- 1

    return(prev_read)
}


RA_to_PA <- function(RA_df, PA_threshold) {
    prev_RA <- RA_df %>% column_to_rownames("npm_research_id")
    prev_RA[prev_RA <= PA_threshold] <- 0
    prev_RA[prev_RA > PA_threshold] <- 1
    
    return(prev_RA)
}


RA_to_clr <- function(df) {
    mat <- df[, colnames(df) != "npm_research_id"]
    clr_df <- clr(mat)
    return(cbind(data.frame(npm_research_id = df$npm_research_id), as.data.frame(clr_df, check.names = F)))
}


filter_taxa_by_presence <- function(prev_df, presence_t) {
    taxa_counts <- apply(prev_df, 2, sum)
    to_keep <- names(taxa_counts)[taxa_counts > presence_t]
    return(prev_df %>% select(all_of(to_keep)))
}

# %% [markdown]
# ### Decontamination functions

# %%
filter_batch_levels <- function(dat, metadat, column) {
    # Remove levels with < x samples
    tmp <- tibble(data.frame(metadat)) %>%
            group_by(get(column)) %>%
            summarise(n = n())

    # Vector of group levels to keep
    to_keep <- tmp[tmp$n >= min_samples, "get(column)"]$`get(column)`
    to_keep <- to_keep[to_keep != "Unknown"]
    n_levels <- length(to_keep)

    if (n_levels < 2) {
        print(str_glue("After pruning, {column} has < 2 levels"))
    } else {
        print(str_glue("After pruning, {column} has {n_levels} levels"))
    }

    # Remove rows in metadata
    dat_meta <- dat %>%
        left_join(metadat, by = "npm_research_id") %>%
        filter(get(column) %in% to_keep)

    return(dat_meta)
}


get_taxon_diff_prev <- function(dat_meta, column, taxon) {
    prev_stats <- dat_meta %>%
        group_by_at(c(column)) %>%
        summarise(prevalence = sum(get(taxon)) / n())

    max_prev <- max(prev_stats$prevalence)
    min_prev <- min(prev_stats$prevalence)
    fold_diff <- max_prev / min_prev
    max_level <- pull(prev_stats, column)[which(prev_stats$prevalence == max(prev_stats$prevalence))][1]
    min_level <- pull(prev_stats, column)[which(prev_stats$prevalence == min(prev_stats$prevalence))][1]

    crumb <- tibble(taxa = taxon, meta_col = column,
           max_level = max_level, min_level = min_level, 
           max_prev = max_prev, min_prev = min_prev,
           fold_diff = fold_diff)

    crumb <- distinct(crumb, taxa, .keep_all = T)

    return(crumb)
}

get_diff_prev <- function(dat, metadat, meta_cols, taxa_vec, prev_threshold, min_samples) {
    morsels <- foreach (column = meta_cols) %do% {
        dat_meta <- filter_batch_levels(dat, metadat, column)
        
        crumbs <- foreach (taxon = taxa_vec) %dopar% {
            get_taxon_diff_prev(dat_meta, column, taxon)
        }
        
        stopImplicitCluster()
        
        morsel <- bind_rows(crumbs)
        return(morsel)
    }

    result_df <- bind_rows(morsels)
    return(result_df)
}


preprocess_data <- function(df, meta_filt, RA_threshold, read_threshold, presence_t) {
    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    RA_df <- otu_to_RA(df_filt2)
    prev_RA <- RA_to_PA(RA_df, RA_threshold)
    prev_read <- otu_to_PA(df_filt2, read_threshold)
    prev_df <- as.data.frame(prev_read & prev_RA)
    prev_df <- filter_taxa_by_presence(prev_df, presence_t = presence_t) # Remove taxa that are not present in any samples
    prev_df <- prev_df %>% rownames_to_column("npm_research_id")
    return(prev_df)
}

decontaminate <- function(df, meta_filt, meta_cols, n, human, RA_threshold, read_threshold, presence_t, min_samples, taxa_vec = NA) {
    # Preprocess df
    prev_df <- preprocess_data(df, meta_filt, RA_threshold, read_threshold, presence_t)
    
    # Get list of taxa
    if (is.na(taxa_vec)) {
        taxa_vec <- colnames(prev_df)
        taxa_vec <- taxa_vec[taxa_vec != "npm_research_id"]
    }

    # Differential prevalence
    res <- get_diff_prev(prev_df, meta_filt, meta_cols, taxa_vec, min_samples = min_samples)

    return(res)
}

# %% [markdown]
# ### Run decontamination

# %%
taxa_rank <- "S"
n <- 9999
human <- "Homo sapiens"
RA_threshold <- 0.01
read_threshold <- 10
presence_t <- 0
min_samples <- 100

# Load data and remove low microbial read samples
to_retain <- fread("data/samples_above_100_microbial_reads.txt")$npm_research_id

df <- load_data(str_glue("data/temp_files_9999/07_abundance_matrix/abundance_matrix.subset_9999.{taxa_rank}.tsv")) %>% 
    filter(npm_research_id %in% to_retain)

meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df) %>% 
    filter(npm_research_id %in% to_retain)

# Get metadata columns of interest
meta_cols <- get_meta_cols(meta, 
                           meta_regex = "kit|flow_cell|site_supplying", 
                           to_exclude = c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id"))

# Get metadata subset
meta_filt <- subset_metadata(meta, n)

# Run decontamination
decon_raw <- decontaminate(df, meta, meta_cols, n, human, RA_threshold, read_threshold, presence_t, min_samples)
# Out:
# Error in fread("data/samples_above_100_microbial_reads.txt"): could not find function "fread"
# Traceback:

# %%
decon_raw
# Out:
#      taxa
# 1    Paraburkholderia fungorum
# 2    Paraburkholderia xenovorans
# 3    Paraburkholderia hospita
# 4    Ralstonia pickettii
# 5    Ralstonia insidiosa
# 6    Ralstonia mannitolilytica
# 7    Ralstonia solanacearum
# 8    Burkholderia cepacia
# 9    Burkholderia metallica
# 10   Burkholderia contaminans
# 11   Burkholderia gladioli
# 12   Burkholderia sp. OLGA172
# 13   Bordetella genomosp. 13
# 14   Massilia sp. WG5
# 15   Bradyrhizobium sp. SK17
# 16   Bradyrhizobium sp. BTAi1
# 17   Bradyrhizobium erythrophlei
# 18   Bradyrhizobium icense
# 19   Bradyrhizobium diazoefficiens
# 20   Bradyrhizobium sp. WSM471
# 21   Bradyrhizobium ottawaense
# 22   Rhodopseudomonas palustris
# 23   Oligotropha carboxidovorans
# 24   Afipia sp. GAS231
# 25   Methylobacterium radiotolerans
# 26   Methylobacterium sp. C1
# 27   Methylobacterium sp. 4-46
# 28   Methylorubrum populi
# 29   Rhizobium tropici
# 30   Rhizobium sp. 11515TR
# ⋮    ⋮
# 3919 Ureaplasma parvum
# 3920 Streptococcus sp. JS71
# 3921 Lactobacillus reuteri
# 3922 Aggregatibacter aphrophilus
# 3923 Streptococcus sp. A12
# 3924 Haemophilus sp. oral taxon 036
# 3925 Torque teno virus 23
# 3926 Proteus vulgaris
# 3927 Exiguobacterium sp. MH3
# 3928 Arcobacter skirrowii
# 3929 Leptotrichia sp. oral taxon 498
# 3930 Rickettsia amblyommatis
# 3931 Rickettsia bellii
# 3932 Wolbachia endosymbiont of Culex quinquefasciatus
# 3933 Chroococcidiopsis thermalis
# 3934 Torque teno virus 21
# 3935 Ruminococcus champanellensis
# 3936 Bacillus flexus
# 3937 Ureaplasma urealyticum
# 3938 Streptococcus pasteurianus
# 3939 Erysipelotrichaceae bacterium SG0102
# 3940 Snodgrassella alvi
# 3941 Pseudonocardia sp. EC080625-04
# 3942 Human betaherpesvirus 5
# 3943 Human alphaherpesvirus 2
# 3944 Staphylococcus argenteus
# 3945 Primate erythroparvovirus 1
# 3946 Hepatitis B virus
# 3947 Woolly monkey hepatitis B virus
# 3948 Lactobacillus phage Lv-1
#      meta_col                     max_level min_level max_prev    min_prev
# 1    site_supplying_sample        SERI      HELIOS    0.370038412 0.000000000
# 2    site_supplying_sample        SERI      GUSTO     0.025608195 0.000000000
# 3    site_supplying_sample        SERI      GUSTO     0.014084507 0.000000000
# 4    site_supplying_sample        TTSH      GUSTO     0.708661417 0.001038422
# 5    site_supplying_sample        SERI      HELIOS    0.435339309 0.000000000
# 6    site_supplying_sample        SERI      GUSTO     0.371318822 0.000000000
# 7    site_supplying_sample        SERI      GUSTO     0.386683739 0.000000000
# 8    site_supplying_sample        TTSH      GUSTO     0.020472441 0.000000000
# 9    site_supplying_sample        TTSH      GUSTO     0.001574803 0.000000000
# 10   site_supplying_sample        TTSH      GUSTO     0.196850394 0.000000000
# 11   site_supplying_sample        SERI      GUSTO     0.010243278 0.000000000
# 12   site_supplying_sample        SERI      GUSTO     0.025608195 0.000000000
# 13   site_supplying_sample        PRISM     GUSTO     0.828525641 0.000000000
# 14   site_supplying_sample        TTSH      GUSTO     0.003149606 0.000000000
# 15   site_supplying_sample        GUSTO     SERI      0.771547248 0.001280410
# 16   site_supplying_sample        MEC       GUSTO     0.407243163 0.000000000
# 17   site_supplying_sample        MEC       SERI      0.539541759 0.001280410
# 18   site_supplying_sample        MEC       GUSTO     0.236511456 0.000000000
# 19   site_supplying_sample        MEC       GUSTO     0.266814486 0.000000000
# 20   site_supplying_sample        HELIOS    GUSTO     0.001751313 0.000000000
# 21   site_supplying_sample        MEC       GUSTO     0.024759793 0.000000000
# 22   site_supplying_sample        MEC       GUSTO     0.942719882 0.000000000
# 23   site_supplying_sample        MEC       GUSTO     0.243163341 0.000000000
# 24   site_supplying_sample        MEC       GUSTO     0.094974132 0.000000000
# 25   site_supplying_sample        GUSTO     SERI      0.289719626 0.000000000
# 26   site_supplying_sample        GUSTO     SERI      0.185877466 0.000000000
# 27   site_supplying_sample        GUSTO     MEC       0.473520249 0.000000000
# 28   site_supplying_sample        GUSTO     MEC       0.482866044 0.000000000
# 29   site_supplying_sample        TTSH      GUSTO     0.001574803 0.000000000
# 30   site_supplying_sample        TTSH      HELIOS    0.003149606 0.000000000
# ⋮    ⋮                            ⋮         ⋮         ⋮           ⋮
# 3919 hiseq_xtm_flow_cell_v2_5_lot 20335774  20285943  0.021551724 0
# 3920 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3921 hiseq_xtm_flow_cell_v2_5_lot 20367085  20285943  0.004016064 0
# 3922 hiseq_xtm_flow_cell_v2_5_lot 20347589  20285943  0.002403846 0
# 3923 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3924 hiseq_xtm_flow_cell_v2_5_lot 20328452  20285943  0.002242152 0
# 3925 hiseq_xtm_flow_cell_v2_5_lot 20350042  20285943  0.002242152 0
# 3926 hiseq_xtm_flow_cell_v2_5_lot 20328452  20285943  0.002242152 0
# 3927 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3928 hiseq_xtm_flow_cell_v2_5_lot 20328452  20285943  0.002242152 0
# 3929 hiseq_xtm_flow_cell_v2_5_lot 20350042  20285943  0.002242152 0
# 3930 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3931 hiseq_xtm_flow_cell_v2_5_lot 20393560  20285943  0.003787879 0
# 3932 hiseq_xtm_flow_cell_v2_5_lot 20328452  20285943  0.002242152 0
# 3933 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3934 hiseq_xtm_flow_cell_v2_5_lot 20350042  20285943  0.002242152 0
# 3935 hiseq_xtm_flow_cell_v2_5_lot 20347583  20285943  0.001360544 0
# 3936 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3937 hiseq_xtm_flow_cell_v2_5_lot 20335774  20285943  0.004310345 0
# 3938 hiseq_xtm_flow_cell_v2_5_lot 20347583  20285943  0.001360544 0
# 3939 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3940 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3941 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3942 hiseq_xtm_flow_cell_v2_5_lot 20335902  20285943  0.007299270 0
# 3943 hiseq_xtm_flow_cell_v2_5_lot 20328452  20285943  0.002242152 0
# 3944 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3945 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3946 hiseq_xtm_flow_cell_v2_5_lot 20358945  20285943  0.001584786 0
# 3947 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
# 3948 hiseq_xtm_flow_cell_v2_5_lot 20285943  20285943  0.000000000 0
#      fold_diff
# 1         Inf
# 2         Inf
# 3         Inf
# 4    682.4409
# 5         Inf
# 6         Inf
# 7         Inf
# 8         Inf
# 9         Inf
# 10        Inf
# 11        Inf
# 12        Inf
# 13        Inf
# 14        Inf
# 15   602.5784
# 16        Inf
# 17   421.3821
# 18        Inf
# 19        Inf
# 20        Inf
# 21        Inf
# 22        Inf
# 23        Inf
# 24        Inf
# 25        Inf
# 26        Inf
# 27        Inf
# 28        Inf
# 29        Inf
# 30        Inf
# ⋮    ⋮
# 3919 Inf
# 3920 NaN
# 3921 Inf
# 3922 Inf
# 3923 NaN
# 3924 Inf
# 3925 Inf
# 3926 Inf
# 3927 NaN
# 3928 Inf
# 3929 Inf
# 3930 NaN
# 3931 Inf
# 3932 Inf
# 3933 NaN
# 3934 Inf
# 3935 Inf
# 3936 NaN
# 3937 Inf
# 3938 Inf
# 3939 NaN
# 3940 NaN
# 3941 NaN
# 3942 Inf
# 3943 Inf
# 3944 NaN
# 3945 NaN
# 3946 Inf
# 3947 NaN
# 3948 NaN

# %%
decon_raw %>%
    group_by(taxa) %>%
    summarise(max_max_prev = max(max_prev)) %>%
    ggplot(aes(x = max_max_prev)) +
    geom_histogram() +
    labs(x = "Maximum batch prevalence", y = "No. of taxa")

ggsave("results/decontamination/diff_prev_V3/max_batch_prev.png", dpi = 300)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Saving 6.67 x 6.67 in image
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
morsels <- foreach(max_prev_t = c(0.25, 0.5, 0.75)) %do% {
    crumbs <- foreach(fold_diff_t = c(2, 5, 10)) %do% {
        temp_contam <- decon_raw %>%
            mutate(fold_diff = max_prev / min_prev) %>% 
            mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
            filter(max_prev > max_prev_t, diff_abn) %>%
            distinct(taxa)
        tibble(max_prev = max_prev_t, fold_diff = fold_diff_t, n_contam = length(temp_contam$taxa))
    }
    
    return(bind_rows(crumbs))
}

bind_rows(morsels)
# Out:
#   max_prev fold_diff n_contam
# 1 0.25      2        86
# 2 0.25      5        86
# 3 0.25     10        86
# 4 0.50      2        66
# 5 0.50      5        66
# 6 0.50     10        66
# 7 0.75      2        54
# 8 0.75      5        54
# 9 0.75     10        54

# %%
prev_df <- preprocess_data(df, meta_filt, RA_threshold, read_threshold, presence_t)
fwrite(prev_df, "results/decontamination/prevalence_RA0.01_read10.csv")

# %%
max_prev_t <- 0.25
fold_diff_t <- 2

contam <- decon_raw %>%
    mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
    filter(max_prev > max_prev_t, diff_abn) %>%
    distinct(taxa)

contam

nc <- colnames(prev_df)
nc <- nc[!(nc %in% contam$taxa)]
nc <- tibble(taxa = nc[nc != "npm_research_id"])
# Out:
#    taxa
# 1  Paraburkholderia fungorum
# 2  Ralstonia pickettii
# 3  Ralstonia insidiosa
# 4  Ralstonia mannitolilytica
# 5  Ralstonia solanacearum
# 6  Bordetella genomosp. 13
# 7  Bradyrhizobium sp. SK17
# 8  Bradyrhizobium sp. BTAi1
# 9  Bradyrhizobium erythrophlei
# 10 Bradyrhizobium diazoefficiens
# 11 Rhodopseudomonas palustris
# 12 Methylobacterium radiotolerans
# 13 Methylobacterium sp. 4-46
# 14 Methylorubrum populi
# 15 Sphingobium sp. YG1
# 16 Sphingobium yanoikuyae
# 17 Sphingomonas sp. LM7
# 18 Sphingomonas hengshuiensis
# 19 Sphingomonas sp. Cra20
# 20 Sphingomonas koreensis
# 21 Sphingomonas sp. FARSPH
# 22 Sphingomonas sanxanigenens
# 23 Sphingomonas sp. LK11
# 24 Sphingomonas wittichii
# 25 Sphingomonas melonis
# 26 Sphingomonas panacis
# 27 Sphingomonas taxi
# 28 Bradyrhizobium lablabi
# 29 Bradyrhizobiaceae bacterium SG-6C
# 30 Methylobacterium currus
# ⋮  ⋮
# 57 Alcaligenes faecalis
# 58 Alcaligenes aquatilis
# 59 Pseudomonas pseudoalcaligenes
# 60 Pseudomonas sihuiensis
# 61 Pseudomonas sp. LPH1
# 62 Pseudomonas sp. phDV1
# 63 Pseudomonas alcaliphila
# 64 Bradyrhizobium icense
# 65 Oligotropha carboxidovorans
# 66 Brevundimonas sp. GW460-12-10-14-LB2
# 67 Afipia sp. GAS231
# 68 Methylobacterium sp. C1
# 69 Sphingomonas sp. MM-1
# 70 Bradyrhizobium japonicum
# 71 Bradyrhizobium sp. CCGE-LA001
# 72 Nitrobacter hamburgensis
# 73 Phyllobacterium zundukense
# 74 Caulobacter mirabilis
# 75 Delftia tsuruhatensis
# 76 Achromobacter denitrificans
# 77 Massilia oculi
# 78 Microbacterium chocolatum
# 79 Methylobacterium phyllosphaerae
# 80 Acinetobacter johnsonii
# 81 Rhodococcus erythropolis
# 82 Sphingomonas sp. NIC1
# 83 Herbaspirillum rubrisubalbicans
# 84 Microbacterium sp. 10M-3C3
# 85 Herbaspirillum seropedicae
# 86 Bradyrhizobium sp. ORS 285

# %%
length(contam$taxa)
length(nc$taxa)
# Out:
# [1] 86
# [1] 478

# %% [markdown]
# #### Determine how many taxa were not analysable

# %%
not_analysable <- decon_raw %>%
    group_by(taxa) %>%
    summarise(max_max_prev = max(max_prev)) %>%
    filter(max_max_prev <= 0.25)

sum(not_analysable$taxa %in% nc$taxa)
# Out:
# [1] 478

# %%
fwrite(decon_raw, str_glue("results/decontamination/diff_prev_V3/decon_V3_raw.RA{RA_threshold}.read_threshold{read_threshold}.csv"))
# fwrite(contam, str_glue("results/decontamination/diff_prev_V3/contaminants.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))
# fwrite(nc, str_glue("results/decontamination/diff_prev_V3/noncontaminants.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))
# decon_raw <- fread("results/decontamination/diff_prev_V2/decon_V2_raw.read_t10.csv")

# %% [markdown]
# ### Sanity check

# %%
taxon <- "Alcaligenes faecalis"
taxon <- "Pseudomonas aeruginosa"
column <- "extraction_kit"
# column <- "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
prev_df %>% 
    left_join(meta_filt) %>%
    group_by_at(c(column)) %>%
    summarise(prevalence = sum(get(taxon)) / n()) %>%
    filter(get(column) != "Unknown") %>%
    ggplot(aes(x = get(column), y = prevalence)) +
        geom_bar(stat = "identity") +
        theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    ylim(0, 1) +
    labs(x = column, y = "Prevalence", title = taxon)
ggsave(str_glue("results/decontamination/diff_prev_V3/{taxon}.{column}.batch_prevalence.png"), dpi = 300)
# Out:
# Joining, by = "npm_research_id"
#
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# #### Query taxa that have overall prevalence > 0.2

# %%
prevalence_t <- 0.1
prev_stats <- apply(prev_df[, 2:ncol(prev_df)], 2, sum) / nrow(prev_df)
overall_prev <- data.frame(taxa = names(prev_stats), prevalence = as.vector(prev_stats))
prevalent_taxa <- overall_prev %>% filter(prevalence > prevalence_t)
prevalent_taxa <- prevalent_taxa$taxa
length(prevalent_taxa)
# Out:
# [1] 41

# %%
sum(contam$taxa %in% prevalent_taxa)
# Out:
# [1] 41

# %%
overall_prev %>% arrange(desc(prevalence))
# Out:
#     taxa                                             prevalence
# 1   Bradyrhizobiaceae bacterium SG-6C                0.3076477
# 2   Rhodopseudomonas palustris                       0.3066032
# 3   Bradyrhizobium sp. SK17                          0.2713241
# 4   Alcaligenes faecalis                             0.2620402
# 5   Methylobacterium currus                          0.2561216
# 6   Sphingomonas sp. LM7                             0.2541488
# 7   Sphingomonas sp. Cra20                           0.2477660
# 8   Sphingomonas hengshuiensis                       0.2466055
# 9   Sphingomonas koreensis                           0.2310549
# 10  Sphingomonas sp. FARSPH                          0.2282697
# 11  Caulobacter segnis                               0.2152721
# 12  Caulobacter vibrioides                           0.2143437
# 13  Sphingobium sp. YG1                              0.2097018
# 14  Alcaligenes aquatilis                            0.1920622
# 15  Sphingomonas sanxanigenens                       0.1891610
# 16  Methylobacterium brachiatum                      0.1855634
# 17  Sphingomonas sp. LK11                            0.1842869
# 18  Caulobacter flavus                               0.1818498
# 19  Caulobacter sp. K31                              0.1760473
# 20  Sphingomonas melonis                             0.1754671
# 21  Bradyrhizobium erythrophlei                      0.1725659
# 22  Sphingomonas wittichii                           0.1591041
# 23  Pseudomonas aeruginosa                           0.1464547
# 24  Sphingomonas taxi                                0.1437855
# 25  Bradyrhizobium sp. BTAi1                         0.1379831
# 26  Sphingobium yanoikuyae                           0.1375189
# 27  Caulobacter henricii                             0.1368226
# 28  Pseudomonas mendocina                            0.1350818
# 29  Ralstonia pickettii                              0.1312522
# 30  Pseudomonas sihuiensis                           0.1285830
# ⋮   ⋮                                                ⋮
# 535 Haemophilus haemolyticus                         0.0001160497
# 536 Neisseria mucosa                                 0.0001160497
# 537 Streptococcus sp. I-G2                           0.0001160497
# 538 Staphylococcus sp. M0911                         0.0001160497
# 539 Streptococcus gallolyticus                       0.0001160497
# 540 Streptococcus mutans                             0.0001160497
# 541 Frischella perrara                               0.0001160497
# 542 Streptococcus sp. JS71                           0.0001160497
# 543 Lactobacillus reuteri                            0.0001160497
# 544 Aggregatibacter aphrophilus                      0.0001160497
# 545 Streptococcus sp. A12                            0.0001160497
# 546 Haemophilus sp. oral taxon 036                   0.0001160497
# 547 Torque teno virus 23                             0.0001160497
# 548 Proteus vulgaris                                 0.0001160497
# 549 Exiguobacterium sp. MH3                          0.0001160497
# 550 Arcobacter skirrowii                             0.0001160497
# 551 Leptotrichia sp. oral taxon 498                  0.0001160497
# 552 Rickettsia amblyommatis                          0.0001160497
# 553 Rickettsia bellii                                0.0001160497
# 554 Wolbachia endosymbiont of Culex quinquefasciatus 0.0001160497
# 555 Ruminococcus champanellensis                     0.0001160497
# 556 Bacillus flexus                                  0.0001160497
# 557 Streptococcus pasteurianus                       0.0001160497
# 558 Erysipelotrichaceae bacterium SG0102             0.0001160497
# 559 Snodgrassella alvi                               0.0001160497
# 560 Human alphaherpesvirus 2                         0.0001160497
# 561 Staphylococcus argenteus                         0.0001160497
# 562 Primate erythroparvovirus 1                      0.0001160497
# 563 Woolly monkey hepatitis B virus                  0.0001160497
# 564 Lactobacillus phage Lv-1                         0.0001160497

# %% [markdown]
# #### Positive and negative controls

# %%
pos_control <- read.csv("data/reported_controls/damgaard_2015_positive.txt")$positive_controls
torque_tenos <- (overall_prev %>% filter(grepl("torque teno", taxa, ignore.case = T)))$taxa
herpes <- (overall_prev %>% filter(grepl("herpes", taxa, ignore.case = T)))$taxa
pos_control <- c(pos_control, 
                 "Escherichia coli",
                 "Pasteurella multocida", 
                 "Bartonella henselae", "Bartonella clarridgeiae", 
                 "Enterococcus faecalis", "Cutibacterium acnes", "Staphylococcus epidermis", "Actinomyces viscosus",
                 "Streptococcus agalactiae",
                 "Yersinia enterocolitica",
                 "Leclercia adecarboxylata",
                 "Streptococcus pneumoniae",
                 torque_tenos,
                 herpes
                 )
neg_control1 <- read.csv("data/reported_controls/asmp_parsed_negative.txt")$taxa
neg_control2 <- read.csv("data/reported_controls/chng_2020_parsed_negative.txt")$taxa
neg_control3 <- read.csv("data/reported_controls/caregiver_parsed_negative.txt")$taxa

intersection <- Reduce(intersect, list(neg_control1, neg_control2, neg_control3))
union <- unique(c(neg_control1, neg_control2, neg_control3))

# At least 2 studies
all_neg <- table(c(neg_control1, neg_control2, neg_control3))
semi_union <- names(all_neg[all_neg >= 2])

pos_not_intersect <- pos_control[!(pos_control %in% intersection)]
pos_not_union <- pos_control[!(pos_control %in% union)]
pos_not_semi <- pos_control[!(pos_control %in% semi_union)]

print(length(intersection))
print(length(union))
print(length(semi_union))
print(length(pos_control))
print(length(pos_not_intersect))
print(length(pos_not_union))
# Out:
# [1] 8
# [1] 320
# [1] 53
# [1] 51
# [1] 50
# [1] 39

# %%
tibble(intersection)
# Out:
#   intersection
# 1 Rhodopseudomonas palustris
# 2 Micrococcus luteus
# 3 Staphylococcus haemolyticus
# 4 Pseudomonas aeruginosa
# 5 Klebsiella pneumoniae
# 6 Gordonia terrae
# 7 Delftia acidovorans
# 8 Staphylococcus aureus

# %% [markdown]
# #### Plot venn diagrams of controls

# %%
venn_list1 <- list(nc = nc$taxa,
                  contam = contam$taxa, 
                  pos_not_semi = pos_not_semi)

venn_list2 <- list(nc = nc$taxa,
                  contam = contam$taxa, 
                  semi_union = semi_union)

# ggVennDiagram(venn_list1, category.names = c("Non-contaminants", "Contaminants", "Found in blood")) +
#     scale_fill_gradient(low = "#F4FAFE", high = "#4981BF") +
#     scale_color_manual(values = "black")
#     theme(legend.position = "none")

# ggVennDiagram(venn_list2, category.names = c("Non-contaminants", "Contaminants", "Common contaminants (union)")) +
#     scale_fill_gradient(low = "#F4FAFE", high = "#4981BF") +
#     theme(legend.position = "none")

venn.diagram(venn_list1, 
             filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_pos_controls.png"),
#              category.names = c("Identified non-contaminants", "Identified contaminants", "Found in blood"),
             category.names = c("", "", ""),
             print.mode = c("raw"),
             fill = c("#999999", "#E69F00", "#66a182")
             )

venn.diagram(venn_list2, 
             filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_neg_controls.png"),
#              category.names = c("Identified non-contaminants", "Identified contaminants", "Common contaminants (union)"),
             category.names = c("", "", ""),
             print.mode = c("raw"),
             fill = c("#999999", "#E69F00", "#f8766d")
             )

# filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_pos_controls.png"),
# Out:
# [1] 1
# [1] 1

# %%
# venn_list1 <- list(asmp = neg_control1,
#                   caregiver = neg_control3, 
#                   hospital = neg_control2,
#                   prevalent = prevalent_taxa)

# venn.diagram(venn_list1, 
#              filename = str_glue("results/decontamination/diff_prev_V3/negative_controls_venn.png"),
#              category.names = c("ASMP", "Caregiver", "Hospital", str_glue(">{prevalence_t} prevalence")),
#              print.mode = c("raw", "percent")
#              )

# venn_list2 <- list(intersection = intersection,
#                   pos_control = pos_control,
#                   prevalent = prevalent_taxa)

# venn.diagram(venn_list2, 
#              filename = str_glue("results/decontamination/diff_prev_V3/pos_intersection_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
#              category.names = c("Negative (intersect)", "Positive", str_glue(">{prevalence_t} prevalence")),
#              print.mode = c("raw", "percent")
#              )

# venn_list3 <- list(union = union,
#                   pos_control = pos_control,
#                   prevalent = prevalent_taxa)

# venn.diagram(venn_list3, 
#              filename = str_glue("results/decontamination/diff_prev_V3/pos_union_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
#              category.names = c("Negative (union)", "Positive", str_glue(">{prevalence_t} prevalence")),
#              print.mode = c("raw", "percent"),
#              height = 5000, width = 5000
#              )

venn_list4 <- list(asmp = neg_control1,
                  caregiver = neg_control3, 
                  hospital = neg_control2)

venn.diagram(venn_list4, 
             filename = str_glue("results/decontamination/diff_prev_V3/negative_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
             category.names = c("ASMP", "Caregiver", "Hospital"),
             print.mode = c("raw", "percent")
             )
# Out:
# [1] 1
