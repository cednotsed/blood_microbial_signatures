# %% [markdown]
# # Visualising taxa abundance

# %%
setwd("/home/projects/14001280/PROJECTS/blood_microbiome/")
require(tidyverse)
require(ggplot2)
require(data.table)
require(ggsci)
# Out:
# Loading required package: tidyverse
#
# Warning message:
# “Your system is mis-configured: ‘/etc/localtime’ is not a symlink”
# Warning message:
# “It is strongly recommended to set envionment variable TZ to ‘Asia/Singapore’ (or equivalent)”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: ggsci

# %%
meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv")
head(meta)
# Out:
#   npm_research_id multiplex_pool_id supplier_id gis_internal_sample_id
# 1 WHB10000        MUX9693           00358       HELIOS_00358_1
# 2 WHB10001        MUX9693           00359       HELIOS_00359_1
# 3 WHB10002        MUX9695           00360       HELIOS_00360_1
# 4 WHB10003        MUX9694           00361       HELIOS_00361_1
# 5 WHB10005        MUX9694           00363       HELIOS_00363_1
# 6 WHB10006        MUX9694           00364       HELIOS_00364_1
#   site_supplying_sample year_of_birth supplied_gender self_reported_ethnicity
# 1 HELIOS                1982          F               Chinese
# 2 HELIOS                1979          F               Chinese
# 3 HELIOS                1970          F               Chinese
# 4 HELIOS                1969          M               Chinese
# 5 HELIOS                1959          F               Chinese
# 6 HELIOS                1955          F               Chinese
#   extraction_kit                                 date_of_dna_extraction ⋯
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 2 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 3 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 4 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 5 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 6 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
#   supplied_and_computed_ethinicity_match
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   sop_agreement_for_coverage_14/28_for_15x/30x sample_life_cycle current
# 1 Y                                            HELIOS VCF        Y
# 2 Y                                            HELIOS VCF        Y
# 3 N                                            HELIOS VCF        Y
# 4 Y                                            HELIOS VCF        Y
# 5 N                                            HELIOS VCF        Y
# 6 Y                                            HELIOS VCF        Y
#   source_cohort originalsupplierid duplicateinfo duplicate duplicatepair
# 1 HELIOS        00358                            PASS
# 2 HELIOS        00359                            PASS
# 3 HELIOS        00360                            PASS
# 4 HELIOS        00361                            PASS
# 5 HELIOS        00363                            PASS
# 6 HELIOS        00364                            PASS
#   removalrequestedbysupplier
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %% [markdown]
# ## Pre-process data

# %%
genus_df <- fread("data/temp_files/07_abundance_matrix/subset_100.F.tsv") %>%
    column_to_rownames("sample")
head(genus_df)
# Out:
#                  Pseudomonadaceae Moraxellaceae Aeromonadaceae Xanthomonadaceae
# MUX8204_WHB3640  118564           7             133            114
# MUX5236_WHB847        1           0               0              1
# MUX10761_WHB8529     10           6               0              8
# MUX9197_WHB4499       2           3               0              5
# MUX5260_WHH5152      16           0               0              1
# MUX9014_WHB3959      27           1               2              9
#                  Rhodanobacteraceae Enterobacteriaceae Yersiniaceae Erwiniaceae
# MUX8204_WHB3640  7                  52                 19           14
# MUX5236_WHB847   0                   7                  0            0
# MUX10761_WHB8529 0                   6                  0            0
# MUX9197_WHB4499  0                   2                  0            0
# MUX5260_WHH5152  0                   2                  1            0
# MUX9014_WHB3959  0                   4                  6            0
#                  Pectobacteriaceae Halomonadaceae ⋯ Mycoplasmataceae
# MUX8204_WHB3640  4                 29             ⋯ 0
# MUX5236_WHB847   0                  0             ⋯ 0
# MUX10761_WHB8529 2                  1             ⋯ 0
# MUX9197_WHB4499  0                  0             ⋯ 0
# MUX5260_WHH5152  0                  0             ⋯ 0
# MUX9014_WHB3959  0                  1             ⋯ 0
#                  Mariprofundaceae Dermatophilaceae Hydrogenophilaceae
# MUX8204_WHB3640  0                0                0
# MUX5236_WHB847   0                0                0
# MUX10761_WHB8529 0                0                0
# MUX9197_WHB4499  0                0                0
# MUX5260_WHH5152  0                0                0
# MUX9014_WHB3959  0                0                0
#                  Limnochordaceae Natranaerobiaceae Aphanizomenonaceae
# MUX8204_WHB3640  0               0                 0
# MUX5236_WHB847   0               0                 0
# MUX10761_WHB8529 0               0                 0
# MUX9197_WHB4499  0               0                 0
# MUX5260_WHH5152  0               0                 0
# MUX9014_WHB3959  0               0                 0
#                  Methanosarcinaceae Hapalosiphonaceae Segniliparaceae
# MUX8204_WHB3640  0                  0                 0
# MUX5236_WHB847   0                  0                 0
# MUX10761_WHB8529 0                  0                 0
# MUX9197_WHB4499  0                  0                 0
# MUX5260_WHH5152  0                  0                 0
# MUX9014_WHB3959  0                  0                 0

# %% [markdown]
# ### Count and remove samples with no classified reads
# This may include samples that originally had no reads, and samples whose reads cannot be classified

# %%
genus_df %>%
    rowwise() %>%
    mutate(total = sum(across(everything()))) %>%
    filter(total == 0) %>%
    nrow()
# Out:
# [1] 0

# %% [markdown]
# ### Normalise to relative abundance

# %%
RA_df <- t(apply(genus_df, 1, function(x) {x / sum(x) * 100}))

# %% [markdown]
# ## Relative abundance for all samples

# %% [markdown]
# ### Matrix --> long format

# %%
plot_df <- as_tibble(RA_df, rownames = "sample") %>%
    pivot_longer(!sample, names_to = "rank", values_to = "abundance")

# %% [markdown]
# ### Keep only top N ranks
# ranked by median relative abundance

# %%
n_keep <- 8
ranks_to_keep <- plot_df %>% 
    group_by(rank) %>%
    summarise(median = median(abundance)) %>%
    arrange(desc(median))
  ranks_to_keep <- ranks_to_keep$rank[1:n_keep]
ranks_to_keep
# Out:
# [1] "Hominidae"           "Bradyrhizobiaceae"   "Pseudomonadaceae"
# [4] "Burkholderiaceae"    "Sphingomonadaceae"   "Rhizobiaceae"
# [7] "Methylobacteriaceae" "Comamonadaceae"

# %% [markdown]
# ### Visualise relative abundances

# %% [markdown]
# Define palette

# %%
pal <- c("#d1495b", "#00798c", "#edae49", 
         "#66a182", "#2e4057", "#8d96a3",
         "#8E44AD", "#2980b9")

# %%
plt1 <- plot_df %>%
    filter(rank %in% ranks_to_keep) %>%
    mutate(sample = factor(sample, levels = unique(sample)[order(sample)])) %>%
    ggplot(aes(x = sample, y = abundance, fill = rank)) +
        geom_bar(stat = "identity", position = "stack") +
        labs(x = "Sample", y = "Relative abundance (%)", fill = "Genus") +
        theme(axis.text.x = element_text(angle = 45, hjust = 1),
              axis.ticks.x = element_blank()) +
        scale_fill_manual(values = pal[1:n_keep])
plt1
# Out:
# plot without title

# %% [markdown]
# Rather heterogenous

# %% [markdown]
# ## Relative abundance by cohort

# %% [markdown]
# ### Add metadata

# %%
plot2_df <- as_tibble(RA_df, rownames = "sample") %>%
    separate(sample, into = c(NA, "npm_research_id"), sep = "_") %>%
    left_join(meta, by = "npm_research_id")

# %% [markdown]
# ### Group by cohort and --> long format

# %%
plot2_df <- plot2_df %>%
    group_by(source_cohort) %>%
    summarise(across(where(is.numeric), ~ mean(.x, na.rm = T))) %>%
    pivot_longer(!source_cohort, names_to = "rank", values_to = "abundance")
# Out:
# Warning message:
# “Predicate functions must be wrapped in `where()`.
#
#   # Bad
#   data %>% select(is.numeric)
#
#   # Good
#   data %>% select(where(is.numeric))
#
# ℹ Please update your code.
# This message is displayed once per session.”

# %% [markdown]
# ### Visualise

# %%
plt <- plot2_df %>%
    filter(rank %in% ranks_to_keep) %>%
#     mutate(sample = factor(sample, levels = unique(sample)[order(sample)])) %>%
    ggplot(aes(x = source_cohort, y = abundance, fill = rank)) +
        geom_bar(stat = "identity", position = "stack") +
        labs(x = "Sample", y = "Mean Relative abundance (%)", fill = "Genus") +
        theme(axis.text.x = element_text(angle = 45, hjust = 1),
              axis.ticks.x = element_blank()) +
        scale_fill_manual(values = pal[1:n_keep])
plt
# Out:
# plot without title
