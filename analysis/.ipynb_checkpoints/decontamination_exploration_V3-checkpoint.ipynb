# %% [markdown]
# # Visualising taxa abundance

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(tidyverse)
require(ggplot2)
require(data.table)
require(foreach)
require(compositions)
require(ggpubr)
require(see)
require(doParallel)
require(VennDiagram)
require(randomcoloR)
require(vegan)
# registerDoParallel(cores=8)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: compositions
#
# Welcome to compositions, a package for compositional data analysis.
# Find an intro with "? compositions"
#
#
#
# Attaching package: ‘compositions’
#
#
# The following objects are masked from ‘package:stats’:
#
#     anova, cor, cov, dist, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %*%, norm, scale, scale.default
#
#
# Loading required package: ggpubr
#
# Loading required package: see
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: VennDiagram
#
# Loading required package: grid
#
# Loading required package: futile.logger
#
#
# Attaching package: ‘VennDiagram’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     rotate
#
#
# Loading required package: randomcoloR
#
# Loading required package: vegan
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.5-7

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# ### Load and parse data

# %%
get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id|site_supplying", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


load_data <- function(file_path) {
    df <- fread(file_path) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}

# %%
rank <- "S"

to_retain <- fread("data/samples_above_100_microbial_reads.txt")$npm_research_id

meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv") %>%
    filter(npm_research_id %in% to_retain)

meta_cols <- get_meta_cols(meta)

species_df <- load_data(str_glue("data/taxonomic_profiles/07_abundance_matrix/abundance_matrix.S.pipeline2_210322.tsv")) %>%
    filter(npm_research_id %in% to_retain) %>%
    select(-unclassified, -"Homo sapiens")

prev_df <- fread("results/decontamination/prevalence_RA0.005_read10.csv")

# %% [markdown]
# ## Basic stats

# %% [markdown]
# ## Decontamination

# %% [markdown]
# #### Load non-contaminant list

# %%
# Differential prevalence
diff_prev_nc <- read.csv("results/decontamination/diff_prev_V3/noncontaminants.RA0.005.read_threshold10.max_prev0.25.fold_diff2.txt")$taxa
diff_prev_c <- read.csv("results/decontamination/diff_prev_V3/contaminants.RA0.005.read_threshold10.max_prev0.25.fold_diff2.txt")$taxa

# Correlation filter
corr_nc <- read.csv("results/decontamination/correlation_decontamination/nc.diff_prev_V3.RA0.005.read_threshold10.max_prev0.25.fold_diff2.corr_t0.7.S.n9999.txt")$non_contaminant_taxon
corr_c <- read.csv("results/decontamination/correlation_decontamination/contam.diff_prev_V3.RA0.005.read_threshold10.max_prev0.25.fold_diff2.corr_t0.7.S.n9999.txt")$contaminant

# Simple batch filter
batch_nc <- read.csv("results/decontamination/simple_batch_decontam/nc.corr_t0.7.txt")$taxa

# %% [markdown]
# ### Set 'absent' taxa to zero

# %%
species_zeroed <- species_df %>% 
    select(all_of(colnames(prev_df))) %>%
    column_to_rownames("npm_research_id")

prev_bool_df <- prev_df %>%
    column_to_rownames("npm_research_id")

for(i in seq(ncol(species_zeroed))) {
    species_zeroed[!prev_bool_df[, i], i] <- 0
}

species_filt <- species_zeroed %>% 
    rownames_to_column("npm_research_id") %>%
    select(all_of(c("npm_research_id", batch_nc)))


fwrite(species_zeroed %>% rownames_to_column("npm_research_id"), "results/decontamination/read_matrix.raw.zeroed.csv")

# %% [markdown]
# #### Relative abundance

# %%
otu_to_RA <- function(df) {
    row_names <- df$npm_research_id
    RA_df <- t(apply(df[, 2:ncol(df)], 1, function(x) {x / sum(x)}))
    
    return(cbind(data.frame(npm_research_id = row_names), as.data.frame(RA_df, check.names = F)))
}

species_filt_RA <- otu_to_RA(species_filt)

# %% [markdown]
# #### CLR transform

# %%
RA_to_clr <- function(df) {
    row_names <- df$npm_research_id
    clr_df <- clr(df %>% select(where(is.numeric)))
    return(cbind(data.frame(npm_research_id = row_names), as.data.frame(clr_df, check.names = F)))
}

# species_clr <- RA_to_clr(species_RA)
# head(species_clr)

# %% [markdown]
# ### Summary stats of non-contaminants

# %% [markdown]
# #### Max read count

# %%
max_df <- species_filt %>% 
    select(-npm_research_id) %>%
    pivot_longer(everything(), names_to = "taxa", values_to = "read_count") %>%
    group_by(taxa) %>%
    summarise(max_count = max(read_count)) %>%
    arrange(desc(max_count))

# %% [markdown]
# #### Overall prevalence

# %%
sum(colSums(prev_df %>% select(-npm_research_id)) != 0)
# Out:
# [1] 870

# %%
prev_df %>% left_join(meta) %>% group_by(site_supplying_sample) %>% summarise(n = n())
# Out:
# Joining, by = "npm_research_id"
#   site_supplying_sample n
# 1 GUSTO                  967
# 2 HELIOS                2285
# 3 MEC                   2738
# 4 PRISM                 1248
# 5 SERI                   923
# 6 SSMP                     4
# 7 TTSH                   663

# %%
nrow(prev_df) - sum(rowSums(prev_df %>% select(-npm_research_id)) == 0)
# Out:
# [1] 8704

# %%
prev_stats <- apply(prev_df[, 2:ncol(prev_df)], 2, sum) / nrow(prev_df)
overall_prev <- data.frame(taxa = names(prev_stats), overall_prevalence = as.vector(prev_stats))

# %%
prev_max <- max_df %>%
    left_join(overall_prev) %>%
    arrange(desc(overall_prevalence)) %>%
    mutate(n_samples = overall_prevalence * nrow(prev_df),
           max_bin = case_when(max_count < 10 ~ "<10",
                               max_count >= 10 & max_count < 50 ~ "10-50",
                               max_count >= 50 & max_count < 100 ~ "50-100",
                               max_count >= 100 & max_count < 500 ~"100-500",
                               max_count >= 500 ~">=500")) %>%
    mutate(max_bin = factor(max_bin, levels = c("<10", "10-50", "50-100", "100-500", ">=500"))) %>%
    arrange(desc(overall_prevalence))
prev_max
# Out:
# Joining, by = "taxa"
#     taxa                                      max_count overall_prevalence
# 1   Cutibacterium acnes                        22596    0.047462619
# 2   Microbacterium sp. PM5                     83419    0.035681921
# 3   Pseudomonas tolaasii                         161    0.024014499
# 4   Moraxella osloensis                         2402    0.019143634
# 5   Mesorhizobium sp. Pch-S                      405    0.019143634
# 6   Bradyrhizobium arachidis                      47    0.018690530
# 7   Human mastadenovirus C                     17475    0.018577254
# 8   Paraburkholderia sp. 7MH5                    182    0.015745356
# 9   Paraburkholderia tropica                     153    0.014839148
# 10  Paraburkholderia acidiphila                  188    0.014499320
# 11  Bradyrhizobium guangxiense                    37    0.014272768
# 12  Microbacterium sp. Nx66                    67485    0.013706389
# 13  Paraburkholderia acidisoli                   112    0.013253285
# 14  Mycolicibacterium aubagnense                1938    0.012233802
# 15  Lactobacillus iners                         1104    0.012007250
# 16  Aquabacterium olei                           452    0.010987766
# 17  Rhodococcus sp. NJ-530                       175    0.010761214
# 18  Lactobacillus crispatus                     7799    0.010647938
# 19  Staphylococcus haemolyticus               117929    0.010534662
# 20  Variovorax paradoxus                         271    0.009628455
# 21  Phyllobacterium zundukense                   336    0.009401903
# 22  Staphylococcus epidermidis                  9140    0.008608971
# 23  Sulfuritalea hydrogenivorans                  86    0.008608971
# 24  Gardnerella vaginalis                       2123    0.008495696
# 25  Staphylococcus cohnii                      18768    0.008042592
# 26  Acidovorax sp. KKS102                        336    0.007362936
# 27  Micrococcus luteus                           329    0.006343453
# 28  Rhodococcus qingshengii                      112    0.006116901
# 29  Bifidobacterium adolescentis                 222    0.006003625
# 30  Rhizobacter sp. AJA081-3                     266    0.005437245
# ⋮   ⋮                                         ⋮         ⋮
# 209 Skermanella pratensis                     471       0.0002265519
# 210 Deinococcus gobiensis                     378       0.0002265519
# 211 Corynebacterium aurimucosum               344       0.0002265519
# 212 Deinococcus geothermalis                  338       0.0002265519
# 213 Rickettsia endosymbiont of Bemisia tabaci 334       0.0002265519
# 214 Corynebacterium amycolatum                216       0.0002265519
# 215 Deinococcus actinosclerus                 190       0.0002265519
# 216 Deinococcus ficus                         171       0.0002265519
# 217 Deinococcus swuensis                      161       0.0002265519
# 218 Dermacoccus nishinomiyaensis              148       0.0002265519
# 219 Limosilactobacillus reuteri               124       0.0002265519
# 220 Deinococcus sp. AJ005                      93       0.0002265519
# 221 Massilia sp. WG5                           87       0.0002265519
# 222 Torque teno virus 19                       84       0.0002265519
# 223 Corynebacterium singulare                  66       0.0002265519
# 224 Delftia sp. Cs1-4                          63       0.0002265519
# 225 Streptococcus salivarius                   63       0.0002265519
# 226 Klebsiella quasipneumoniae                 50       0.0002265519
# 227 Streptococcus pseudopneumoniae             44       0.0002265519
# 228 Brevundimonas sp. DS20                     42       0.0002265519
# 229 Brevibacterium linens                      37       0.0002265519
# 230 Acinetobacter sp. WCHA45                   31       0.0002265519
# 231 Burkholderia gladioli                      27       0.0002265519
# 232 Massilia sp. NR 4-1                        23       0.0002265519
# 233 Parabacteroides goldsteinii                23       0.0002265519
# 234 Actinomyces sp. HMT 175                    20       0.0002265519
# 235 Paraburkholderia sp. PGU19                 18       0.0002265519
# 236 Chryseobacterium manosquense               16       0.0002265519
# 237 Corynebacterium sp. NML98-0116             14       0.0002265519
# 238 Burkholderia cepacia                       13       0.0002265519
#     n_samples max_bin
# 1   419       >=500
# 2   315       >=500
# 3   212       100-500
# 4   169       >=500
# 5   169       100-500
# 6   165       10-50
# 7   164       >=500
# 8   139       100-500
# 9   131       100-500
# 10  128       100-500
# 11  126       10-50
# 12  121       >=500
# 13  117       100-500
# 14  108       >=500
# 15  106       >=500
# 16   97       100-500
# 17   95       100-500
# 18   94       >=500
# 19   93       >=500
# 20   85       100-500
# 21   83       100-500
# 22   76       >=500
# 23   76       50-100
# 24   75       >=500
# 25   71       >=500
# 26   65       100-500
# 27   56       100-500
# 28   54       100-500
# 29   53       100-500
# 30   48       100-500
# ⋮   ⋮         ⋮
# 209 2         100-500
# 210 2         100-500
# 211 2         100-500
# 212 2         100-500
# 213 2         100-500
# 214 2         100-500
# 215 2         100-500
# 216 2         100-500
# 217 2         100-500
# 218 2         100-500
# 219 2         100-500
# 220 2         50-100
# 221 2         50-100
# 222 2         50-100
# 223 2         50-100
# 224 2         50-100
# 225 2         50-100
# 226 2         50-100
# 227 2         10-50
# 228 2         10-50
# 229 2         10-50
# 230 2         10-50
# 231 2         10-50
# 232 2         10-50
# 233 2         10-50
# 234 2         10-50
# 235 2         10-50
# 236 2         10-50
# 237 2         10-50
# 238 2         10-50

# %% [markdown]
# #### Max count filter

# %%
prev_max_filt <- prev_max %>% filter(max_count > 100)
prev_max_filt
# Out:
#     taxa                                      max_count overall_prevalence
# 1   Cutibacterium acnes                        22596    0.047462619
# 2   Microbacterium sp. PM5                     83419    0.035681921
# 3   Pseudomonas tolaasii                         161    0.024014499
# 4   Moraxella osloensis                         2402    0.019143634
# 5   Mesorhizobium sp. Pch-S                      405    0.019143634
# 6   Human mastadenovirus C                     17475    0.018577254
# 7   Paraburkholderia sp. 7MH5                    182    0.015745356
# 8   Paraburkholderia tropica                     153    0.014839148
# 9   Paraburkholderia acidiphila                  188    0.014499320
# 10  Microbacterium sp. Nx66                    67485    0.013706389
# 11  Paraburkholderia acidisoli                   112    0.013253285
# 12  Mycolicibacterium aubagnense                1938    0.012233802
# 13  Lactobacillus iners                         1104    0.012007250
# 14  Aquabacterium olei                           452    0.010987766
# 15  Rhodococcus sp. NJ-530                       175    0.010761214
# 16  Lactobacillus crispatus                     7799    0.010647938
# 17  Staphylococcus haemolyticus               117929    0.010534662
# 18  Variovorax paradoxus                         271    0.009628455
# 19  Phyllobacterium zundukense                   336    0.009401903
# 20  Staphylococcus epidermidis                  9140    0.008608971
# 21  Gardnerella vaginalis                       2123    0.008495696
# 22  Staphylococcus cohnii                      18768    0.008042592
# 23  Acidovorax sp. KKS102                        336    0.007362936
# 24  Micrococcus luteus                           329    0.006343453
# 25  Rhodococcus qingshengii                      112    0.006116901
# 26  Bifidobacterium adolescentis                 222    0.006003625
# 27  Rhizobacter sp. AJA081-3                     266    0.005437245
# 28  Rhodococcus erythropolis                     115    0.005323969
# 29  Inhella inkyongensis                         256    0.005210693
# 30  Bifidobacterium longum                       870    0.005097417
# ⋮   ⋮                                         ⋮         ⋮
# 128 Prevotella jejuni                         1937      0.0003398278
# 129 Deinococcus sp. NW-56                      731      0.0003398278
# 130 Corynebacterium sp. zg-917                 483      0.0003398278
# 131 Vibrio anguillarum                         379      0.0003398278
# 132 Roseomonas gilardii                        234      0.0003398278
# 133 Actinomyces sp. oral taxon 414             188      0.0003398278
# 134 Corynebacterium genitalium                 120      0.0003398278
# 135 Pseudonocardia autotrophica                118      0.0003398278
# 136 Rickettsia sp. Tillamook 23               2923      0.0002265519
# 137 Prevotella sp. oral taxon 299             2518      0.0002265519
# 138 Corynebacterium imitans                   1976      0.0002265519
# 139 Neisseria meningitidis                    1166      0.0002265519
# 140 Rickettsia felis                          1123      0.0002265519
# 141 Prevotella oris                            842      0.0002265519
# 142 Veillonella nakazawae                      699      0.0002265519
# 143 Paracoccus zhejiangensis                   616      0.0002265519
# 144 Rothia kristinae                           588      0.0002265519
# 145 Paracoccus haeundaensis                    571      0.0002265519
# 146 Torque teno virus 6                        496      0.0002265519
# 147 Skermanella pratensis                      471      0.0002265519
# 148 Deinococcus gobiensis                      378      0.0002265519
# 149 Corynebacterium aurimucosum                344      0.0002265519
# 150 Deinococcus geothermalis                   338      0.0002265519
# 151 Rickettsia endosymbiont of Bemisia tabaci  334      0.0002265519
# 152 Corynebacterium amycolatum                 216      0.0002265519
# 153 Deinococcus actinosclerus                  190      0.0002265519
# 154 Deinococcus ficus                          171      0.0002265519
# 155 Deinococcus swuensis                       161      0.0002265519
# 156 Dermacoccus nishinomiyaensis               148      0.0002265519
# 157 Limosilactobacillus reuteri                124      0.0002265519
#     n_samples max_bin
# 1   419       >=500
# 2   315       >=500
# 3   212       100-500
# 4   169       >=500
# 5   169       100-500
# 6   164       >=500
# 7   139       100-500
# 8   131       100-500
# 9   128       100-500
# 10  121       >=500
# 11  117       100-500
# 12  108       >=500
# 13  106       >=500
# 14   97       100-500
# 15   95       100-500
# 16   94       >=500
# 17   93       >=500
# 18   85       100-500
# 19   83       100-500
# 20   76       >=500
# 21   75       >=500
# 22   71       >=500
# 23   65       100-500
# 24   56       100-500
# 25   54       100-500
# 26   53       100-500
# 27   48       100-500
# 28   47       100-500
# 29   46       100-500
# 30   45       >=500
# ⋮   ⋮         ⋮
# 128 3         >=500
# 129 3         >=500
# 130 3         100-500
# 131 3         100-500
# 132 3         100-500
# 133 3         100-500
# 134 3         100-500
# 135 3         100-500
# 136 2         >=500
# 137 2         >=500
# 138 2         >=500
# 139 2         >=500
# 140 2         >=500
# 141 2         >=500
# 142 2         >=500
# 143 2         >=500
# 144 2         >=500
# 145 2         >=500
# 146 2         100-500
# 147 2         100-500
# 148 2         100-500
# 149 2         100-500
# 150 2         100-500
# 151 2         100-500
# 152 2         100-500
# 153 2         100-500
# 154 2         100-500
# 155 2         100-500
# 156 2         100-500
# 157 2         100-500

# %% [markdown]
# #### Add organism grouping

# %%
patho_meta <- fread("data/kraken2_taxonomy/plusPF_20210517_species_meta.csv") %>%
    select(-n_map_taxon) %>%
    mutate(taxa = gsub("\\[|\\]", "", taxa))

path_prev_max_filt <- prev_max_filt %>%
    left_join(patho_meta) %>%
    arrange(desc(max_count))

bact <- path_prev_max_filt %>% filter(org_group == "Bacteria")
viru <- path_prev_max_filt %>% filter(org_group == "Viruses")
fungi <- path_prev_max_filt %>% filter(org_group == "Fungi")
others <- path_prev_max_filt %>% filter(org_group == "Other Eukaryotes")

fwrite(path_prev_max_filt, "results/decontamination/global_decontamination_stats.csv")
# Out:
# Joining, by = "taxa"

# %% [markdown]
# ### Save decontaminated data

# %%
n_final <- nrow(prev_max_filt)
species_read_final <- species_filt %>%
    select(all_of(c("npm_research_id", prev_max_filt$taxa)))

# Remove zero rows
non_zero_rows <- species_read_final$npm_research_id[rowSums(species_read_final %>% select(-npm_research_id)) != 0]

species_read_zeroed <- species_read_final %>%
    filter(npm_research_id %in% non_zero_rows)

species_PA_final <- prev_df %>%
    select(all_of(c("npm_research_id", prev_max_filt$taxa))) %>%
    filter(npm_research_id %in% non_zero_rows)

species_RA_final <- otu_to_RA(species_read_final %>% filter(npm_research_id %in% non_zero_rows))

fwrite(species_read_final, 
       str_glue("results/decontamination/read_matrix_n{n_final}.global_decontaminated.zeroed.csv"))
fwrite(species_PA_final, 
       str_glue("results/decontamination/PA_matrix_n{n_final}.global_decontaminated.zeroed.csv"))
fwrite(species_RA_final, 
       str_glue("results/decontamination/RA_matrix_n{n_final}.global_decontaminated.zeroed.csv"))
fwrite(species_RA_final %>% select(npm_research_id), 
       str_glue("results/decontamination/ids_n{n_final}.global_decontaminated.zeroed.txt"), 
       row.names = F)

# %% [markdown]
# ### Print decontamination taxa

# %%
raw_no <- sum(colSums(species_df %>% select(-npm_research_id)) != 0)
print(str_glue("Raw no. of taxa: {raw_no}"))
print(str_glue("After zero-filter: {ncol(prev_df)}"))
print(str_glue("After diff. prev. filter: {length(diff_prev_nc)}"))
print(str_glue("After corr. filter: {length(corr_nc)}"))
print(str_glue("After batch filter: {length(batch_nc)}"))
print(str_glue("After max. count filter: {nrow(prev_max_filt)}"))
# Out:
# Raw no. of taxa: 8841
# After zero-filter: 871
# After diff. prev. filter: 710
# After corr. filter: 645
# After batch filter: 238
# After max. count filter: 157

# %% [markdown]
# ### Save non-contaminant table

# %%
all_stats <- species_RA_final %>%
    pivot_longer(!npm_research_id, names_to = "taxa", values_to = "rel_a") %>%
    mutate(rel_a = ifelse(rel_a == 0, NA, rel_a)) %>%
    group_by(taxa) %>% 
    summarise(median_rel_a = median(rel_a, na.rm = T)) %>%
    right_join(prev_max_filt) %>%
    select(-max_bin) %>%
    mutate(pathogen_type = ifelse(grepl("virus", taxa), "virus", "bacteria")) %>%
    arrange(desc(overall_prevalence))

all_stats 

fwrite(all_stats, str_glue("results/decontamination/curated_n{n_final}_global_decontamination_stats.csv"))
# Out:
# Joining, by = "taxa"
#     taxa                                      median_rel_a max_count
# 1   Cutibacterium acnes                       0.8213058     22596
# 2   Microbacterium sp. PM5                    1.0000000     83419
# 3   Pseudomonas tolaasii                      1.0000000       161
# 4   Mesorhizobium sp. Pch-S                   1.0000000       405
# 5   Moraxella osloensis                       0.4825581      2402
# 6   Human mastadenovirus C                    1.0000000     17475
# 7   Paraburkholderia sp. 7MH5                 0.2579075       182
# 8   Paraburkholderia tropica                  0.2236842       153
# 9   Paraburkholderia acidiphila               0.2192236       188
# 10  Microbacterium sp. Nx66                   1.0000000     67485
# 11  Paraburkholderia acidisoli                0.2058824       112
# 12  Mycolicibacterium aubagnense              1.0000000      1938
# 13  Lactobacillus iners                       0.6331699      1104
# 14  Aquabacterium olei                        1.0000000       452
# 15  Rhodococcus sp. NJ-530                    1.0000000       175
# 16  Lactobacillus crispatus                   1.0000000      7799
# 17  Staphylococcus haemolyticus               0.8658678    117929
# 18  Variovorax paradoxus                      0.2558140       271
# 19  Phyllobacterium zundukense                0.5348837       336
# 20  Staphylococcus epidermidis                0.4318996      9140
# 21  Gardnerella vaginalis                     0.6081081      2123
# 22  Staphylococcus cohnii                     0.1369306     18768
# 23  Acidovorax sp. KKS102                     1.0000000       336
# 24  Micrococcus luteus                        0.1743737       329
# 25  Rhodococcus qingshengii                   0.2877750       112
# 26  Bifidobacterium adolescentis              0.1862745       222
# 27  Rhizobacter sp. AJA081-3                  0.2328803       266
# 28  Rhodococcus erythropolis                  0.3013699       115
# 29  Inhella inkyongensis                      0.2084026       256
# 30  Bifidobacterium longum                    0.1551552       870
# ⋮   ⋮                                         ⋮            ⋮
# 128 Corynebacterium genitalium                0.04155844    120
# 129 Corynebacterium sp. zg-917                0.23116883    483
# 130 Deinococcus sp. NW-56                     0.32706935    731
# 131 Hepatitis B virus                         1.00000000   4979
# 132 Prevotella jejuni                         0.03402663   1937
# 133 Pseudonocardia autotrophica               1.00000000    118
# 134 Roseomonas gilardii                       0.02689487    234
# 135 Vibrio anguillarum                        0.40123457    379
# 136 Corynebacterium amycolatum                0.05820251    216
# 137 Corynebacterium aurimucosum               0.06855345    344
# 138 Corynebacterium imitans                   0.14424835   1976
# 139 Deinococcus actinosclerus                 0.08633676    190
# 140 Deinococcus ficus                         0.10156672    171
# 141 Deinococcus geothermalis                  0.09671911    338
# 142 Deinococcus gobiensis                     0.12677155    378
# 143 Deinococcus swuensis                      0.05874517    161
# 144 Dermacoccus nishinomiyaensis              0.34503943    148
# 145 Limosilactobacillus reuteri               0.51406650    124
# 146 Neisseria meningitidis                    0.01770405   1166
# 147 Paracoccus haeundaensis                   0.01422907    571
# 148 Paracoccus zhejiangensis                  0.01475452    616
# 149 Prevotella oris                           0.19888493    842
# 150 Prevotella sp. oral taxon 299             0.16318786   2518
# 151 Rickettsia endosymbiont of Bemisia tabaci 0.52377589    334
# 152 Rickettsia felis                          0.63217985   1123
# 153 Rickettsia sp. Tillamook 23               0.84404426   2923
# 154 Rothia kristinae                          0.49612929    588
# 155 Skermanella pratensis                     0.34384661    471
# 156 Torque teno virus 6                       0.57962283    496
# 157 Veillonella nakazawae                     0.01569565    699
#     overall_prevalence n_samples pathogen_type
# 1   0.047462619        419       bacteria
# 2   0.035681921        315       bacteria
# 3   0.024014499        212       bacteria
# 4   0.019143634        169       bacteria
# 5   0.019143634        169       bacteria
# 6   0.018577254        164       virus
# 7   0.015745356        139       bacteria
# 8   0.014839148        131       bacteria
# 9   0.014499320        128       bacteria
# 10  0.013706389        121       bacteria
# 11  0.013253285        117       bacteria
# 12  0.012233802        108       bacteria
# 13  0.012007250        106       bacteria
# 14  0.010987766         97       bacteria
# 15  0.010761214         95       bacteria
# 16  0.010647938         94       bacteria
# 17  0.010534662         93       bacteria
# 18  0.009628455         85       bacteria
# 19  0.009401903         83       bacteria
# 20  0.008608971         76       bacteria
# 21  0.008495696         75       bacteria
# 22  0.008042592         71       bacteria
# 23  0.007362936         65       bacteria
# 24  0.006343453         56       bacteria
# 25  0.006116901         54       bacteria
# 26  0.006003625         53       bacteria
# 27  0.005437245         48       bacteria
# 28  0.005323969         47       bacteria
# 29  0.005210693         46       bacteria
# 30  0.005097417         45       bacteria
# ⋮   ⋮                  ⋮         ⋮
# 128 0.0003398278       3         bacteria
# 129 0.0003398278       3         bacteria
# 130 0.0003398278       3         bacteria
# 131 0.0003398278       3         virus
# 132 0.0003398278       3         bacteria
# 133 0.0003398278       3         bacteria
# 134 0.0003398278       3         bacteria
# 135 0.0003398278       3         bacteria
# 136 0.0002265519       2         bacteria
# 137 0.0002265519       2         bacteria
# 138 0.0002265519       2         bacteria
# 139 0.0002265519       2         bacteria
# 140 0.0002265519       2         bacteria
# 141 0.0002265519       2         bacteria
# 142 0.0002265519       2         bacteria
# 143 0.0002265519       2         bacteria
# 144 0.0002265519       2         bacteria
# 145 0.0002265519       2         bacteria
# 146 0.0002265519       2         bacteria
# 147 0.0002265519       2         bacteria
# 148 0.0002265519       2         bacteria
# 149 0.0002265519       2         bacteria
# 150 0.0002265519       2         bacteria
# 151 0.0002265519       2         bacteria
# 152 0.0002265519       2         bacteria
# 153 0.0002265519       2         bacteria
# 154 0.0002265519       2         bacteria
# 155 0.0002265519       2         bacteria
# 156 0.0002265519       2         virus
# 157 0.0002265519       2         bacteria

# %% [markdown]
# ## Plot prevalence of contaminants and non-contaminants

# %%
get_prev_plot <- function(taxon) {
    contam_plt <- prev_df %>%
        left_join(meta) %>%
        group_by(extraction_kit) %>%
        summarise(prev = sum(get(taxon)) / n(), n = n()) %>%
        filter(extraction_kit != "Unknown") %>%
        ggplot(aes(x = extraction_kit, y = prev, fill = extraction_kit)) +
            geom_bar(stat = "identity") +
            theme(axis.text.x = element_text(angle = 45, hjust = 1),
                  axis.title = element_blank(),
                  text = element_text(size = 15)) +
            scale_x_discrete(label = function(x) stringr::str_trunc(x, 12)) +
            labs(x = "Extraction Kit", y = "Prevalence", title = taxon) +
            geom_hline(yintercept = 0.25, 
                       color = "red",
                       lty = "dashed") +
            ylim(0, 1)
    }
                         
                    
                    
ggarrange(get_prev_plot("Pseudomonas mendocina"), get_prev_plot("Moraxella osloensis"), 
          common.legend = T,
          legend = "none")
                             
ggsave("results/decontamination/contam_versus_nc_prevalence.png", dpi = 600, height = 6.67, width = 7.5)
# Out:
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# plot without title

# %% [markdown]
# #### Compare with fine grain analysis

# %%
# global_not_fine <- read.csv("results/decontamination/global_not_fine_taxa.txt")$taxa
# length(global_not_fine)
# prev_max_filt %>% 
#     filter(taxa %in% global_not_fine) %>%
#     separate(taxa, sep = " ", into = c("genus", "species")) %>%
#     group_by(genus) %>%
#     summarise(n = n()) %>%
#     arrange(desc(n))

# %% [markdown]
# ### Rank species by prevalence and max read count

# %%
top_max_count <- prev_max_filt %>% 
    arrange(desc(max_count)) %>% 
    mutate(count_rank = seq(nrow(prev_max_filt)))

top_prev <- prev_max_filt %>% 
    arrange(desc(overall_prevalence)) %>%
    mutate(prev_rank = seq(nrow(prev_max_filt)))

top_max_count %>% 
    full_join(top_prev) %>%
    mutate(ranksum = count_rank + prev_rank) %>%
    arrange(prev_rank)
# Out:
# Joining, by = c("taxa", "max_count", "overall_prevalence", "n_samples", "max_bin")
#     taxa                                      max_count overall_prevalence
# 1   Cutibacterium acnes                        22596    0.047462619
# 2   Microbacterium sp. PM5                     83419    0.035681921
# 3   Pseudomonas tolaasii                         161    0.024014499
# 4   Moraxella osloensis                         2402    0.019143634
# 5   Mesorhizobium sp. Pch-S                      405    0.019143634
# 6   Human mastadenovirus C                     17475    0.018577254
# 7   Paraburkholderia sp. 7MH5                    182    0.015745356
# 8   Paraburkholderia tropica                     153    0.014839148
# 9   Paraburkholderia acidiphila                  188    0.014499320
# 10  Microbacterium sp. Nx66                    67485    0.013706389
# 11  Paraburkholderia acidisoli                   112    0.013253285
# 12  Mycolicibacterium aubagnense                1938    0.012233802
# 13  Lactobacillus iners                         1104    0.012007250
# 14  Aquabacterium olei                           452    0.010987766
# 15  Rhodococcus sp. NJ-530                       175    0.010761214
# 16  Lactobacillus crispatus                     7799    0.010647938
# 17  Staphylococcus haemolyticus               117929    0.010534662
# 18  Variovorax paradoxus                         271    0.009628455
# 19  Phyllobacterium zundukense                   336    0.009401903
# 20  Staphylococcus epidermidis                  9140    0.008608971
# 21  Gardnerella vaginalis                       2123    0.008495696
# 22  Staphylococcus cohnii                      18768    0.008042592
# 23  Acidovorax sp. KKS102                        336    0.007362936
# 24  Micrococcus luteus                           329    0.006343453
# 25  Rhodococcus qingshengii                      112    0.006116901
# 26  Bifidobacterium adolescentis                 222    0.006003625
# 27  Rhizobacter sp. AJA081-3                     266    0.005437245
# 28  Rhodococcus erythropolis                     115    0.005323969
# 29  Inhella inkyongensis                         256    0.005210693
# 30  Bifidobacterium longum                       870    0.005097417
# ⋮   ⋮                                         ⋮         ⋮
# 128 Prevotella jejuni                         1937      0.0003398278
# 129 Deinococcus sp. NW-56                      731      0.0003398278
# 130 Corynebacterium sp. zg-917                 483      0.0003398278
# 131 Vibrio anguillarum                         379      0.0003398278
# 132 Roseomonas gilardii                        234      0.0003398278
# 133 Actinomyces sp. oral taxon 414             188      0.0003398278
# 134 Corynebacterium genitalium                 120      0.0003398278
# 135 Pseudonocardia autotrophica                118      0.0003398278
# 136 Rickettsia sp. Tillamook 23               2923      0.0002265519
# 137 Prevotella sp. oral taxon 299             2518      0.0002265519
# 138 Corynebacterium imitans                   1976      0.0002265519
# 139 Neisseria meningitidis                    1166      0.0002265519
# 140 Rickettsia felis                          1123      0.0002265519
# 141 Prevotella oris                            842      0.0002265519
# 142 Veillonella nakazawae                      699      0.0002265519
# 143 Paracoccus zhejiangensis                   616      0.0002265519
# 144 Rothia kristinae                           588      0.0002265519
# 145 Paracoccus haeundaensis                    571      0.0002265519
# 146 Torque teno virus 6                        496      0.0002265519
# 147 Skermanella pratensis                      471      0.0002265519
# 148 Deinococcus gobiensis                      378      0.0002265519
# 149 Corynebacterium aurimucosum                344      0.0002265519
# 150 Deinococcus geothermalis                   338      0.0002265519
# 151 Rickettsia endosymbiont of Bemisia tabaci  334      0.0002265519
# 152 Corynebacterium amycolatum                 216      0.0002265519
# 153 Deinococcus actinosclerus                  190      0.0002265519
# 154 Deinococcus ficus                          171      0.0002265519
# 155 Deinococcus swuensis                       161      0.0002265519
# 156 Dermacoccus nishinomiyaensis               148      0.0002265519
# 157 Limosilactobacillus reuteri                124      0.0002265519
#     n_samples max_bin count_rank prev_rank ranksum
# 1   419       >=500     6         1          7
# 2   315       >=500     4         2          6
# 3   212       100-500 132         3        135
# 4   169       >=500    28         4         32
# 5   169       100-500  80         5         85
# 6   164       >=500     8         6         14
# 7   139       100-500 126         7        133
# 8   131       100-500 136         8        144
# 9   128       100-500 123         9        132
# 10  121       >=500     5        10         15
# 11  117       100-500 152        11        163
# 12  108       >=500    31        12         43
# 13  106       >=500    45        13         58
# 14   97       100-500  79        14         93
# 15   95       100-500 128        15        143
# 16   94       >=500    17        16         33
# 17   93       >=500     2        17         19
# 18   85       100-500 100        18        118
# 19   83       100-500  88        19        107
# 20   76       >=500    13        20         33
# 21   75       >=500    29        21         50
# 22   71       >=500     7        22         29
# 23   65       100-500  89        23        112
# 24   56       100-500  93        24        117
# 25   54       100-500 153        25        178
# 26   53       100-500 113        26        139
# 27   48       100-500 101        27        128
# 28   47       100-500 151        28        179
# 29   46       100-500 106        29        135
# 30   45       >=500    50        30         80
# ⋮   ⋮         ⋮       ⋮          ⋮         ⋮
# 128 3         >=500    32        128       160
# 129 3         >=500    55        129       184
# 130 3         100-500  75        130       205
# 131 3         100-500  84        131       215
# 132 3         100-500 110        132       242
# 133 3         100-500 124        133       257
# 134 3         100-500 146        134       280
# 135 3         100-500 149        135       284
# 136 2         >=500    26        136       162
# 137 2         >=500    27        137       164
# 138 2         >=500    30        138       168
# 139 2         >=500    41        139       180
# 140 2         >=500    43        140       183
# 141 2         >=500    53        141       194
# 142 2         >=500    59        142       201
# 143 2         >=500    64        143       207
# 144 2         >=500    66        144       210
# 145 2         >=500    68        145       213
# 146 2         100-500  73        146       219
# 147 2         100-500  76        147       223
# 148 2         100-500  85        148       233
# 149 2         100-500  86        149       235
# 150 2         100-500  87        150       237
# 151 2         100-500  90        151       241
# 152 2         100-500 116        152       268
# 153 2         100-500 122        153       275
# 154 2         100-500 131        154       285
# 155 2         100-500 133        155       288
# 156 2         100-500 139        156       295
# 157 2         100-500 144        157       301

# %% [markdown]
# ### Get samples with max. read counts

# %% [markdown]
# #### Get metadata of top 20 bacterial taxa ranked by max count

# %%
top_20 <- top_max_count %>%
    filter(!grepl("Human", taxa)) %>%
    select(taxa, max_count, overall_prevalence, n_samples) %>%
    head(20)

morsels <- foreach (i = seq(nrow(top_20))) %do% {
    row <- top_20[i, ]
    taxon <- row$taxa
    max_count <- row$max_count
    sample_with_max_count <- (species_filt %>% filter(get(taxon) == max_count))$npm_research_id
    
    RA <- species_filt_RA %>% 
        filter(npm_research_id == sample_with_max_count) %>%
        select(all_of(taxon))
    RA <- deframe(RA)
    
    row$max_sample <- sample_with_max_count
    row$rel_a <- RA
    
    return(row)
}

top_20_parsed <- bind_rows(morsels)

top_20_parsed

fwrite(top_20_parsed, "results/irep_analysis/global_top_20_bacteria_max_count.csv")
# Out:
#    taxa                        max_count overall_prevalence n_samples
# 1  Fusobacterium nucleatum     194199    0.0011327594        10
# 2  Staphylococcus haemolyticus 117929    0.0105346624        93
# 3  Paracoccus yeei              85256    0.0035115541        31
# 4  Microbacterium sp. PM5       83419    0.0356819212       315
# 5  Microbacterium sp. Nx66      67485    0.0137063888       121
# 6  Cutibacterium acnes          22596    0.0474626189       419
# 7  Staphylococcus cohnii        18768    0.0080425918        71
# 8  Neisseria subflava           15385    0.0015858632        14
# 9  Corynebacterium segmentosum  14476    0.0010194835         9
# 10 Haemophilus parainfluenzae   12183    0.0020389669        18
# 11 Fannyhessea vaginae          10395    0.0023787947        21
# 12 Staphylococcus epidermidis    9140    0.0086089715        76
# 13 Aspergillus oryzae            7909    0.0005663797         5
# 14 Lactobacillus crispatus       7799    0.0106479384        94
# 15 Acinetobacter baumannii       7673    0.0031717263        28
# 16 Cupriavidus metallidurans     5506    0.0036248301        32
# 17 Hepatitis B virus             4979    0.0003398278         3
# 18 Neisseria mucosa              4683    0.0012460353        11
# 19 Malassezia restricta          4237    0.0011327594        10
# 20 Neisseria flavescens          3787    0.0005663797         5
#    max_sample rel_a
# 1  WHB4594    0.98161112
# 2  0416-0024  0.86270364
# 3  WHH1680    0.97894133
# 4  WHB10821   1.00000000
# 5  WHB3375    1.00000000
# 6  WHB8433    1.00000000
# 7  0416-0024  0.13729636
# 8  WHB9179    0.27026315
# 9  WHB6459    0.51296953
# 10 WHB9179    0.21401469
# 11 WHB4035    0.97313237
# 12 WHB6459    0.32388377
# 13 WHB4056    1.00000000
# 14 WHB10710   1.00000000
# 15 0116-0053  1.00000000
# 16 WHB9583    0.90978189
# 17 WHH4833    1.00000000
# 18 WHB9179    0.08226469
# 19 WHB7667    0.67564982
# 20 WHB9179    0.06652496

# %%
# taxon <- "Paracoccus yeei"
# taxon <- "Fusobacterium nucleatum"
# taxon <- "Cutibacterium acnes"
# taxon <- "Bacillus cereus"
taxon <- "Burkholderia contaminans"
# taxon <- "Microbacterium hominis"
taxon <- "Microbacterium sp. PM5"
max_count <- prev_max_filt[prev_max_filt$taxa == taxon, ]$max_count
id <- (species_filt %>%
    filter(get(taxon) == max_count))$npm_research_id
print(id)

# species_RA %>% 
#     filter(npm_research_id == id) %>%
#     select(all_of(c(taxon)))

species_filt %>%
    select(all_of(c("npm_research_id", taxon))) %>%
    arrange(desc(get(taxon))) %>%
#     filter(get(taxon) > 100) %>%
    ggplot(aes(x = log(get(taxon), base = 10))) +
    geom_histogram() +
    labs(x = "log(read count, base = 10)", y = "No. of libraries", title = taxon)
# Out:
# [1] "WHB10821"
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 8513 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# ### No. of taxa per sample

# %%
# After PA thresholding
tax_plt <- tibble(n = rowSums(prev_df %>% select(-npm_research_id))) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After non-zero filter")

# After correlation decontamination
species_prev_filt1 <- prev_df %>% select(all_of(corr_nc))
tax_plt1 <- tibble(n = rowSums(species_prev_filt1)) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After correlation filter")

# After simple batch filter
species_prev_filt2 <- prev_df %>% select(all_of(batch_nc))
tax_plt2 <- tibble(n = rowSums(species_prev_filt2)) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After >2 batch filter")


# After max count filter
species_prev_filt3 <- prev_df %>% select(all_of(prev_max_filt$taxa))
tax_plt3 <- tibble(n = rowSums(species_prev_filt3)) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After max count filter")

ggarrange(tax_plt, tax_plt1, tax_plt2, tax_plt3)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
sum(rowSums(species_prev_filt3) == 0)
# Out:
# [1] 6154

# %% [markdown]
# ## Visualising batch effects

# %% [markdown]
# ### PCA on CLR

# %% [markdown]
# #### CLR transformation

# %%
X_before <- RA_to_clr(otu_to_RA(species_zeroed %>% rownames_to_column("npm_research_id"))) %>% 
    column_to_rownames("npm_research_id")
X_after <- RA_to_clr(otu_to_RA(species_read_final)) %>% 
    column_to_rownames("npm_research_id")
# # Get Bray-curtis dists
# dist_before <- dist(as.matrix(X_before),  method = "euclidean")
# dist_after <- dist(as.matrix(X_after),  method = "euclidean")

# %% [markdown]
# #### Run PCA analysis on CLR abundances

# %%
get_pca_plot <- function(X, loadings_scale_factor = 4) {
    # Run Singular Value Decomposition
    pca <- prcomp(X, retx = T)
    
    # Extract loadings
    loadings <- data.frame(Variables = rownames(pca$rotation), pca$rotation) %>%
    mutate(sum_pc = abs(PC1) + abs(PC2)) %>%
    filter(sum_pc > 0.2)
    
    # Extract proportion of variance
    prop_variance <- pca$sdev ^ 2 / sum(pca$sdev ^ 2)
    PC1_prop <- round(prop_variance[1] * 100, 2)
    PC2_prop <- round(prop_variance[2] * 100, 2)
    
    # Plot
    as_tibble(pca$x) %>%
        add_column(npm_research_id = rownames(pca$x), .before = 1) %>%
        left_join(meta) %>%
        ggplot(aes(x = PC1, y = PC2, color = site_supplying_sample)) +
        geom_point(size = 6) + 
        geom_segment(data = loadings, 
                     aes(x = 0, y = 0, 
                         xend = (PC1 * loadings_scale_factor),
                         yend = (PC2 * loadings_scale_factor)), 
                     arrow = arrow(length = unit(1/2, "picas")),
                     color = "grey30") +
        annotate("text", 
                 size = 6,
                 x = (loadings$PC1 * loadings_scale_factor * 0.7), 
                 y = (loadings$PC2 * loadings_scale_factor * 0.7),
                 label = loadings$Variables) +
    labs(x = str_glue("PC1 ({PC1_prop}%)"), 
         y = str_glue("PC2 ({PC2_prop}%)"), 
         color = "Cohort") +
    theme_bw() +
    theme(panel.grid = element_blank(),
          axis.title = element_text(size = 20),
          legend.text = element_text(size = 20),
          legend.title = element_text(size = 20),
          legend.position = "none")
    
}

ggarrange(get_pca_plot(X_before),
          get_pca_plot(X_after), 
          common.legend = T,
          legend = "left")

ggsave("results/decontamination/PCoA/PCoA_Aitchinson.png", dpi = 600, width = 12)
# Get separate plots
get_pca_plot(X_before)
ggsave("results/decontamination/PCoA/PCoA_Aitchinson_before.png", dpi = 600)
get_pca_plot(X_after)
ggsave("results/decontamination/PCoA/PCoA_Aitchinson_after.png", dpi = 600)

# ggarrange(get_pca_plot(X_before),
#           get_pca_plot(X_after), 
#           common.legend = T,
#           legend = "none")

# ggsave("results/decontamination/PCoA/PCoA_Aitchinson_nolegend.png", dpi = 600, width = 12, height = 6)
# Out:
# Joining, by = "npm_research_id"
# Joining, by = "npm_research_id"
# Saving 12 x 6.67 in image
#
# Joining, by = "npm_research_id"
# plot without title
# Saving 6.67 x 6.67 in image
#
# Joining, by = "npm_research_id"
# plot without title
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# ### PCoA on BC

# %%
X_before_RA <- otu_to_RA(species_zeroed %>% rownames_to_column("npm_research_id")) %>% 
    column_to_rownames("npm_research_id")
X_before_RA <- X_before_RA %>% 
    filter(rowSums(X_before_RA) != 0)
#     sample_n(100)

X_after_RA <- otu_to_RA(species_read_final) %>% 
    column_to_rownames("npm_research_id")
X_after_RA <- X_after_RA %>% 
    filter(rowSums(X_after_RA) != 0)
#     sample_n(100)

# %%
get_pcoa_plot <- function(X, legend) {
    # Get BC distances
    bc_dist <- vegdist(X, method = "bray")
    pcoa <- cmdscale (bc_dist, eig = TRUE)
    
    # Extract proportion of variance
    prop_variance <- pcoa$eig / sum(pcoa$eig)
    PC1_prop <- round(prop_variance[1] * 100, 1)
    PC2_prop <- round(prop_variance[2] * 100, 1)
    
    # Plot
    plot_df <- tibble(npm_research_id = rownames(pcoa$points), 
               PC1 = pcoa$points[, 1], 
               PC2 = pcoa$points[, 2]) %>%
            left_join(meta)
    density_plt1 <- plot_df %>%
        ggplot(aes(x = PC1, fill = site_supplying_sample, color = site_supplying_sample)) + 
            geom_density(alpha = 0.5) + 
            theme_classic() +
            theme(axis.text.x = element_blank(),
                  axis.title.x = element_blank(),
                  legend.position = "none") +
        labs(x = "Density", 
             y = "Density",
             fill = "Cohort", , color = "Cohort")

    density_plt2 <- plot_df %>%
        ggplot(aes(x = PC2, fill = site_supplying_sample, color = site_supplying_sample)) + 
            geom_density(alpha = 0.5) + 
            theme_classic() +
            theme(axis.text.y = element_blank(),
                  axis.title.y = element_blank(),
                  legend.position = "none") +
            coord_flip() +
        labs(x = "Density", 
             y = "Density",
             fill = "Cohort", color = "Cohort")

    empty_plt <- ggplot(plot_df) + 
        geom_blank() +
        theme(panel.background = element_rect("white"))

    scatter_plt <- plot_df %>%
        ggplot(aes(x = PC1, y = PC2, color = site_supplying_sample)) + 
            geom_point() +
            theme(legend.position = "none") +
        labs(x = str_glue("PCo1 ({PC1_prop}%)"), 
             y = str_glue("PCo2 ({PC2_prop}%)"), 
             color = "Cohort") +
        theme_bw() +
        theme(panel.grid = element_blank(),
              axis.title = element_text(size = 20),
              legend.text = element_text(size = 20),
              legend.title = element_text(size = 20),
              legend.position = "none") +
        geom_text(aes(x = min(PC1) + 0.5, 
                      y = min(PC2), 
                      label = str_glue("n = {nrow(plot_df)}")),
                  color = "black")
        
        if (legend) {
            ggarrange(density_plt1, empty_plt, scatter_plt, density_plt2, 
                      nrow = 2, ncol = 2,
                      widths = c(3, 1, 3, 1),
                      heights = c(1, 3, 1, 3),
                      common.legend = T,
                      legend = "right")
        } else {
            ggarrange(density_plt1, empty_plt, scatter_plt, density_plt2, 
                      nrow = 2, ncol = 2,
                      widths = c(3, 1, 3, 1),
                      heights = c(1, 3, 1, 3),
                      common.legend = F)
        }

}

# Get separate plots
get_pcoa_plot(X_before_RA, legend = F)
ggsave("results/decontamination/PCoA/PCoA_Bray_before.png", dpi = 600)
get_pcoa_plot(X_after_RA, legend = F)
ggsave("results/decontamination/PCoA/PCoA_Bray_after.png", dpi = 600)

get_pcoa_plot(X_after_RA, legend = T)
# Out:
# Joining, by = "npm_research_id"
# Saving 6.67 x 6.67 in image
#
# Joining, by = "npm_research_id"
# plot without title
# Saving 6.67 x 6.67 in image
#
# Joining, by = "npm_research_id"
# plot without title
# plot without title
