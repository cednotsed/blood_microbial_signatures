# %% [markdown]
# # QC for pre-processing steps

# %%
setwd("/home/projects/14001280/PROJECTS/blood_microbiome/")
require(tidyverse)
require(ggplot2)
require(data.table)
require(ShortRead)
# Out:
# Loading required package: ShortRead
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: BiocParallel
#
# Loading required package: Biostrings
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:base’:
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: XVector
#
#
# Attaching package: ‘XVector’
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: Rsamtools
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomicAlignments
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘GenomicAlignments’
#
#
# The following object is masked from ‘package:data.table’:
#
#     last
#
#
# The following object is masked from ‘package:dplyr’:
#
#     last
#
#
#
# Attaching package: ‘ShortRead’
#
#
# The following object is masked from ‘package:data.table’:
#
#     tables
#
#
# The following object is masked from ‘package:dplyr’:
#
#     id
#
#
# The following object is masked from ‘package:purrr’:
#
#     compose
#
#
# The following object is masked from ‘package:tibble’:
#
#     view

# %%
meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv")

# %%
head(meta)
# Out:
#   npm_research_id multiplex_pool_id supplier_id gis_internal_sample_id
# 1 WHB10000        MUX9693           00358       HELIOS_00358_1
# 2 WHB10001        MUX9693           00359       HELIOS_00359_1
# 3 WHB10002        MUX9695           00360       HELIOS_00360_1
# 4 WHB10003        MUX9694           00361       HELIOS_00361_1
# 5 WHB10005        MUX9694           00363       HELIOS_00363_1
# 6 WHB10006        MUX9694           00364       HELIOS_00364_1
#   site_supplying_sample year_of_birth supplied_gender self_reported_ethnicity
# 1 HELIOS                1982          F               Chinese
# 2 HELIOS                1979          F               Chinese
# 3 HELIOS                1970          F               Chinese
# 4 HELIOS                1969          M               Chinese
# 5 HELIOS                1959          F               Chinese
# 6 HELIOS                1955          F               Chinese
#   extraction_kit                                 date_of_dna_extraction ⋯
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 2 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 3 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 4 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 5 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 6 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
#   supplied_and_computed_ethinicity_match
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   sop_agreement_for_coverage__14/_28_for_15x/30x sample_life_cycle current
# 1 Y                                              HELIOS VCF        Y
# 2 Y                                              HELIOS VCF        Y
# 3 N                                              HELIOS VCF        Y
# 4 Y                                              HELIOS VCF        Y
# 5 N                                              HELIOS VCF        Y
# 6 Y                                              HELIOS VCF        Y
#   source_cohort original_supplier_id duplicate_info duplicate duplicate_pair
# 1 HELIOS        00358                               PASS
# 2 HELIOS        00359                               PASS
# 3 HELIOS        00360                               PASS
# 4 HELIOS        00361                               PASS
# 5 HELIOS        00363                               PASS
# 6 HELIOS        00364                               PASS
#   removal_requested_by_supplier
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %% [markdown]
# ### Get intermediate file directories for all pre-processing steps

# %%
steps <- list.dirs("data/temp_files")

# %% [markdown]
# ### Iterate through preprocessing step directories and through fastq/bam/files

# %%
df <- tibble()

for (step in steps) {
#     step <- steps[3]
    if (grepl("_fastq|_bam", step)) {
        step_name <- strsplit(step, "/")
        step_name <- unlist(step_name)[3]
        file_names <- list.files(step)
        print(paste("pre-processing step:", step))

        for (file in file_names) {
    #         file <- file_names[40]
            file_path <- paste0(step, "/", file)

            # Get file size
            file_size <- file.size(file_path)
            npm_research_id <- strsplit(file, "\\.")
            npm_research_id <- unlist(npm_research_id)[2]

            # Get no. of reads
            if (grepl(".fastq", file_path)) {
                n_reads <- countLines(file_path) / 4
            } else {
                n_reads <- NA
            }

            morsel <- tibble(step_name = step_name, 
                             npm_research_id = npm_research_id,
                             file_size = file_size, 
                             file_name = file, 
                             n_reads = n_reads)

            df <- df %>% bind_rows(morsel)

        }
    }
}

df
# Out:
# [1] "pre-processing step: data/temp_files/01_bam"
# [1] "pre-processing step: data/temp_files/01_fastq"
# [1] "pre-processing step: data/temp_files/02_fastq"
# [1] "pre-processing step: data/temp_files/03_fastq"
# [1] "pre-processing step: data/temp_files/04_fastq"
# [1] "pre-processing step: data/temp_files/05_fastq"
# [1] "pre-processing step: data/temp_files/06_unclassified_fastq"
#      step_name             npm_research_id file_size
# 1    01_bam                0216-0003                0
# 2    01_bam                0416-0021                0
# 3    01_bam                0416-0031                0
# 4    01_bam                0416-0056                0
# 5    01_bam                0416-0062                0
# 6    01_bam                0515-0049                0
# 7    01_bam                0516-0003                0
# 8    01_bam                0516-0088                0
# 9    01_bam                0815-0037                0
# 10   01_bam                WHB6482          517522499
# 11   01_bam                WHB6482          109038307
# 12   01_bam                WHB6552         1096025725
# 13   01_bam                WHB6552          230484537
# 14   01_bam                WHB7574         1146553466
# 15   01_bam                WHB7574          220243698
# 16   01_bam                WHB7618          873930151
# 17   01_bam                WHB7618          180348337
# 18   01_bam                WHB6828           36326704
# 19   01_bam                WHB6828           12929655
# 20   01_bam                WHB6865           42679287
# 21   01_bam                WHB6865            9062002
# 22   01_bam                WHB6959         1075472620
# 23   01_bam                WHB6959          203257538
# 24   01_bam                WHB7016           15983671
# 25   01_bam                WHB7016            4389414
# 26   01_bam                WHB7048         1020659145
# 27   01_bam                WHB7048          216903600
# 28   01_bam                WHB7064          289852067
# 29   01_bam                WHB7064           53698901
# 30   01_bam                WHB6703          865396684
# ⋮    ⋮                     ⋮               ⋮
# 3790 06_unclassified_fastq WHB10062        1405858
# 3791 06_unclassified_fastq WHB10062        1405556
# 3792 06_unclassified_fastq WHB8836         3315900
# 3793 06_unclassified_fastq WHB8836         3314516
# 3794 06_unclassified_fastq WHB10155         897655
# 3795 06_unclassified_fastq WHB10155         897579
# 3796 06_unclassified_fastq WHB10244        1093926
# 3797 06_unclassified_fastq WHB10244        1093388
# 3798 06_unclassified_fastq WHB10470        2006375
# 3799 06_unclassified_fastq WHB10470        2006085
# 3800 06_unclassified_fastq WHB9453         4415692
# 3801 06_unclassified_fastq WHB9453         4413756
# 3802 06_unclassified_fastq WHB9715         1134162
# 3803 06_unclassified_fastq WHB9715         1133982
# 3804 06_unclassified_fastq WHB10417        1215147
# 3805 06_unclassified_fastq WHB10417        1214923
# 3806 06_unclassified_fastq WHB10436        5611334
# 3807 06_unclassified_fastq WHB10436        5610704
# 3808 06_unclassified_fastq WHB10082         775042
# 3809 06_unclassified_fastq WHB10082         774998
# 3810 06_unclassified_fastq WHB10100         845480
# 3811 06_unclassified_fastq WHB10100         845022
# 3812 06_unclassified_fastq WHB10342        2196887
# 3813 06_unclassified_fastq WHB10342        2196321
# 3814 06_unclassified_fastq WHB10598        2047482
# 3815 06_unclassified_fastq WHB10598        2047118
# 3816 06_unclassified_fastq WHB6405          966209
# 3817 06_unclassified_fastq WHB6405          966031
# 3818 06_unclassified_fastq WHB6241         1019917
# 3819 06_unclassified_fastq WHB6241         1019555
#      file_name
# 1    "".0216-0003.unmapped-both-read-and-mate.bam
# 2    "".0416-0021.unmapped-both-read-and-mate.bam
# 3    "".0416-0031.unmapped-both-read-and-mate.bam
# 4    "".0416-0056.unmapped-both-read-and-mate.bam
# 5    "".0416-0062.unmapped-both-read-and-mate.bam
# 6    "".0515-0049.unmapped-both-read-and-mate.bam
# 7    "".0516-0003.unmapped-both-read-and-mate.bam
# 8    "".0516-0088.unmapped-both-read-and-mate.bam
# 9    "".0815-0037.unmapped-both-read-and-mate.bam
# 10   MUX10021.WHB6482.unmapped-both-read-and-mate.bam
# 11   MUX10021.WHB6482.unmapped-both-read-and-mate.qsort.bam
# 12   MUX10033.WHB6552.unmapped-both-read-and-mate.bam
# 13   MUX10033.WHB6552.unmapped-both-read-and-mate.qsort.bam
# 14   MUX10046.WHB7574.unmapped-both-read-and-mate.bam
# 15   MUX10046.WHB7574.unmapped-both-read-and-mate.qsort.bam
# 16   MUX10053.WHB7618.unmapped-both-read-and-mate.bam
# 17   MUX10053.WHB7618.unmapped-both-read-and-mate.qsort.bam
# 18   MUX10080.WHB6828.unmapped-both-read-and-mate.bam
# 19   MUX10080.WHB6828.unmapped-both-read-and-mate.qsort.bam
# 20   MUX10092.WHB6865.unmapped-both-read-and-mate.bam
# 21   MUX10092.WHB6865.unmapped-both-read-and-mate.qsort.bam
# 22   MUX10112.WHB6959.unmapped-both-read-and-mate.bam
# 23   MUX10112.WHB6959.unmapped-both-read-and-mate.qsort.bam
# 24   MUX10121.WHB7016.unmapped-both-read-and-mate.bam
# 25   MUX10121.WHB7016.unmapped-both-read-and-mate.qsort.bam
# 26   MUX10128.WHB7048.unmapped-both-read-and-mate.bam
# 27   MUX10128.WHB7048.unmapped-both-read-and-mate.qsort.bam
# 28   MUX10138.WHB7064.unmapped-both-read-and-mate.bam
# 29   MUX10138.WHB7064.unmapped-both-read-and-mate.qsort.bam
# 30   MUX10143.WHB6703.unmapped-both-read-and-mate.bam
# ⋮    ⋮
# 3790 MUX9707.WHB10062.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3791 MUX9707.WHB10062.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3792 MUX9711.WHB8836.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3793 MUX9711.WHB8836.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3794 MUX9774.WHB10155.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3795 MUX9774.WHB10155.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3796 MUX9801.WHB10244.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3797 MUX9801.WHB10244.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3798 MUX9808.WHB10470.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3799 MUX9808.WHB10470.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3800 MUX9812.WHB9453.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3801 MUX9812.WHB9453.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3802 MUX9813.WHB9715.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3803 MUX9813.WHB9715.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3804 MUX9829.WHB10417.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3805 MUX9829.WHB10417.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3806 MUX9834.WHB10436.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3807 MUX9834.WHB10436.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3808 MUX9841.WHB10082.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3809 MUX9841.WHB10082.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3810 MUX9844.WHB10100.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3811 MUX9844.WHB10100.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3812 MUX9870.WHB10342.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3813 MUX9870.WHB10342.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3814 MUX9933.WHB10598.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3815 MUX9933.WHB10598.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3816 MUX9982.WHB6405.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3817 MUX9982.WHB6405.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3818 MUX9989.WHB6241.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 3819 MUX9989.WHB6241.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
#      n_reads
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   NA
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   NA
# 24   NA
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 3790  4035
# 3791  4035
# 3792  9520
# 3793  9520
# 3794  2576
# 3795  2576
# 3796  3139
# 3797  3139
# 3798  5756
# 3799  5756
# 3800 12672
# 3801 12672
# 3802  3255
# 3803  3255
# 3804  3488
# 3805  3488
# 3806 16108
# 3807 16108
# 3808  2226
# 3809  2226
# 3810  2427
# 3811  2427
# 3812  6304
# 3813  6304
# 3814  5876
# 3815  5876
# 3816  2772
# 3817  2772
# 3818  2927
# 3819  2927

# %% [markdown]
# ### Files that failed CRAM to fastq extraction
# These files do not have any reads/mates that are unmapped.

# %%
for (i in c("01_bam", "01_fastq", "02_fastq", "03_fastq", "04_fastq")) {
    n <- df %>%
        filter(!is.na(step_name)) %>% # Omit entries of directories
        filter(step_name == i) %>%
        filter(file_size != 0) %>%
        nrow()
    print(paste0(i, ": ", n))
    }
# Out:
# [1] "01_bam: 382"
# [1] "01_fastq: 382"
# [1] "02_fastq: 382"
# [1] "03_fastq: 382"
# [1] "04_fastq: 382"

# %% [markdown]
# ### Plot read count distributions

# %%
df %>%
    filter(grepl("01|02|03|04", step_name),
           n_reads != 0) %>%
    mutate(step_name = case_when(step_name == "01_fastq" ~ "01_raw",
                                 step_name == "02_fastq" ~ "02_trim",
                                 step_name == "03_fastq" ~ "03_filter",
                                 step_name == "04_fastq" ~ "04_low_complexity"),
           n_reads = log(n_reads, base = 10)) %>%
    filter(!grepl("04", step_name)) %>%
    ggplot(aes(x = n_reads, fill = step_name)) +
        geom_density(alpha = 0.4) +
        scale_fill_discrete() +
        labs(x = "lg(Read Count)", y = "Density")
# Out:
# plot without title
