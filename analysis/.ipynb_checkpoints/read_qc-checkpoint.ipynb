# %% [markdown]
# # QC for pre-processing steps

# %%
setwd("/home/projects/14001280/PROJECTS/blood_microbiome/")
require(tidyverse)
require(ggplot2)
require(data.table)
# Out:
# Loading required package: tidyverse
#
# Warning message:
# “Your system is mis-configured: ‘/etc/localtime’ is not a symlink”
# Warning message:
# “It is strongly recommended to set envionment variable TZ to ‘Asia/Singapore’ (or equivalent)”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: ShortRead
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: BiocParallel
#
# Loading required package: Biostrings
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:base’:
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: XVector
#
#
# Attaching package: ‘XVector’
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: Rsamtools
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomicAlignments
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘GenomicAlignments’
#
#
# The following object is masked from ‘package:data.table’:
#
#     last
#
#
# The following object is masked from ‘package:dplyr’:
#
#     last
#
#
#
# Attaching package: ‘ShortRead’
#
#
# The following object is masked from ‘package:data.table’:
#
#     tables
#
#
# The following object is masked from ‘package:dplyr’:
#
#     id
#
#
# The following object is masked from ‘package:purrr’:
#
#     compose
#
#
# The following object is masked from ‘package:tibble’:
#
#     view

# %%
meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv")

# %%
head(meta)
# Out:
#   npm_research_id multiplex_pool_id supplier_id gis_internal_sample_id
# 1 WHB10000        MUX9693           00358       HELIOS_00358_1
# 2 WHB10001        MUX9693           00359       HELIOS_00359_1
# 3 WHB10002        MUX9695           00360       HELIOS_00360_1
# 4 WHB10003        MUX9694           00361       HELIOS_00361_1
# 5 WHB10005        MUX9694           00363       HELIOS_00363_1
# 6 WHB10006        MUX9694           00364       HELIOS_00364_1
#   site_supplying_sample year_of_birth supplied_gender self_reported_ethnicity
# 1 HELIOS                1982          F               Chinese
# 2 HELIOS                1979          F               Chinese
# 3 HELIOS                1970          F               Chinese
# 4 HELIOS                1969          M               Chinese
# 5 HELIOS                1959          F               Chinese
# 6 HELIOS                1955          F               Chinese
#   extraction_kit                                 date_of_dna_extraction ⋯
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 2 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 3 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 4 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 5 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
# 6 abGENIX Whole Blood Genomic DNA Extraction Kit 6/6/2019               ⋯
#   supplied_and_computed_ethinicity_match
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   sop_agreement_for_coverage_14/28_for_15x/30x sample_life_cycle current
# 1 Y                                            HELIOS VCF        Y
# 2 Y                                            HELIOS VCF        Y
# 3 N                                            HELIOS VCF        Y
# 4 Y                                            HELIOS VCF        Y
# 5 N                                            HELIOS VCF        Y
# 6 Y                                            HELIOS VCF        Y
#   source_cohort originalsupplierid duplicateinfo duplicate duplicatepair
# 1 HELIOS        00358                            PASS
# 2 HELIOS        00359                            PASS
# 3 HELIOS        00360                            PASS
# 4 HELIOS        00361                            PASS
# 5 HELIOS        00363                            PASS
# 6 HELIOS        00364                            PASS
#   removalrequestedbysupplier
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %% [markdown]
# ### Get intermediate file directories for all pre-processing steps

# %%
steps <- list.dirs("data/temp_files")

# %% [markdown]
# ### Iterate through preprocessing step directories and through fastq/bam/files

# %%
df <- tibble()

for (step in steps) {
#     step <- steps[3]
    if (grepl("_fastq|_bam", step)) {
        step_name <- strsplit(step, "/")
        step_name <- unlist(step_name)[3]
        file_names <- list.files(step)
        print(paste("pre-processing step:", step))

        for (file in file_names) {
    #         file <- file_names[40]
            file_path <- paste0(step, "/", file)

            # Get file size
            file_size <- file.size(file_path)
            npm_research_id <- strsplit(file, "\\.")
            npm_research_id <- unlist(npm_research_id)[2]

            # Get no. of reads
            if (grepl(".fastq", file_path)) {
                n_reads <- countLines(file_path) / 4
            } else {
                n_reads <- NA
            }

            morsel <- tibble(step_name = step_name, 
                             npm_research_id = npm_research_id,
                             file_size = file_size, 
                             file_name = file, 
                             n_reads = n_reads)

            df <- df %>% bind_rows(morsel)

        }
    }
}

df
# Out:
# [1] "pre-processing step: data/temp_files/01_bam"
# [1] "pre-processing step: data/temp_files/01_fastq"
# [1] "pre-processing step: data/temp_files/02_fastq"
# [1] "pre-processing step: data/temp_files/03_fastq"
# [1] "pre-processing step: data/temp_files/04_fastq"
# [1] "pre-processing step: data/temp_files/05_fastq"
# [1] "pre-processing step: data/temp_files/06_unclassified_fastq"
#      step_name             npm_research_id file_size
# 1    01_bam                1216-0079                0
# 2    01_bam                SSM010                   0
# 3    01_bam                SSM019                   0
# 4    01_bam                SSM031                   0
# 5    01_bam                SSM036                   0
# 6    01_bam                SSM050                   0
# 7    01_bam                SSM079                   0
# 8    01_bam                SSM080                   0
# 9    01_bam                SSM081                   0
# 10   01_bam                SSM082                   0
# 11   01_bam                SSM083                   0
# 12   01_bam                WHB7283          785680669
# 13   01_bam                WHB7283          161322158
# 14   01_bam                WHB7804          359459417
# 15   01_bam                WHB7804           86347535
# 16   01_bam                WHB7859          986678372
# 17   01_bam                WHB7859          216600179
# 18   01_bam                WHB7936         1445023291
# 19   01_bam                WHB7936          324128389
# 20   01_bam                WHB8070          678495276
# 21   01_bam                WHB8070          134660183
# 22   01_bam                WHB8286          800843938
# 23   01_bam                WHB8286          137629470
# 24   01_bam                WHB8421           63773012
# 25   01_bam                WHB8421           20144799
# 26   01_bam                WHB7981          589839513
# 27   01_bam                WHB7981          124371522
# 28   01_bam                WHB8529          194293973
# 29   01_bam                WHB8529           46383905
# 30   01_bam                WHH563            63495202
# ⋮    ⋮                     ⋮               ⋮
# 1072 06_unclassified_fastq WHB4441         1537926
# 1073 06_unclassified_fastq WHB4441         1537906
# 1074 06_unclassified_fastq WHB4499         1423011
# 1075 06_unclassified_fastq WHB4499         1421665
# 1076 06_unclassified_fastq WHB4586         2661516
# 1077 06_unclassified_fastq WHB4586         2659886
# 1078 06_unclassified_fastq WHB4724         1019061
# 1079 06_unclassified_fastq WHB4724         1018669
# 1080 06_unclassified_fastq WHB6108         1654884
# 1081 06_unclassified_fastq WHB6108         1654512
# 1082 06_unclassified_fastq WHB9368         2702651
# 1083 06_unclassified_fastq WHB9368         2701743
# 1084 06_unclassified_fastq WHB9395         1039307
# 1085 06_unclassified_fastq WHB9395         1039011
# 1086 06_unclassified_fastq WHB9484         1769187
# 1087 06_unclassified_fastq WHB9484         1768703
# 1088 06_unclassified_fastq WHB9488         6065619
# 1089 06_unclassified_fastq WHB9488         6064655
# 1090 06_unclassified_fastq WHB9637         2030293
# 1091 06_unclassified_fastq WHB9637         2029975
# 1092 06_unclassified_fastq WHB9736         1978872
# 1093 06_unclassified_fastq WHB9736         1978658
# 1094 06_unclassified_fastq WHB9818         3196794
# 1095 06_unclassified_fastq WHB9818         3196202
# 1096 06_unclassified_fastq WHB10411        1246068
# 1097 06_unclassified_fastq WHB10411        1245974
# 1098 06_unclassified_fastq WHB10415        1406402
# 1099 06_unclassified_fastq WHB10415        1406180
# 1100 06_unclassified_fastq WHB7715          649974
# 1101 06_unclassified_fastq WHB7715          649872
#      file_name
# 1    "".1216-0079.unmapped-both-read-and-mate.bam
# 2    "".SSM010.unmapped-both-read-and-mate.bam
# 3    "".SSM019.unmapped-both-read-and-mate.bam
# 4    "".SSM031.unmapped-both-read-and-mate.bam
# 5    "".SSM036.unmapped-both-read-and-mate.bam
# 6    "".SSM050.unmapped-both-read-and-mate.bam
# 7    "".SSM079.unmapped-both-read-and-mate.bam
# 8    "".SSM080.unmapped-both-read-and-mate.bam
# 9    "".SSM081.unmapped-both-read-and-mate.bam
# 10   "".SSM082.unmapped-both-read-and-mate.bam
# 11   "".SSM083.unmapped-both-read-and-mate.bam
# 12   MUX10202.WHB7283.unmapped-both-read-and-mate.bam
# 13   MUX10202.WHB7283.unmapped-both-read-and-mate.qsort.bam
# 14   MUX10299.WHB7804.unmapped-both-read-and-mate.bam
# 15   MUX10299.WHB7804.unmapped-both-read-and-mate.qsort.bam
# 16   MUX10317.WHB7859.unmapped-both-read-and-mate.bam
# 17   MUX10317.WHB7859.unmapped-both-read-and-mate.qsort.bam
# 18   MUX10334.WHB7936.unmapped-both-read-and-mate.bam
# 19   MUX10334.WHB7936.unmapped-both-read-and-mate.qsort.bam
# 20   MUX10360.WHB8070.unmapped-both-read-and-mate.bam
# 21   MUX10360.WHB8070.unmapped-both-read-and-mate.qsort.bam
# 22   MUX10398.WHB8286.unmapped-both-read-and-mate.bam
# 23   MUX10398.WHB8286.unmapped-both-read-and-mate.qsort.bam
# 24   MUX10432.WHB8421.unmapped-both-read-and-mate.bam
# 25   MUX10432.WHB8421.unmapped-both-read-and-mate.qsort.bam
# 26   MUX10571.WHB7981.unmapped-both-read-and-mate.bam
# 27   MUX10571.WHB7981.unmapped-both-read-and-mate.qsort.bam
# 28   MUX10761.WHB8529.unmapped-both-read-and-mate.bam
# 29   MUX10761.WHB8529.unmapped-both-read-and-mate.qsort.bam
# 30   MUX3316.WHH563.unmapped-both-read-and-mate.bam
# ⋮    ⋮
# 1072 MUX9155.WHB4441.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1073 MUX9155.WHB4441.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1074 MUX9197.WHB4499.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1075 MUX9197.WHB4499.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1076 MUX9216.WHB4586.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1077 MUX9216.WHB4586.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1078 MUX9265.WHB4724.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1079 MUX9265.WHB4724.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1080 MUX9366.WHB6108.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1081 MUX9366.WHB6108.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1082 MUX9544.WHB9368.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1083 MUX9544.WHB9368.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1084 MUX9549.WHB9395.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1085 MUX9549.WHB9395.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1086 MUX9567.WHB9484.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1087 MUX9567.WHB9484.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1088 MUX9587.WHB9488.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1089 MUX9587.WHB9488.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1090 MUX9611.WHB9637.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1091 MUX9611.WHB9637.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1092 MUX9629.WHB9736.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1093 MUX9629.WHB9736.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1094 MUX9657.WHB9818.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1095 MUX9657.WHB9818.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1096 MUX9829.WHB10411.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1097 MUX9829.WHB10411.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1098 MUX9830.WHB10415.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1099 MUX9830.WHB10415.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1100 MUX9964.WHB7715.unmapped-both-read-and-mate._1.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
# 1101 MUX9964.WHB7715.unmapped-both-read-and-mate._2.trimmed.filtered.low_complexity.decontaminated.unclassified.fastq
#      n_reads
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    NA
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   NA
# 14   NA
# 15   NA
# 16   NA
# 17   NA
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   NA
# 24   NA
# 25   NA
# 26   NA
# 27   NA
# 28   NA
# 29   NA
# 30   NA
# ⋮    ⋮
# 1072  4455
# 1073  4455
# 1074  4113
# 1075  4113
# 1076  7672
# 1077  7672
# 1078  2979
# 1079  2979
# 1080  4761
# 1081  4761
# 1082  7772
# 1083  7772
# 1084  2996
# 1085  2996
# 1086  5094
# 1087  5094
# 1088 17427
# 1089 17427
# 1090  5840
# 1091  5840
# 1092  5693
# 1093  5693
# 1094  9192
# 1095  9192
# 1096  3593
# 1097  3593
# 1098  4049
# 1099  4049
# 1100  1893
# 1101  1893

# %% [markdown]
# ### Files that failed CRAM to fastq extraction
# These files do not have any reads/mates that are unmapped.

# %%
df %>%
    filter(!is.na(step_name)) %>% # Omit entries of directories
    filter(step_name == "01_bam") %>%
    filter(file_size == 0) %>%
    nrow()
# Out:
# [1] 31

# %% [markdown]
# ### Plot read count distributions

# %%
df %>%
    filter(grepl("01|02|03|04", step_name),
           n_reads != 0) %>%
    mutate(step_name = case_when(step_name == "01_fastq" ~ "01_raw",
                                 step_name == "02_fastq" ~ "02_trim",
                                 step_name == "03_fastq" ~ "03_filter",
                                 step_name == "04_fastq" ~ "04_low_complexity"),
           n_reads = log(n_reads, base = 10)) %>%
    ggplot(aes(x = n_reads, fill = step_name)) +
        geom_density(alpha = 0.4) +
        scale_fill_discrete() +
        labs(x = "lg(Read Count)", y = "Density")
# Out:
# plot without title
