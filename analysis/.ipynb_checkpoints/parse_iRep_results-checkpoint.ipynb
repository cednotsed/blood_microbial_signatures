# %% [markdown]
# # iRep (bPTR) and coverage breadth analysis

# %%
rm(list = ls())
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require("Rsamtools")
require(Biostrings)
require(tidyverse)
require(data.table)
require(foreach)
require(doParallel)
registerDoParallel(cores = 10)
# Out:
# Loading required package: Rsamtools
#
# Loading required package: GenomeInfoDb
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks Biostrings::collapse(), IRanges::collapse()
# ✖ dplyr::combine()    masks BiocGenerics::combine()
# ✖ purrr::compact()    masks XVector::compact()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::slice()      masks XVector::slice(), IRanges::slice()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: doParallel
#
# Loading required package: iterators

# %%
species_df <- fread("results/decontamination/read_matrix.raw.zeroed.csv")

# %%
files <- list.files("results/irep_analysis/raw_output/irep_out", full.names = T)
files <- files[grepl(".tsv", files)]

morsels <- foreach(file = files) %do% {
    temp_df <- read.csv(file, sep = "\t", check.names = F)
    colnames(temp_df)[1] <- "ref_path"
    temp_df %>% 
        mutate(across(c(4:ncol(temp_df)), function(x) (as.numeric(ifelse(x == "n/a", NA, x)))),
               across(c(1:3), as.character)) %>%
        pivot_longer(!all_of(c("ref_path", "ORI", "TER")), names_to = "prefix", values_to = "bPTR") %>%
        separate(ref_path, sep = "/", into = c(rep(NA, 11), "file_name")) %>%
        separate(file_name, sep = "_", into = c("genus", "species", "suffix1", "suffix2"), remove = F) %>%
        separate(prefix, into = c(rep(NA, 6), "id"), sep = "/") %>%
        separate(id, into = c("npm_research_id"), sep = "_") %>%
        mutate(prefix = gsub(".fasta", "", file_name))
}

irep_df <- bind_rows(morsels)
# Out:
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 4 rows [1, 2, 3, 4].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 3 rows [1, 2, 3].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 3 rows [1, 2, 3].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”

# %% [markdown]
# ## Parse coverage breadth

# %%
irep_df
# Out:
#     file_name                                         genus
# 1   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 2   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 3   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 4   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 5   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 6   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 7   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 8   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 9   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 10  Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 11  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 12  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 13  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 14  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 15  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 16  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 17  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 18  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 19  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 20  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 21  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 22  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 23  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 24  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 25  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 26  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 27  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 28  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 29  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 30  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# ⋮   ⋮                                                 ⋮
# 124 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 125 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 126 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 127 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 128 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 129 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 130 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 131 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 132 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 133 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 134 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 135 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 136 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 137 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 138 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 139 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 140 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 141 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 142 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 143 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 144 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 145 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 146 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 147 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 148 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 149 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 150 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 151 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 152 Torque_teno_virus_6_NC_014094.1.fasta             Torque
# 153 Torque_teno_virus_6_NC_014094.1.fasta             Torque
#     species        suffix1 suffix2              ORI       TER
# 1   xylosoxidans   NZ      CP043820.1.fasta     0         0
# 2   xylosoxidans   NZ      CP043820.1.fasta     0         0
# 3   xylosoxidans   NZ      CP043820.1.fasta     0         0
# 4   xylosoxidans   NZ      CP043820.1.fasta     0         0
# 5   xylosoxidans   NZ      CP043820.1.fasta     0         0
# 6   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227
# 7   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227
# 8   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227
# 9   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227
# 10  baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227
# 11  faecalis       NZ      CP013119.1.fasta     0         0
# 12  faecalis       NZ      CP013119.1.fasta     0         0
# 13  faecalis       NZ      CP013119.1.fasta     0         0
# 14  faecalis       NZ      CP013119.1.fasta     0         0
# 15  faecalis       NZ      CP013119.1.fasta     0         0
# 16  oryzae         NC      036435.1.fasta       0         0
# 17  oryzae         NC      036435.1.fasta       0         0
# 18  oryzae         NC      036435.1.fasta       0         0
# 19  oryzae         NC      036435.1.fasta       0         0
# 20  oryzae         NC      036435.1.fasta       0         0
# 21  segmentosum    NZ      LR134408.1.fasta     0         0
# 22  segmentosum    NZ      LR134408.1.fasta     0         0
# 23  segmentosum    NZ      LR134408.1.fasta     0         0
# 24  segmentosum    NZ      LR134408.1.fasta     0         0
# 25  segmentosum    NZ      LR134408.1.fasta     0         0
# 26  metallidurans  NZ      FYAX01000013.1.fasta 0         0
# 27  metallidurans  NZ      FYAX01000013.1.fasta 0         0
# 28  metallidurans  NZ      FYAX01000013.1.fasta 0         0
# 29  metallidurans  NZ      FYAX01000013.1.fasta 0         0
# 30  metallidurans  NZ      FYAX01000013.1.fasta 0         0
# ⋮   ⋮              ⋮       ⋮                    ⋮         ⋮
# 124 melaninogenica NC      014370.1.fasta       0         0
# 125 melaninogenica NC      014370.1.fasta       0         0
# 126 melaninogenica NC      014370.1.fasta       0         0
# 127 melaninogenica NC      014370.1.fasta       0         0
# 128 oral           taxon   299                  0         0
# 129 oral           taxon   299                  0         0
# 130 mendocina      NZ      CP013124.1.fasta     0         0
# 131 mendocina      NZ      CP013124.1.fasta     0         0
# 132 mendocina      NZ      CP013124.1.fasta     0         0
# 133 mendocina      NZ      CP013124.1.fasta     0         0
# 134 mendocina      NZ      CP013124.1.fasta     0         0
# 135 Tillamook      23      NZ                   240,832   888,370
# 136 Tillamook      23      NZ                   240,832   888,370
# 137 cohnii         NZ      UHDA01000001.1.fasta 0         0
# 138 cohnii         NZ      UHDA01000001.1.fasta 0         0
# 139 cohnii         NZ      UHDA01000001.1.fasta 0         0
# 140 cohnii         NZ      UHDA01000001.1.fasta 0         0
# 141 cohnii         NZ      UHDA01000001.1.fasta 0         0
# 142 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375
# 143 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375
# 144 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375
# 145 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375
# 146 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375
# 147 haemolyticus   NZ      CP013911.1.fasta     0         0
# 148 haemolyticus   NZ      CP013911.1.fasta     0         0
# 149 haemolyticus   NZ      CP013911.1.fasta     0         0
# 150 haemolyticus   NZ      CP013911.1.fasta     0         0
# 151 haemolyticus   NZ      CP013911.1.fasta     0         0
# 152 teno           virus   6                    0         0
# 153 teno           virus   6                    0         0
#     npm_research_id bPTR     prefix
# 1   1116-0023             NA Achromobacter_xylosoxidans_NZ_CP043820.1
# 2   WHB3658               NA Achromobacter_xylosoxidans_NZ_CP043820.1
# 3   WHB3674               NA Achromobacter_xylosoxidans_NZ_CP043820.1
# 4   WHB3686               NA Achromobacter_xylosoxidans_NZ_CP043820.1
# 5   WHB3734               NA Achromobacter_xylosoxidans_NZ_CP043820.1
# 6   0116-0053       1.896385 Acinetobacter_baumannii_NZ_CP043953.1
# 7   WHB4240               NA Acinetobacter_baumannii_NZ_CP043953.1
# 8   WHB4251               NA Acinetobacter_baumannii_NZ_CP043953.1
# 9   WHB4438               NA Acinetobacter_baumannii_NZ_CP043953.1
# 10  WHB4828               NA Acinetobacter_baumannii_NZ_CP043953.1
# 11  WHB9245               NA Alcaligenes_faecalis_NZ_CP013119.1
# 12  WHB9246               NA Alcaligenes_faecalis_NZ_CP013119.1
# 13  WHB9270               NA Alcaligenes_faecalis_NZ_CP013119.1
# 14  WHB9282               NA Alcaligenes_faecalis_NZ_CP013119.1
# 15  WHB9317               NA Alcaligenes_faecalis_NZ_CP013119.1
# 16  WHB3883               NA Aspergillus_oryzae_NC_036435.1
# 17  WHB4048               NA Aspergillus_oryzae_NC_036435.1
# 18  WHB4056               NA Aspergillus_oryzae_NC_036435.1
# 19  WHB4130               NA Aspergillus_oryzae_NC_036435.1
# 20  WHH1822               NA Aspergillus_oryzae_NC_036435.1
# 21  WHB6459               NA Corynebacterium_segmentosum_NZ_LR134408.1
# 22  WHB6776               NA Corynebacterium_segmentosum_NZ_LR134408.1
# 23  WHB6849               NA Corynebacterium_segmentosum_NZ_LR134408.1
# 24  WHB8186               NA Corynebacterium_segmentosum_NZ_LR134408.1
# 25  WHB8568               NA Corynebacterium_segmentosum_NZ_LR134408.1
# 26  WHB6155               NA Cupriavidus_metallidurans_NZ_FYAX01000013.1
# 27  WHB9217               NA Cupriavidus_metallidurans_NZ_FYAX01000013.1
# 28  WHB9583               NA Cupriavidus_metallidurans_NZ_FYAX01000013.1
# 29  WHB9649               NA Cupriavidus_metallidurans_NZ_FYAX01000013.1
# 30  WHB9882               NA Cupriavidus_metallidurans_NZ_FYAX01000013.1
# ⋮   ⋮               ⋮        ⋮
# 124 WHB3939               NA Prevotella_melaninogenica_NC_014370.1
# 125 WHB5008               NA Prevotella_melaninogenica_NC_014370.1
# 126 WHB8397               NA Prevotella_melaninogenica_NC_014370.1
# 127 WHB9179               NA Prevotella_melaninogenica_NC_014370.1
# 128 WHB4373               NA Prevotella_oral_taxon_299_NC_022124.1
# 129 WHB9179               NA Prevotella_oral_taxon_299_NC_022124.1
# 130 0415-0080             NA Pseudomonas_mendocina_NZ_CP013124.1
# 131 0715-0061             NA Pseudomonas_mendocina_NZ_CP013124.1
# 132 0816-0014             NA Pseudomonas_mendocina_NZ_CP013124.1
# 133 WHB3477               NA Pseudomonas_mendocina_NZ_CP013124.1
# 134 WHB3479               NA Pseudomonas_mendocina_NZ_CP013124.1
# 135 WHB6775               NA Rickettsia_Tillamook_23_NZ_CP060138.1
# 136 WHB9978         1.346660 Rickettsia_Tillamook_23_NZ_CP060138.1
# 137 0416-0021             NA Staphylococcus_cohnii_NZ_UHDA01000001.1
# 138 0416-0024             NA Staphylococcus_cohnii_NZ_UHDA01000001.1
# 139 0416-0026             NA Staphylococcus_cohnii_NZ_UHDA01000001.1
# 140 0416-0031             NA Staphylococcus_cohnii_NZ_UHDA01000001.1
# 141 0416-0032             NA Staphylococcus_cohnii_NZ_UHDA01000001.1
# 142 WHB4219               NA Staphylococcus_epidermidis_NZ_CP035288.1
# 143 WHB4398               NA Staphylococcus_epidermidis_NZ_CP035288.1
# 144 WHB6459         1.566844 Staphylococcus_epidermidis_NZ_CP035288.1
# 145 WHB6651               NA Staphylococcus_epidermidis_NZ_CP035288.1
# 146 WHB8186               NA Staphylococcus_epidermidis_NZ_CP035288.1
# 147 0416-0024             NA Staphylococcus_haemolyticus_NZ_CP013911.1
# 148 0416-0026             NA Staphylococcus_haemolyticus_NZ_CP013911.1
# 149 0416-0027             NA Staphylococcus_haemolyticus_NZ_CP013911.1
# 150 0416-0031             NA Staphylococcus_haemolyticus_NZ_CP013911.1
# 151 0715-0059             NA Staphylococcus_haemolyticus_NZ_CP013911.1
# 152 WHB7619               NA Torque_teno_virus_6_NC_014094.1
# 153 WHB9685               NA Torque_teno_virus_6_NC_014094.1

# %%
bam_path <- "results/irep_analysis/raw_output/bam_files"
ref_path <- "data/irep_data/genome_references"
prefixes <- list.files(ref_path, ".fasta", full.names = F)
prefixes <- gsub(".fasta", "", prefixes)
prefixes
# Out:
#  [1] "Achromobacter_xylosoxidans_NZ_CP043820.1"
#  [2] "Acinetobacter_baumannii_NZ_CP043953.1"
#  [3] "Alcaligenes_faecalis_NZ_CP013119.1"
#  [4] "Aspergillus_oryzae_NC_036435.1"
#  [5] "Corynebacterium_segmentosum_NZ_LR134408.1"
#  [6] "Cupriavidus_metallidurans_NZ_FYAX01000013.1"
#  [7] "Cutibacterium_acnes_NC_021085.1"
#  [8] "Fannyhessea_vaginae_NZ_UFSV01000001.1"
#  [9] "Fusobacterium_nucleatum_NZ_LN831027.1"
# [10] "Fusobacterium_pseudoperiodonticum_NZ_CP024702.1"
# [11] "Gardnerella_vaginalis_NZ_PKJK01000001.1"
# [12] "Haemophilus_parainfluenzae_NZ_GL872339.1"
# [13] "Hepatitis_B_virus_genB_JX661488.1"
# [14] "Human_betaherpesvirus_6A_NC_001664.4"
# [15] "Human_betaherpesvirus_6B_NC_000898.1"
# [16] "Human_mastadenovirus_C_NC_001405.1"
# [17] "Lactobacillus_crispatus_NZ_CP039266.1"
# [18] "Malassezia_restricta_NC_040193.1"
# [19] "Moraxella_osloensis_NZ_CP014234.1"
# [20] "Neisseria_flavescens_NZ_CP039886.1"
# [21] "Neisseria_mucosa_NZ_UGRT01000001.1"
# [22] "Neisseria_subflava_NZ_CP039887.1"
# [23] "Prevotella_melaninogenica_NC_014370.1"
# [24] "Prevotella_oral_taxon_299_NC_022124.1"
# [25] "Pseudomonas_mendocina_NZ_CP013124.1"
# [26] "Rickettsia_Tillamook_23_NZ_CP060138.1"
# [27] "Staphylococcus_cohnii_NZ_UHDA01000001.1"
# [28] "Staphylococcus_epidermidis_NZ_CP035288.1"
# [29] "Staphylococcus_haemolyticus_NZ_CP013911.1"
# [30] "Torque_teno_virus_6_NC_014094.1"

# %%
morsels <- foreach (i = seq(length(prefixes))) %dopar% {
    prefix <- prefixes[i]
    bams <- list.files(str_glue("{bam_path}/{prefix}"))
    bams <- bams[!grepl(".bai", bams)]

    crumbs <- foreach (j = seq(length(bams))) %do% {
        bam <- bams[j]
        id <- str_split(bam, "_")[[1]][1]
        ref <- readDNAStringSet(str_glue("{ref_path}/{prefixes[i]}.fasta"))
        ref_length <- width(ref)
        params <- PileupParam(distinguish_strands = F, distinguish_nucleotides = F)
        pile_df <- pileup(str_glue("{bam_path}/{prefix}/{bam}"), pileupParam = params)
        
        n_covered1 <- pile_df %>%
            filter(count >= 1) %>%
            nrow()
        
        n_covered5 <- pile_df %>%
            filter(count >= 5) %>%
            nrow()

        perc_covered1 <- n_covered1 / ref_length * 100
        perc_covered5 <- n_covered5 / ref_length * 100
        
        taxon <- str_split(prefix, "_")[[1]]
            read_count <- species_df %>% 
                filter(npm_research_id == id) %>%
                select(contains(taxon[1])) %>%
                select(contains(taxon[2])) %>%
                select(!contains("monkey"))

        if (ncol(read_count) > 1) {
            read_count <- read_count %>% 
                select(contains(taxon[3]))
            if (ncol(read_count) > 1) {
            read_count <- read_count %>% 
                select(contains(paste0(" ", taxon[4])))
            }
        }
        
        if (all(dim(read_count) == 1)) {
            read_count <- deframe(read_count)
        } else {
            read_count <- NA
        }
        
        return(tibble(prefix = prefix, 
                      npm_research_id = id,
                      pairs_assigned = read_count,
                      perc_covered1 = perc_covered1,
                      perc_covered5 = perc_covered5))
    }
    
    return(bind_rows(crumbs))
}

cov_df <- bind_rows(morsels)

# %%
# prefixes
# prefix <- "Hepatitis_B_virus_genB_JX661488.1"    
# id <- "WHB4594"
# taxon <- str_split(prefix, "_")[[1]]
#     read_count <- species_df %>% 
#         filter(npm_research_id == id) %>%
#         select(contains(taxon[1])) %>%
#         select(contains(taxon[2])) %>%
#         select(!contains("monkey"))
    
# #     if (ncol(read_count) > 1) {
# #         read_count <- read_count %>% 
# #             select(contains(taxon[3]))
# #         if (ncol(read_count) > 1) {
# #         read_count <- read_count %>% 
# #             select(contains(paste0(" ", taxon[4])))
# #         }
# #     }

# #     if (all(dim(read_count) == 1)) {
# #         read_count <- deframe(read_count)
# #     } else {
# #         read_count <- NA
# #     }

# read_count
# Out:
#   Hepatitis B virus
# 1 0

# %% [markdown]
# ### Merged results

# %%
mapping_df <- fread("results/irep_analysis/raw_output/mapping_read_counts.csv")
mapping_df %>% filter(grepl("Prevo", prefix))

# %%
merged_df <- cov_df %>%
    left_join(mapping_df) %>%
    left_join(irep_df) %>%
    relocate(pairs_mapped, .after = 3) %>%
    mutate(pairs_mapped = pairs_mapped / 2)

merged_df

fwrite(merged_df, "results/irep_analysis/coverage_irep_results.raw.csv")

# %%
merged_df %>% filter(grepl("oral", prefix))

# %%
ori_df <- merged_df %>%
    select(prefix, ORI, TER) %>%
    filter(ORI != "0" & TER != "0") %>%
    distinct()

# %%
summarised_df <- merged_df %>%
    group_by(prefix) %>%
    summarise(mean_perc_covered1 = mean(perc_covered1),
              mean_perc_covered5 = mean(perc_covered5),
              min_perc_covered1 = min(perc_covered1),
              max_perc_covered1 = max(perc_covered1),
              max_bPTR = max(bPTR, na.rm = T)) %>%
    mutate(max_bPTR = ifelse(max_bPTR == -Inf, NA, max_bPTR)) %>%
    left_join(ori_df) %>%
    separate(prefix, into = c("genus", "species", "suffix1", "suffix2"), sep = "_", remove = F) %>%
    mutate(taxa = ifelse(grepl("Torque", prefix), 
                         paste(genus, species, suffix1, suffix2), 
                         paste(genus, species, suffix1)), .before = 1) %>%
    mutate(taxa = gsub(" NZ| NC", "", taxa)) %>%
    mutate(taxa = gsub("Microbacterium", "Microbacterium sp.", taxa)) %>%
    mutate(taxa = gsub("Prevotella oral taxon", "Prevotella sp. oral taxon 299", taxa)) %>%
    mutate(taxa = gsub("Rickettsia", "Rickettsia sp.", taxa)) %>%
    select(-prefix, -genus, -species, -suffix1, -suffix2) %>%
    arrange(desc(mean_perc_covered1))


fwrite(summarised_df, "results/irep_analysis/coverage_irep_results.parsed.csv")

summarised_df
