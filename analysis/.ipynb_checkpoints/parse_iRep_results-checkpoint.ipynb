# %% [markdown]
# # iRep (bPTR) and coverage breadth analysis

# %%
rm(list = ls())
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require("Rsamtools")
require(Biostrings)
require(tidyverse)
require(data.table)
require(foreach)
require(doParallel)
require(ape)
registerDoParallel(cores = 10)
# Out:
# Loading required package: Rsamtools
#
# Loading required package: GenomeInfoDb
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks Biostrings::collapse(), IRanges::collapse()
# ✖ dplyr::combine()    masks BiocGenerics::combine()
# ✖ purrr::compact()    masks XVector::compact()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::slice()      masks XVector::slice(), IRanges::slice()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: ape
#
#
# Attaching package: ‘ape’
#
#
# The following object is masked from ‘package:Biostrings’:
#
#     complement

# %%
species_df <- fread("results/decontamination/read_matrix.raw.zeroed.csv")

# %%
files <- list.files("results/irep_analysis/raw_output/irep_out", full.names = T)
files <- files[grepl(".tsv", files)]

morsels <- foreach(file = files) %do% {
    temp_df <- read.csv(file, sep = "\t", check.names = F)
    colnames(temp_df)[1] <- "ref_path"
    temp_df %>% 
        mutate(across(c(4:ncol(temp_df)), function(x) (as.numeric(ifelse(x == "n/a", NA, x)))),
               across(c(1:3), as.character)) %>%
        pivot_longer(!all_of(c("ref_path", "ORI", "TER")), names_to = "prefix", values_to = "bPTR") %>%
        separate(ref_path, sep = "/", into = c(rep(NA, 11), "file_name")) %>%
        separate(file_name, sep = "_", into = c("genus", "species", "suffix1", "suffix2"), remove = F) %>%
        separate(prefix, into = c(rep(NA, 6), "id"), sep = "/") %>%
        separate(id, into = c("npm_research_id"), sep = "_") %>%
        mutate(prefix = gsub(".fasta", "", file_name))
}

irep_df <- bind_rows(morsels)
# Out:
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 4 rows [1, 2, 3, 4].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 3 rows [1, 2, 3].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 3 rows [1, 2, 3].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 5 rows [1, 2, 3, 4, 5].”
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 2 rows [1, 2].”
# Warning message:
# “Expected 1 pieces. Additional pieces discarded in 2 rows [1, 2].”

# %% [markdown]
# ## Parse coverage breadth

# %%
bam_path <- "results/irep_analysis/raw_output/bam_files"
ref_path <- "data/irep_data/genome_references"
ref_files <- list.files(ref_path, ".fasta", full.names = F)
prefixes <- gsub(".fasta", "", ref_files)
prefixes
# Out:
#  [1] "Achromobacter_xylosoxidans_NZ_CP043820.1"
#  [2] "Acinetobacter_baumannii_NZ_CP043953.1"
#  [3] "Alcaligenes_faecalis_NZ_CP013119.1"
#  [4] "Aspergillus_oryzae_NC_036435.1"
#  [5] "Corynebacterium_segmentosum_NZ_LR134408.1"
#  [6] "Cupriavidus_metallidurans_NZ_FYAX01000013.1"
#  [7] "Cutibacterium_acnes_NC_021085.1"
#  [8] "Fannyhessea_vaginae_NZ_UFSV01000001.1"
#  [9] "Fusobacterium_nucleatum_NZ_LN831027.1"
# [10] "Fusobacterium_pseudoperiodonticum_NZ_CP024702.1"
# [11] "Gardnerella_vaginalis_NZ_PKJK01000001.1"
# [12] "Haemophilus_parainfluenzae_NZ_GL872339.1"
# [13] "Hepatitis_B_virus_genB_JX661488.1"
# [14] "Human_betaherpesvirus_6A_NC_001664.4"
# [15] "Human_betaherpesvirus_6B_NC_000898.1"
# [16] "Human_mastadenovirus_C_NC_001405.1"
# [17] "Lactobacillus_crispatus_NZ_CP039266.1"
# [18] "Malassezia_restricta_NC_040193.1"
# [19] "Moraxella_osloensis_NZ_CP014234.1"
# [20] "Neisseria_flavescens_NZ_CP039886.1"
# [21] "Neisseria_mucosa_NZ_UGRT01000001.1"
# [22] "Neisseria_subflava_NZ_CP039887.1"
# [23] "Prevotella_melaninogenica_NC_014370.1"
# [24] "Prevotella_oral_taxon_299_NC_022124.1"
# [25] "Pseudomonas_mendocina_NZ_CP013124.1"
# [26] "Rickettsia_Tillamook_23_NZ_CP060138.1"
# [27] "Staphylococcus_cohnii_NZ_UHDA01000001.1"
# [28] "Staphylococcus_epidermidis_NZ_CP035288.1"
# [29] "Staphylococcus_haemolyticus_NZ_CP013911.1"
# [30] "Torque_teno_virus_6_NC_014094.1"

# %%
morsels <- foreach (i = seq(length(prefixes))) %dopar% {
    prefix <- prefixes[i]
    bams <- list.files(str_glue("{bam_path}/{prefix}"))
    bams <- bams[!grepl(".bai", bams)]

    crumbs <- foreach (j = seq(length(bams))) %do% {
        bam <- bams[j]
        id <- str_split(bam, "_")[[1]][1]
        ref <- readDNAStringSet(str_glue("{ref_path}/{prefixes[i]}.fasta"))
        ref_length <- width(ref)
        params <- PileupParam(distinguish_strands = F, distinguish_nucleotides = F)
        pile_df <- pileup(str_glue("{bam_path}/{prefix}/{bam}"), pileupParam = params)
        
        n_covered1 <- pile_df %>%
            filter(count >= 1) %>%
            nrow()
        
        n_covered5 <- pile_df %>%
            filter(count >= 5) %>%
            nrow()

        perc_covered1 <- n_covered1 / ref_length * 100
        perc_covered5 <- n_covered5 / ref_length * 100
        
        taxon <- str_split(prefix, "_")[[1]]
            read_count <- species_df %>% 
                filter(npm_research_id == id) %>%
                select(contains(taxon[1])) %>%
                select(contains(taxon[2])) %>%
                select(!contains("monkey"))

        if (ncol(read_count) > 1) {
            read_count <- read_count %>% 
                select(contains(taxon[3]))
            if (ncol(read_count) > 1) {
            read_count <- read_count %>% 
                select(contains(paste0(" ", taxon[4])))
            }
        }
        
        if (all(dim(read_count) == 1)) {
            read_count <- deframe(read_count)
        } else {
            read_count <- NA
        }
        
        return(tibble(prefix = prefix, 
                      npm_research_id = id,
                      pairs_assigned = read_count,
                      perc_covered1 = perc_covered1,
                      perc_covered5 = perc_covered5))
    }
    
    return(bind_rows(crumbs))
}

cov_df <- bind_rows(morsels)

# %% [markdown]
# ### Add number of human or microbial reads mapped

# %%
microbe_df <- fread("results/irep_analysis/raw_output/microbial_mapped_read_counts.csv") %>%
    rename(microbe_pairs_mapped = pairs_mapped)
human_df <- fread("results/irep_analysis/raw_output/human_mapped_read_counts.csv") %>%
    rename(human_pairs_mapped = pairs_mapped)

# %% [markdown]
# ### Add microbe to human cell ratio
# Estimates from https://bmcresnotes.biomedcentral.com/articles/10.1186/s13104-019-4137-z/tables/2
# Leucocyte count from https://pubmed.ncbi.nlm.nih.gov/15782774/

# %%
human_length <- 6320012150
human_gc <- 40.89
leuco_per_ul <- 6750

# %%
ref_paths <- paste0(ref_path, "/", ref_files)

length_morsels <- foreach(prefix_name = prefixes) %do% {
    microbe_ref_path <- ref_paths[grepl(prefix_name, ref_paths)]
    microbe_ref <- read.FASTA(microbe_ref_path)
    microbe_length <- length(as.character(microbe_ref)[[1]])

    tibble(prefix = prefix_name, 
           microbe_length = microbe_length)
}

length_df <- bind_rows(length_morsels)

# %%
merged_df <- cov_df %>%
    left_join(microbe_df) %>%
    left_join(human_df %>% distinct(.keep_all = T)) %>%
    left_join(irep_df) %>%
    left_join(length_df) %>%
    relocate(microbe_pairs_mapped, human_pairs_mapped, .after = 3) %>%
    mutate(microbe_pairs_mapped = microbe_pairs_mapped / 2,
           human_pairs_mapped = human_pairs_mapped / 2) %>%
    mutate(microbe_count = (microbe_pairs_mapped / microbe_length) / (human_pairs_mapped / human_length) * leuco_per_ul) 

merged_df
# Out:
# Joining, by = c("prefix", "npm_research_id")
# Joining, by = "npm_research_id"
# Joining, by = c("prefix", "npm_research_id")
# Joining, by = "prefix"
#     prefix                                      npm_research_id pairs_assigned
# 1   Achromobacter_xylosoxidans_NZ_CP043820.1    1116-0023       430178
# 2   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3658         385855
# 3   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3674         459561
# 4   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3686         541795
# 5   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3734         688629
# 6   Acinetobacter_baumannii_NZ_CP043953.1       0116-0053         7673
# 7   Acinetobacter_baumannii_NZ_CP043953.1       WHB4240            168
# 8   Acinetobacter_baumannii_NZ_CP043953.1       WHB4251            183
# 9   Acinetobacter_baumannii_NZ_CP043953.1       WHB4438            379
# 10  Acinetobacter_baumannii_NZ_CP043953.1       WHB4828            190
# 11  Alcaligenes_faecalis_NZ_CP013119.1          WHB9245            982
# 12  Alcaligenes_faecalis_NZ_CP013119.1          WHB9246            896
# 13  Alcaligenes_faecalis_NZ_CP013119.1          WHB9270            996
# 14  Alcaligenes_faecalis_NZ_CP013119.1          WHB9282            766
# 15  Alcaligenes_faecalis_NZ_CP013119.1          WHB9317           1104
# 16  Aspergillus_oryzae_NC_036435.1              WHB3883             24
# 17  Aspergillus_oryzae_NC_036435.1              WHB4048             32
# 138     22               171579152          16.0863698    14.170040486
#     file_name                                         genus
# 1   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 2   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 3   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 4   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 5   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 6   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 7   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 8   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 9   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 10  Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 11  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 12  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 13  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 14  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 15  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 16  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 17  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 18  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 19  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 20  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 21  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 22  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 23  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 24  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 25  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 26  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 27  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 28  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 29  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 30  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# ⋮   ⋮                                                 ⋮
# 109 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 110 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 111 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 112 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 113 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 114 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 115 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 116 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 117 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 118 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 119 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 120 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 121 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 122 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 123 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 124 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 125 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 126 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 127 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 128 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 129 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 130 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 131 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 132 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 133 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 134 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 135 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 136 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 137 Torque_teno_virus_6_NC_014094.1.fasta             Torque
# 138 Torque_teno_virus_6_NC_014094.1.fasta             Torque
#     species        suffix1 suffix2              ORI       TER       bPTR
# 1   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 2   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 3   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 4   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 5   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 6   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227 1.896385
# 7   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 8   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 9   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 10  baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 11  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 12  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 13  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 14  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 15  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 16  oryzae         NC      036435.1.fasta       0         0               NA
# 17  oryzae         NC      036435.1.fasta       0         0               NA
# 18  oryzae         NC      036435.1.fasta       0         0               NA
# 19  oryzae         NC      036435.1.fasta       0         0               NA
# 20  oryzae         NC      036435.1.fasta       0         0               NA
# 21  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 22  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 23  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 24  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 25  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 26  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 27  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 28  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 29  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 30  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# ⋮   ⋮              ⋮       ⋮                    ⋮         ⋮         ⋮
# 109 melaninogenica NC      014370.1.fasta       0         0               NA
# 110 melaninogenica NC      014370.1.fasta       0         0               NA
# 111 melaninogenica NC      014370.1.fasta       0         0               NA
# 112 melaninogenica NC      014370.1.fasta       0         0               NA
# 113 oral           taxon   299                  0         0               NA
# 114 oral           taxon   299                  0         0               NA
# 115 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 116 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 117 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 118 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 119 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 120 Tillamook      23      NZ                   240,832   888,370         NA
# 121 Tillamook      23      NZ                   240,832   888,370   1.346660
# 122 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 123 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 124 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 125 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 126 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 127 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 128 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 129 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375 1.566844
# 130 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 131 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 132 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 133 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 134 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 135 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 136 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 137 teno           virus   6                    0         0               NA
# 138 teno           virus   6                    0         0               NA
#     microbe_length microbe_count
# 1   6402982        8.208410e+03
# 2   6402982        8.016719e+03
# 3   6402982        1.006331e+04
# 4   6402982        1.159937e+04
# 5   6402982        1.383176e+04
# 6   3972439        8.490606e+02
# 7   3972439        6.168933e+00
# 8   3972439        8.806120e+00
# 9   3972439        1.191050e+01
# 10  3972439        6.671090e+00
# 11  4233756        3.147800e+02
# 12  4233756        2.866889e+02
# 13  4233756        3.283332e+02
# 14  4233756        2.559892e+02
# 15  4233756        3.634384e+02
# 16  6520266        8.358461e-02
# 17  6520266        0.000000e+00
# 18  6520266        5.564388e-01
# 19  6520266        0.000000e+00
# 20  6520266        0.000000e+00
# 21  2373440        1.281144e+03
# 22  2373440        2.349839e+01
# 23  2373440        2.718599e+00
# 24  2373440        8.151247e+00
# 25  2373440        3.591426e+00
# 26  1219865        4.991215e+00
# 27  1219865        7.195421e+00
# 28  1219865        1.635871e+02
# 29  1219865        5.089812e+01
# 30  1219865        2.072968e+01
# ⋮   ⋮              ⋮
# 109 1796408        5.207783e+00
# 110 1796408        2.199103e+00
# 111 1796408        9.091555e+00
# 112 1796408        2.011119e+02
# 113  709850        4.037009e+00
# 114  709850        1.644861e+02
# 115 5120146        1.608426e+04
# 116 5120146        8.433911e+03
# 117 5120146        7.256389e+03
# 118 5120146        1.753857e+04
# 119 5120146        1.988941e+04
# 120 1438973        4.189249e+00
# 121 1438973        1.197889e+03
# 122 2666496        2.879700e-01
# 123 2666496        0.000000e+00
# 124 2666496        7.631791e-02
# 125 2666496        9.209316e-02
# 126 2666496        3.076552e-01
# 127 2466502        4.482955e+01
# 128 2466502        2.726678e+01
# 129 2466502        7.349293e+02
# 130 2466502        7.767734e+01
# 131 2466502        2.031801e+01
# 132 2549338        8.848055e-02
# 133 2549338        3.991260e-02
# 134 2549338        3.216969e-01
# 135 2549338        1.605424e-01
# 136 2549338        2.301288e-01
# 137    3705        4.477293e+03
# 138    3705        1.476358e+03

# %%
parsed_df <- merged_df %>% 
    left_join(ori_df)
parsed_df
fwrite(merged_df, "results/irep_analysis/coverage_irep_results.raw.csv")
# Out:
# Joining, by = c("prefix", "ORI", "TER")
#     prefix                                      npm_research_id pairs_assigned
# 1   Achromobacter_xylosoxidans_NZ_CP043820.1    1116-0023       430178
# 2   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3658         385855
# 3   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3674         459561
# 4   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3686         541795
# 5   Achromobacter_xylosoxidans_NZ_CP043820.1    WHB3734         688629
# 6   Acinetobacter_baumannii_NZ_CP043953.1       0116-0053         7673
# 7   Acinetobacter_baumannii_NZ_CP043953.1       WHB4240            168
# 8   Acinetobacter_baumannii_NZ_CP043953.1       WHB4251            183
# 9   Acinetobacter_baumannii_NZ_CP043953.1       WHB4438            379
# 10  Acinetobacter_baumannii_NZ_CP043953.1       WHB4828            190
# 11  Alcaligenes_faecalis_NZ_CP013119.1          WHB9245            982
# 12  Alcaligenes_faecalis_NZ_CP013119.1          WHB9246            896
# 13  Alcaligenes_faecalis_NZ_CP013119.1          WHB9270            996
# 14  Alcaligenes_faecalis_NZ_CP013119.1          WHB9282            766
# 15  Alcaligenes_faecalis_NZ_CP013119.1          WHB9317           1104
# 16  Aspergillus_oryzae_NC_036435.1              WHB3883             24
# 137     60               154301162          21.5924426    19.946018893
# 138     22               171579152          16.0863698    14.170040486
#     file_name                                         genus
# 1   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 2   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 3   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 4   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 5   Achromobacter_xylosoxidans_NZ_CP043820.1.fasta    Achromobacter
# 6   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 7   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 8   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 9   Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 10  Acinetobacter_baumannii_NZ_CP043953.1.fasta       Acinetobacter
# 11  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 12  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 13  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 14  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 15  Alcaligenes_faecalis_NZ_CP013119.1.fasta          Alcaligenes
# 16  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 17  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 18  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 19  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 20  Aspergillus_oryzae_NC_036435.1.fasta              Aspergillus
# 21  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 22  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 23  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 24  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 25  Corynebacterium_segmentosum_NZ_LR134408.1.fasta   Corynebacterium
# 26  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 27  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 28  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 29  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# 30  Cupriavidus_metallidurans_NZ_FYAX01000013.1.fasta Cupriavidus
# ⋮   ⋮                                                 ⋮
# 109 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 110 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 111 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 112 Prevotella_melaninogenica_NC_014370.1.fasta       Prevotella
# 113 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 114 Prevotella_oral_taxon_299_NC_022124.1.fasta       Prevotella
# 115 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 116 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 117 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 118 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 119 Pseudomonas_mendocina_NZ_CP013124.1.fasta         Pseudomonas
# 120 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 121 Rickettsia_Tillamook_23_NZ_CP060138.1.fasta       Rickettsia
# 122 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 123 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 124 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 125 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 126 Staphylococcus_cohnii_NZ_UHDA01000001.1.fasta     Staphylococcus
# 127 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 128 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 129 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 130 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 131 Staphylococcus_epidermidis_NZ_CP035288.1.fasta    Staphylococcus
# 132 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 133 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 134 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 135 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 136 Staphylococcus_haemolyticus_NZ_CP013911.1.fasta   Staphylococcus
# 137 Torque_teno_virus_6_NC_014094.1.fasta             Torque
# 138 Torque_teno_virus_6_NC_014094.1.fasta             Torque
#     species        suffix1 suffix2              ORI       TER       bPTR
# 1   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 2   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 3   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 4   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 5   xylosoxidans   NZ      CP043820.1.fasta     0         0               NA
# 6   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227 1.896385
# 7   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 8   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 9   baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 10  baumannii      NZ      CP043953.1.fasta     3,869,401 1,967,227       NA
# 11  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 12  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 13  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 14  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 15  faecalis       NZ      CP013119.1.fasta     0         0               NA
# 16  oryzae         NC      036435.1.fasta       0         0               NA
# 17  oryzae         NC      036435.1.fasta       0         0               NA
# 18  oryzae         NC      036435.1.fasta       0         0               NA
# 19  oryzae         NC      036435.1.fasta       0         0               NA
# 20  oryzae         NC      036435.1.fasta       0         0               NA
# 21  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 22  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 23  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 24  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 25  segmentosum    NZ      LR134408.1.fasta     0         0               NA
# 26  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 27  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 28  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 29  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# 30  metallidurans  NZ      FYAX01000013.1.fasta 0         0               NA
# ⋮   ⋮              ⋮       ⋮                    ⋮         ⋮         ⋮
# 109 melaninogenica NC      014370.1.fasta       0         0               NA
# 110 melaninogenica NC      014370.1.fasta       0         0               NA
# 111 melaninogenica NC      014370.1.fasta       0         0               NA
# 112 melaninogenica NC      014370.1.fasta       0         0               NA
# 113 oral           taxon   299                  0         0               NA
# 114 oral           taxon   299                  0         0               NA
# 115 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 116 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 117 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 118 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 119 mendocina      NZ      CP013124.1.fasta     0         0               NA
# 120 Tillamook      23      NZ                   240,832   888,370         NA
# 121 Tillamook      23      NZ                   240,832   888,370   1.346660
# 122 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 123 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 124 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 125 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 126 cohnii         NZ      UHDA01000001.1.fasta 0         0               NA
# 127 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 128 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 129 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375 1.566844
# 130 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 131 epidermidis    NZ      CP035288.1.fasta     237,449   1,347,375       NA
# 132 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 133 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 134 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 135 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 136 haemolyticus   NZ      CP013911.1.fasta     0         0               NA
# 137 teno           virus   6                    0         0               NA
# 138 teno           virus   6                    0         0               NA
#     microbe_length microbe_count
# 1   6402982        8.208410e+03
# 2   6402982        8.016719e+03
# 3   6402982        1.006331e+04
# 4   6402982        1.159937e+04
# 5   6402982        1.383176e+04
# 6   3972439        8.490606e+02
# 7   3972439        6.168933e+00
# 8   3972439        8.806120e+00
# 9   3972439        1.191050e+01
# 10  3972439        6.671090e+00
# 11  4233756        3.147800e+02
# 12  4233756        2.866889e+02
# 13  4233756        3.283332e+02
# 14  4233756        2.559892e+02
# 15  4233756        3.634384e+02
# 16  6520266        8.358461e-02
# 17  6520266        0.000000e+00
# 18  6520266        5.564388e-01
# 19  6520266        0.000000e+00
# 20  6520266        0.000000e+00
# 21  2373440        1.281144e+03
# 22  2373440        2.349839e+01
# 23  2373440        2.718599e+00
# 24  2373440        8.151247e+00
# 25  2373440        3.591426e+00
# 26  1219865        4.991215e+00
# 27  1219865        7.195421e+00
# 28  1219865        1.635871e+02
# 29  1219865        5.089812e+01
# 30  1219865        2.072968e+01
# ⋮   ⋮              ⋮
# 109 1796408        5.207783e+00
# 110 1796408        2.199103e+00
# 111 1796408        9.091555e+00
# 112 1796408        2.011119e+02
# 113  709850        4.037009e+00
# 114  709850        1.644861e+02
# 115 5120146        1.608426e+04
# 116 5120146        8.433911e+03
# 117 5120146        7.256389e+03
# 118 5120146        1.753857e+04
# 119 5120146        1.988941e+04
# 120 1438973        4.189249e+00
# 121 1438973        1.197889e+03
# 122 2666496        2.879700e-01
# 123 2666496        0.000000e+00
# 124 2666496        7.631791e-02
# 125 2666496        9.209316e-02
# 126 2666496        3.076552e-01
# 127 2466502        4.482955e+01
# 128 2466502        2.726678e+01
# 129 2466502        7.349293e+02
# 130 2466502        7.767734e+01
# 131 2466502        2.031801e+01
# 132 2549338        8.848055e-02
# 133 2549338        3.991260e-02
# 134 2549338        3.216969e-01
# 135 2549338        1.605424e-01
# 136 2549338        2.301288e-01
# 137    3705        4.477293e+03
# 138    3705        1.476358e+03

# %%
ori_df <- merged_df %>%
    select(prefix, ORI, TER) %>%
    filter(ORI != "0" & TER != "0") %>%
    distinct()

# %%
summarised_df <- merged_df %>%
    group_by(prefix) %>%
    summarise(mean_perc_covered1 = mean(perc_covered1),
              mean_perc_covered5 = mean(perc_covered5),
              min_perc_covered1 = min(perc_covered1),
              max_perc_covered1 = max(perc_covered1),
              max_bPTR = max(bPTR, na.rm = T),
              max_microbe_count = max(microbe_count)) %>%
    mutate(max_bPTR = ifelse(max_bPTR == -Inf, NA, max_bPTR)) %>%
    left_join(ori_df) %>%
    separate(prefix, into = c("genus", "species", "suffix1", "suffix2"), sep = "_", remove = F) %>%
    mutate(taxa = ifelse(grepl("Torque", prefix), 
                         paste(genus, species, suffix1, suffix2), 
                         paste(genus, species, suffix1)), .before = 1) %>%
    mutate(taxa = gsub(" NZ| NC", "", taxa)) %>%
    mutate(taxa = gsub("Microbacterium", "Microbacterium sp.", taxa)) %>%
    mutate(taxa = gsub("Prevotella oral taxon", "Prevotella sp. oral taxon 299", taxa)) %>%
    mutate(taxa = gsub("Rickettsia", "Rickettsia sp.", taxa)) %>%
    select(-genus, -species, -suffix1, -suffix2) %>%
    arrange(desc(mean_perc_covered1))


fwrite(summarised_df, "results/irep_analysis/coverage_irep_results.parsed.csv")

summarised_df
# Out:
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(bPTR, na.rm = T):
# “no non-missing arguments to max; returning -Inf”
# Joining, by = "prefix"
# Warning message:
# “Expected 4 pieces. Additional pieces discarded in 7 rows [13, 14, 15, 16, 24, 26, 30].”
#    taxa
# 1  Human betaherpesvirus 6B
# 2  Human betaherpesvirus 6A
# 3  Achromobacter xylosoxidans
# 4  Hepatitis B virus
# 5  Pseudomonas mendocina
# 6  Cutibacterium acnes
# 7  Rickettsia sp. Tillamook 23
# 8  Alcaligenes faecalis
# 9  Torque teno virus 6
# 10 Neisseria subflava
# 11 Acinetobacter baumannii
# 12 Fannyhessea vaginae
# 13 Neisseria flavescens
# 14 Staphylococcus epidermidis
# 15 Haemophilus parainfluenzae
# 16 Fusobacterium nucleatum
# 17 Corynebacterium segmentosum
# 18 Lactobacillus crispatus
# 19 Fusobacterium pseudoperiodonticum
# 20 Prevotella sp. oral taxon 299
# 21 Moraxella osloensis
# 22 Gardnerella vaginalis
# 23 Human mastadenovirus C
# 24 Prevotella melaninogenica
# 25 Cupriavidus metallidurans
# 26 Neisseria mucosa
# 27 Malassezia restricta
# 28 Staphylococcus haemolyticus
# 29 Staphylococcus cohnii
# 30 Aspergillus oryzae
#    prefix                                          mean_perc_covered1
# 1  Human_betaherpesvirus_6B_NC_000898.1            98.48291943
# 2  Human_betaherpesvirus_6A_NC_001664.4            96.76555108
# 3  Achromobacter_xylosoxidans_NZ_CP043820.1        79.03047361
# 4  Hepatitis_B_virus_genB_JX661488.1               76.39191291
# 5  Pseudomonas_mendocina_NZ_CP013124.1             71.41336595
# 6  Cutibacterium_acnes_NC_021085.1                 36.15403798
# 7  Rickettsia_Tillamook_23_NZ_CP060138.1           31.85980557
# 8  Alcaligenes_faecalis_NZ_CP013119.1              28.02434056
# 9  Torque_teno_virus_6_NC_014094.1                 18.83940621
# 10 Neisseria_subflava_NZ_CP039887.1                17.89799782
# 11 Acinetobacter_baumannii_NZ_CP043953.1           17.31466235
# 12 Fannyhessea_vaginae_NZ_UFSV01000001.1           17.26185948
# 13 Neisseria_flavescens_NZ_CP039886.1              16.77717729
# 14 Staphylococcus_epidermidis_NZ_CP035288.1        15.36405809
# 15 Haemophilus_parainfluenzae_NZ_GL872339.1        14.73871027
# 16 Fusobacterium_nucleatum_NZ_LN831027.1           14.22900825
# 17 Corynebacterium_segmentosum_NZ_LR134408.1       13.99622489
# 18 Lactobacillus_crispatus_NZ_CP039266.1           13.00527270
# 19 Fusobacterium_pseudoperiodonticum_NZ_CP024702.1 11.77652109
# 20 Prevotella_oral_taxon_299_NC_022124.1           10.85898429
# 21 Moraxella_osloensis_NZ_CP014234.1                9.14462141
# 22 Gardnerella_vaginalis_NZ_PKJK01000001.1          8.67918722
# 23 Human_mastadenovirus_C_NC_001405.1               8.37354259
# 24 Prevotella_melaninogenica_NC_014370.1            6.79420265
# 25 Cupriavidus_metallidurans_NZ_FYAX01000013.1      5.16601427
# 26 Neisseria_mucosa_NZ_UGRT01000001.1               5.01441152
# 27 Malassezia_restricta_NC_040193.1                 3.38365554
# 28 Staphylococcus_haemolyticus_NZ_CP013911.1        0.26897963
# 29 Staphylococcus_cohnii_NZ_UHDA01000001.1          0.24924845
# 30 Aspergillus_oryzae_NC_036435.1                   0.03715799
#    mean_perc_covered5 min_perc_covered1 max_perc_covered1 max_bPTR
# 1  9.544136e+01       98.34129070       98.6928951              NA
# 2  9.096362e+01       96.63755349       96.9826450        1.282505
# 3  7.481513e+01       78.38978776       79.5830599              NA
# 4  4.486262e+01       61.33748056       98.7558320              NA
# 5  6.739544e+01       71.12799127       71.7810391              NA
# 6  3.473737e+00       15.33223211       77.4795425              NA
# 7  2.757348e+00        0.35879756       63.3608136        1.346660
# 8  5.987024e-01       23.36010861       31.7478145              NA
# 9  1.705803e+01       16.08636977       21.5924426              NA
# 10 5.411104e+00        1.20911307       81.7316806        1.506405
# 11 3.395586e+00        1.31604286       79.3290721        1.896385
# 12 1.865483e+00        1.22422672       75.9249475        1.876599
# 13 4.927474e+00        1.11999649       76.9177761        1.380708
# 14 2.958846e-01        2.03810903       52.9612382        1.566844
# 15 7.062885e-01        0.65722936       60.4802455        1.172580
# 16 1.150248e+01        0.32135060       65.7792926        1.675886
# 17 1.490941e+00        0.24934273       66.3968333              NA
# 18 3.891430e-01        3.96804644       41.0523459        1.571468
# 19 6.551175e+00        0.27596339       39.3815911              NA
# 20 1.770092e-01        1.00176094       20.7162076              NA
# 21 1.206725e-02        5.59357092       17.0975911        1.329333
# 22 1.926305e-02        5.29527766       14.6525344              NA
# 23 6.947158e+00        4.61084676       22.3363108              NA
# 24 5.026698e-02        0.44878446       25.1270313              NA
# 25 8.541929e-03        0.44472134       15.7048526              NA
# 26 9.105637e-01        0.11922013       22.5393464              NA
# 27 8.145150e-03        0.04072575       12.5383255              NA
# 28 8.480633e-02        0.23562980        0.2961161              NA
# 29 6.094140e-02        0.21837648        0.2688547              NA
# 30 8.741975e-04        0.00000000        0.1697323              NA
#    max_microbe_count ORI       TER
# 1  6.952852e+03      NA        NA
# 2  1.111746e+04      44,954    132,612
# 3  1.383176e+04      NA        NA
# 4  2.496341e+05      NA        NA
# 5  1.988941e+04      NA        NA
# 6  1.763105e+03      NA        NA
# 7  1.197889e+03      240,832   888,370
# 8  3.634384e+02      NA        NA
# 9  4.477293e+03      NA        NA
# 10 1.882095e+03      1,883,368 797,590
# 11 8.490606e+02      3,869,401 1,967,227
# 12 7.075888e+02      613,931   1,264,620
# 13 1.721050e+03      1,737,155 716,802
# 14 7.349293e+02      237,449   1,347,375
# 15 7.445671e+02      492,915   1,443,748
# 16 3.657746e+03      201,937   1,345,205
# 17 1.281144e+03      NA        NA
# 18 5.414163e+02      328,627   1,239,005
# 19 1.354117e+03      NA        NA
# 20 1.644861e+02      NA        NA
# 21 1.381334e+02      1,501,499 405,889
# 22 1.417187e+02      NA        NA
# 23 1.920488e+04      NA        NA
# 24 2.011119e+02      NA        NA
# 25 1.635871e+02      NA        NA
# 26 3.361585e+02      NA        NA
# 27 1.162379e+02      NA        NA
# 28 3.216969e-01      NA        NA
# 29 3.076552e-01      NA        NA
# 30 5.564388e-01      NA        NA
