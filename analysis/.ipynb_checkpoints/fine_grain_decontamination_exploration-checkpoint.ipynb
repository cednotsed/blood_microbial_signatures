# %% [markdown]
# # Visualising taxa abundance

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(tidyverse)
require(ggplot2)
require(data.table)
require(foreach)
require(compositions)
require(ggpubr)
require(see)
require(doParallel)
require(Rtsne)
require(vegan)
require(VennDiagram)
registerDoParallel(cores=8)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: compositions
#
# Welcome to compositions, a package for compositional data analysis.
# Find an intro with "? compositions"
#
#
#
# Attaching package: ‘compositions’
#
#
# The following objects are masked from ‘package:stats’:
#
#     anova, cor, cov, dist, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %*%, norm, scale, scale.default
#
#
# Loading required package: ggpubr
#
# Loading required package: see
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: Rtsne
#
# Loading required package: vegan
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.5-7
#
# Loading required package: VennDiagram
#
# Loading required package: grid
#
# Loading required package: futile.logger
#
#
# Attaching package: ‘VennDiagram’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     rotate

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# ### Load and parse data

# %%
get_meta_cols <- function(meta, meta_regex, to_exclude) {
    meta_cols <- colnames(meta)[grep(meta_regex, colnames(meta))]
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}


load_data <- function(file_path) {
    df <- fread(file_path) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}


otu_to_RA <- function(df) {
    row_names <- df$npm_research_id
    RA_df <- t(apply(df[, 2:ncol(df)], 1, function(x) {x / sum(x)}))
    
    return(cbind(data.frame(npm_research_id = row_names), as.data.frame(RA_df, check.names = F)))
}


otu_to_PA <- function(df, read_threshold) {
    prev_read <- df %>%
        column_to_rownames("npm_research_id")
    
    prev_read[prev_read <= read_threshold] <- 0
    prev_read[prev_read > read_threshold] <- 1

    return(prev_read)
}


RA_to_PA <- function(RA_df, PA_threshold) {
    prev_RA <- RA_df %>% column_to_rownames("npm_research_id")
    prev_RA[prev_RA <= PA_threshold] <- 0
    prev_RA[prev_RA > PA_threshold] <- 1
    
    return(prev_RA)
}


RA_to_clr <- function(df) {
    row_names <- df$npm_research_id
    clr_df <- clr(df %>% select(where(is.numeric)))
    return(cbind(data.frame(npm_research_id = row_names), as.data.frame(clr_df, check.names = F)))
}


get_prev_df <- function(df) {
    RA_df <- otu_to_RA(df)
    prev_RA <- RA_to_PA(RA_df, PA_threshold = 0.01)
    prev_read <- otu_to_PA(df, read_threshold = 10)
    prev_df <- as.data.frame(prev_read & prev_RA)
    prev_df <- filter_taxa_by_presence(prev_df, presence_t = 0) # Remove taxa that are not present in any samples
    prev_df <- prev_df %>% rownames_to_column("npm_research_id")
    return(prev_df)
}


filter_taxa_by_presence <- function(prev_df, presence_t) {
    taxa_counts <- apply(prev_df, 2, sum)
    to_keep <- names(taxa_counts)[taxa_counts > presence_t]
    return(prev_df %>% select(all_of(to_keep)))
}

# %%
rank <- "S"
n_subset <- 9999
human <- "Homo sapiens"

to_retain <- fread("data/samples_above_100_microbial_reads.txt")$npm_research_id

meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv") %>%
    filter(npm_research_id %in% to_retain) %>%
    as_tibble()

meta_cols <- get_meta_cols(meta, 
                           meta_regex = "kit|flow_cell|site_supplying", 
                           to_exclude = c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id"))


species_df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>%
      filter(npm_research_id %in% to_retain) %>%
    as_tibble()

species_df <- remove_cols(species_df, c(human, "unclassified"))
prev_df <- get_prev_df(species_df)

# %% [markdown]
# ### Remove contaminants and renormalise

# %%
column <- "extraction_kit"
contam_df <- fread(str_glue("results/decontamination/post_hoc_fine_grain/{column}_fine_grain_results.csv"))
contam_df
# Out:
#   meta_col       level                                          n_samples
# 1 extraction_kit abGENIX Whole Blood Genomic DNA Extraction Kit 2280
# 2 extraction_kit Chemagic DNA Blood Kit (Perkin Elmer, MA)      1040
# 3 extraction_kit Maxwell RSC Blood DNA Kit (AS1400)             2113
# 4 extraction_kit QIAsymphony DSP DNA Mini Kit (192)              593
# 5 extraction_kit QIAsymphony DSP DNA Midi Kit                    963
# 6 extraction_kit QIAamp DNA Blood Mini Kit                       635
#   n_prev_contams n_all_contams
# 1 10             28
# 2 11             40
# 3 26             59
# 4 15             45
# 5 16             26
# 6  5              8
#   contams
# 1 Acinetobacter johnsonii|Brevundimonas diminuta|Brevundimonas naejangsanensis|Brevundimonas sp. DS20|Brevundimonas sp. LM2|Caulobacter mirabilis|Microbacterium aurum|Microbacterium chocolatum|Microbacterium foliorum|Microbacterium hominis|Microbacterium paludicola|Microbacterium pygmaeum|Microbacterium sp. 10M-3C3|Microbacterium sp. ABRD_28|Microbacterium sp. LKL04|Microbacterium sp. No. 7|Microbacterium sp. PM5|Pseudomonas aeruginosa|Alcaligenes aquatilis|Alcaligenes faecalis|Caulobacter flavus|Caulobacter henricii|Caulobacter segnis|Caulobacter sp. K31|Caulobacter vibrioides|Microbacterium sp. BH-3-3-3|Microbacterium testaceum|Sphingomonas melonis
# 2 Bosea sp. Tri-49|Clavibacter michiganensis|Gordonia sp. KTR9|Gordonia terrae|Microbacterium sp. Y-01|Paracoccus aminovorans|Paracoccus contaminans|Paracoccus sp. CBA4604|Paracoccus sp. SC2-6|Paracoccus yeei|Paracoccus zhejiangensis|Phreatobacter cathodiphilus|Pseudomonas alcaligenes|Pseudomonas entomophila|Pseudomonas fluorescens|Pseudomonas fulva|Pseudomonas koreensis|Pseudomonas monteilii|Pseudomonas oryzihabitans|Pseudomonas plecoglossicida|Pseudomonas psychrotolerans|Pseudomonas putida|Pseudomonas sp. 02C 26|Pseudomonas sp. CMR5c|Pseudomonas sp. LTJR-52|Pseudomonas sp. NC02|Pseudomonas tolaasii|Stenotrophomonas maltophilia|Stenotrophomonas sp. LM091|Bordetella genomosp. 13|Bradyrhizobium sp. SK17|Microcella alkaliphila|Pseudomonas aeruginosa|Pseudomonas alcaliphila|Pseudomonas mendocina|Pseudomonas pseudoalcaligenes|Pseudomonas sihuiensis|Pseudomonas sp. LPH1|Pseudomonas sp. phDV1|Pseudomonas stutzeri
# 3 Afipia sp. GAS231|Altererythrobacter sp. B11|Bradyrhizobium japonicum|Bradyrhizobium oligotrophicum|Bradyrhizobium ottawaense|Bradyrhizobium sp.|Bradyrhizobium sp. 3 85S1MB|Bradyrhizobium sp. CCGE-LA001|Bradyrhizobium sp. ORS 278|Bradyrhizobium sp. ORS 285|Bradyrhizobium sp. ORS 3257|Bradyrhizobium sp. S23321|Brevundimonas diminuta|Caulobacter flavus|Caulobacter mirabilis|Nitrobacter hamburgensis|Nitrobacter winogradskyi|Pannonibacter phragmitetus|Sphingobium baderi|Sphingobium cloacae|Sphingobium herbicidovorans|Sphingobium hydrophobicum|Sphingobium sp. RAC03|Sphingobium sp. SCG-1|Sphingomonas indica|Sphingomonas melonis|Sphingomonas sp. JJ-A5|Sphingomonas sp. MM-1|Sphingomonas sp. NIC1|Sphingopyxis granuli|Sphingopyxis macrogoltabida|Sphingopyxis sp. WS5A3p|Xanthobacter autotrophicus|Bradyrhizobiaceae bacterium SG-6C|Bradyrhizobium diazoefficiens|Bradyrhizobium erythrophlei|Bradyrhizobium icense|Bradyrhizobium lablabi|Bradyrhizobium sp. BTAi1|Bradyrhizobium sp. SK17|Brevundimonas sp. GW460-12-10-14-LB2|Brevundimonas vesicularis|Devosia sp. H5989|Methylobacterium brachiatum|Methylobacterium currus|Oligotropha carboxidovorans|Rhodopseudomonas palustris|Sphingobium sp. YG1|Sphingobium yanoikuyae|Sphingomonas hengshuiensis|Sphingomonas koreensis|Sphingomonas panacis|Sphingomonas sanxanigenens|Sphingomonas sp. Cra20|Sphingomonas sp. FARSPH|Sphingomonas sp. LK11|Sphingomonas sp. LM7|Sphingomonas taxi|Sphingomonas wittichii
# 4 Afipia sp. GAS231|Altererythrobacter sp. B11|Bradyrhizobium diazoefficiens|Bradyrhizobium erythrophlei|Bradyrhizobium icense|Bradyrhizobium japonicum|Bradyrhizobium lablabi|Bradyrhizobium oligotrophicum|Bradyrhizobium sp. BTAi1|Bradyrhizobium sp. CCGE-LA001|Bradyrhizobium sp. ORS 285|Bradyrhizobium sp. SK17|Caulobacter flavus|Devosia sp. H5989|Nitrobacter hamburgensis|Oligotropha carboxidovorans|Sphingobium baderi|Sphingobium cloacae|Sphingobium herbicidovorans|Sphingobium hydrophobicum|Sphingobium sp. RAC03|Sphingobium sp. SCG-1|Sphingomonas indica|Sphingomonas melonis|Sphingomonas sp. JJ-A5|Sphingomonas sp. MM-1|Sphingomonas sp. NIC1|Sphingopyxis macrogoltabida|Sphingopyxis sp. WS5A3p|Xanthobacter autotrophicus|Bradyrhizobiaceae bacterium SG-6C|Methylobacterium currus|Rhodopseudomonas palustris|Sphingobium sp. YG1|Sphingobium yanoikuyae|Sphingomonas hengshuiensis|Sphingomonas koreensis|Sphingomonas panacis|Sphingomonas sanxanigenens|Sphingomonas sp. Cra20|Sphingomonas sp. FARSPH|Sphingomonas sp. LK11|Sphingomonas sp. LM7|Sphingomonas taxi|Sphingomonas wittichii
# 5 Methylobacterium phyllosphaerae|Methylobacterium sp. C1|Methylobacterium sp. XJLW|Methylorubrum zatmanii|Microvirga ossetica|Microvirga sp. 17 mud 1-3|Phyllobacterium zundukense|Ralstonia insidiosa|Rhodococcus erythropolis|Rhodopseudomonas palustris|Bradyrhizobium sp. SK17|Methylobacterium aquaticum|Methylobacterium brachiatum|Methylobacterium currus|Methylobacterium nodulans|Methylobacterium radiotolerans|Methylobacterium sp. 17SD2-17|Methylobacterium sp. 17Sr1-1|Methylobacterium sp. 17Sr1-28|Methylobacterium sp. 17Sr1-43|Methylobacterium sp. 4-46|Methylobacterium sp. AMS5|Methylobacterium sp. DM1|Methylorubrum extorquens|Methylorubrum populi|Stenotrophomonas maltophilia
# 6 Burkholderia contaminans|Comamonas testosteroni|Cupriavidus basilensis|Paraburkholderia fungorum|Ralstonia insidiosa|Ralstonia mannitolilytica|Ralstonia pickettii|Ralstonia solanacearum

# %% [markdown]
# #### Set 'absent' taxa to zero

# %%
species_filt <- species_df %>% 
    select(all_of(colnames(prev_df))) %>%
    column_to_rownames("npm_research_id")

prev_bool_df <- prev_df %>%
    column_to_rownames("npm_research_id")

for(i in seq(ncol(species_filt))) {
    species_filt[!prev_bool_df[, i], i] <- 0
}

species_filt <- species_filt %>% rownames_to_column("npm_research_id")

dat_meta <- species_filt %>%
    left_join(meta)
# Out:
# Joining, by = "npm_research_id"

# %% [markdown]
# #### Set contaminants to zero in affected levels

# %%
for(i in seq(nrow(contam_df))) {
# i <- 1
    level <- contam_df[i, ]$level
    contam_string <- contam_df[i, ]$contams
    contams <- unlist(str_split(contam_string, "\\|"))
    
    dat_meta[dat_meta[, column] == level, contams] <- 0
}

# # Check
# taxon <- "Microbacterium aurum"
# dat_meta %>% 
#     filter(!grepl("abGENIX", extraction_kit)) %>%
#     summarise(max = max(get(taxon)))

# dat_meta %>% 
#     filter(grepl("abGENIX", extraction_kit)) %>%
#     summarise(max = max(get(taxon)))

# Get zeroed read count and prevalence matrix
meta_cols_to_remove <- colnames(meta)[colnames(meta) != "npm_research_id"]
species_zeroed <- dat_meta %>% 
    select(-all_of(meta_cols_to_remove))
prev_zeroed <- get_prev_df(species_zeroed)

# %% [markdown]
# ### Simple batch filter

# %%
taxa_vec <- colnames(prev_zeroed) 
taxa_vec <- taxa_vec[taxa_vec != "npm_research_id"]

# %%
result_df <- tibble(taxa = taxa_vec)

for(column in meta_cols) {
    res <- prev_zeroed %>% 
        left_join(meta %>% select(all_of(c("npm_research_id", column)))) %>%
        select(-npm_research_id) %>%
        pivot_longer(!column, names_to = "taxa", values_to = "presence") %>%
        filter(presence) %>%
        group_by(taxa) %>%
        summarise(n_batches = n_distinct(get(column)))  # Count number of batches in each column
    colnames(res)[2] <- column

    result_df <- result_df %>%
        left_join(res, "taxa")
}

result_df <- result_df %>% column_to_rownames("taxa")
result_df[result_df <= 1] <- 0
result_df[result_df > 1] <- 1

# Parse results
row_sums <- rowSums(result_df)
parsed_df <- tibble(taxa = names(row_sums), n_cols = row_sums)

prev_stats <- apply(prev_zeroed[, 2:ncol(prev_zeroed)], 2, sum) / nrow(prev_zeroed)
overall_prev <- data.frame(taxa = names(prev_stats), overall_prevalence = as.vector(prev_stats)) %>%
    mutate(n_samples = overall_prevalence * nrow(prev_zeroed))

parsed_df %>% 
    left_join(overall_prev) %>%
    filter(n_cols == 7) %>%
    arrange(desc(overall_prevalence))

batch_nc <- parsed_df %>%
    filter(n_cols == 7) %>%
    select(taxa)

batch_nc <- batch_nc$taxa
# Out:
# Joining, by = "npm_research_id"
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(column)` instead of `column` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Joining, by = "npm_research_id"
#
# Joining, by = "npm_research_id"
#
# Joining, by = "npm_research_id"
#
# Joining, by = "npm_research_id"
#
# Joining, by = "npm_research_id"
#
# Joining, by = "npm_research_id"
#
# Joining, by = "taxa"
#     taxa                             n_cols overall_prevalence n_samples
# 1   Ralstonia pickettii              7      0.07902982         681
# 2   Achromobacter xylosoxidans       7      0.07554833         651
# 3   Methylobacterium sp. 17SD2-17    7      0.06835326         589
# 4   Methylobacterium sp. 17Sr1-43    7      0.05721249         493
# 5   Ralstonia insidiosa              7      0.05709644         492
# 6   Ralstonia solanacearum           7      0.05454334         470
# 7   Methylobacterium brachiatum      7      0.04943716         426
# 8   Pseudomonas aeruginosa           7      0.04479517         386
# 9   Methylorubrum populi             7      0.04444702         383
# 10  Ralstonia mannitolilytica        7      0.04386677         378
# 11  Sphingomonas sp. LM7             7      0.04317048         372
# 12  Brevundimonas vesicularis        7      0.04189393         361
# 13  Methylobacterium aquaticum       7      0.03910874         337
# 14  Sphingomonas sp. FARSPH          7      0.03899269         336
# 15  Delftia tsuruhatensis            7      0.03829639         330
# 16  Sphingomonas sp. Cra20           7      0.03713589         320
# 17  Sphingomonas hengshuiensis       7      0.03620750         312
# 18  Paraburkholderia fungorum        7      0.03458280         298
# 19  Cutibacterium acnes              7      0.03388650         292
# 20  Methylobacterium currus          7      0.03307416         285
# 21  Xanthomonas euvesicatoria        7      0.03191366         275
# 22  Methylobacterium sp. 4-46        7      0.02901242         250
# 23  Pseudomonas sihuiensis           7      0.02878032         248
# 24  Mitsuaria sp. 7                  7      0.02680747         231
# 25  Pseudomonas mendocina            7      0.02587908         223
# 26  Pseudomonas stutzeri             7      0.02576303         222
# 27  Methylorubrum extorquens         7      0.02518278         217
# 28  Pseudomonas alcaliphila          7      0.02483463         214
# 29  Sphingomonas taxi                7      0.02448648         211
# 30  Sphingomonas sp. NIC1            7      0.02146919         185
# ⋮   ⋮                                ⋮      ⋮                  ⋮
# 216 Xanthomonas campestris           7      0.0002320993       2
# 217 Pseudomonas monteilii            7      0.0002320993       2
# 218 Corynebacterium ureicelerivorans 7      0.0002320993       2
# 219 Deinococcus irradiatisoli        7      0.0002320993       2
# 220 Brevundimonas naejangsanensis    7      0.0002320993       2
# 221 Agrobacterium fabrum             7      0.0002320993       2
# 222 Paracoccus sp. SC2-6             7      0.0002320993       2
# 223 Pseudomonas plecoglossicida      7      0.0002320993       2
# 224 Pseudomonas sp. CMR5c            7      0.0002320993       2
# 225 Brevibacterium siliguriense      7      0.0002320993       2
# 226 Streptococcus pseudopneumoniae   7      0.0002320993       2
# 227 Pseudomonas entomophila          7      0.0002320993       2
# 228 Dermacoccus nishinomiyaensis     7      0.0002320993       2
# 229 Corynebacterium imitans          7      0.0002320993       2
# 230 Deinococcus geothermalis         7      0.0002320993       2
# 231 Deinococcus gobiensis            7      0.0002320993       2
# 232 Deinococcus swuensis             7      0.0002320993       2
# 233 Prevotella sp. oral taxon 299    7      0.0002320993       2
# 234 Prevotella oris                  7      0.0002320993       2
# 235 Corynebacterium aurimucosum      7      0.0002320993       2
# 236 Pseudomonas libanensis           7      0.0002320993       2
# 237 Corynebacterium singulare        7      0.0002320993       2
# 238 Deinococcus ficus                7      0.0002320993       2
# 239 Corynebacterium sp. NML98-0116   7      0.0002320993       2
# 240 Deinococcus actinosclerus        7      0.0002320993       2
# 241 Veillonella dispar               7      0.0002320993       2
# 242 Torque teno virus 6              7      0.0002320993       2
# 243 Prevotella jejuni                7      0.0002320993       2
# 244 Torque teno virus 21             7      0.0002320993       2
# 245 Hepatitis B virus                7      0.0002320993       2

# %% [markdown]
# #### Taxa stats

# %%
length(batch_nc)
# Out:
# [1] 245

# %%
max_df <- species_zeroed %>% 
    select(all_of(batch_nc)) %>%
    pivot_longer(everything(), names_to = "taxa", values_to = "read_count") %>%
    group_by(taxa) %>%
    summarise(max_count = max(read_count)) %>%
    arrange(desc(max_count))

prev_stats <- apply(prev_zeroed[, 2:ncol(prev_zeroed)], 2, sum) / nrow(prev_zeroed)
overall_prev <- data.frame(taxa = names(prev_stats), overall_prevalence = as.vector(prev_stats))

prev_max <- max_df %>%
    left_join(overall_prev) %>%
    arrange(desc(overall_prevalence)) %>%
    mutate(n_samples = overall_prevalence * nrow(prev_zeroed),
           max_bin = case_when(max_count < 10 ~ "<10",
                               max_count >= 10 & max_count < 50 ~ "10-50",
                               max_count >= 50 & max_count < 100 ~ "50-100",
                               max_count >= 100 & max_count < 500 ~"100-500",
                               max_count >= 500 ~">=500")) %>%
    mutate(max_bin = factor(max_bin, levels = c("<10", "10-50", "50-100", "100-500", ">=500"))) %>%
    arrange(desc(overall_prevalence))
# Out:
# Joining, by = "taxa"

# %%
prev_max_filt <- prev_max %>% 
    filter(max_count > 100)

nrow(prev_max)
nrow(prev_max_filt)
# Out:
# [1] 245
# [1] 184

# %%
top_max_count <- prev_max_filt %>% 
    arrange(desc(max_count)) %>% 
    mutate(count_rank = seq(nrow(prev_max_filt)))

top_prev <- prev_max_filt %>% 
    arrange(desc(overall_prevalence)) %>%
    mutate(prev_rank = seq(nrow(prev_max_filt)))

top_max_count %>% 
    full_join(top_prev) %>%
    mutate(ranksum = count_rank + prev_rank) %>%
    arrange(prev_rank)
# Out:
# Joining, by = c("taxa", "max_count", "overall_prevalence", "n_samples", "max_bin")
#     taxa                              max_count overall_prevalence n_samples
# 1   Ralstonia pickettii                  5110   0.07902982         681
# 2   Achromobacter xylosoxidans        1386884   0.07554833         651
# 3   Methylobacterium sp. 17SD2-17        4683   0.06835326         589
# 4   Methylobacterium sp. 17Sr1-43        3633   0.05721249         493
# 5   Ralstonia insidiosa                 21522   0.05709644         492
# 6   Ralstonia solanacearum             181086   0.05454334         470
# 7   Methylobacterium brachiatum          3082   0.04943716         426
# 8   Pseudomonas aeruginosa              76659   0.04479517         386
# 9   Methylorubrum populi                 2480   0.04444702         383
# 10  Ralstonia mannitolilytica             756   0.04386677         378
# 11  Sphingomonas sp. LM7                 5550   0.04317048         372
# 12  Brevundimonas vesicularis             372   0.04189393         361
# 13  Methylobacterium aquaticum            972   0.03910874         337
# 14  Sphingomonas sp. FARSPH              3306   0.03899269         336
# 15  Delftia tsuruhatensis                2306   0.03829639         330
# 16  Sphingomonas sp. Cra20               4767   0.03713589         320
# 17  Sphingomonas hengshuiensis           4809   0.03620750         312
# 18  Paraburkholderia fungorum             531   0.03458280         298
# 19  Cutibacterium acnes                 22588   0.03388650         292
# 20  Methylobacterium currus               812   0.03307416         285
# 21  Xanthomonas euvesicatoria             189   0.03191366         275
# 22  Methylobacterium sp. 4-46            1959   0.02901242         250
# 23  Pseudomonas sihuiensis              56224   0.02878032         248
# 24  Mitsuaria sp. 7                       953   0.02680747         231
# 25  Pseudomonas mendocina             1526900   0.02587908         223
# 26  Pseudomonas stutzeri                33747   0.02576303         222
# 27  Methylorubrum extorquens             1184   0.02518278         217
# 28  Pseudomonas alcaliphila             52692   0.02483463         214
# 29  Sphingomonas taxi                    8320   0.02448648         211
# 30  Sphingomonas sp. NIC1                1780   0.02146919         185
# ⋮   ⋮                                 ⋮         ⋮                  ⋮
# 155 Bifidobacterium pseudocatenulatum   102     0.0004641987       4
# 156 Rickettsia felis                  11403     0.0003481490       3
# 157 Fusobacterium periodonticum        4777     0.0003481490       3
# 158 Neisseria meningitidis             2173     0.0003481490       3
# 159 Deinococcus sp. NW-56               840     0.0003481490       3
# 160 Corynebacterium sp. ATCC 6931       705     0.0003481490       3
# 161 Phyllobacterium zundukense          302     0.0003481490       3
# 162 Corynebacterium matruchotii         163     0.0003481490       3
# 163 Agrobacterium rhizogenes            143     0.0003481490       3
# 164 Porphyromonas gingivalis            107     0.0003481490       3
# 165 Pseudomonas monteilii              5730     0.0002320993       2
# 166 Hepatitis B virus                  4237     0.0002320993       2
# 167 Prevotella sp. oral taxon 299      2418     0.0002320993       2
# 168 Prevotella jejuni                  2079     0.0002320993       2
# 169 Corynebacterium imitans            2033     0.0002320993       2
# 170 Veillonella dispar                 1149     0.0002320993       2
# 171 Prevotella oris                     853     0.0002320993       2
# 172 Deinococcus geothermalis            484     0.0002320993       2
# 173 Deinococcus gobiensis               462     0.0002320993       2
# 174 Corynebacterium ureicelerivorans    393     0.0002320993       2
# 175 Corynebacterium aurimucosum         310     0.0002320993       2
# 176 Deinococcus actinosclerus           231     0.0002320993       2
# 177 Deinococcus swuensis                223     0.0002320993       2
# 178 Torque teno virus 6                 209     0.0002320993       2
# 179 Deinococcus ficus                   197     0.0002320993       2
# 180 Roseomonas gilardii                 178     0.0002320993       2
# 181 Agrobacterium fabrum                149     0.0002320993       2
# 182 Dermacoccus nishinomiyaensis        143     0.0002320993       2
# 183 Torque teno virus 21                135     0.0002320993       2
# 184 Deinococcus irradiatisoli           128     0.0002320993       2
#     max_bin count_rank prev_rank ranksum
# 1   >=500    42         1         43
# 2   >=500     2         2          4
# 3   >=500    47         3         50
# 4   >=500    51         4         55
# 5   >=500    22         5         27
# 6   >=500     4         6         10
# 7   >=500    54         7         61
# 8   >=500     8         8         16
# 9   >=500    55         9         64
# 10  >=500    98        10        108
# 11  >=500    39        11         50
# 12  100-500 124        12        136
# 13  >=500    82        13         95
# 14  >=500    52        14         66
# 15  >=500    61        15         76
# 16  >=500    45        16         61
# 17  >=500    43        17         60
# 18  >=500   111        18        129
# 19  >=500    19        19         38
# 20  >=500    95        20        115
# 21  100-500 161        21        182
# 22  >=500    67        22         89
# 23  >=500    10        23         33
# 24  >=500    83        24        107
# 25  >=500     1        25         26
# 26  >=500    15        26         41
# 27  >=500    77        27        104
# 28  >=500    12        28         40
# 29  >=500    32        29         61
# 30  >=500    69        30         99
# ⋮   ⋮       ⋮          ⋮         ⋮
# 155 100-500 184        155       339
# 156 >=500    25        156       181
# 157 >=500    44        157       201
# 158 >=500    63        158       221
# 159 >=500    93        159       252
# 160 >=500   102        160       262
# 161 100-500 138        161       299
# 162 100-500 165        162       327
# 163 100-500 171        163       334
# 164 100-500 182        164       346
# 165 >=500    37        165       202
# 166 >=500    48        166       214
# 167 >=500    57        167       224
# 168 >=500    65        168       233
# 169 >=500    66        169       235
# 170 >=500    78        170       248
# 171 >=500    92        171       263
# 172 100-500 118        172       290
# 173 100-500 120        173       293
# 174 100-500 123        174       297
# 175 100-500 135        175       310
# 176 100-500 152        176       328
# 177 100-500 153        177       330
# 178 100-500 158        178       336
# 179 100-500 160        179       339
# 180 100-500 164        180       344
# 181 100-500 167        181       348
# 182 100-500 172        182       354
# 183 100-500 174        183       357
# 184 100-500 176        184       360

# %%
fwrite(top_max_count, "results/decontamination/fine_grain_max_count.csv")

# %% [markdown]
# ### No. of taxa per sample

# %%
# After non-zero filter
tax_plt <- tibble(n = rowSums(prev_df %>% select(-npm_research_id))) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After non-zero filter")

# After fine grain decontamination
tax_plt1 <- tibble(n = rowSums(prev_zeroed %>% select(-npm_research_id))) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After fine grain filter")

# After simple batch filter
species_prev_filt2 <- prev_zeroed %>% select(all_of(batch_nc))
tax_plt2 <- tibble(n = rowSums(species_prev_filt2)) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After >2 batch filter")

# After max count filter
species_prev_filt3 <- prev_zeroed %>% select(all_of(prev_max_filt$taxa))
tax_plt3 <- tibble(n = rowSums(species_prev_filt3)) %>%
    ggplot(aes(x = n)) +
    geom_histogram() +
    labs(x = "No. of species", y = "No. of samples", title = "After max count filter")


ggarrange(tax_plt, tax_plt1, tax_plt2, tax_plt3)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ### Compare taxa with global analysis

# %%
global_stats <- fread("results/decontamination/global_decontamination_stats.csv")
global_taxa <- global_stats$taxa
fine_taxa <- prev_max_filt$taxa
venn_list <- list(global = global_taxa, fine = fine_taxa)

venn.diagram(venn_list, filename = "results/decontamination/global_versus_fine_grain_taxa.png",
             category.names = c("", ""),
             print.mode = c("raw", "percent"),
             fill = c("red", "blue")
             )
# Out:
# [1] 1

# %%
global_not_fine <- global_taxa[!(global_taxa %in% fine_taxa)]
fine_not_global <- fine_taxa[!(fine_taxa %in% global_taxa)]
fwrite(tibble(taxa = global_not_fine), "results/decontamination/global_not_fine_taxa.txt")
prev_max_filt %>% 
    filter(taxa %in% fine_not_global) %>%
    separate(taxa, into = c("genus", "species", "strain"), sep = " ", remove = F) %>%
    group_by(genus) %>%
    summarise(n = n()) %>%
    arrange(desc(n))
# Out:
# Warning message:
# “Expected 3 pieces. Additional pieces discarded in 1 rows [53].”
# Warning message:
# “Expected 3 pieces. Missing pieces filled with `NA` in 41 rows [1, 2, 5, 6, 7, 8, 9, 10, 12, 13, 15, 17, 18, 19, 20, 22, 23, 24, 25, 26, ...].”
#    genus             n
# 1  Methylobacterium  14
# 2  Pseudomonas        9
# 3  Sphingomonas       8
# 4  Bradyrhizobium     7
# 5  Ralstonia          4
# 6  Brevundimonas      3
# 7  Delftia            2
# 8  Herbaspirillum     2
# 9  Methylorubrum      2
# 10 Achromobacter      1
# 11 Acinetobacter      1
# 12 Bosea              1
# 13 Bradyrhizobiaceae  1
# 14 Caulobacter        1
# 15 Massilia           1
# 16 Microcella         1
# 17 Paraburkholderia   1
# 18 Phreatobacter      1
# 19 Phyllobacterium    1
# 20 Rhodopseudomonas   1
# 21 Sphingobium        1
# 22 Xanthomonas        1

# %% [markdown]
# #### Intersection of non-contaminants identified

# %%
prev_max_filt %>% 
    filter(taxa %in% intersect(fine_taxa, global_taxa))

prev_max_filt %>%
    separate(taxa, into = c("genus", "species", "strain"), sep = " ", remove = F) %>%
    filter(taxa %in% intersect(fine_taxa, global_taxa)) %>%
    group_by(genus) %>%
    summarise(n = n()) %>%
    arrange(desc(n))
# Out:
#     taxa                                 max_count overall_prevalence n_samples
# 1   Cutibacterium acnes                  22588     0.033886503        292
# 2   Mitsuaria sp. 7                        953     0.026807474        231
# 3   Bacillus cereus                      39574     0.017059301        147
# 4   Moraxella osloensis                   2378     0.016711152        144
# 5   Human mastadenovirus C               17476     0.014738308        127
# 6   Rhodococcus sp. NJ-530                 281     0.010908669         94
# 7   Agrobacterium tumefaciens              871     0.010676570         92
# 8   Staphylococcus haemolyticus          79966     0.010560520         91
# 9   Gardnerella vaginalis                 2183     0.009748172         84
# 10  Roseateles depolymerans                537     0.009632123         83
# 11  Staphylococcus cohnii                52898     0.009516073         82
# 12  Paucibacter sp. KCTC 42545             515     0.009516073         82
# 13  Lactobacillus crispatus               7633     0.009400023         81
# 14  Burkholderia lata                     6689     0.009400023         81
# 15  Rubrivivax gelatinosus                 530     0.009167924         79
# 16  Micrococcus luteus                     318     0.006266682         54
# 17  Paraburkholderia phytofirmans          289     0.006150632         53
# 18  Staphylococcus epidermidis            9095     0.005570384         48
# 19  Bifidobacterium adolescentis           220     0.005222235         45
# 20  Klebsiella pneumoniae                 1274     0.004758036         41
# 21  Pseudomonas sp. NC02                   896     0.004409887         38
# 22  Bifidobacterium bifidum                838     0.004177788         36
# 23  Bifidobacterium longum                 872     0.004061738         35
# 24  Microbacterium sp. PAMC 28756        24529     0.003829639         33
# 25  Aquabacterium olei                     528     0.003481490         30
# 26  Propionibacterium sp. oral taxon 193   463     0.003481490         30
# 27  Acidovorax sp. KKS102                  351     0.003481490         30
# 28  Bifidobacterium breve                  572     0.003365440         29
# 29  Paracoccus yeei                      85304     0.003133341         27
# 30  Zhihengliuella sp. ISTPL4            10360     0.003133341         27
# ⋮   ⋮                                    ⋮         ⋮                  ⋮
# 91  Pseudonocardia autotrophica            127     0.0004641987       4
# 92  Megasphaera elsdenii                   122     0.0004641987       4
# 93  Bifidobacterium pseudocatenulatum      102     0.0004641987       4
# 94  Rickettsia felis                     11403     0.0003481490       3
# 95  Fusobacterium periodonticum           4777     0.0003481490       3
# 96  Neisseria meningitidis                2173     0.0003481490       3
# 97  Deinococcus sp. NW-56                  840     0.0003481490       3
# 98  Corynebacterium sp. ATCC 6931          705     0.0003481490       3
# 99  Corynebacterium matruchotii            163     0.0003481490       3
# 100 Agrobacterium rhizogenes               143     0.0003481490       3
# 101 Porphyromonas gingivalis               107     0.0003481490       3
# 102 Hepatitis B virus                     4237     0.0002320993       2
# 103 Prevotella sp. oral taxon 299         2418     0.0002320993       2
# 104 Prevotella jejuni                     2079     0.0002320993       2
# 105 Corynebacterium imitans               2033     0.0002320993       2
# 106 Veillonella dispar                    1149     0.0002320993       2
# 107 Prevotella oris                        853     0.0002320993       2
# 108 Deinococcus geothermalis               484     0.0002320993       2
# 109 Deinococcus gobiensis                  462     0.0002320993       2
# 110 Corynebacterium ureicelerivorans       393     0.0002320993       2
# 111 Corynebacterium aurimucosum            310     0.0002320993       2
# 112 Deinococcus actinosclerus              231     0.0002320993       2
# 113 Deinococcus swuensis                   223     0.0002320993       2
# 114 Torque teno virus 6                    209     0.0002320993       2
# 115 Deinococcus ficus                      197     0.0002320993       2
# 116 Roseomonas gilardii                    178     0.0002320993       2
# 117 Agrobacterium fabrum                   149     0.0002320993       2
# 118 Dermacoccus nishinomiyaensis           143     0.0002320993       2
# 119 Torque teno virus 21                   135     0.0002320993       2
# 120 Deinococcus irradiatisoli              128     0.0002320993       2
#     max_bin
# 1   >=500
# 2   >=500
# 3   >=500
# 4   >=500
# 5   >=500
# 6   100-500
# 7   >=500
# 8   >=500
# 9   >=500
# 10  >=500
# 11  >=500
# 12  >=500
# 13  >=500
# 14  >=500
# 15  >=500
# 16  100-500
# 17  100-500
# 18  >=500
# 19  100-500
# 20  >=500
# 21  >=500
# 22  >=500
# 23  >=500
# 24  >=500
# 25  >=500
# 26  100-500
# 27  100-500
# 28  >=500
# 29  >=500
# 30  >=500
# ⋮   ⋮
# 91  100-500
# 92  100-500
# 93  100-500
# 94  >=500
# 95  >=500
# 96  >=500
# 97  >=500
# 98  >=500
# 99  100-500
# 100 100-500
# 101 100-500
# 102 >=500
# 103 >=500
# 104 >=500
# 105 >=500
# 106 >=500
# 107 >=500
# 108 100-500
# 109 100-500
# 110 100-500
# 111 100-500
# 112 100-500
# 113 100-500
# 114 100-500
# 115 100-500
# 116 100-500
# 117 100-500
# 118 100-500
# 119 100-500
# 120 100-500
# Warning message:
# “Expected 3 pieces. Additional pieces discarded in 11 rows [56, 72, 77, 79, 92, 98, 133, 160, 167, 178, 183].”
# Warning message:
# “Expected 3 pieces. Missing pieces filled with `NA` in 133 rows [1, 2, 5, 6, 7, 8, 9, 10, 12, 13, 15, 17, 18, 19, 20, 21, 23, 25, 26, 27, ...].”
#    genus             n
# 1  Deinococcus       9
# 2  Corynebacterium   7
# 3  Bifidobacterium   6
# 4  Staphylococcus    6
# 5  Microbacterium    5
# 6  Prevotella        5
# 7  Streptococcus     4
# 8  Acinetobacter     3
# 9  Agrobacterium     3
# 10 Cutibacterium     3
# 11 Human             3
# 12 Paraburkholderia  3
# 13 Paracoccus        3
# 14 Burkholderia      2
# 15 Delftia           2
# 16 Fusobacterium     2
# 17 Lactobacillus     2
# 18 Neisseria         2
# 19 Roseomonas        2
# 20 Rothia            2
# 21 Torque            2
# 22 Veillonella       2
# 23 Acidovorax        1
# 24 Actinomyces       1
# 25 Anaerostipes      1
# 26 Aquabacterium     1
# 27 Bacillus          1
# 28 Bacteroides       1
# 29 Burkholderiales   1
# 30 Chryseobacterium  1
# ⋮  ⋮                 ⋮
# 35 Enterobacter      1
# 36 Escherichia       1
# 37 Faecalibacterium  1
# 38 Gardnerella       1
# 39 Gemella           1
# 40 Haemophilus       1
# 41 Hepatitis         1
# 42 Klebsiella        1
# 43 Leptothrix        1
# 44 Massilia          1
# 45 Megasphaera       1
# 46 Methylibium       1
# 47 Micrococcus       1
# 48 Mitsuaria         1
# 49 Moraxella         1
# 50 Pantoea           1
# 51 Paucibacter       1
# 52 Porphyromonas     1
# 53 Propionibacterium 1
# 54 Pseudomonas       1
# 55 Pseudonocardia    1
# 56 Ramlibacter       1
# 57 Rhizobacter       1
# 58 Rhodococcus       1
# 59 Rickettsia        1
# 60 Roseateles        1
# 61 Rubrivivax        1
# 62 Rubrobacter       1
# 63 Variovorax        1
# 64 Zhihengliuella    1

# %%
# species_df %>% 
#     filter(npm_research_id == "0416-0024") %>%
#     pivot_longer(!npm_research_id, names_to = "taxa", values_to = "read_count") %>%
#     arrange(desc(read_count))

# %%
taxon <- "Gardnerella vaginalis"
# taxon <- "Bacillus cereus"
taxon <- "Human mastadenovirus C"
taxon <- "Cutibacterium acnes"
taxon <- "Staphylococcus haemolyticus"
taxon <- "Pseudomonas mendocina"
taxon <- "Achromobacter xylosoxidans"
taxon <- "Fusobacterium nucleatum"
# taxon <- "Ralstonia solanacearum"
# taxon <- "Paracoccus yeei"
taxon <- "Neisseria subflava"
taxon <- "Haemophilus parainfluenzae"
taxon <- "Rickettsia felis"
taxon <- "Corynebacterium segmentosum"
taxon <- "Enterobacter cloacae"
taxon <- "Staphylococcus epidermidis"
taxon <- "Staphylococcus cohnii"
taxon <- "Pseudomonas stutzeri"
max_count <- prev_max_filt[prev_max_filt$taxa == taxon, ]$max_count

id <- (species_zeroed %>%
    filter(get(taxon) == max_count))$npm_research_id
print(id)

species_RA_filt <- otu_to_RA(species_zeroed %>% select(all_of(c("npm_research_id", prev_max_filt$taxa))))
species_RA_filt %>% 
    filter(npm_research_id == id) %>%
    select(all_of(c(taxon)))

species_zeroed %>%
    select(all_of(c("npm_research_id", taxon))) %>%
    arrange(desc(get(taxon))) %>%
#     filter(get(taxon) > 100) %>%
    ggplot(aes(x = log(get(taxon), base = 10))) +
    geom_histogram() +
    labs(x = "log(read count, base = 10)", y = "No. of libraries", title = taxon)

species_RA_filt %>% 
    select(all_of(c(taxon))) %>%
    filter(get(taxon) > 0) %>%
    ggplot(aes(x = get(taxon))) +
    geom_histogram() +
    labs(x = "Relative abundance", y = "No. of libraries", title = taxon)

species_zeroed %>% 
    filter(get(taxon) > 0) %>%
    select(all_of(c("npm_research_id", taxon))) %>%
    arrange(desc(get(taxon)))
# Out:
# [1] "0816-0014"
#   Pseudomonas stutzeri
# 1 0.01643001
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 8395 rows containing non-finite values (stat_bin).”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
#     npm_research_id Pseudomonas stutzeri
# 1   0816-0014       33747
# 2   0715-0061       32688
# 3   0415-0080       29149
# 4   0715-0059       25388
# 5   0416-0089       22716
# 6   0316-0061       21534
# 7   0516-0003       20917
# 8   0516-0038       20875
# 9   0416-0038       20739
# 10  0516-0019       20257
# 11  0516-0033       20186
# 12  0715-0045       20078
# 13  0515-0019       19637
# 14  0615-0016       19635
# 15  0416-0084       19444
# 16  0416-0092       19081
# 17  0516-0028       18686
# 18  0416-0062       18618
# 19  0416-0031       18598
# 20  0615-0018       18504
# 21  0515-0023       18462
# 22  0815-0037       18313
# 23  0416-0049       17534
# 24  0516-0004       17469
# 25  0715-0074       17408
# 26  0516-0042       17270
# 27  0515-0054       17264
# 28  0615-0038       17203
# 29  0715-0054       17090
# 30  0615-0015       17044
# ⋮   ⋮               ⋮
# 193 0816-0077       97
# 194 WHB6463         90
# 195 WHH1458         89
# 196 WHB7707         75
# 197 WHB8139         68
# 198 WHB9713         63
# 199 WHB7620         63
# 200 WHB7724         49
# 201 WHB8794         43
# 202 WHB8194         42
# 203 WHB7013         39
# 204 WHB7262         33
# 205 WHH1825         27
# 206 WHB6876         27
# 207 WHB783          22
# 208 WHB6831         22
# 209 WHB4078         19
# 210 WHH4856         18
# 211 WHB4491         17
# 212 WHH1552         17
# 213 WHB7713         17
# 214 WHB4695         17
# 215 WHB6928         16
# 216 WHH1782         15
# 217 WHH1361         14
# 218 WHB4329         14
# 219 WHH990          13
# 220 WHB535          12
# 221 WHB4447         12
# 222 WHH1827         11
# plot without title
