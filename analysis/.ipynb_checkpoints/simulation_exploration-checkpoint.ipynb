# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(tidyverse)
require(ggplot2)
require(data.table)
require(egg)
require(foreach)
require(doParallel)
registerDoParallel(cores=8)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: egg
#
# Loading required package: gridExtra
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: parallel

# %% [markdown]
# ## Pre-process data

# %%
load_data <- function(file_path) {
    df <- fread(file_path) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}

to_retain <- fread("data/samples_above_95_reads.txt")$npm_research_id

species_df <- load_data(str_glue("data/temp_files_9999/07_abundance_matrix/abundance_matrix.subset_9999.S.tsv"))

# rank <- "G"
# genus_df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>%
#     filter(npm_research_id %in% to_retain)

meta <- fread("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv") %>%
    as_tibble()

# %%
get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id|site_supplying", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}

meta_cols <- get_meta_cols(meta)
# meta_cols <- c("extraction_kit", "site_supplying_sample", "instrument_id")

# %% [markdown]
# ### Parameters for simulations

# %%
median(meta$error_rate)
med_library_depth <- median(meta$raw_total_sequences)
med_microbial_depth <- median(rowSums(species_df %>% select(-npm_research_id, -unclassified, -"Homo sapiens")))
med_library_depth
median(meta$insert_size_average)
# Out:
# [1] 0.006573206
# [1] 373365373
# [1] 318

# %%
micro_df <- species_df %>% select(-npm_research_id, -unclassified, -"Homo sapiens")
rowsum_df <- tibble(npm_research_id = species_df$npm_research_id, rowsums = rowSums(micro_df))
rowsum_df <- rowsum_df %>%
    left_join(meta) %>%
    mutate(microbe_frac = (rowsums * 2) / raw_total_sequences, .before = 2)
rowsum_df
# Out:
# Joining, by = "npm_research_id"
#      npm_research_id microbe_frac rowsums multiplex_pool_id supplier_id
# 1    WHB669          1.965706e-06    377  MUX5172           CG-CTR-0454
# 2    WHB8678         6.566073e-05  12050  MUX10495          17003-2474
# 3    WHH7080         4.359685e-05   6725  MUX8946           01999
# 4    WHB4818         5.442242e-07    183  MUX9298           020-50145
# 5    WHB9470         8.387687e-05  15698  MUX9565           02753
# 6    WHB4637         7.178605e-06   2981  MUX9235           010-20811
# 7    WHH891          4.837169e-07     77  MUX3434           IS33788
# 8    WHB3974         1.762617e-05   6233  MUX9016           020-66017
# 9    WHB7065         2.328698e-06    416  MUX10137          17003-0861
# 10   WHB8830         5.364870e-05  10001  MUX9710           01717
# 11   WHH1586         5.694904e-07     99  MUX4068           CS53512
# 12   WHB7956         2.583108e-04  49274  MUX10566          17003-1752
# 13   WHB6790         5.249720e-06   1103  MUX10073          17003-0586
# 14   WHH1857         5.987857e-07    110  MUX4127           MS16704
# 15   WHH6873         1.928009e-04  37313  MUX8837           01789
# 16   WHB7476         1.776501e-04  35657  MUX10267          17003-1272
# 17   WHH1107         4.066843e-07     76  MUX3936           IS31479
# 18   WHB11053        8.069124e-05  15916  MUX10688          17003-2901
# 19   WHH1078         7.428292e-07    124  MUX3936           IS40310
# 20   WHB9042         5.582442e-05   9585  MUX9576           02318
# 21   WHB5386         4.055486e-04 154360  MUX8432           0518-0088
# 22   WHH4937         3.658921e-07     61  MUX5305           CG-CTR-1214
# 23   WHH766          7.065475e-07    127  MUX3381           IS38245
# 24   WHB7157         6.469585e-06   1031  MUX10177          17003-0953
# 25   WHH1653         2.094779e-05   3482  MUX4095           CS61436
# 26   WHB9075         2.183839e-05   3497  MUX9499           02354
# 27   WHB6917         2.188169e-06    435  MUX10103          17003-0713
# 28   WHB5810         2.880954e-05   4830  MUX8776           01635
# 29   WHB9248         1.209230e-04  20984  MUX9509           02529
# 30   WHB8945         3.708370e-05   6634  MUX9448           02206
# ⋮    ⋮               ⋮            ⋮       ⋮                 ⋮
# 9677 WHB3857         5.721526e-06   2044  MUX8960           020-66123
# 9678 WHB8402         7.637778e-05  14489  MUX10429          17003-2198
# 9679 WHB7889         4.111570e-07     62  MUX10324          17003-1685
# 9680 WHB10311        1.447330e-04  27712  MUX9868           03189
# 9681 WHH922          7.942676e-07    122  MUX3529           IS40785
# 9682 WHB4108         5.384518e-06   1782  MUX9056           010-20494
# 9683 WHB3591         5.605380e-04 185721  MUX8186           0916-0044
# 9684 WHB5362         1.710598e-05   5828  MUX8390           CS50650
# 9685 WHB6801         3.401352e-06    660  MUX10074          17003-0597
# 9686 WHB1065         3.213181e-06    471  MUX5848           CG-CTR-2262
# 9687 WHH2152         2.657294e-07     42  MUX4150           MS18588
# 9688 WHB7938         3.430111e-05   7752  MUX10328          17003-1734
# 9689 WHB9984         1.551576e-04  24299  MUX9690           00333
# 9690 WHB10068        4.352802e-05   6355  MUX9707           00481
# 9691 WHH1517         1.120451e-05   2141  MUX4050           CS55643
# 9692 WHB4873         1.156723e-03 502114  MUX8258           0617-0064
# 9693 WHB4699         9.651248e-07    372  MUX9247           029-04273
# 9694 WHH689          3.042068e-07     50  MUX3359           IS41051
# 9695 WHB9883         6.131568e-05  10385  MUX9671           01421
# 9696 WHB713          3.926052e-07     71  MUX5185           CG-CTR-0571
# 9697 WHB1060         3.452051e-06    624  MUX5540           CG-CTR-2255
# 9698 WHB8417         8.436888e-06   1506  MUX10432          17003-2213
# 9699 WHB6339         1.269043e-06    230  MUX9998           17003-0154
# 9700 WHB8356         1.163444e-04  24999  MUX10448          17003-2152
# 9701 WHB7090         1.221559e-05   2152  MUX10164          17003-0886
# 9702 0116-0039       1.402905e-03 574527  PRISM_topup       0116-0039
# 9703 WHB5654         1.187654e-05   1965  MUX8718           01425
# 9704 WHB9085         3.638580e-05   6347  MUX9501           02364
# 9705 WHH7014         3.422007e-05   5627  MUX8866           01932
# 9706 WHB9254         2.122465e-04  33580  MUX9510           02535
#      gis_internal_sample_id    site_supplying_sample year_of_birth
# 1    TTSH_CG_CTR_0454_1        TTSH                  1987
# 2    MEC_17003_2474_1          MEC                   1980
# 3    NTU_01999_1               HELIOS                1957
# 4    GUSTO_Kids_020_50145_1    GUSTO                 2010
# 5    HELIOS_02753_1            HELIOS                1961
# 6    GUSTO_Kids_010_20811_1    GUSTO                 2010
# 7    SERI_IS33788_1            SERI                  1964
# 8    GUSTO_Kids_020_66017_1    GUSTO                 2010
# 9    MEC_17003_0861_1          MEC                   1955
# 10   HELIOS_01717_2            HELIOS                1970
# 11   SERI_CS53512_1            SERI                  1956
# 12   MEC_17003_1752_1          MEC                   1940
# 13   MEC_17003_0586_1          MEC                   1958
# 14   SERI_MS16704_1            SERI                  1949
# 15   NTU_01789_1               HELIOS                1961
# 16   MEC_17003_1272_1          MEC                   1979
# 17   SERI_IS31479_1            SERI                  1952
# 18   MEC_17003_2901_1          MEC                   1955
# 19   SERI_IS40310_1            SERI                  1964
# 20   NTU_02318_1               HELIOS                1956
# 21   PRISM_0518_0088_NHC_SLH_1 PRISM                 1970
# 22   TTSH_CG_CTR_1214_1        TTSH                  1969
# 23   SERI_IS38245_1            SERI                  1960
# 24   MEC_17003_0953_1          MEC                   1967
# 25   SEED_CS61436_2            SERI                  1961
# 26   NTU_02354_1               HELIOS                1988
# 27   MEC_17003_0713_1          MEC                   1958
# 28   NTU_01635_1               HELIOS                1973
# 29   NTU_02529_1               HELIOS                1953
# 30   NTU_02206_1               HELIOS                1981
# ⋮    ⋮                         ⋮                     ⋮
# 9677 GUSTO_Kids_020_66123_1    GUSTO                 2010
# 9678 MEC_17003_2198_1          MEC                   1957
# 9679 MEC_17003_1685_1          MEC                   1944
# 9680 HELIOS_03189_1            HELIOS                1957
# 9681 SERI_IS40785_1            SERI                  1963
# 9682 GUSTO_Kids_010_20494_1    GUSTO                 2011
# 9683 PRISM_0916_0044_NHC_TGK_1 PRISM                 1957
# 9684 PRISM_CS50650_1           PRISM                 1954
# 9685 MEC_17003_0597_1          MEC                   1956
# 9686 TTSH_CG_CTR_2262_1        TTSH                  1972
# 9687 SERI_MS18588_1            SERI                  1955
# 9688 MEC_17003_1734_1          MEC                   1951
# 9689 HELIOS_00333_1            HELIOS                1972
# 9690 HELIOS_00481_1            HELIOS                1955
# 9691 SERI_CS55643_1            SERI                  1953
# 9692 PRISM_0617_0064_NHC_TWK_1 PRISM                 1990
# 9693 GUSTO_Kids_029_04273_1    GUSTO                 2010
# 9694 SERI_IS41051_1            SERI                  1961
# 9695 HELIOS_01421_1            HELIOS                1966
# 9696 TTSH_CG_CTR_0571_1        TTSH                  1975
# 9697 TTSH_CG_CTR_2255_1        TTSH                  1993
# 9698 MEC_17003_2213_1          MEC                   1949
# 9699 MEC_17003_0154_1          MEC                   1969
# 9700 MEC_17003_2152_1          MEC                   1957
# 9701 MEC_17003_0886_1          MEC                   1953
# 9702 PRISM_0116_0039_CYW_1     PRISM                 1969
# 9703 NTU_01425_1               HELIOS                1986
# 9704 NTU_02364_1               HELIOS                1957
# 9705 NTU_01932_1               HELIOS                1960
# 9706 NTU_02535_1               HELIOS                1960
#      supplied_gender self_reported_ethnicity ⋯
# 1    F               Indian                  ⋯
# 2    F               Indian                  ⋯
# 3    M               Chinese                 ⋯
# 4    F               Chinese                 ⋯
# 5    F               Chinese                 ⋯
# 6    M               Indian                  ⋯
# 7    F               Indian                  ⋯
# 8    M               Chinese                 ⋯
# 9    M               Chinese                 ⋯
# 10   M               Chinese                 ⋯
# 11   M               Chinese                 ⋯
# 12   M               Chinese                 ⋯
# 13   M               Chinese                 ⋯
# 14   M               Malay                   ⋯
# 15   F               Chinese                 ⋯
# 16   F               Indian                  ⋯
# 17   M               Indian                  ⋯
# 18   F               Chinese                 ⋯
# 19   F               Indian                  ⋯
# 20   F               Chinese                 ⋯
# 21   M               Chinese                 ⋯
# 22   F               Chinese                 ⋯
# 23   F               Indian                  ⋯
# 24   M               Indian                  ⋯
# 25   F               Chinese                 ⋯
# 26   F               Indian                  ⋯
# 27   M               Indian                  ⋯
# 28   F               Chinese                 ⋯
# 29   F               Chinese                 ⋯
# 30   M               Chinese                 ⋯
# ⋮    ⋮               ⋮                       ⋱
# 9677 M               Indian                  ⋯
# 9678 M               Indian                  ⋯
# 9679 M               Chinese                 ⋯
# 9680 M               Malay                   ⋯
# 9681 F               Indian                  ⋯
# 9682 F               Malay                   ⋯
# 9683 F               Chinese                 ⋯
# 9684 M               Chinese                 ⋯
# 9685 F               Chinese                 ⋯
# 9686 F               Chinese                 ⋯
# 9687 F               Malay                   ⋯
# 9688 M               Malay                   ⋯
# 9689 F               Chinese                 ⋯
# 9690 M               Chinese                 ⋯
# 9691 F               Chinese                 ⋯
# 9692 M               Chinese                 ⋯
# 9693 F               Chinese                 ⋯
# 9694 F               Indian                  ⋯
# 9695 F               Chinese                 ⋯
# 9696 M               Chinese                 ⋯
# 9697 F               Indian                  ⋯
# 9698 M               Indian                  ⋯
# 9699 F               Indian                  ⋯
# 9700 F               Chinese                 ⋯
# 9701 M               Chinese                 ⋯
# 9702 M               Chinese                 ⋯
# 9703 F               Chinese                 ⋯
# 9704 F               Chinese                 ⋯
# 9705 F               Chinese                 ⋯
# 9706 F               Chinese                 ⋯
#      supplied_and_computed_gender_match
# 1    Y
# 2    Y
# 3    Y
# 4    Y
# 5    Y
# 6    Y
# 7    Y
# 8    Y
# 9    Y
# 10   Y
# 11   Y
# 12   Y
# 13   Y
# 14   Y
# 15   Y
# 16   Y
# 17   Y
# 18   Y
# 19   Y
# 20   Y
# 21   Y
# 22   Y
# 23   Y
# 24   Y
# 25   Y
# 26   Y
# 27   Y
# 28   Y
# 29   Y
# 30   Y
# ⋮    ⋮
# 9677 Y
# 9678 Y
# 9679 Y
# 9680 Y
# 9681 Y
# 9682 Y
# 9683 Y
# 9684 Y
# 9685 Y
# 9686 Y
# 9687 Y
# 9688 Y
# 9689 Y
# 9690 Y
# 9691 Y
# 9692 Y
# 9693 Y
# 9694 Y
# 9695 Y
# 9696 Y
# 9697 Y
# 9698 Y
# 9699 Y
# 9700 Y
# 9701 Y
# 9702 Y
# 9703 Y
# 9704 Y
# 9705 Y
# 9706 Y
#      sop_agreement_for_coverage__14/_28_for_15x/30x sample_life_cycle current
# 1    Y                                              TTSH VCF          Y
# 2    Y                                              MEC VCF           Y
# 3    N                                              HELIOS VCF        Y
# 4    Y                                              GUSTO_Kids VCF    Y
# 5    Y                                              HELIOS VCF        Y
# 6    Y                                              GUSTO_Kids VCF    Y
# 7    N                                              SEED VCF          Y
# 8    Y                                              GUSTO_Kids VCF    Y
# 9    Y                                              MEC VCF           Y
# 10   Y                                              HELIOS VCF        Y
# 11   N                                              SEED VCF          Y
# 12   Y                                              MEC VCF           Y
# 13   Y                                              MEC VCF           Y
# 14   Y                                              SEED VCF          Y
# 15   Y                                              HELIOS VCF        Y
# 16   Y                                              MEC VCF           Y
# 17   Y                                              SEED VCF          Y
# 18   Y                                              MEC VCF           Y
# 19   N                                              SEED VCF          Y
# 20   Y                                              HELIOS VCF        Y
# 21   Y                                              PRISM VCF         Y
# 22   Y                                              TTSH VCF          Y
# 23   Y                                              SEED VCF          Y
# 24   N                                              MEC VCF           Y
# 25   N                                              SEED VCF          Y
# 26   N                                              HELIOS VCF        Y
# 27   Y                                              MEC VCF           Y
# 28   Y                                              HELIOS VCF        Y
# 29   Y                                              HELIOS VCF        Y
# 30   Y                                              HELIOS VCF        Y
# ⋮    ⋮                                              ⋮                 ⋮
# 9677 Y                                              GUSTO_Kids VCF    Y
# 9678 Y                                              MEC VCF           Y
# 9679 N                                              MEC VCF           Y
# 9680 Y                                              HELIOS VCF        Y
# 9681 N                                              SEED VCF          Y
# 9682 N                                              GUSTO_Kids VCF    Y
# 9683 Y                                              PRISM VCF         Y
# 9684 Y                                              PRISM VCF         Y
# 9685 Y                                              MEC VCF           Y
# 9686 N                                              TTSH VCF          Y
# 9687 N                                              SEED VCF          Y
# 9688 Y                                              MEC VCF           Y
# 9689 N                                              HELIOS VCF        Y
# 9690 N                                              HELIOS VCF        Y
# 9691 Y                                              SEED VCF          Y
# 9692 Y                                              PRISM VCF         Y
# 9693 Y                                              GUSTO_Kids VCF    Y
# 9694 N                                              SEED VCF          Y
# 9695 Y                                              HELIOS VCF        Y
# 9696 Y                                              TTSH VCF          Y
# 9697 Y                                              TTSH VCF          Y
# 9698 Y                                              MEC VCF           Y
# 9699 Y                                              MEC VCF           Y
# 9700 Y                                              MEC VCF           Y
# 9701 Y                                              MEC VCF           Y
# 9702 Y                                              PRISM VCF         Y
# 9703 N                                              HELIOS VCF        Y
# 9704 Y                                              HELIOS VCF        Y
# 9705 Y                                              HELIOS VCF        Y
# 9706 N                                              HELIOS VCF        Y
#      source_cohort original_supplier_id duplicate_info duplicate duplicate_pair
# 1    TTSH_mini     CG-CTR-0454          Unknown        PASS      Unknown
# 2    MEC           17003-2474           Unknown        PASS      Unknown
# 3    HELIOS        01999                Unknown        PASS      Unknown
# 4    GUSTO_Kids    020-50145            Unknown        PASS      Unknown
# 5    HELIOS        02753                Unknown        PASS      Unknown
# 6    GUSTO_Kids    010-20811            Unknown        PASS      Unknown
# 7    SEED_mini     IS33788              Unknown        PASS      Unknown
# 8    GUSTO_Kids    020-66017            Unknown        PASS      Unknown
# 9    MEC           17003-0861           Unknown        PASS      Unknown
# 10   HELIOS        01717                Unknown        PASS      Unknown
# 11   SEED_mini     CS53512              Unknown        PASS      Unknown
# 12   MEC           17003-1752           Unknown        PASS      Unknown
# 13   MEC           17003-0586           Unknown        PASS      Unknown
# 14   SEED_mini     MS16704              Unknown        PASS      Unknown
# 15   HELIOS        01789                Unknown        PASS      Unknown
# 16   MEC           17003-1272           Unknown        PASS      Unknown
# 17   SEED_mini     IS31479              Unknown        PASS      Unknown
# 18   MEC           17003-2901           Unknown        PASS      Unknown
# 19   SEED_mini     IS40310              Unknown        PASS      Unknown
# 20   HELIOS        02318                Unknown        PASS      Unknown
# 21   PRISM         0518-0088/NHC/SLH    Unknown        PASS      Unknown
# 22   TTSH_TP       CG-CTR-1214          Unknown        PASS      Unknown
# 23   SEED_mini     IS38245              Unknown        PASS      Unknown
# 24   MEC           17003-0953           Unknown        PASS      Unknown
# 25   SEED_TP       CS61436              Unknown        PASS      Unknown
# 26   HELIOS        02354                Unknown        PASS      Unknown
# 27   MEC           17003-0713           Unknown        PASS      Unknown
# 28   HELIOS        01635                Unknown        PASS      Unknown
# 29   HELIOS        02529                Unknown        PASS      Unknown
# 30   HELIOS        02206                Unknown        PASS      Unknown
# ⋮    ⋮             ⋮                    ⋮              ⋮         ⋮
# 9677 GUSTO_Kids    020-66123            Unknown        PASS      Unknown
# 9678 MEC           17003-2198           Unknown        PASS      Unknown
# 9679 MEC           17003-1685           Unknown        PASS      Unknown
# 9680 HELIOS        03189                Unknown        PASS      Unknown
# 9681 SEED_mini     IS40785              Unknown        PASS      Unknown
# 9682 GUSTO_Kids    010-20494            Unknown        PASS      Unknown
# 9683 PRISM         0916-0044/NHC/TGK    Unknown        PASS      Unknown
# 9684 PRISM         CS50650              Unknown        PASS      Unknown
# 9685 MEC           17003-0597           Unknown        PASS      Unknown
# 9686 TTSH_TP       CG-CTR-2262          Unknown        PASS      Unknown
# 9687 SEED_mini     MS18588              Unknown        PASS      Unknown
# 9688 MEC           17003-1734           Unknown        PASS      Unknown
# 9689 HELIOS        00333                Unknown        PASS      Unknown
# 9690 HELIOS        00481                Unknown        PASS      Unknown
# 9691 SEED_mini     CS55643              Unknown        PASS      Unknown
# 9692 PRISM         0617-0064/NHC/TWK    Unknown        PASS      Unknown
# 9693 GUSTO_Kids    029-04273            Unknown        PASS      Unknown
# 9694 SEED_mini     IS41051              Unknown        PASS      Unknown
# 9695 HELIOS        01421                Unknown        PASS      Unknown
# 9696 TTSH_TP       CG-CTR-0571          Unknown        PASS      Unknown
# 9697 TTSH_TP       CG-CTR-2255          Unknown        PASS      Unknown
# 9698 MEC           17003-2213           Unknown        PASS      Unknown
# 9699 MEC           17003-0154           Unknown        PASS      Unknown
# 9700 MEC           17003-2152           Unknown        PASS      Unknown
# 9701 MEC           17003-0886           Unknown        PASS      Unknown
# 9702 PRISM_TP      0116-0039-CYW        Unknown        PASS      Unknown
# 9703 HELIOS        01425                Unknown        PASS      Unknown
# 9704 HELIOS        02364                Unknown        PASS      Unknown
# 9705 HELIOS        01932                Unknown        PASS      Unknown
# 9706 HELIOS        02535                Unknown        PASS      Unknown
#      removal_requested_by_supplier
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# 5    Unknown
# 6    Unknown
# 7    Unknown
# 8    Unknown
# 9    Unknown
# 10   Unknown
# 11   Unknown
# 12   Unknown
# 13   Unknown
# 14   Unknown
# 15   Unknown
# 16   Unknown
# 17   Unknown
# 18   Unknown
# 19   Unknown
# 20   Unknown
# 21   Unknown
# 22   Unknown
# 23   Unknown
# 24   Unknown
# 25   Unknown
# 26   Unknown
# 27   Unknown
# 28   Unknown
# 29   Unknown
# 30   Unknown
# ⋮    ⋮
# 9677 Unknown
# 9678 Unknown
# 9679 Unknown
# 9680 Unknown
# 9681 Unknown
# 9682 Unknown
# 9683 Unknown
# 9684 Unknown
# 9685 Unknown
# 9686 Unknown
# 9687 Unknown
# 9688 Unknown
# 9689 Unknown
# 9690 Unknown
# 9691 Unknown
# 9692 Unknown
# 9693 Unknown
# 9694 Unknown
# 9695 Unknown
# 9696 Unknown
# 9697 Unknown
# 9698 Unknown
# 9699 Unknown
# 9700 Unknown
# 9701 Unknown
# 9702 Unknown
# 9703 Unknown
# 9704 Unknown
# 9705 Unknown
# 9706 Unknown

# %%
rowsum_df %>% 
    ggplot(aes(x = log(rowsums,base = 10))) +
    geom_histogram(bins = 50) +
    labs(x = "log(microbial reads, base = 10)", y = "No. of samples")
# Out:
# Warning message:
# “Removed 55 rows containing non-finite values (stat_bin).”
# plot without title

# %%
rowsum_df %>% 
#     filter(rowsums < 5000) %>%
    ggplot(aes(x = log(microbe_frac,base = 10))) +
    geom_histogram(bins = 50) +
    labs(x = "Log(microbial fraction, base = 10)", y = "No. of samples")
# Out:
# Warning message:
# “Removed 55 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# #### No. of taxa in blanks

# %%
care_df <- read.csv("data/reported_controls/raw_files/caregiver.table.s.tsv", sep = "") %>%
  rownames_to_column("taxa")

care_meta <- fread("data/reported_controls/raw_files/caregiver.meta.tsv")

controls <- care_meta %>%
    filter(sample_category == "blank")
controls <- controls$LibraryID

care_df <- care_df %>% 
    select(all_of(c("taxa", controls))) %>%
    mutate(taxa = gsub("\\[|\\]", "", taxa)) %>%
    mutate(taxa = gsub("_", " ", taxa)) %>%
    select(-taxa)

care_df[care_df <= 100] <- 0
care_df[care_df > 100] <- 1

apply(care_df, 2, sum)
# Out:
# WHB11420 WHB11437 WHB11438 WHB11439 WHB11687
#      149      169       88       96      143

# %% [markdown]
# # Finding presence absence threshold

# %% [markdown]
# #### No. of assigned species per sample

# %%
test_prev %>%
    left_join(rowsum_df) %>%
    filter(rowsums <= 100)
# Out:
# Joining, by = "npm_research_id"
#      npm_research_id n_assigned microbe_frac rowsums multiplex_pool_id
# 1    WHH891          36         4.837169e-07 77      MUX3434
# 2    WHH1586         67         5.694904e-07 99      MUX4068
# 3    WHH1107         49         4.066843e-07 76      MUX3936
# 4    WHH4937         23         3.658921e-07 61      MUX5305
# 5    WHH533          27         4.241334e-07 72      MUX3316
# 6    WHH4924         47         5.224353e-07 95      MUX5325
# 7    WHH1855         23         2.073730e-07 36      MUX4127
# 8    WHH881          39         4.188714e-07 74      MUX3434
# 9    WHH1896         19         2.057246e-07 37      MUX4127
# 10   WHH619          26         3.413649e-07 61      MUX3316
# 11   WHH2194         21         2.904333e-07 49      MUX4150
# 12   WHH774          35         5.331770e-07 92      MUX3381
# 13   WHH430          35         4.579560e-07 83      MUX3275
# 14   WHH2148         22         2.189039e-07 38      MUX4150
# 15   WHH2154         23         2.729851e-07 53      MUX4150
# 16   WHH1099         14         1.829035e-07 29      MUX3936
# 17   WHH5017         19         1.490405e-07 27      MUX5243
# 18   WHH1894         15         2.305753e-07 35      MUX4127
# 19   WHH2196         31         3.926638e-07 65      MUX4150
# 20   WHB850          33         3.670734e-07 69      MUX5254
# 21   WHH892          42         5.086180e-07 95      MUX3434
# 22   WHH785          34         4.455088e-07 85      MUX3381
# 23   WHH1851         42         3.752245e-07 65      MUX4127
# 24   WHH1002         48         5.003862e-07 84      MUX3529
# 25   WHH1877         37         4.550685e-07 88      MUX4127
# 26   WHH693          24         3.846067e-07 70      MUX3359
# 27   WHH4982         23         1.595981e-07 29      MUX5310
# 28   WHH4972         32         2.445574e-07 42      MUX5309
# 29   WHH905          37         4.697495e-07 87      MUX3434
# 30   WHH1313         42         4.189459e-07 55      MUX3969
# ⋮    ⋮               ⋮          ⋮            ⋮       ⋮
# 1065 WHH564          23         2.156306e-07 36      MUX3316
# 1066 WHH1926         24         2.692379e-07 51      MUX4127
# 1067 WHH603          34         4.058229e-07 74      MUX3316
# 1068 WHH889          31         4.474176e-07 71      MUX3434
# 1069 WHH1079         35         3.441342e-07 62      MUX3936
# 1070 WHH740          34         4.018097e-07 66      MUX3381
# 1071 WHH5067         26         2.628838e-07 46      MUX5247
# 1072 WHH637          28         3.187279e-07 54      MUX3359
# 1073 WHH633          37         3.412344e-07 67      MUX3359
# 1074 WHH1785         21         2.252918e-07 49      MUX4111
# 1075 WHH690          34         4.959845e-07 81      MUX3359
# 1076 WHH589          23         3.440928e-07 55      MUX3316
# 1077 WHH598          38         4.269699e-07 80      MUX3316
# 1078 WHB7712         21         1.658079e-07 28      MUX9979
# 1079 WHH4970         13         1.048726e-07 16      MUX5309
# 1080 WHH1104         29         2.876837e-07 54      MUX3936
# 1081 WHH1173         27         4.638361e-07 86      MUX3949
# 1082 WHH819          35         4.553635e-07 69      MUX3434
# 1083 WHB769          39         4.366428e-07 77      MUX5227
# 1084 WHB742          52         4.733290e-07 87      MUX5323
# 1085 WHH646          21         2.376411e-07 41      MUX3359
# 1086 WHH429          19         2.320606e-07 40      MUX3275
# 1087 SSM059           0         0.000000e+00  0      SSMP_050_to_059
# 1088 WHH557          21         3.091097e-07 49      MUX3316
# 1089 WHH4932         17         1.013909e-07 17      MUX5299
# 1090 WHH461          41         4.448902e-07 77      MUX3275
# 1091 WHB7889         29         4.111570e-07 62      MUX10324
# 1092 WHH2152         23         2.657294e-07 42      MUX4150
# 1093 WHH689          23         3.042068e-07 50      MUX3359
# 1094 WHB713          45         3.926052e-07 71      MUX5185
#      supplier_id gis_internal_sample_id site_supplying_sample year_of_birth
# 1    IS33788     SERI_IS33788_1         SERI                  1964
# 2    CS53512     SERI_CS53512_1         SERI                  1956
# 3    IS31479     SERI_IS31479_1         SERI                  1952
# 4    CG-CTR-1214 TTSH_CG_CTR_1214_1     TTSH                  1969
# 5    IS38429     SERI_IS38429_1         SERI                  1956
# 6    CG-CTR-1190 TTSH_CG_CTR_1190_1     TTSH                  1955
# 7    MS10324     SERI_MS10324_1         SERI                  1951
# 8    IS33559     SERI_IS33559_1         SERI                  1954
# 9    MS25627     SERI_MS25627_1         SERI                  1962
# 10   IS30300     SERI_IS30300_1         SERI                  1948
# 11   MS19756     SERI_MS19756_1         SERI                  1948
# 12   IS31765     SERI_IS31765_1         SERI                  1962
# 13   IS34346     SERI_IS34346_1         SERI                  1949
# 14   MS23648     SERI_MS23648_1         SERI                  1956
# 15   MS18108     SERI_MS18108_1         SERI                  1959
# 16   IS40238     SERI_IS40238_1         SERI                  1960
# 17   CG-CTR-1374 TTSH_CG_CTR_1374_1     TTSH                  1983
# 18   MS17310     SERI_MS17310_1         SERI                  1959
# 19   MS18933     SERI_MS18933_1         SERI                  1963
# 20   CG-CTR-0856 TTSH_CG_CTR_0856_1     TTSH                  1969
# 21   IS35428     SERI_IS35428_1         SERI                  1958
# 22   IS35433     SERI_IS35433_1         SERI                  1962
# 23   MS16656     SERI_MS16656_1         SERI                  1927
# 24   IS40739     SERI_IS40739_1         SERI                  1940
# 25   MS17067     SERI_MS17067_1         SERI                  1960
# 26   IS35565     SERI_IS35565_1         SERI                  1956
# 27   CG-CTR-1302 TTSH_CG_CTR_1302_1     TTSH                  1971
# 28   CG-CTR-1285 TTSH_CG_CTR_1285_1     TTSH                  1963
# 29   IS41549     SERI_IS41549_1         SERI                  1930
# 30   CS50117     SERI_CS50117_1         SERI                  1946
# ⋮    ⋮           ⋮                      ⋮                     ⋮
# 1065 IS36879     SERI_IS36879_1         SERI                  1963
# 1066 MS25227     SERI_MS25227_1         SERI                  1959
# 1067 IS37712     SERI_IS37712_1         SERI                  1947
# 1068 IS37612     SERI_IS37612_1         SERI                  1963
# 1069 IS39678     SERI_IS39678_1         SERI                  1955
# 1070 IS30564     SERI_IS30564_1         SERI                  1964
# 1071 CG-CTR-1468 TTSH_CG_CTR_1468_1     TTSH                  1959
# 1072 IS37351     SERI_IS37351_1         SERI                  1960
# 1073 IS36992     SERI_IS36992_1         SERI                  1948
# 1074 MS15583     SEED_MS15583_2         SERI                  1958
# 1075 IS35010     SERI_IS35010_1         SERI                  1952
# 1076 IS36568     SERI_IS36568_1         SERI                  1962
# 1077 IS37878     SERI_IS37878_1         SERI                  1953
# 1078 17003-1508  MEC_17003_1508_1       MEC                   1932
# 1079 CG-CTR-1282 TTSH_CG_CTR_1282_1     TTSH                  1979
# 1080 IS32736     SERI_IS32736_1         SERI                  1963
# 1081 CS58440     SERI_CS58440_1         SERI                  1961
# 1082 IS38060     SERI_IS38060_1         SERI                  1961
# 1083 CG-CTR-0693 TTSH_CG_CTR_0693_1     TTSH                  1971
# 1084 CG-CTR-0633 TTSH_CG_CTR_0633_1     TTSH                  1947
# 1085 IS35789     SERI_IS35789_1         SERI                  1961
# 1086 IS30408     SERI_IS30408_1         SERI                  1947
# 1087 SSM059      SE_ASIAN_SSM059_1      SSMP                  1949
# 1088 IS38137     SERI_IS38137_1         SERI                  1963
# 1089 CG-CTR-1204 TTSH_CG_CTR_1204_1     TTSH                  1954
# 1090 IS30160     SERI_IS30160_1         SERI                  1962
# 1091 17003-1685  MEC_17003_1685_1       MEC                   1944
# 1092 MS18588     SERI_MS18588_1         SERI                  1955
# 1093 IS41051     SERI_IS41051_1         SERI                  1961
# 1094 CG-CTR-0571 TTSH_CG_CTR_0571_1     TTSH                  1975
#      supplied_gender ⋯ supplied_and_computed_gender_match
# 1    F               ⋯ Y
# 2    M               ⋯ Y
# 3    M               ⋯ Y
# 4    F               ⋯ Y
# 5    F               ⋯ Y
# 6    F               ⋯ Y
# 7    M               ⋯ Y
# 8    F               ⋯ Y
# 9    F               ⋯ Y
# 10   F               ⋯ Y
# 11   M               ⋯ Y
# 12   M               ⋯ Y
# 13   F               ⋯ Y
# 14   M               ⋯ Y
# 15   F               ⋯ Y
# 16   F               ⋯ Y
# 17   F               ⋯ Y
# 18   M               ⋯ Y
# 19   F               ⋯ Y
# 20   F               ⋯ Y
# 21   F               ⋯ Y
# 22   M               ⋯ Y
# 23   M               ⋯ Y
# 24   F               ⋯ Y
# 25   F               ⋯ Y
# 26   M               ⋯ Y
# 27   F               ⋯ Y
# 28   M               ⋯ Y
# 29   M               ⋯ Y
# 30   F               ⋯ Y
# ⋮    ⋮               ⋱ ⋮
# 1065 F               ⋯ Y
# 1066 F               ⋯ Y
# 1067 F               ⋯ Y
# 1068 F               ⋯ Y
# 1069 F               ⋯ Y
# 1070 F               ⋯ Y
# 1071 F               ⋯ Y
# 1072 F               ⋯ Y
# 1073 M               ⋯ Y
# 1074 F               ⋯ Y
# 1075 F               ⋯ Y
# 1076 M               ⋯ Y
# 1077 M               ⋯ Y
# 1078 F               ⋯ Y
# 1079 F               ⋯ Y
# 1080 F               ⋯ Y
# 1081 F               ⋯ Y
# 1082 F               ⋯ Y
# 1083 F               ⋯ Y
# 1084 F               ⋯ Y
# 1085 M               ⋯ Y
# 1086 F               ⋯ Y
# 1087 F               ⋯ Y
# 1088 F               ⋯ Y
# 1089 M               ⋯ Y
# 1090 F               ⋯ Y
# 1091 M               ⋯ Y
# 1092 F               ⋯ Y
# 1093 F               ⋯ Y
# 1094 M               ⋯ Y
#      sop_agreement_for_coverage__14/_28_for_15x/30x sample_life_cycle current
# 1    N                                              SEED VCF          Y
# 2    N                                              SEED VCF          Y
# 3    Y                                              SEED VCF          Y
# 4    Y                                              TTSH VCF          Y
# 5    N                                              SEED VCF          Y
# 6    Y                                              TTSH VCF          Y
# 7    Y                                              SEED VCF          Y
# 8    Y                                              SEED VCF          Y
# 9    Y                                              SEED VCF          Y
# 10   Y                                              SEED VCF          Y
# 11   N                                              SEED VCF          Y
# 12   Y                                              SEED VCF          Y
# 13   Y                                              SEED VCF          Y
# 14   N                                              SEED VCF          Y
# 15   Y                                              SEED VCF          Y
# 16   N                                              SEED VCF          Y
# 17   Y                                              TTSH VCF          Y
# 18   N                                              SEED VCF          Y
# 19   N                                              SEED VCF          Y
# 20   Y                                              TTSH VCF          Y
# 21   Y                                              SEED VCF          Y
# 22   Y                                              SEED VCF          Y
# 23   Y                                              SEED VCF          Y
# 24   Y                                              SEED VCF          Y
# 25   Y                                              SEED VCF          Y
# 26   N                                              SEED VCF          Y
# 27   Y                                              TTSH VCF          Y
# 28   Y                                              TTSH VCF          Y
# 29   Y                                              SEED VCF          Y
# 30   N                                              SEED VCF          Y
# ⋮    ⋮                                              ⋮                 ⋮
# 1065 N                                              SEED VCF          Y
# 1066 Y                                              SEED VCF          Y
# 1067 Y                                              SEED VCF          Y
# 1068 N                                              SEED VCF          Y
# 1069 Y                                              SEED VCF          Y
# 1070 Y                                              SEED VCF          Y
# 1071 Y                                              TTSH VCF          Y
# 1072 N                                              SEED VCF          Y
# 1073 Y                                              SEED VCF          Y
# 1074 Y                                              SEED VCF          Y
# 1075 N                                              SEED VCF          Y
# 1076 N                                              SEED VCF          Y
# 1077 Y                                              SEED VCF          Y
# 1078 Y                                              MEC VCF           Y
# 1079 N                                              TTSH VCF          Y
# 1080 Y                                              SEED VCF          Y
# 1081 Y                                              SEED VCF          Y
# 1082 N                                              SEED VCF          Y
# 1083 Y                                              TTSH VCF          Y
# 1084 Y                                              TTSH VCF          Y
# 1085 N                                              SEED VCF          Y
# 1086 Y                                              SEED VCF          Y
# 1087 Y                                              SE ASIAN VCF      Y
# 1088 N                                              SEED VCF          Y
# 1089 Y                                              TTSH VCF          Y
# 1090 Y                                              SEED VCF          Y
# 1091 N                                              MEC VCF           Y
# 1092 N                                              SEED VCF          Y
# 1093 N                                              SEED VCF          Y
# 1094 Y                                              TTSH VCF          Y
#      source_cohort original_supplier_id duplicate_info duplicate duplicate_pair
# 1    SEED_mini     IS33788              Unknown        PASS      Unknown
# 2    SEED_mini     CS53512              Unknown        PASS      Unknown
# 3    SEED_mini     IS31479              Unknown        PASS      Unknown
# 4    TTSH_TP       CG-CTR-1214          Unknown        PASS      Unknown
# 5    SEED_mini     IS38429              Unknown        PASS      Unknown
# 6    TTSH_TP       CG-CTR-1190          Unknown        PASS      Unknown
# 7    SEED_mini     MS10324              Unknown        PASS      Unknown
# 8    SEED_mini     IS33559              Unknown        PASS      Unknown
# 9    SEED_mini     MS25627              Unknown        PASS      Unknown
# 10   SEED_mini     IS30300              Unknown        PASS      Unknown
# 11   SEED_mini     MS19756              Unknown        PASS      Unknown
# 12   SEED_mini     IS31765              Unknown        PASS      Unknown
# 13   SEED_mini     IS34346              Unknown        PASS      Unknown
# 14   SEED_mini     MS23648              Unknown        PASS      Unknown
# 15   SEED_mini     MS18108              Unknown        PASS      Unknown
# 16   SEED_mini     IS40238              Unknown        PASS      Unknown
# 17   TTSH_mini     CG-CTR-1374          Unknown        PASS      Unknown
# 18   SEED_mini     MS17310              Unknown        PASS      Unknown
# 19   SEED_mini     MS18933              Unknown        PASS      Unknown
# 20   TTSH_mini     CG-CTR-0856          Unknown        PASS      Unknown
# 21   SEED_mini     IS35428              Unknown        PASS      Unknown
# 22   SEED_mini     IS35433              Unknown        PASS      Unknown
# 23   SEED_mini     MS16656              Unknown        PASS      Unknown
# 24   SEED_mini     IS40739              Unknown        PASS      Unknown
# 25   SEED_mini     MS17067              Unknown        PASS      Unknown
# 26   SEED_mini     IS35565              Unknown        PASS      Unknown
# 27   TTSH_TP       CG-CTR-1302          Unknown        PASS      Unknown
# 28   TTSH_TP       CG-CTR-1285          Unknown        PASS      Unknown
# 29   SEED_mini     IS41549              Unknown        PASS      Unknown
# 30   SEED_mini     CS50117              Unknown        PASS      Unknown
# ⋮    ⋮             ⋮                    ⋮              ⋮         ⋮
# 1065 SEED_mini     IS36879              Unknown        PASS      Unknown
# 1066 SEED_mini     MS25227              Unknown        PASS      Unknown
# 1067 SEED_mini     IS37712              Unknown        PASS      Unknown
# 1068 SEED_mini     IS37612              Unknown        PASS      Unknown
# 1069 SEED_mini     IS39678              Unknown        PASS      Unknown
# 1070 SEED_mini     IS30564              Unknown        PASS      Unknown
# 1071 TTSH_mini     CG-CTR-1468          Unknown        PASS      Unknown
# 1072 SEED_mini     IS37351              Unknown        PASS      Unknown
# 1073 SEED_mini     IS36992              Unknown        PASS      Unknown
# 1074 SEED_TP       MS15583              Unknown        PASS      Unknown
# 1075 SEED_mini     IS35010              Unknown        PASS      Unknown
# 1076 SEED_mini     IS36568              Unknown        PASS      Unknown
# 1077 SEED_mini     IS37878              Unknown        PASS      Unknown
# 1078 MEC           17003-1508           Unknown        PASS      Unknown
# 1079 TTSH_TP       CG-CTR-1282          Unknown        PASS      Unknown
# 1080 SEED_mini     IS32736              Unknown        PASS      Unknown
# 1081 SEED_mini     CS58440              Unknown        PASS      Unknown
# 1082 SEED_mini     IS38060              Unknown        PASS      Unknown
# 1083 TTSH_mini     CG-CTR-0693          Unknown        PASS      Unknown
# 1084 TTSH_TP       CG-CTR-0633          Unknown        PASS      Unknown
# 1085 SEED_mini     IS35789              Unknown        PASS      Unknown
# 1086 SEED_mini     IS30408              Unknown        PASS      Unknown
# 1087 SE ASIAN_TP   SSM059               Unknown        PASS      Unknown
# 1088 SEED_mini     IS38137              Unknown        PASS      Unknown
# 1089 TTSH_mini     CG-CTR-1204          Unknown        PASS      Unknown
# 1090 SEED_mini     IS30160              Unknown        PASS      Unknown
# 1091 MEC           17003-1685           Unknown        PASS      Unknown
# 1092 SEED_mini     MS18588              Unknown        PASS      Unknown
# 1093 SEED_mini     IS41051              Unknown        PASS      Unknown
# 1094 TTSH_TP       CG-CTR-0571          Unknown        PASS      Unknown
#      removal_requested_by_supplier
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# 5    Unknown
# 6    Unknown
# 7    Unknown
# 8    Unknown
# 9    Unknown
# 10   Unknown
# 11   Unknown
# 12   Unknown
# 13   Unknown
# 14   Unknown
# 15   Unknown
# 16   Unknown
# 17   Unknown
# 18   Unknown
# 19   Unknown
# 20   Unknown
# 21   Unknown
# 22   Unknown
# 23   Unknown
# 24   Unknown
# 25   Unknown
# 26   Unknown
# 27   Unknown
# 28   Unknown
# 29   Unknown
# 30   Unknown
# ⋮    ⋮
# 1065 Unknown
# 1066 Unknown
# 1067 Unknown
# 1068 Unknown
# 1069 Unknown
# 1070 Unknown
# 1071 Unknown
# 1072 Unknown
# 1073 Unknown
# 1074 Unknown
# 1075 Unknown
# 1076 Unknown
# 1077 Unknown
# 1078 Unknown
# 1079 Unknown
# 1080 Unknown
# 1081 Unknown
# 1082 Unknown
# 1083 Unknown
# 1084 Unknown
# 1085 Unknown
# 1086 Unknown
# 1087 Unknown
# 1088 Unknown
# 1089 Unknown
# 1090 Unknown
# 1091 Unknown
# 1092 Unknown
# 1093 Unknown
# 1094 Unknown

# %%
test_prev <- species_df %>%
    select(-npm_research_id, -"Homo sapiens", -unclassified)

test_prev[test_prev <= 0] <- 0
test_prev[test_prev > 0] <- 1

test_prev <- tibble(npm_research_id = species_df$npm_research_id, n_assigned = rowSums(test_prev))
    
test_prev %>%
    ggplot(aes(x = log(n_assigned, base = 10))) +
    geom_histogram() +
    labs(x = "No. of taxa with >= 1 read", y = "No. of samples")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 55 rows containing non-finite values (stat_bin).”
# plot without title

# %%
test_prev %>%
    left_join(rowsum_df) %>%
#     mutate(n_assigned = 10 ^ n_assigned) %>%
    ggplot(aes(x = rowsums, y = n_assigned)) +
    geom_point()
# Out:
# Joining, by = "npm_research_id"
# plot without title

# %% [markdown]
# ### 10 species simulation (no human)

# %%
tp <- c("Yersinia enterocolitica", "Leclercia adecarboxylata", "Moraxella osloensis", 
        "Pasteurella multocida", "Streptococcus pneumoniae", "Streptococcus agalactiae", 
        "Actinomyces viscosus", "Staphylococcus epidermidis", "Torque teno virus", 
        "Human betaherpesvirus 6A")

# %%
otu_to_RA <- function(df) {
    row_names <- df$sample
    RA_df <- t(apply(df %>% select(-sample, -unclassified), 1, function(x) {x / sum(x)}))
    
    return(cbind(data.frame(sample = row_names), as.data.frame(RA_df, check.names = F)))
}

parse_df <- function(sim_df) {
    parsed_sim <- sim_df %>% 
        pivot_longer(!sample, names_to = "taxa", values_to = "read_count") %>%
        filter(read_count != 0) %>%
        mutate(classification = case_when(taxa == "unclassified" ~ "Unclassified", 
                                          taxa %in% tp ~ "TP", 
                                          TRUE ~ "FP"),
               sample = gsub("simulated.", "", sample)) %>%
        arrange(desc(classification))

    parsed_sim <- parsed_sim %>% mutate(taxa = factor(taxa, levels = unique(parsed_sim$taxa)))
}

# %%
sim_df <- fread("data/simulation_out/07_abundance_matrix/abundance_matrix.subset_.S.tsv")
sim_RA <- otu_to_RA(sim_df)

parsed_sim <- parse_df(sim_df)
parsed_sim_RA <- parse_df(sim_RA)

# %%
parsed_sim %>%
    filter(sample == "10e-6")
# Out:
#    sample taxa                           read_count classification
# 1  10e-6  unclassified                    2         Unclassified
# 2  10e-6  Leclercia adecarboxylata       15         TP
# 3  10e-6  Yersinia enterocolitica        16         TP
# 4  10e-6  Moraxella osloensis            18         TP
# 5  10e-6  Pasteurella multocida          18         TP
# 6  10e-6  Streptococcus pneumoniae       16         TP
# 7  10e-6  Streptococcus agalactiae        3         TP
# 8  10e-6  Staphylococcus epidermidis     15         TP
# 9  10e-6  Actinomyces viscosus           18         TP
# 10 10e-6  Torque teno virus              18         TP
# 11 10e-6  Human betaherpesvirus 6A       18         TP
# 12 10e-6  Streptococcus sp. FDAARGOS_522  1         FP
# 13 10e-6  Staphylococcus hominis          1         FP

# %% [markdown]
# #### No. of assigned species per sample

# %%
micro_sim <- sim_df %>% select(-sample, -unclassified, -"Homo sapiens")
rowsum_sim <- tibble(sample = sim_df$sample, rowsums = rowSums(micro_sim))

rowsum_sim


sim_prev <- sim_df %>%
    select(-sample, -"Homo sapiens", -unclassified)

sim_prev[sim_prev <= 0] <- 0
sim_prev[sim_prev > 0] <- 1

sim_prev <- tibble(sample = sim_df$sample, n_assigned = rowSums(sim_prev))
    
sim_prev %>%
    left_join(rowsum_sim) %>%
    ggplot(aes(x = rowsums, y = n_assigned)) +
    geom_point() 

v
# Out:
#   sample          rowsums
# 1 simulated.10e-4  15921
# 2 simulated.10e-5   1591
# 3 simulated.10e-6    157
# 4 simulated.10e-3 159268
# Joining, by = "sample"
# plot without title

# %% [markdown]
# #### Distribution of read counts for FP/TP

# %%
micro_sim <- sim_df %>% select(-sample, -unclassified, -"Homo sapiens")
rowsum_sim <- tibble(sample = sim_df$sample, rowsums = rowSums(micro_sim))

rowsum_sim


sim_prev <- sim_df %>%
    select(-sample, -"Homo sapiens", -unclassified)

sim_prev[sim_prev <= 0] <- 0
sim_prev[sim_prev > 0] <- 1

sim_prev <- tibble(sample = sim_df$sample, n_assigned = rowSums(sim_prev))
    
sim_prev %>%
    left_join(rowsum_sim) %>%
    ggplot(aes(x = rowsums, y = n_assigned)) +
    geom_point()
# Out:
#   sample          rowsums
# 1 simulated.10e-4  15921
# 2 simulated.10e-5   1591
# 3 simulated.10e-6    157
# 4 simulated.10e-3 159268
# Joining, by = "sample"
# plot without title

# %%
PA_threshold <- 0.01
read_plt <- parsed_sim %>%
    filter(classification != "Unclassified") %>%
    ggplot(aes(x = read_count, fill = classification)) +
    theme_bw() +
    geom_histogram(bins = 100) +
    facet_grid(rows = vars(sample)) +
    labs(x = "Reads assigned", y = "No. of taxa", fill = "Classification")
RA_plt <- parsed_sim_RA %>% 
    ggplot(aes(x = read_count, fill = classification)) +
    theme_bw() +
    geom_histogram(bins = 100) +
    facet_grid(rows = vars(sample)) +
    labs(x = "Relative abundance", y = "No. of taxa", fill = "Classification") +
    geom_vline(xintercept = PA_threshold, color = "black", linetype = "dotted")

combined <- ggpubr::ggarrange(read_plt, RA_plt, ncol = 2, common.legend = T)
combined
ggsave("results/simulations/abundance_distribution_fp_tp.png", dpi = 300, plot = combined, width = 7, height = 4)
# Out:
# plot without title

# %%
parsed_sim_RA %>%
    filter(read_count < 0.05, classification == "TP")
# Out:
#   sample taxa                     read_count  classification
# 1 10e-4  Streptococcus agalactiae 0.009669722 TP
# 2 10e-5  Streptococcus agalactiae 0.010056568 TP
# 3 10e-6  Streptococcus agalactiae 0.019108280 TP
# 4 10e-3  Streptococcus agalactiae 0.009754260 TP

# %% [markdown]
# ### Read counts for each microbial depth

# %%
plots <- foreach(sim_run = c("simulated.10e-3", "simulated.10e-4", "simulated.10e-5", "simulated.10e-6")) %do% {
    parsed_sim %>%
        filter(sample == sim_run) %>%
        ggplot(aes(x = taxa, y = read_count, fill = classification)) +
        geom_bar(stat = "identity") +
        labs(x = "Taxa", y = "Reads assigned", fill = "Taxon classification") +
        theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
        facet_grid(cols = vars(sample))
}

# %%
plots
# Out:
# ERROR while rich displaying an object: Error: Faceting variables must have at least one value
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.default(obj)
# 9. paste(capture.output(print(obj)), collapse = "\n")
# 10. capture.output(print(obj))
# 11. withVisible(...elt(i))
# 12. print(obj)
# 13. print.default(obj)
# 14. (function (x, ...)
#   . UseMethod("print"))(x)
# 15. print.ggplot(x)
# 16. ggplot_build(x)
# 17. ggplot_build.ggplot(x)
# 18. layout$setup(data, plot$data, plot$plot_env)
# 19. f(..., self = self)
# 20. self$facet$compute_layout(data, self$facet_params)
# 21. f(...)
# 22. combine_vars(data, params$plot_env, cols, drop = params$drop)
# 23. abort("Faceting variables must have at least one value")
# 24. signal_abort(cnd)
# plot without title
