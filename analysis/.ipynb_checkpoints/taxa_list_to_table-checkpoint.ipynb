# %% [markdown]
# # Convert taxa list to a pretty table

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(tidyverse)
require(ggplot2)
require(data.table)
require(foreach)
require(reactable)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: reactable

# %% [markdown]
# ### Load  data

# %%
species_df <- fread("results/decontamination/read_matrix_n157.global_decontaminated.zeroed.csv")
species_RA <- fread("results/decontamination/RA_matrix_n157.global_decontaminated.zeroed.csv")

patho_meta <- fread("data/kraken2_taxonomy/plusPF_20210517_species_meta.csv") %>%
    select(-n_map_taxon) %>%
    mutate(taxa = gsub("\\[|\\]", "", taxa))

prev_max_filt <- fread("results/decontamination/global_decontamination_stats.csv")
path_prev_max_filt <- prev_max_filt %>%
    left_join(patho_meta) %>%
    arrange(desc(max_count))

bact <- path_prev_max_filt %>% filter(org_group == "Bacteria")
viru <- path_prev_max_filt %>% filter(org_group == "Viruses")
fungi <- path_prev_max_filt %>% filter(org_group == "Fungi")
others <- path_prev_max_filt %>% filter(org_group == "Other Eukaryotes")
# Out:
# Joining, by = "taxa"

# %% [markdown]
# #### Save files for iRep

# %%
prev_max_filt %>% arrange(desc(max_count))
# Out:
#     taxa                              max_count overall_prevalence n_samples
# 1   Fusobacterium nucleatum           194199    0.0011327594        10
# 2   Staphylococcus haemolyticus       117929    0.0105346624        93
# 3   Paracoccus yeei                    85256    0.0035115541        31
# 4   Microbacterium sp. PM5             83419    0.0356819212       315
# 5   Microbacterium sp. Nx66            67485    0.0137063888       121
# 6   Cutibacterium acnes                22596    0.0474626189       419
# 7   Staphylococcus cohnii              18768    0.0080425918        71
# 8   Human mastadenovirus C             17475    0.0185772542       164
# 9   Neisseria subflava                 15385    0.0015858632        14
# 10  Corynebacterium segmentosum        14476    0.0010194835         9
# 11  Haemophilus parainfluenzae         12183    0.0020389669        18
# 12  Fannyhessea vaginae                10395    0.0023787947        21
# 13  Staphylococcus epidermidis          9140    0.0086089715        76
# 14  Human betaherpesvirus 6A            8770    0.0020389669        18
# 15  Human betaherpesvirus 6B            8476    0.0033982782        30
# 16  Aspergillus oryzae                  7909    0.0005663797         5
# 17  Lactobacillus crispatus             7799    0.0106479384        94
# 18  Acinetobacter baumannii             7673    0.0031717263        28
# 19  Cupriavidus metallidurans           5506    0.0036248301        32
# 20  Hepatitis B virus                   4979    0.0003398278         3
# 21  Neisseria mucosa                    4683    0.0012460353        11
# 22  Malassezia restricta                4237    0.0011327594        10
# 23  Neisseria flavescens                3787    0.0005663797         5
# 24  Fusobacterium pseudoperiodonticum   3638    0.0004531038         4
# 25  Prevotella melaninogenica           3549    0.0011327594        10
# 26  Rickettsia sp. Tillamook 23         2923    0.0002265519         2
# 27  Prevotella sp. oral taxon 299       2518    0.0002265519         2
# 28  Moraxella osloensis                 2402    0.0191436339       169
# 29  Gardnerella vaginalis               2123    0.0084956955        75
# 30  Corynebacterium imitans             1976    0.0002265519         2
# ⋮   ⋮                                 ⋮         ⋮                  ⋮
# 128 Rhodococcus sp. NJ-530            175       0.0107612143        95
# 129 Paraburkholderia aromaticivorans  175       0.0036248301        32
# 130 Staphylococcus warneri            171       0.0004531038         4
# 131 Deinococcus ficus                 171       0.0002265519         2
# 132 Pseudomonas tolaasii              161       0.0240144993       212
# 133 Deinococcus swuensis              161       0.0002265519         2
# 134 Cutibacterium avidum              157       0.0007929316         7
# 135 Ramlibacter tataouinensis         155       0.0005663797         5
# 136 Paraburkholderia tropica          153       0.0148391482       131
# 137 Staphylococcus aureus             150       0.0012460353        11
# 138 Clostridium innocuum              148       0.0009062075         8
# 139 Dermacoccus nishinomiyaensis      148       0.0002265519         2
# 140 Streptococcus sp. oral taxon 431  147       0.0005663797         5
# 141 Anaerobutyricum hallii            142       0.0006796556         6
# 142 Gemella haemolysans               128       0.0005663797         5
# 143 Megasphaera elsdenii              124       0.0005663797         5
# 144 Limosilactobacillus reuteri       124       0.0002265519         2
# 145 Microbacterium schleiferi         122       0.0004531038         4
# 146 Corynebacterium genitalium        120       0.0003398278         3
# 147 Paraburkholderia phytofirmans     119       0.0044177617        39
# 148 Roseomonas sp. FDAARGOS_362       118       0.0004531038         4
# 149 Pseudonocardia autotrophica       118       0.0003398278         3
# 150 Hydrogenophaga crassostreae       116       0.0007929316         7
# 151 Rhodococcus erythropolis          115       0.0053239692        47
# 152 Paraburkholderia acidisoli        112       0.0132532850       117
# 153 Rhodococcus qingshengii           112       0.0061169008        54
# 154 Porphyromonas gingivalis          107       0.0005663797         5
# 155 Bifidobacterium pseudocatenulatum 104       0.0004531038         4
# 156 Blautia sp. SC05B48               101       0.0013593113        12
# 157 Acidovorax sp. JMULE5             101       0.0005663797         5
#     max_bin
# 1   >=500
# 2   >=500
# 3   >=500
# 4   >=500
# 5   >=500
# 6   >=500
# 7   >=500
# 8   >=500
# 9   >=500
# 10  >=500
# 11  >=500
# 12  >=500
# 13  >=500
# 14  >=500
# 15  >=500
# 16  >=500
# 17  >=500
# 18  >=500
# 19  >=500
# 20  >=500
# 21  >=500
# 22  >=500
# 23  >=500
# 24  >=500
# 25  >=500
# 26  >=500
# 27  >=500
# 28  >=500
# 29  >=500
# 30  >=500
# ⋮   ⋮
# 128 100-500
# 129 100-500
# 130 100-500
# 131 100-500
# 132 100-500
# 133 100-500
# 134 100-500
# 135 100-500
# 136 100-500
# 137 100-500
# 138 100-500
# 139 100-500
# 140 100-500
# 141 100-500
# 142 100-500
# 143 100-500
# 144 100-500
# 145 100-500
# 146 100-500
# 147 100-500
# 148 100-500
# 149 100-500
# 150 100-500
# 151 100-500
# 152 100-500
# 153 100-500
# 154 100-500
# 155 100-500
# 156 100-500
# 157 100-500

# %%
bact %>%
    head(20)
# Out:
#    taxa                              max_count overall_prevalence n_samples
# 1  Fusobacterium nucleatum           194199    0.0011327594        10
# 2  Staphylococcus haemolyticus       117929    0.0105346624        93
# 3  Paracoccus yeei                    85256    0.0035115541        31
# 4  Microbacterium sp. PM5             83419    0.0356819212       315
# 5  Microbacterium sp. Nx66            67485    0.0137063888       121
# 6  Cutibacterium acnes                22596    0.0474626189       419
# 7  Staphylococcus cohnii              18768    0.0080425918        71
# 8  Neisseria subflava                 15385    0.0015858632        14
# 9  Corynebacterium segmentosum        14476    0.0010194835         9
# 10 Haemophilus parainfluenzae         12183    0.0020389669        18
# 11 Fannyhessea vaginae                10395    0.0023787947        21
# 12 Staphylococcus epidermidis          9140    0.0086089715        76
# 13 Lactobacillus crispatus             7799    0.0106479384        94
# 14 Acinetobacter baumannii             7673    0.0031717263        28
# 15 Cupriavidus metallidurans           5506    0.0036248301        32
# 16 Neisseria mucosa                    4683    0.0012460353        11
# 17 Neisseria flavescens                3787    0.0005663797         5
# 18 Fusobacterium pseudoperiodonticum   3638    0.0004531038         4
# 19 Prevotella melaninogenica           3549    0.0011327594        10
# 20 Rickettsia sp. Tillamook 23         2923    0.0002265519         2
#    max_bin org_group
# 1  >=500   Bacteria
# 2  >=500   Bacteria
# 3  >=500   Bacteria
# 4  >=500   Bacteria
# 5  >=500   Bacteria
# 6  >=500   Bacteria
# 7  >=500   Bacteria
# 8  >=500   Bacteria
# 9  >=500   Bacteria
# 10 >=500   Bacteria
# 11 >=500   Bacteria
# 12 >=500   Bacteria
# 13 >=500   Bacteria
# 14 >=500   Bacteria
# 15 >=500   Bacteria
# 16 >=500   Bacteria
# 17 >=500   Bacteria
# 18 >=500   Bacteria
# 19 >=500   Bacteria
# 20 >=500   Bacteria
