# %% [markdown]
# # Identication of putative contaminant taxa

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(foreach)
require(tidyverse)
require(ggplot2)
require(data.table)
require(doParallel)
registerDoParallel(cores=6)

# %%
load_data <- function(file_path) {
    df <- as.data.frame(fread(file_path)) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}


load_metadata <- function(file_path, df) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% df$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}


subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}


retrieve_rows_from_meta <- function(df, meta) {
    return(df %>% filter(npm_research_id %in% meta$npm_research_id)) 
}


remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}


remove_low_freq_taxa <- function(df, frac_presence) {
    n_original <- ncol(df[, colnames(df) != "npm_research_id"])
    PA_df <- apply(df[, 2:ncol(df)], 2, function(x) {ifelse(x > 0, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    n_new <- length(to_keep) - 1
    print(str_glue("{n_new} / {n_original} taxa are present in {frac_presence} of samples"))
    return(df %>% select(all_of(to_keep)))
}


otu_to_RA <- function(df) {
    mat <- as.matrix(df[, colnames(df) != "npm_research_id"])
    RA_df <- as.data.frame(mat / rowSums(mat))
    RA_df <- add_column(RA_df, df$npm_research_id, .before = 1)
    colnames(RA_df)[1] <- "npm_research_id"
    
    return(RA_df)
}


get_metadata_plots <- function(meta, meta_cols) {
    meta <- as.matrix(meta)
    meta <- as_tibble(meta, rownames = "sample")

    plots <- list()
    
    for (column in meta_cols) {
        plt <- meta %>%
            mutate(across(everything(), as.character)) %>%
            select(all_of(column)) %>%
            group_by_at(column) %>%
            summarise(n = n()) %>%
            ggplot(aes_string(x = column, y = "n", fill = column)) +
                geom_bar(stat = "identity") +
                theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
                geom_text(aes_string(label = "n"))
        plots[[column]] <- plt
    }
    
    return(plots)
}


get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


print_group_freqs <- function(meta, meta_cols) {
    for (col in meta_cols) {
        tmp <- tibble(data.frame(meta)) %>%
            group_by(get(col)) %>%
            summarise(n = n())
        print(col)
        print(tmp)
    }
}


get_batch_prevalence <- function(x) {sum(x) / length(x)}


remove_low_read_samples <- function(df) {
    to_retain <- fread("data/samples_above_10_reads.txt")$npm_research_id
    return(df %>% filter(npm_research_id %in% to_retain))
}


remove_empty_rows <- function(df) {
    df_filt <- df %>% 
        rowwise(npm_research_id) %>% 
        mutate(total = sum(across(everything()))) %>%
        filter(total != 0) %>%
        select(-total)
    
    n_original <- nrow(df)
    n_removed <- n_original - nrow(df_filt)
    
    print(str_glue("{n_removed}/{n_original} samples removed due to having no reads of interest"))
    
    return(as.data.frame(df_filt))
}

# %% [markdown]
# #### Test for differential prevalence

# %%
run_diff_prev <- function(dat, metadat, meta_cols, read_threshold, prev_threshold, min_samples) {
    morsels <- foreach (column = meta_cols) %do% {
        print(column)
        # Remove levels with < x samples
        tmp <- tibble(data.frame(metadat)) %>%
                group_by(get(column)) %>%
                summarise(n = n())

        # Vector of group levels to keep
        to_keep <- tmp[tmp$n >= min_samples, "get(column)"]$`get(column)`
        to_keep <- to_keep[to_keep != "Unknown"]
        n_levels <- length(to_keep)

        if (n_levels < 2) {
            print(str_glue("After pruning, {column} has < 2 levels"))
        } else {
            print(str_glue("After pruning, {column} has {n_levels} levels"))
        }

        # Remove rows in metadata
        metadat_filt <- metadat %>% filter(get(column) %in% to_keep)

        # Retrieve rows
        dat_filt <- retrieve_rows_from_meta(dat, metadat_filt)
        metadat_filt <- metadat_filt %>% filter(npm_research_id %in% dat_filt$npm_research_id)

        # Convert abundance table to presence absence table
        prev_filt <- dat_filt[, colnames(dat_filt) != "npm_research_id"]
        prev_filt[prev_filt <= read_threshold] <- 0
        prev_filt[prev_filt > read_threshold] <- 1
        prev_filt$npm_research_id <- dat_filt$npm_research_id
        
        taxa_vec <- colnames(prev_filt)
        taxa_vec <- taxa_vec[taxa_vec != "npm_research_id"]

        crumbs <- foreach (taxon = taxa_vec) %dopar% {
            prev_stats <- prev_filt %>% 
                left_join(metadat_filt, by = "npm_research_id") %>%
                group_by_at(c(column)) %>%
                summarise(sum = sum(get(taxon))) %>%
                mutate(batch_n = as.vector(table(metadat_filt[, column])),
                       prevalence = sum / as.vector(table(metadat_filt[, column])))

            max_prev <- max(prev_stats$prevalence)
            min_prev <- min(prev_stats$prevalence)
            fold_diff <- max_prev / min_prev
            max_level <- pull(prev_stats, column)[which(prev_stats$prevalence == max(prev_stats$prevalence))][1]
            min_level <- pull(prev_stats, column)[which(prev_stats$prevalence == min(prev_stats$prevalence))][1]
            diff_prev <- ifelse(fold_diff > prev_threshold, T, F)

            crumb <- tibble(taxa = taxon, meta_col = column,
                   max_level = max_level, min_level = min_level, 
                   max_prev = max_prev, min_prev = min_prev,
                   fold_diff = fold_diff,
                   diff_prev = diff_prev)
            
            crumb <- distinct(crumb, taxa, .keep_all = T)

            return(crumb)
        }
        
        stopImplicitCluster()
        
        morsel <- bind_rows(crumbs)
        return(morsel)
    }

    result_df <- bind_rows(morsels)
    return(result_df)
}

# %% [markdown]
# #### Diff. prevalence decontamination procedure

# %%
decontaminate <- function(rank, n_subset, n, human, read_threshold, min_samples) {
    # Load data and remove low microbial read samples
    to_retain <- fread("data/samples_above_95_reads.txt")$npm_research_id
    df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>% 
        filter(npm_research_id %in% to_retain)
    meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)
    
    # Get metadata subset
    meta_filt <- subset_metadata(meta, n)

    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    df_filt3 <- remove_low_freq_taxa(df_filt2, frac_presence = 0.05)
    df_filt4 <- remove_empty_rows(df_filt3)
#     df_filt4 <- otu_to_RA(df_filt4)

    # Get metadata columns of interest
    meta_cols <- get_meta_cols(meta_filt)
    
#     # Print group freqs
#     print_group_freqs(meta_filt, meta_cols)
    
    # Differential prevalence
    res <- run_diff_prev(df_filt4, meta_filt, meta_cols, read_threshold = read_threshold, prev_threshold = 2 , min_samples = min_samples)
    
    return(res)
}


parse_decontamination_results <- function(decontam_res) {
    non_contaminants <- decontam_res %>%     
        group_by(taxa) %>%
        summarise(n_diff = sum(diff_prev)) %>%
        filter(n_diff == 0)
    non_contaminants <- non_contaminants$taxa

    contaminants <- decontam_res %>%
        group_by(taxa) %>%
        summarise(n_diff = sum(diff_prev)) %>%
        filter(n_diff > 0)
    contaminants <- contaminants$taxa
    
    return(list(non_contaminants = non_contaminants, contaminants = contaminants))
}

# %% [markdown]
# #### Rarefy decontamination procedure

# %%
# rarefy_decontaminate <- function(rank, human, breaks) {
#     morsels <- foreach (n = breaks) %do% {
#         res <- decontaminate(rank, 9999, n, human, 0.001)
#         res_list <- parse_decontamination_results(res)
#         morsel <- tibble(non_contaminants = res_list[["non_contaminants"]], n = n)
#         return(morsel)
#     }

#     nc_df <- bind_rows(morsels)
#     return(nc_df)
# }

# %% [markdown]
# #### Visualise

# %%
# diff_prev_heatmap <- function(nc) {
#     plt <- nc %>% 
#         mutate(n = as.factor(n)) %>%
#         ggplot(aes(x = n, y = non_contaminants)) +
#         geom_tile(color = "black") +
#         scale_x_discrete(breaks = breaks) +
#         theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
#         labs(x = "No. of samples", y = "Non-contaminant taxa")

#         return(plt)
# }

# %% [markdown]
# ### Main for diff. prevalence decontamination

# %%
# breaks <- c(100, 200, 400, 800, seq(1000, 9000, 1000), 9999)
# # breaks <- c(100, 200, 400)
# # breaks <- c(9999)
# breaks

# species_nc_df <- rarefy_decontaminate("S", "Homo sapiens", breaks)
# genus_nc_df <- rarefy_decontaminate("G", "Homo", breaks)

# %%
# diff_prev_heatmap(species_nc_df)
# ggsave("results/decontamination/non_contaminant_species_heatmap.png", dpi = 300, width = 5, height = 10)

# %%
# diff_prev_heatmap(genus_nc_df)
# ggsave("results/decontamination/non_contaminant_genus_heatmap.png", dpi = 300, width = 5, height = 10)

# %%
# min_samples <- 50
# # full_genus_df <- decontaminate("G", 9999, 9999, "Homo", 0.001, min_samples)
# # full_genus_res <- parse_decontamination_results(full_genus_df)
# # fwrite(full_genus_df, str_glue("results/decontamination/diff_prev_raw/diff_prev_results.9999.min_samples{min_samples}.G.RA.csv"))

# full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens", 0.001, min_samples)
# full_species_res <- parse_decontamination_results(full_species_df)
# fwrite(full_species_df, str_glue("results/decontamination/diff_prev_raw/diff_prev_results.9999.min_samples{min_samples}.S.RA.csv"))

# # fwrite(tibble(non_contaminants = full_genus_res[["non_contaminants"]]), str_glue("results/decontamination/prevalence.noncontam.min_samples{min_samples}.G.n9999.RA.txt"))
# # fwrite(tibble(contaminants = full_genus_res[["contaminants"]]), str_glue("results/decontamination/prevalence.contam.G.n9999.RA.txt"))

# fwrite(tibble(non_contaminants = full_species_res[["non_contaminants"]]), str_glue("results/decontamination/prevalence.noncontam.min_samples{min_samples}.S.n9999.RA.txt"))
# fwrite(tibble(contaminants = full_species_res[["contaminants"]]), str_glue("results/decontamination/prevalence.contam.min_samples{min_samples}.S.n9999.RA.txt"))

# %%
min_samples <- 100
full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens", 0, min_samples)
full_species_res <- parse_decontamination_results(full_species_df)
# Out:
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels

# %%
full_species_res
# Out:
# $non_contaminants
# [1] "Altererythrobacter sp. B11"  "Bradyrhizobium erythrophlei"
# [3] "Bradyrhizobium sp. SK17"     "Cutibacterium acnes"
# [5] "Rhodopseudomonas palustris"
#
# $contaminants
#    [1] "Acetobacter aceti"
#    [2] "Acetobacter ghanensis"
#    [3] "Acetobacter pasteurianus"
#    [4] "Acetobacter persici"
#    [5] "Achromobacter denitrificans"
#    [6] "Achromobacter insolitus"
#    [7] "Achromobacter ruhlandii"
#    [8] "Achromobacter sp. AONIH1"
#    [9] "Achromobacter sp. B7"
#   [10] "Achromobacter sp. MFA1 R4"
#   [11] "Achromobacter spanius"
#   [12] "Achromobacter xylosoxidans"
#   [13] "Acidiferrobacter sp. SPIII_3"
#   [14] "Acidihalobacter ferrooxidans"
#   [15] "Acidihalobacter prosperus"
#   [16] "Acidiphilium cryptum"
#   [17] "Acidiphilium multivorum"
#   [18] "Acidipropionibacterium acidipropionici"
#   [19] "Acidipropionibacterium jensenii"
#   [20] "Acidipropionibacterium virtanenii"
#   [21] "Acidisphaera sp. G45-3"
#   [22] "Acidithiobacillus caldus"
#   [23] "Acidithiobacillus ferridurans"
#   [24] "Acidobacteriaceae bacterium SBC82"
#   [25] "Acidobacterium capsulatum"
#   [26] "Acidovorax avenae"
#   [27] "Acidovorax carolinensis"
#   [28] "Acidovorax cattleyae"
#   [29] "Acidovorax citrulli"
#   [30] "Acidovorax ebreus"
#   [31] "Acidovorax sp. 1608163"
#   [32] "Acidovorax sp. JS42"
#   [33] "Acidovorax sp. KKS102"
#   [34] "Acidovorax sp. RAC01"
#   [35] "Acidovorax sp. T1"
#   [36] "Acinetobacter baumannii"
#   [37] "Acinetobacter bereziniae"
#   [38] "Acinetobacter guillouiae"
#   [39] "Acinetobacter haemolyticus"
#   [40] "Acinetobacter indicus"
#   [41] "Acinetobacter johnsonii"
#   [42] "Acinetobacter junii"
#   [43] "Acinetobacter lwoffii"
#   [44] "Acinetobacter pittii"
#   [45] "Acinetobacter radioresistens"
#   [46] "Acinetobacter schindleri"
#   [47] "Acinetobacter soli"
#   [48] "Acinetobacter sp. ACNIH1"
#   [49] "Acinetobacter sp. ACNIH2"
#   [50] "Acinetobacter sp. LoGeW2-3"
#   [51] "Acinetobacter sp. NCu2D-2"
#   [52] "Acinetobacter sp. SWBY1"
#   [53] "Acinetobacter sp. WCHA45"
#   [54] "Acinetobacter sp. WCHA55"
#   [55] "Acinetobacter sp. WCHAc010034"
#   [56] "Acinetobacter ursingii"
#   [57] "Acinetobacter venetianus"
#   [58] "Acinetobacter wuhouensis"
#   [59] "Actinoalloteichus hoggarensis"
#   [60] "Actinoalloteichus hymeniacidonis"
#   [61] "Actinoalloteichus sp. AHMU CJ021"
#   [62] "Actinobacteria bacterium YIM 96077"
#   [63] "Actinomadura amylolytica"
#   [64] "Actinomyces hongkongensis"
#   [65] "Actinomyces howellii"
#   [66] "Actinomyces israelii"
#   [67] "Actinomyces oris"
#   [68] "Actinomyces radicidentis"
#   [69] "Actinomyces slackii"
#   [70] "Actinomyces sp. Chiba101"
#   [71] "Actinomyces sp. oral taxon 414"
#   [72] "Actinomyces sp. oral taxon 897"
#   [73] "Actinomyces sp. Z16"
#   [74] "Actinomyces viscosus"
#   [75] "Actinoplanes derwentensis"
#   [76] "Actinoplanes friuliensis"
#   [77] "Actinoplanes missouriensis"
#   [78] "Actinoplanes sp. N902-109"
#   [79] "Actinoplanes teichomyceticus"
#   [80] "Actinopolymorpha singaporensis"
#   [81] "Actinopolyspora erythraea"
#   [82] "Actinosynnema pretiosum"
#   [83] "Adlercreutzia equolifaciens"
#   [84] "Advenella kashmirensis"
#   [85] "Advenella mimigardefordensis"
#   [86] "Aeromicrobium choanae"
#   [87] "Aeromicrobium erythreum"
#   [88] "Aeromicrobium marinum"
#   [89] "Aeromicrobium sp. 592"
#   [90] "Aeromicrobium sp. A1-2"
#   [91] "Aeromonas caviae"
#   [92] "Aeromonas encheleia"
#   [93] "Aeromonas hydrophila"
#   [94] "Aeromonas media"
#   [95] "Aeromonas salmonicida"
#   [96] "Aeromonas schubertii"
#   [97] "Aeromonas sp. ASNIH1"
#   [98] "Aeromonas sp. ASNIH3"
#   [99] "Aeromonas sp. CA23"
#  [100] "Aeromonas veronii"
#  [101] "Afipia sp. GAS231"
#  [102] "Agrobacterium fabrum"
#  [103] "Agrobacterium rhizogenes"
#  [104] "Agrobacterium sp. H13-3"
#  [105] "Agrobacterium sp. RAC06"
#  [106] "Agrobacterium tumefaciens"
#  [107] "Agrobacterium vitis"
#  [108] "Agrococcus carbonis"
#  [109] "Agrococcus jejuensis"
#  [110] "Agromyces aureus"
#  [111] "Agromyces flavus"
#  [112] "Agromyces sp. 30A"
#  [113] "Ahniella affigens"
#  [114] "Alcaligenes aquatilis"
#  [115] "Alcaligenes faecalis"
#  [116] "Alcanivorax dieselolei"
#  [117] "Alcanivorax pacificus"
#  [118] "Alcanivorax sp. N3-2A"
#  [119] "Alcanivorax xenomutans"
#  [120] "Alicycliphilus denitrificans"
#  [121] "Alicyclobacillus acidocaldarius"
#  [122] "Alistipes shahii"
#  [123] "Alistipes sp. Marseille-P5997"
#  [124] "Alkalilimnicola ehrlichii"
#  [125] "Alloactinosynnema sp. L-07"
#  [126] "Allochromatium vinosum"
#  [127] "Allokutzneria albata"
#  [128] "Alphaproteobacteria bacterium WS11"
#  [129] "Altererythrobacter atlanticus"
#  [130] "Altererythrobacter dongtanensis"
#  [131] "Altererythrobacter epoxidivorans"
#  [132] "Altererythrobacter ishigakiensis"
#  [133] "Altererythrobacter mangrovi"
#  [134] "Altererythrobacter marensis"
#  [135] "Altererythrobacter namhicola"
#  [136] "Altererythrobacter sp. NS1"
#  [137] "Altererythrobacter sp. ZODW24"
#  [138] "Alteromonas macleodii"
#  [139] "Alteromonas mediterranea"
#  [140] "Alteromonas sp. MB-3u-76"
#  [141] "Aminobacter aminovorans"
#  [142] "Aminobacter sp. MSH1"
#  [143] "Amycolatopsis albispora"
#  [144] "Amycolatopsis japonica"
#  [145] "Amycolatopsis keratiniphila"
#  [146] "Amycolatopsis mediterranei"
#  [147] "Amycolatopsis methanolica"
#  [148] "Amycolatopsis orientalis"
#  [149] "Amycolatopsis sp. AA4"
#  [150] "Amycolatopsis sp. BJA-103"
#  [151] "Anaeromyxobacter dehalogenans"
#  [152] "Anaeromyxobacter sp. Fw109-5"
#  [153] "Anaeromyxobacter sp. K"
#  [154] "Anderseniella sp. Alg231-50"
#  [155] "Antarctobacter heliothermus"
#  [156] "Aquabacterium olei"
#  [157] "Aquaspirillum sp. LM1"
#  [158] "Aquitalea magnusonii"
#  [159] "Archangium gephyra"
#  [160] "Aromatoleum aromaticum"
#  [161] "Arsenicicoccus sp. oral taxon 190"
#  [162] "Arthrobacter alpinus"
#  [163] "Arthrobacter crystallopoietes"
#  [164] "Arthrobacter sp. DCT-5"
#  [165] "Arthrobacter sp. ERGS1:01"
#  [166] "Arthrobacter sp. FB24"
#  [167] "Arthrobacter sp. PAMC 25486"
#  [168] "Arthrobacter sp. PGP41"
#  [169] "Arthrobacter sp. QXT-31"
#  [170] "Arthrobacter sp. U41"
#  [171] "Arthrobacter sp. YC-RL1"
#  [172] "Arthrobacter sp. YN"
#  [173] "Arthrobacter sp. ZXY-2"
#  [174] "Asaia bogorensis"
#  [175] "Asticcacaulis excentricus"
#  [176] "Atlantibacter hermannii"
#  [177] "Aurantimicrobium sp. MWH-Mo1"
#  [178] "Auraticoccus monumenti"
#  [179] "Aureimonas sp. AU20"
#  [180] "Auritidibacter sp. NML130574"
#  [181] "Austwickia chelonae"
#  [182] "Azoarcus communis"
#  [183] "Azoarcus olearius"
#  [184] "Azoarcus sp. BH72"
#  [185] "Azoarcus sp. CIB"
#  [186] "Azoarcus sp. DN11"
#  [187] "Azoarcus sp. KH32C"
#  [188] "Azoarcus sp. SY39"
#  [189] "Azorhizobium caulinodans"
#  [190] "Azospira oryzae"
#  [191] "Azospirillum brasilense"
#  [192] "Azospirillum humicireducens"
#  [193] "Azospirillum lipoferum"
#  [194] "Azospirillum sp. CFH 70021"
#  [195] "Azospirillum sp. M2T2B2"
#  [196] "Azospirillum sp. TSH58"
#  [197] "Azospirillum thiophilum"
#  [198] "Azotobacter chroococcum"
#  [199] "Azotobacter vinelandii"
#  [200] "Bacillus cereus"
#  [201] "Bacillus coagulans"
#  [202] "Bacillus thuringiensis"
#  [203] "Bacteroides fragilis"
#  [204] "Bacteroides zoogleoformans"
#  [205] "Bartonella apis"
#  [206] "Beijerinckia indica"
#  [207] "Betaproteobacteria bacterium GR16-43"
#  [208] "Beutenbergia cavernae"
#  [209] "Bifidobacterium adolescentis"
#  [210] "Bifidobacterium animalis"
#  [211] "Bifidobacterium bifidum"
#  [212] "Bifidobacterium breve"
#  [213] "Bifidobacterium choerinum"
#  [214] "Bifidobacterium dentium"
#  [215] "Bifidobacterium longum"
#  [216] "Bifidobacterium pseudolongum"
#  [217] "Bifidobacterium scardovii"
#  [218] "Blastochloris sp. GI"
#  [219] "Blastochloris viridis"
#  [220] "Blastococcus saxobsidens"
#  [221] "Blastomonas fulva"
#  [222] "Blastomonas sp. RAC04"
#  [223] "blood disease bacterium A2-HR MARDI"
#  [224] "Bordetella avium"
#  [225] "Bordetella bronchialis"
#  [226] "Bordetella bronchiseptica"
#  [227] "Bordetella flabilis"
#  [228] "Bordetella genomosp. 13"
#  [229] "Bordetella genomosp. 6"
#  [230] "Bordetella genomosp. 8"
#  [231] "Bordetella genomosp. 9"
#  [232] "Bordetella hinzii"
#  [233] "Bordetella holmesii"
#  [234] "Bordetella parapertussis"
#  [235] "Bordetella petrii"
#  [236] "Bordetella pseudohinzii"
#  [237] "Bordetella sp. H567"
#  [238] "Bordetella sp. HZ20"
#  [239] "Bordetella sp. N"
#  [240] "Bordetella trematum"
#  [241] "Bosea sp. AS-1"
#  [242] "Bosea sp. PAMC 26642"
#  [243] "Bosea sp. RAC05"
#  [244] "Bosea sp. Tri-49"
#  [245] "Bosea vaviloviae"
#  [246] "Brachybacterium faecium"
#  [247] "Brachybacterium ginsengisoli"
#  [248] "Brachybacterium saurashtrense"
#  [249] "Brachybacterium sp. P6-10-X1"
#  [250] "Brachybacterium sp. VM2412"
#  [251] "Brachybacterium sp. VR2415"
#  [252] "Bradymonas sediminis"
#  [253] "Bradyrhizobiaceae bacterium SG-6C"
#  [254] "Bradyrhizobium diazoefficiens"
#  [255] "Bradyrhizobium icense"
#  [256] "Bradyrhizobium japonicum"
#  [257] "Bradyrhizobium lablabi"
#  [258] "Bradyrhizobium oligotrophicum"
#  [259] "Bradyrhizobium ottawaense"
#  [260] "Bradyrhizobium sp."
#  [261] "Bradyrhizobium sp. 2 39S1MB"
#  [262] "Bradyrhizobium sp. 3 85S1MB"
#  [263] "Bradyrhizobium sp. BTAi1"
#  [264] "Bradyrhizobium sp. CCGE-LA001"
#  [265] "Bradyrhizobium sp. ORS 278"
#  [266] "Bradyrhizobium sp. ORS 285"
#  [267] "Bradyrhizobium sp. ORS 3257"
#  [268] "Bradyrhizobium sp. S23321"
#  [269] "Bradyrhizobium sp. WSM471"
#  [270] "Brenneria goodwinii"
#  [271] "Brenneria sp. EniD312"
#  [272] "Breoghania sp. L-A4"
#  [273] "Brevibacillus sp. SCSIO 07484"
#  [274] "Brevibacterium aurantiacum"
#  [275] "Brevibacterium linens"
#  [276] "Brevibacterium sandarakinum"
#  [277] "Brevibacterium siliguriense"
#  [278] "Brevirhabdus pacifica"
#  [279] "Brevundimonas diminuta"
#  [280] "Brevundimonas naejangsanensis"
#  [281] "Brevundimonas sp. DS20"
#  [282] "Brevundimonas sp. GW460-12-10-14-LB2"
#  [283] "Brevundimonas sp. LM2"
#  [284] "Brevundimonas subvibrioides"
#  [285] "Brevundimonas vesicularis"
#  [286] "Burkholderia ambifaria"
#  [287] "Burkholderia anthina"
#  [288] "Burkholderia cenocepacia"
#  [289] "Burkholderia cepacia"
#  [290] "Burkholderia contaminans"
#  [291] "Burkholderia diffusa"
#  [292] "Burkholderia dolosa"
#  [293] "Burkholderia gladioli"
#  [294] "Burkholderia glumae"
#  [295] "Burkholderia insecticola"
#  [296] "Burkholderia lata"
#  [297] "Burkholderia latens"
#  [298] "Burkholderia metallica"
#  [299] "Burkholderia multivorans"
#  [300] "Burkholderia oklahomensis"
#  [301] "Burkholderia plantarii"
#  [302] "Burkholderia pseudomallei"
#  [303] "Burkholderia pseudomultivorans"
#  [304] "Burkholderia pyrrocinia"
#  [305] "Burkholderia seminalis"
#  [306] "Burkholderia sp. BDU6"
#  [307] "Burkholderia sp. BDU8"
#  [308] "Burkholderia sp. Bp7605"
#  [309] "Burkholderia sp. CCGE1001"
#  [310] "Burkholderia sp. CCGE1002"
#  [311] "Burkholderia sp. CCGE1003"
#  [312] "Burkholderia sp. HB1"
#  [313] "Burkholderia sp. IDO3"
#  [314] "Burkholderia sp. JP2-270"
#  [315] "Burkholderia sp. KK1"
#  [316] "Burkholderia sp. LA-2-3-30-S1-D2"
#  [317] "Burkholderia sp. MSMB0856"
#  [318] "Burkholderia sp. NRF60-BP8"
#  [319] "Burkholderia sp. OLGA172"
#  [320] "Burkholderia sp. PAMC 26561"
#  [321] "Burkholderia sp. PAMC 28687"
#  [322] "Burkholderia sp. RPE67"
#  [323] "Burkholderia sp. YI23"
#  [324] "Burkholderia stabilis"
#  [325] "Burkholderia stagnalis"
#  [326] "Burkholderia territorii"
#  [327] "Burkholderia thailandensis"
#  [328] "Burkholderia ubonensis"
#  [329] "Burkholderia vietnamiensis"
#  [330] "Burkholderiales bacterium GJ-E10"
#  [331] "Burkholderiales bacterium JOSHI_001"
#  [332] "Caldilinea aerophila"
#  [333] "Candidatus Accumulibacter phosphatis"
#  [334] "Candidatus Desulforudis audaxviator"
#  [335] "Candidatus Filomicrobium marinum"
#  [336] "Candidatus Nitrospira inopinata"
#  [337] "Candidatus Nucleicultrix amoebiphila"
#  [338] "Candidatus Phaeomarinobacter ectocarpi"
#  [339] "Candidatus Promineofilum breve"
#  [340] "Candidatus Solibacter usitatus"
#  [341] "Candidatus Symbiobacter mobilis"
#  [342] "Candidatus Thiodictyon syntrophicum"
#  [343] "Candidatus Xiphinematobacter sp. Idaho Grape"
#  [344] "Cardiobacterium hominis"
#  [345] "Castellaniella defragrans"
#  [346] "Catenulispora acidiphila"
#  [347] "Caulobacter flavus"
#  [348] "Caulobacter henricii"
#  [349] "Caulobacter mirabilis"
#  [350] "Caulobacter segnis"
#  [351] "Caulobacter sp. K31"
#  [352] "Caulobacter vibrioides"
#  [353] "Caulobacteraceae bacterium OTSz_A_272"
#  [354] "Cedecea neteri"
#  [355] "Celeribacter baekdonensis"
#  [356] "Celeribacter ethanolicus"
#  [357] "Celeribacter indicus"
#  [358] "Celeribacter manganoxidans"
#  [359] "Celeribacter marinus"
#  [360] "Cellulomonas fimi"
#  [361] "Cellulomonas flavigena"
#  [362] "Cellulomonas gilvus"
#  [363] "Cellulomonas sp. PSBB021"
#  [364] "Cellulosimicrobium cellulans"
#  [365] "Cellulosimicrobium sp. TH-20"
#  [366] "Cellvibrio japonicus"
#  [367] "Cellvibrio sp. PSBB006"
#  [368] "Chelativorans sp. BNC1"
#  [369] "Chelatococcus daeguensis"
#  [370] "Chelatococcus sp. CO-6"
#  [371] "Chloracidobacterium thermophilum"
#  [372] "Chlorobaculum limnaeum"
#  [373] "Chlorobium phaeobacteroides"
#  [374] "Chloroflexus aggregans"
#  [375] "Chondromyces crocatus"
#  [376] "Chromatiaceae bacterium 2141T.STBD.0c.01a"
#  [377] "Chromobacterium rhizoryzae"
#  [378] "Chromobacterium sp. ATCC 53434"
#  [379] "Chromobacterium vaccinii"
#  [380] "Chromobacterium violaceum"
#  [381] "Chromohalobacter salexigens"
#  [382] "Chryseobacterium shandongense"
#  [383] "Chryseobacterium sp. F5649"
#  [384] "Chryseobacterium sp. H6466"
#  [385] "Chryseobacterium taklimakanense"
#  [386] "Citrobacter amalonaticus"
#  [387] "Citrobacter freundii"
#  [388] "Citrobacter koseri"
#  [389] "Citrobacter rodentium"
#  [390] "Citrobacter werkmanii"
#  [391] "Citromicrobium sp. JL477"
#  [392] "Clavibacter michiganensis"
#  [393] "Cloacibacterium normanense"
#  [394] "Clostridium botulinum"
#  [395] "Cnuibacter physcomitrellae"
#  [396] "Cobetia marina"
#  [397] "Cohaesibacter sp. ES.047"
#  [398] "Collimonas arenae"
#  [399] "Collimonas fungivorans"
#  [400] "Collimonas pratensis"
#  [401] "Collinsella aerofaciens"
#  [402] "Comamonas aquatica"
#  [403] "Comamonas kerstersii"
#  [404] "Comamonas serinivorans"
#  [405] "Comamonas testosteroni"
#  [406] "Comamonas thiooxydans"
#  [407] "Conexibacter woesei"
#  [408] "Confluentimicrobium sp. EMB200-NS6"
#  [409] "Corallococcus coralloides"
#  [410] "Coriobacterium glomerans"
#  [411] "Corynebacterium ammoniagenes"
#  [412] "Corynebacterium atypicum"
#  [413] "Corynebacterium aurimucosum"
#  [414] "Corynebacterium cystitidis"
#  [415] "Corynebacterium doosanense"
#  [416] "Corynebacterium efficiens"
#  [417] "Corynebacterium epidermidicanis"
#  [418] "Corynebacterium falsenii"
#  [419] "Corynebacterium frankenforstense"
#  [420] "Corynebacterium genitalium"
#  [421] "Corynebacterium glaucum"
#  [422] "Corynebacterium glutamicum"
#  [423] "Corynebacterium glyciniphilum"
#  [424] "Corynebacterium halotolerans"
#  [425] "Corynebacterium humireducens"
#  [426] "Corynebacterium imitans"
#  [427] "Corynebacterium jeikeium"
#  [428] "Corynebacterium marinum"
#  [429] "Corynebacterium maris"
#  [430] "Corynebacterium matruchotii"
#  [431] "Corynebacterium mycetoides"
#  [432] "Corynebacterium provencense"
#  [433] "Corynebacterium renale"
#  [434] "Corynebacterium resistens"
#  [435] "Corynebacterium segmentosum"
#  [436] "Corynebacterium simulans"
#  [437] "Corynebacterium singulare"
#  [438] "Corynebacterium sp. 2183"
#  [439] "Corynebacterium sp. 2184"
#  [440] "Corynebacterium sphenisci"
#  [441] "Corynebacterium striatum"
#  [442] "Corynebacterium terpenotabidum"
#  [443] "Corynebacterium testudinoris"
#  [444] "Corynebacterium timonense"
#  [445] "Corynebacterium urealyticum"
#  [446] "Corynebacterium ureicelerivorans"
#  [447] "Corynebacterium uterequi"
#  [448] "Corynebacterium variabile"
#  [449] "Corynebacterium vitaeruminis"
#  [450] "Corynebacterium xerosis"
#  [451] "Coxiella burnetii"
#  [452] "Crenobacter sp. K1W11S-77"
#  [453] "Croceicoccus marinus"
#  [454] "Croceicoccus naphthovorans"
#  [455] "Cronobacter dublinensis"
#  [456] "Cronobacter turicensis"
#  [457] "Cryobacterium arcticum"
#  [458] "Cryobacterium sp. GCJ02"
#  [459] "Cryobacterium sp. LW097"
#  [460] "Cupriavidus basilensis"
#  [461] "Cupriavidus gilardii"
#  [462] "Cupriavidus metallidurans"
#  [463] "Cupriavidus nantongensis"
#  [464] "Cupriavidus necator"
#  [465] "Cupriavidus oxalaticus"
#  [466] "Cupriavidus pauculus"
#  [467] "Cupriavidus pinatubonensis"
#  [468] "Cupriavidus sp. USMAA2-4"
#  [469] "Cupriavidus sp. USMAHM13"
#  [470] "Cupriavidus taiwanensis"
#  [471] "Curtobacterium pusillum"
#  [472] "Curtobacterium sp. BH-2-1-1"
#  [473] "Curtobacterium sp. MR_MD2014"
#  [474] "Curvibacter sp. AEP1-3"
#  [475] "Cutibacterium avidum"
#  [476] "Cutibacterium granulosum"
#  [477] "Cyanobium gracile"
#  [478] "Cyanobium sp. NIES-981"
#  [479] "Cystobacter fuscus"
#  [480] "Dechloromonas aromatica"
#  [481] "Dechloromonas sp. HYN0024"
#  [482] "Defluviimonas alba"
#  [483] "Deinococcus actinosclerus"
#  [484] "Deinococcus ficus"
#  [485] "Deinococcus geothermalis"
#  [486] "Deinococcus gobiensis"
#  [487] "Deinococcus irradiatisoli"
#  [488] "Deinococcus maricopensis"
#  [489] "Deinococcus peraridilitoris"
#  [490] "Deinococcus proteolyticus"
#  [491] "Deinococcus radiodurans"
#  [492] "Deinococcus soli Cha et al. 2016"
#  [493] "Deinococcus sp. NW-56"
#  [494] "Deinococcus sp. S14-83"
#  [495] "Deinococcus swuensis"
#  [496] "Deinococcus wulumuqiensis"
#  [497] "Delftia acidovorans"
#  [498] "Delftia sp. Cs1-4"
#  [499] "Delftia sp. HK171"
#  [500] "Delftia tsuruhatensis"
#  [501] "Dermabacter vaginalis"
#  [502] "Dermacoccus nishinomiyaensis"
#  [503] "Desulfarculus baarsii"
#  [504] "Desulfomicrobium baculatum"
#  [505] "Desulfovibrio africanus"
#  [506] "Desulfovibrio desulfuricans"
#  [507] "Desulfovibrio fairfieldensis"
#  [508] "Desulfovibrio ferrophilus"
#  [509] "Desulfovibrio gigas"
#  [510] "Desulfovibrio magneticus"
#  [511] "Desulfovibrio piger"
#  [512] "Desulfovibrio sp. FW1012B"
#  [513] "Desulfovibrio vulgaris"
#  [514] "Desulfurivibrio alkaliphilus"
#  [515] "Desulfuromonas soudanensis"
#  [516] "Desulfuromonas sp. DDH964"
#  [517] "Devosia sp. A16"
#  [518] "Devosia sp. H5989"
#  [519] "Devosia sp. I507"
#  [520] "Diaphorobacter polyhydroxybutyrativorans"
#  [521] "Dickeya chrysanthemi"
#  [522] "Dickeya dadantii"
#  [523] "Dickeya dianthicola"
#  [524] "Dickeya sp. Secpp 1600"
#  [525] "Dickeya zeae"
#  [526] "Dietzia lutea"
#  [527] "Dietzia psychralcaliphila"
#  [528] "Dietzia sp. JS16-p6b"
#  [529] "Dietzia sp. oral taxon 368"
#  [530] "Dietzia timorensis"
#  [531] "Dinoroseobacter shibae"
#  [532] "Dokdonella koreensis"
#  [533] "Dyella japonica"
#  [534] "Dyella jiangningensis"
#  [535] "Dyella thiooxydans"
#  [536] "Ectothiorhodospira sp. BSL-9"
#  [537] "Edwardsiella hoshinae"
#  [538] "Eggerthella lenta"
#  [539] "endosymbiont of unidentified scaly snail isolate Monju"
#  [540] "Ensifer adhaerens"
#  [541] "Ensifer sojae"
#  [542] "Enterobacter asburiae"
#  [543] "Enterobacter cloacae"
#  [544] "Enterobacter hormaechei"
#  [545] "Enterobacter lignolyticus"
#  [546] "Enterobacter sp. FY-07"
#  [547] "Enterobacter sp. SA187"
#  [548] "Epibacterium mobile"
#  [549] "Erwinia amylovora"
#  [550] "Erwinia billingiae"
#  [551] "Erwinia persicina"
#  [552] "Erythrobacter atlanticus"
#  [553] "Erythrobacter flavus"
#  [554] "Erythrobacter gangjinensis"
#  [555] "Erythrobacter litoralis"
#  [556] "Erythrobacter seohaensis"
#  [557] "Erythrobacter sp. Alg231-14"
#  [558] "Erythrobacter sp. HL-111"
#  [559] "Erythrobacter sp. KY5"
#  [560] "Erythrobacter sp. YH-07"
#  [561] "Escherichia coli"
#  [562] "Euzebya sp. DY32-46"
#  [563] "Faecalibacterium prausnitzii"
#  [564] "Ferrimonas balearica"
#  [565] "Ferriphaselus amnicola"
#  [566] "Fibrella aestuarina"
#  [567] "Filimonas lacunae"
#  [568] "Fimbriimonas ginsengisoli"
#  [569] "Finegoldia magna"
#  [570] "Flaviflexus salsibiostraticola"
#  [571] "Flavisolibacter tropicus"
#  [572] "Flavonifractor plautii"
#  [573] "Frankia alni"
#  [574] "Frankia casuarinae"
#  [575] "Frankia inefficax"
#  [576] "Frankia sp. EAN1pec"
#  [577] "Frankia sp. QA3"
#  [578] "Frankia symbiont of Datisca glomerata"
#  [579] "Frankineae bacterium MT45"
#  [580] "Frateuria aurantia"
#  [581] "Friedmanniella luteola"
#  [582] "Friedmanniella sagamiharensis"
#  [583] "Frondihabitans sp. 762G35"
#  [584] "Frondihabitans sp. PAMC 28766"
#  [585] "Gallaecimonas sp. HK-28"
#  [586] "gamma proteobacterium HdN1"
#  [587] "Gardnerella vaginalis"
#  [588] "Gemmata obscuriglobus"
#  [589] "Gemmata sp. SH-PL17"
#  [590] "Gemmatimonas aurantiaca"
#  [591] "Gemmatimonas phototrophica"
#  [592] "Gemmatirosa kalamazoonesis"
#  [593] "Gemmobacter sp. HYN0069"
#  [594] "Geoalkalibacter subterraneus"
#  [595] "Geobacter anodireducens"
#  [596] "Geobacter pickeringii"
#  [597] "Geobacter sp. M18"
#  [598] "Geobacter sp. M21"
#  [599] "Geobacter sulfurreducens"
#  [600] "Geodermatophilus obscurus"
#  [601] "Georgenia sp. ZLJ0423"
#  [602] "Gibbsiella quercinecans"
#  [603] "Gloeobacter kilaueensis"
#  [604] "Gluconacetobacter diazotrophicus"
#  [605] "Gluconobacter albidus"
#  [606] "Gluconobacter oxydans"
#  [607] "Glutamicibacter halophytocola"
#  [608] "Glutamicibacter nicotianae"
#  [609] "Gordonia bronchialis"
#  [610] "Gordonia iterans"
#  [611] "Gordonia phthalatica"
#  [612] "Gordonia polyisoprenivorans"
#  [613] "Gordonia rubripertincta"
#  [614] "Gordonia sp. 1D"
#  [615] "Gordonia sp. KTR9"
#  [616] "Gordonia sp. MMS17-SY073"
#  [617] "Gordonia sp. YC-JH1"
#  [618] "Gordonia terrae"
#  [619] "Gordonibacter massiliensis"
#  [620] "Gordonibacter pamelaeae"
#  [621] "Granulibacter bethesdensis"
#  [622] "Granulicella tundricola"
#  [623] "Granulosicoccus antarcticus"
#  [624] "Gryllotalpicola sp. 2DFW10M-5"
#  [625] "Haemophilus parainfluenzae"
#  [626] "Hahella chejuensis"
#  [627] "Haliangium ochraceum"
#  [628] "Haliscomenobacter hydrossis"
#  [629] "Haloarculaceae archaeon HArcel1"
#  [630] "Halobiforma lacisalsi"
#  [631] "Halocynthiibacter arcticus"
#  [632] "Halodesulfurarchaeum formicicum"
#  [633] "Halomonas aestuarii"
#  [634] "Halomonas beimenensis"
#  [635] "Halomonas chromatireducens"
#  [636] "Halomonas elongata"
#  [637] "Halomonas huangheensis"
#  [638] "Halomonas hydrothermalis"
#  [639] "Halomonas sp. 1513"
#  [640] "Halomonas sp. A3H3"
#  [641] "Halomonas sp. JS92-SW72"
#  [642] "Halomonas sp. KO116"
#  [643] "Halomonas sp. SF2003"
#  [644] "Halomonas subglaciescola"
#  [645] "Halopenitus persicus"
#  [646] "Halopiger xanaduensis"
#  [647] "Halorhabdus utahensis"
#  [648] "Halorhodospira halophila"
#  [649] "Halorientalis sp. IM1011"
#  [650] "Halorubrum lacusprofundi"
#  [651] "Halorubrum trapanicum"
#  [652] "Halotalea alkalilenta"
#  [653] "Haloterrigena turkmenica"
#  [654] "Halothiobacillus neapolitanus"
#  [655] "Hartmannibacter diazotrophicus"
#  [656] "Herbaspirillum hiltneri"
#  [657] "Herbaspirillum robiniae"
#  [658] "Herbaspirillum rubrisubalbicans"
#  [659] "Herbaspirillum seropedicae"
#  [660] "Herbaspirillum sp. meg3"
#  [661] "Herminiimonas arsenicoxydans"
#  [662] "Herminiimonas arsenitoxidans"
#  [663] "Hoeflea phototrophica"
#  [664] "Hoeflea sp. IMCC20628"
#  [665] "Hoyosella subflava"
#  [666] "Human betaherpesvirus 7"
#  [667] "Human mastadenovirus C"
#  [668] "Humibacter sp. BT305"
#  [669] "Hydrogenophaga crassostreae"
#  [670] "Hydrogenophaga sp. PBC"
#  [671] "Hydrogenophaga sp. RAC07"
#  [672] "Hydrogenophilus thermoluteolus"
#  [673] "Hymenobacter nivis"
#  [674] "Hymenobacter sedentarius"
#  [675] "Hymenobacter sp. APR13"
#  [676] "Hymenobacter sp. PAMC 26554"
#  [677] "Hymenobacter sp. PAMC 26628"
#  [678] "Hymenobacter sp. sh-6"
#  [679] "Hyphomicrobium denitrificans"
#  [680] "Hyphomicrobium nitrativorans"
#  [681] "Hyphomicrobium sp. MC1"
#  [682] "Hyphomonas neptunium"
#  [683] "Hyphomonas sp. CACIAM 19H1"
#  [684] "Hyphomonas sp. Mor2"
#  [685] "Immundisolibacter cernigliae"
#  [686] "Indioceanicola profundi"
#  [687] "Intrasporangium calvum"
#  [688] "Isoptericola dokdonensis"
#  [689] "Isoptericola variabilis"
#  [690] "Isosphaera pallida"
#  [691] "Janibacter indicus"
#  [692] "Jannaschia sp. CCS1"
#  [693] "Janthinobacterium agaricidamnosum"
#  [694] "Janthinobacterium sp. 1_2014MBL_MicDiv"
#  [695] "Janthinobacterium sp. B9-8"
#  [696] "Janthinobacterium sp. LM6"
#  [697] "Janthinobacterium sp. Marseille"
#  [698] "Janthinobacterium svalbardensis"
#  [699] "Jatrophihabitans sp. GAS493"
#  [700] "Jeongeupia sp. USM3"
#  [701] "Jiangella alkaliphila"
#  [702] "Jiangella sp. DSM 45060"
#  [703] "Ketogulonicigenium robustum"
#  [704] "Ketogulonicigenium vulgare"
#  [705] "Kibdelosporangium phytohabitans"
#  [706] "Kineococcus radiotolerans"
#  [707] "Kiritimatiella glycovorans"
#  [708] "Kitasatospora albolonga"
#  [709] "Kitasatospora aureofaciens"
#  [710] "Kitasatospora setae"
#  [711] "Kitasatospora sp. MMS16-BH015"
#  [712] "Klebsiella aerogenes"
#  [713] "Klebsiella michiganensis"
#  [714] "Klebsiella oxytoca"
#  [715] "Klebsiella pneumoniae"
#  [716] "Kluyvera intermedia"
#  [717] "Kocuria flava"
#  [718] "Kocuria palustris"
#  [719] "Kocuria rosea"
#  [720] "Kocuria turfanensis"
#  [721] "Komagataeibacter europaeus"
#  [722] "Komagataeibacter hansenii"
#  [723] "Komagataeibacter medellinensis"
#  [724] "Komagataeibacter nataicola"
#  [725] "Komagataeibacter saccharivorans"
#  [726] "Komagataeibacter xylinus"
#  [727] "Kosakonia cowanii"
#  [728] "Kosakonia radicincitans"
#  [729] "Kosakonia sp. CCTCC M2018092"
#  [730] "Kozakia baliensis"
#  [731] "Kribbella flavida"
#  [732] "Kushneria konosiri"
#  [733] "Kushneria marisflavi"
#  [734] "Kutzneria albida"
#  [735] "Kytococcus sedentarius"
#  [736] "Labrenzia aggregata"
#  [737] "Labrenzia sp. CP4"
#  [738] "Labrenzia sp. VG12"
#  [739] "Lactobacillus crispatus"
#  [740] "Lactococcus lactis"
#  [741] "Lacunisphaera limnophila"
#  [742] "Laribacter hongkongensis"
#  [743] "Lautropia mirabilis"
#  [744] "Lawsonella clevelandensis"
#  [745] "Legionella hackeliae"
#  [746] "Legionella pneumophila"
# ...
# [1538] "Stappia sp. ES.058"
# [1539] "Starkeya novella"
# [1540] "Stenotrophomonas acidaminiphila"
# [1541] "Stenotrophomonas maltophilia"
# [1542] "Stenotrophomonas rhizophila"
# [1543] "Stenotrophomonas sp. ESTM1D_MKCIP4_1"
# [1544] "Stenotrophomonas sp. G4"
# [1545] "Stenotrophomonas sp. LM091"
# [1546] "Stenotrophomonas sp. MYb57"
# [1547] "Stenotrophomonas sp. Pemsol"
# [1548] "Stenotrophomonas sp. SAU14A_NAIMI4_5"
# [1549] "Stenotrophomonas sp. SAU14A_NAIMI4_8"
# [1550] "Stenotrophomonas sp. WZN-1"
# [1551] "Stenotrophomonas sp. YAU14D1_LEIMI4_1"
# [1552] "Stenotrophomonas sp. ZAC14D2_NAIMI4_6"
# [1553] "Stenotrophomonas sp. ZAC14D2_NAIMI4_7"
# [1554] "Steroidobacter denitrificans"
# [1555] "Sterolibacteriaceae bacterium J5B"
# [1556] "Stigmatella aurantiaca"
# [1557] "Streptacidiphilus sp. DSM 106435"
# [1558] "Streptococcus mitis"
# [1559] "Streptococcus oralis"
# [1560] "Streptococcus pneumoniae"
# [1561] "Streptomyces actuosus"
# [1562] "Streptomyces albireticuli"
# [1563] "Streptomyces alboflavus"
# [1564] "Streptomyces albulus"
# [1565] "Streptomyces albus"
# [1566] "Streptomyces ambofaciens"
# [1567] "Streptomyces antibioticus"
# [1568] "Streptomyces anulatus"
# [1569] "Streptomyces atratus"
# [1570] "Streptomyces avermitilis"
# [1571] "Streptomyces bacillaris"
# [1572] "Streptomyces bingchenggensis"
# [1573] "Streptomyces brunneus"
# [1574] "Streptomyces cattleya"
# [1575] "Streptomyces chartreusis"
# [1576] "Streptomyces clavuligerus"
# [1577] "Streptomyces collinus"
# [1578] "Streptomyces cyaneogriseus"
# [1579] "Streptomyces davaonensis"
# [1580] "Streptomyces dengpaensis"
# [1581] "Streptomyces formicae"
# [1582] "Streptomyces fulvissimus"
# [1583] "Streptomyces fungicidicus"
# [1584] "Streptomyces gilvosporeus"
# [1585] "Streptomyces glaucescens"
# [1586] "Streptomyces globisporus"
# [1587] "Streptomyces globosus"
# [1588] "Streptomyces griseochromogenes"
# [1589] "Streptomyces griseorubiginosus"
# [1590] "Streptomyces griseus"
# [1591] "Streptomyces hundungensis"
# [1592] "Streptomyces hygroscopicus"
# [1593] "Streptomyces katrae"
# [1594] "Streptomyces koyangensis"
# [1595] "Streptomyces lavendulae"
# [1596] "Streptomyces leeuwenhoekii"
# [1597] "Streptomyces lincolnensis"
# [1598] "Streptomyces lunaelactis"
# [1599] "Streptomyces luteoverticillatus"
# [1600] "Streptomyces lydicus"
# [1601] "Streptomyces malaysiensis"
# [1602] "Streptomyces nigra"
# [1603] "Streptomyces niveus"
# [1604] "Streptomyces nodosus"
# [1605] "Streptomyces noursei"
# [1606] "Streptomyces olivaceus"
# [1607] "Streptomyces olivoreticuli"
# [1608] "Streptomyces pactum"
# [1609] "Streptomyces parvulus"
# [1610] "Streptomyces peucetius"
# [1611] "Streptomyces pluripotens"
# [1612] "Streptomyces pratensis"
# [1613] "Streptomyces pristinaespiralis"
# [1614] "Streptomyces puniciscabiei"
# [1615] "Streptomyces qaidamensis"
# [1616] "Streptomyces reticuli"
# [1617] "Streptomyces roseochromogenus"
# [1618] "Streptomyces rubrolavendulae"
# [1619] "Streptomyces scabiei"
# [1620] "Streptomyces sp. 11-1-2"
# [1621] "Streptomyces sp. 2323.1"
# [1622] "Streptomyces sp. 3211"
# [1623] "Streptomyces sp. 3214.6"
# [1624] "Streptomyces sp. 4F"
# [1625] "Streptomyces sp. 769"
# [1626] "Streptomyces sp. ADI95-16"
# [1627] "Streptomyces sp. CB09001"
# [1628] "Streptomyces sp. CCM_MD2014"
# [1629] "Streptomyces sp. CdTB01"
# [1630] "Streptomyces sp. CFMR 7"
# [1631] "Streptomyces sp. CMB-StM0423"
# [1632] "Streptomyces sp. CNQ-509"
# [1633] "Streptomyces sp. ETH9427"
# [1634] "Streptomyces sp. fd1-xmd"
# [1635] "Streptomyces sp. FR-008"
# [1636] "Streptomyces sp. Go-475"
# [1637] "Streptomyces sp. GSSD-12"
# [1638] "Streptomyces sp. HNM0039"
# [1639] "Streptomyces sp. KPB2"
# [1640] "Streptomyces sp. M56"
# [1641] "Streptomyces sp. Mg1"
# [1642] "Streptomyces sp. MK45"
# [1643] "Streptomyces sp. NEAU-S7GS2"
# [1644] "Streptomyces sp. P3"
# [1645] "Streptomyces sp. RTd22"
# [1646] "Streptomyces sp. S8"
# [1647] "Streptomyces sp. SAT1"
# [1648] "Streptomyces sp. SCSIO 03032"
# [1649] "Streptomyces sp. Sge12"
# [1650] "Streptomyces sp. SirexAA-E"
# [1651] "Streptomyces sp. SM18"
# [1652] "Streptomyces sp. TLI_053"
# [1653] "Streptomyces sp. TN58"
# [1654] "Streptomyces sp. Tue 6075"
# [1655] "Streptomyces sp. W1SF4"
# [1656] "Streptomyces sp. WAC 01438"
# [1657] "Streptomyces sp. WAC 01529"
# [1658] "Streptomyces sp. WAC 06738"
# [1659] "Streptomyces sp. WAC00288"
# [1660] "Streptomyces sp. Z022"
# [1661] "Streptomyces sp. ZFG47"
# [1662] "Streptomyces spongiicola"
# [1663] "Streptomyces venezuelae"
# [1664] "Streptomyces vietnamensis"
# [1665] "Streptomyces violaceoruber"
# [1666] "Streptomyces violaceusniger"
# [1667] "Streptomyces xiamenensis"
# [1668] "Streptomyces xinghaiensis"
# [1669] "Streptosporangium roseum"
# [1670] "Streptosporangium sp. 'caverna'"
# [1671] "Sulfitobacter pseudonitzschiae"
# [1672] "Sulfitobacter sp. AM1-D1"
# [1673] "Sulfitobacter sp. D7"
# [1674] "Sulfitobacter sp. JL08"
# [1675] "Sulfitobacter sp. SK011"
# [1676] "Sulfitobacter sp. SK012"
# [1677] "Sulfitobacter sp. SK025"
# [1678] "Sulfuricaulis limicola"
# [1679] "Sulfuricella denitrificans"
# [1680] "Sulfuriferula sp. AH1"
# [1681] "Sulfurifustis variabilis"
# [1682] "Sulfuritalea hydrogenivorans"
# [1683] "Sulfuritortus calidifontis"
# [1684] "Sulfurospirillum multivorans"
# [1685] "Sutterella megalosphaeroides"
# [1686] "Symbiobacterium thermophilum"
# [1687] "Synechococcus sp. KORDI-49"
# [1688] "Synechococcus sp. PCC 7336"
# [1689] "Synechococcus sp. RCC307"
# [1690] "Synechococcus sp. SynAce01"
# [1691] "Syntrophobotulus glycolicus"
# [1692] "Tabrizicola sp. K13M18"
# [1693] "Tateyamaria omphalii"
# [1694] "Terriglobus roseus"
# [1695] "Tessaracoccus aquimaris"
# [1696] "Tessaracoccus flavescens"
# [1697] "Tessaracoccus flavus"
# [1698] "Tessaracoccus sp. Marseille-P5995"
# [1699] "Tessaracoccus sp. T2.5-30"
# [1700] "Thalassococcus sp. SH-1"
# [1701] "Thalassospira marina"
# [1702] "Thalassospira xiamenensis"
# [1703] "Thauera aromatica"
# [1704] "Thauera chlorobenzoica"
# [1705] "Thauera humireducens"
# [1706] "Thauera hydrothermalis"
# [1707] "Thauera sp. K11"
# [1708] "Thauera sp. MZ1T"
# [1709] "Thermaerobacter marianensis"
# [1710] "Thermoanaerobacterales bacterium SK-G1"
# [1711] "Thermobacillus composti"
# [1712] "Thermobifida fusca"
# [1713] "Thermobispora bispora"
# [1714] "Thermomonospora curvata"
# [1715] "Thermus thermophilus"
# [1716] "Thioalkalivibrio nitratireducens"
# [1717] "Thioalkalivibrio paradoxus"
# [1718] "Thioalkalivibrio sp. K90mix"
# [1719] "Thioalkalivibrio sulfidiphilus"
# [1720] "Thioalkalivibrio versutus"
# [1721] "Thiobacillus denitrificans"
# [1722] "Thioclava nitratireducens"
# [1723] "Thiocystis violascens"
# [1724] "Thioflavicoccus mobilis"
# [1725] "Thiohalobacter thiocyanaticus"
# [1726] "Thiolapillus brandeum"
# [1727] "Thiomonas arsenitoxydans"
# [1728] "Thiomonas intermedia"
# [1729] "Thiomonas sp. X19"
# [1730] "Tistrella mobilis"
# [1731] "Tolumonas auensis"
# [1732] "Torque teno virus 13"
# [1733] "Torque teno virus 15"
# [1734] "Torque teno virus 19"
# [1735] "Torque teno virus 24"
# [1736] "Torque teno virus 29"
# [1737] "Truepera radiovictrix"
# [1738] "Trueperella pyogenes"
# [1739] "Tsukamurella paurometabola"
# [1740] "Tsukamurella tyrosinosolvens"
# [1741] "Undibacterium parvum"
# [1742] "Variibacter gotjawalensis"
# [1743] "Variovorax boronicumulans"
# [1744] "Variovorax paradoxus"
# [1745] "Variovorax sp. HW608"
# [1746] "Variovorax sp. PAMC 28711"
# [1747] "Variovorax sp. PMC12"
# [1748] "Verminephrobacter eiseniae"
# [1749] "Verrucomicrobia bacterium"
# [1750] "Verrucomicrobia bacterium IMCC26134"
# [1751] "Verrucomicrobium sp. GAS474"
# [1752] "Verrucomicrobium spinosum"
# [1753] "Verrucosispora maris"
# [1754] "Vibrio fluvialis"
# [1755] "Vibrio furnissii"
# [1756] "Vibrio vulnificus"
# [1757] "Victivallales bacterium CCUG 44730"
# [1758] "Vitreoscilla filiformis"
# [1759] "Vogesella sp. LIG4"
# [1760] "Vulgatibacter incomptus"
# [1761] "Wenzhouxiangella marina"
# [1762] "Xanthobacter autotrophicus"
# [1763] "Xanthomonas albilineans"
# [1764] "Xanthomonas arboricola"
# [1765] "Xanthomonas campestris"
# [1766] "Xanthomonas cassavae"
# [1767] "Xanthomonas citri"
# [1768] "Xanthomonas euvesicatoria"
# [1769] "Xanthomonas fragariae"
# [1770] "Xanthomonas gardneri"
# [1771] "Xanthomonas hortorum"
# [1772] "Xanthomonas oryzae"
# [1773] "Xanthomonas phaseoli"
# [1774] "Xanthomonas sacchari"
# [1775] "Xanthomonas translucens"
# [1776] "Xanthomonas vesicatoria"
# [1777] "Xylanimonas cellulosilytica"
# [1778] "Xylella fastidiosa"
# [1779] "Yangia pacifica"
# [1780] "Yangia sp. CCB-MM3"
# [1781] "Yersinia enterocolitica"
# [1782] "Yoonia vestfoldensis"
# [1783] "Zhihengliuella sp. ISTPL4"
# [1784] "Zobellella denitrificans"
# [1785] "Zoogloeaceae bacteirum Par-f-2"
# [1786] "Zymobacter palmae"
# [1787] "Zymomonas mobilis"

# %%
meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", species_df)
prev_df <- species_df %>% select(-npm_research_id)
prev_df[prev_df <= 0] <- 0
prev_df[prev_df > 0] <- 1
prev_df <- prev_df %>% 
    add_column(npm_research_id = species_df$npm_research_id, .before = 1) %>%
    left_join(meta)

level_counts <- prev_df %>% count(site_supplying_sample)
level_counts
prev_df %>%
    group_by(site_supplying_sample) %>%
    summarise(prev = sum(get("Nocardia brasiliensis")) / n()) %>%
    summarise(fold_diff = max(prev) / min(prev))
# Out:
# Joining, by = "npm_research_id"
#   site_supplying_sample n
# 1 GUSTO                  965
# 2 HELIOS                2285
# 3 MEC                   2708
# 4 PRISM                 1248
# 5 SERI                   874
# 6 TTSH                   648
#   fold_diff
# 1 35.65385

# %%
meta %>% filter(site_supplying_sample == "GUSTO")
# Out:
#     npm_research_id multiplex_pool_id supplier_id   gis_internal_sample_id
# 1   WHB3854         MUX8960           020-66085-011 GUSTO_Kids_020_66085_011_1
# 2   WHB3855         MUX8960           010-22048     GUSTO_Kids_010_22048_1
# 3   WHB3856         MUX8960           020-04240     GUSTO_Kids_020_04240_1
# 4   WHB3857         MUX8960           020-66123     GUSTO_Kids_020_66123_1
# 5   WHB3858         MUX8960           010-20267     GUSTO_Kids_010_20267_1
# 6   WHB3859         MUX8961           010-21795     GUSTO_Kids_010_21795_1
# 7   WHB3860         MUX8961           019-30236     GUSTO_Kids_019_30236_1
# 8   WHB3861         MUX8961           020-04307     GUSTO_Kids_020_04307_1
# 9   WHB3862         MUX8961           020-50162     GUSTO_Kids_020_50162_1
# 10  WHB3863         MUX8961           020-74124     GUSTO_Kids_020_74124_1
# 11  WHB3864         MUX8975           019-30195     GUSTO_Kids_019_30195_1
# 12  WHB3865         MUX8974           010-20986     GUSTO_Kids_010_20986_1
# 13  WHB3866         MUX8974           010-21050     GUSTO_Kids_010_21050_1
# 14  WHB3867         MUX8974           010-22116     GUSTO_Kids_010_22116_1
# 15  WHB3868         MUX8974           020-08071     GUSTO_Kids_020_08071_1
# 16  WHB3869         MUX8974           020-66156     GUSTO_Kids_020_66156_1
# 17  WHB3870         MUX8975           010-20300     GUSTO_Kids_010_20300_1
# 18  WHB3871         MUX8975           010-21800     GUSTO_Kids_010_21800_1
# 19  WHB3872         MUX8975           019-30305     GUSTO_Kids_019_30305_1
# 20  WHB3873         MUX8976           020-04324     GUSTO_Kids_020_04324_1
# 21  WHB3874         MUX8975           020-50177     GUSTO_Kids_020_50177_1
# 22  WHB3875         MUX8976           010-20620     GUSTO_Kids_010_20620_1
# 23  WHB3876         MUX8976           010-21488     GUSTO_Kids_010_21488_1
# 24  WHB3877         MUX8976           020-04271     GUSTO_Kids_020_04271_1
# 25  WHB3878         MUX8976           010-21266     GUSTO_Kids_010_21266_1
# 26  WHB3879         MUX8977           020-00033     GUSTO_Kids_020_00033_1
# 27  WHB3880         MUX8977           020-50006     GUSTO_Kids_020_50006_1
# 28  WHB3881         MUX8977           010-21897     GUSTO_Kids_010_21897_1
# 29  WHB3882         MUX8977           010-20332     GUSTO_Kids_010_20332_1
# 30  WHB3883         MUX8972           010-21833     GUSTO_Kids_010_21833_1
# ⋮   ⋮               ⋮                 ⋮             ⋮
# 936 WHB4821         MUX9298           020-50166     GUSTO_Kids_020_50166_1
# 937 WHB4822         MUX9305           020-74144     GUSTO_Kids_020_74144_1
# 938 WHB4823         MUX9298           020-00050     GUSTO_Kids_020_00050_1
# 939 WHB4826         MUX9306           020-06006     GUSTO_Kids_020_06006_1
# 940 WHB4827         MUX9298           010-10016     GUSTO_Kids_010_10016_1
# 941 WHB4828         MUX9307           010-20978     GUSTO_Kids_010_20978_1
# 942 WHB4829         MUX9306           020-66037     GUSTO_Kids_020_66037_1
# 943 WHB4830         MUX9306           020-74044     GUSTO_Kids_020_74044_1
# 944 WHB4831         MUX9305           010-21934     GUSTO_Kids_010_21934_1
# 945 WHB4832         MUX9306           020-74070     GUSTO_Kids_020_74070_1
# 946 WHB4833         MUX9307           020-74126     GUSTO_Kids_020_74126_1
# 947 WHB4834         MUX9306           020-66155     GUSTO_Kids_020_66155_1
# 948 WHB4836         MUX9241           020-74093     GUSTO_Kids_020_74093_1
# 949 WHB4837         MUX9307           019-30332     GUSTO_Kids_019_30332_1
# 950 WHB4838         MUX9307           010-21851     GUSTO_Kids_010_21851_1
# 951 WHB4839         MUX9308           010-21784     GUSTO_Kids_010_21784_1
# 952 WHB4840         MUX9309           020-66027     GUSTO_Kids_020_66027_1
# 953 WHB4841         MUX9308           010-21797     GUSTO_Kids_010_21797_1
# 954 WHB4842         MUX9308           010-20426     GUSTO_Kids_010_20426_1
# 955 WHB4843         MUX9308           020-08039     GUSTO_Kids_020_08039_1
# 956 WHB4844         MUX9308           020-50026     GUSTO_Kids_020_50026_1
# 957 WHB4845         MUX9309           020-04149     GUSTO_Kids_020_04149_1
# 958 WHB4846         MUX9309           010-20923     GUSTO_Kids_010_20923_1
# 959 WHB4847         MUX9309           020-18007     GUSTO_Kids_020_18007_1
# 960 WHB4848         MUX9309           020-50019     GUSTO_Kids_020_50019_1
# 961 WHB4849         MUX9310           010-20031     GUSTO_Kids_010_20031_1
# 962 WHB4850         MUX9310           010-14064     GUSTO_Kids_010_14064_1
# 963 WHB4851         MUX9310           010-20002     GUSTO_Kids_010_20002_1
# 964 WHB4852         MUX9310           010-21279     GUSTO_Kids_010_21279_1
# 965 WHB4853         MUX9310           020-06012     GUSTO_Kids_020_06012_1
#     site_supplying_sample year_of_birth supplied_gender self_reported_ethnicity
# 1   GUSTO                 2010          M               Chinese
# 2   GUSTO                 2011          F               Malay
# 3   GUSTO                 2010          F               Chinese
# 4   GUSTO                 2010          M               Indian
# 5   GUSTO                 2010          F               Malay
# 6   GUSTO                 2011          F               Malay
# 7   GUSTO                 2010          M               Chinese
# 8   GUSTO                 2010          M               Chinese
# 9   GUSTO                 2011          M               Chinese
# 10  GUSTO                 2011          F               Chinese
# 11  GUSTO                 2010          F               Chinese
# 12  GUSTO                 2010          F               Chinese
# 13  GUSTO                 2010          F               Indian
# 14  GUSTO                 2011          M               Malay
# 15  GUSTO                 2010          F               Indian
# 16  GUSTO                 2011          M               Indian
# 17  GUSTO                 2010          M               Malay
# 18  GUSTO                 2011          M               Indian
# 19  GUSTO                 2011          F               Malay
# 20  GUSTO                 2011          F               Indian
# 21  GUSTO                 2011          F               Indian
# 22  GUSTO                 2010          F               Chinese
# 23  GUSTO                 2010          M               Chinese
# 24  GUSTO                 2010          F               Chinese
# 25  GUSTO                 2010          M               Indian
# 26  GUSTO                 2010          M               Malay
# 27  GUSTO                 2010          M               Indian
# 28  GUSTO                 2011          M               Malay
# 29  GUSTO                 2010          M               Indian
# 30  GUSTO                 2010          F               Malay
# ⋮   ⋮                     ⋮             ⋮               ⋮
# 936 GUSTO                 2011          F               Chinese
# 937 GUSTO                 2011          M               Chinese
# 938 GUSTO                 2010          F               Chinese
# 939 GUSTO                 2009          M               Chinese
# 940 GUSTO                 2010          F               Chinese
# 941 GUSTO                 2010          F               Chinese
# 942 GUSTO                 2010          F               Chinese
# 943 GUSTO                 2010          M               Chinese
# 944 GUSTO                 2011          M               Chinese
# 945 GUSTO                 2010          M               Chinese
# 946 GUSTO                 2011          F               Chinese
# 947 GUSTO                 2011          F               Chinese
# 948 GUSTO                 2010          F               Chinese
# 949 GUSTO                 2011          M               Chinese
# 950 GUSTO                 2011          F               Chinese
# 951 GUSTO                 2011          M               Chinese
# 952 GUSTO                 2010          F               Chinese
# 953 GUSTO                 2011          F               Chinese
# 954 GUSTO                 2010          M               Chinese
# 955 GUSTO                 2010          M               Chinese
# 956 GUSTO                 2010          M               Chinese
# 957 GUSTO                 2010          M               Chinese
# 958 GUSTO                 2010          F               Chinese
# 959 GUSTO                 2009          F               Chinese
# 960 GUSTO                 2010          M               Chinese
# 961 GUSTO                 2010          M               Malay
# 962 GUSTO                 2010          M               Chinese
# 963 GUSTO                 2010          F               Chinese
# 964 GUSTO                 2010          M               Chinese
# 965 GUSTO                 2010          M               Chinese
#     extraction_kit               date_of_dna_extraction ⋯ sequencing_complete
# 1   QIAsymphony DSP DNA Midi Kit 1/11/2018              ⋯ Y
# 2   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 3   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 4   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 5   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 6   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 7   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 8   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 9   QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 10  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 11  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 12  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 13  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 14  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 15  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 16  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 17  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 18  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 19  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 20  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 21  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 22  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 23  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 24  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 25  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 26  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 27  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 28  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 29  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# 30  QIAsymphony DSP DNA Midi Kit 12/10/2018             ⋯ Y
# ⋮   ⋮                            ⋮                      ⋱ ⋮
# 936 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 937 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 938 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 939 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 940 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 941 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 942 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 943 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 944 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 945 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 946 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 947 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 948 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 949 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 950 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 951 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 952 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 953 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 954 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 955 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 956 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 957 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 958 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 959 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 960 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 961 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 962 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 963 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 964 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
# 965 QIAsymphony DSP DNA Midi Kit 19/10/2018             ⋯ Y
#     supplied_and_computed_gender_match
# 1   Y
# 2   Y
# 3   Y
# 4   Y
# 5   Y
# 6   Y
# 7   Y
# 8   Y
# 9   Y
# 10  Y
# 11  Y
# 12  Y
# 13  Y
# 14  Y
# 15  Y
# 16  Y
# 17  Y
# 18  Y
# 19  Y
# 20  Y
# 21  Y
# 22  Y
# 23  Y
# 24  Y
# 25  Y
# 26  Y
# 27  Y
# 28  Y
# 29  Y
# 30  Y
# ⋮   ⋮
# 936 Y
# 937 Y
# 938 Y
# 939 Y
# 940 Y
# 941 Y
# 942 Y
# 943 Y
# 944 Y
# 945 Y
# 946 Y
# 947 Y
# 948 Y
# 949 Y
# 950 Y
# 951 Y
# 952 Y
# 953 Y
# 954 Y
# 955 Y
# 956 Y
# 957 Y
# 958 Y
# 959 Y
# 960 Y
# 961 Y
# 962 Y
# 963 Y
# 964 Y
# 965 Y
#     sop_agreement_for_coverage__14/_28_for_15x/30x sample_life_cycle current
# 1   Y                                              GUSTO_Kids VCF    Y
# 2   Y                                              GUSTO_Kids VCF    Y
# 3   N                                              GUSTO_Kids VCF    Y
# 4   Y                                              GUSTO_Kids VCF    Y
# 5   N                                              GUSTO_Kids VCF    Y
# 6   Y                                              GUSTO_Kids VCF    Y
# 7   Y                                              GUSTO_Kids VCF    Y
# 8   Y                                              GUSTO_Kids VCF    Y
# 9   N                                              GUSTO_Kids VCF    Y
# 10  N                                              GUSTO_Kids VCF    Y
# 11  N                                              GUSTO_Kids VCF    Y
# 12  Y                                              GUSTO_Kids VCF    Y
# 13  Y                                              GUSTO_Kids VCF    Y
# 14  N                                              GUSTO_Kids VCF    Y
# 15  Y                                              GUSTO_Kids VCF    Y
# 16  Y                                              GUSTO_Kids VCF    Y
# 17  N                                              GUSTO_Kids VCF    Y
# 18  Y                                              GUSTO_Kids VCF    Y
# 19  N                                              GUSTO_Kids VCF    Y
# 20  N                                              GUSTO_Kids VCF    Y
# 21  N                                              GUSTO_Kids VCF    Y
# 22  N                                              GUSTO_Kids VCF    Y
# 23  N                                              GUSTO_Kids VCF    Y
# 24  Y                                              GUSTO_Kids VCF    Y
# 25  N                                              GUSTO_Kids VCF    Y
# 26  N                                              GUSTO_Kids VCF    Y
# 27  N                                              GUSTO_Kids VCF    Y
# 28  N                                              GUSTO_Kids VCF    Y
# 29  Y                                              GUSTO_Kids VCF    Y
# 30  N                                              GUSTO_Kids VCF    Y
# ⋮   ⋮                                              ⋮                 ⋮
# 936 Y                                              GUSTO_Kids VCF    Y
# 937 Y                                              GUSTO_Kids VCF    Y
# 938 Y                                              GUSTO_Kids VCF    Y
# 939 Y                                              GUSTO_Kids VCF    Y
# 940 N                                              GUSTO_Kids VCF    Y
# 941 Y                                              GUSTO_Kids VCF    Y
# 942 Y                                              GUSTO_Kids VCF    Y
# 943 Y                                              GUSTO_Kids VCF    Y
# 944 N                                              GUSTO_Kids VCF    Y
# 945 N                                              GUSTO_Kids VCF    Y
# 946 N                                              GUSTO_Kids VCF    Y
# 947 N                                              GUSTO_Kids VCF    Y
# 948 Y                                              GUSTO_Kids VCF    Y
# 949 Y                                              GUSTO_Kids VCF    Y
# 950 N                                              GUSTO_Kids VCF    Y
# 951 Y                                              GUSTO_Kids VCF    Y
# 952 Y                                              GUSTO_Kids VCF    Y
# 953 Y                                              GUSTO_Kids VCF    Y
# 954 Y                                              GUSTO_Kids VCF    Y
# 955 Y                                              GUSTO_Kids VCF    Y
# 956 Y                                              GUSTO_Kids VCF    Y
# 957 Y                                              GUSTO_Kids VCF    Y
# 958 N                                              GUSTO_Kids VCF    Y
# 959 Y                                              GUSTO_Kids VCF    Y
# 960 Y                                              GUSTO_Kids VCF    Y
# 961 Y                                              GUSTO_Kids VCF    Y
# 962 Y                                              GUSTO_Kids VCF    Y
# 963 Y                                              GUSTO_Kids VCF    Y
# 964 Y                                              GUSTO_Kids VCF    Y
# 965 Y                                              GUSTO_Kids VCF    Y
#     source_cohort original_supplier_id duplicate_info duplicate duplicate_pair
# 1   GUSTO_Kids    020-66085-011        Unknown        PASS      Unknown
# 2   GUSTO_Kids    010-22048            Unknown        PASS      Unknown
# 3   GUSTO_Kids    020-04240            Unknown        PASS      Unknown
# 4   GUSTO_Kids    020-66123            Unknown        PASS      Unknown
# 5   GUSTO_Kids    010-20267            Unknown        PASS      Unknown
# 6   GUSTO_Kids    010-21795            Unknown        PASS      Unknown
# 7   GUSTO_Kids    019-30236            Unknown        PASS      Unknown
# 8   GUSTO_Kids    020-04307            Unknown        PASS      Unknown
# 9   GUSTO_Kids    020-50162            Unknown        PASS      Unknown
# 10  GUSTO_Kids    020-74124            Unknown        PASS      Unknown
# 11  GUSTO_Kids    019-30195            Unknown        PASS      Unknown
# 12  GUSTO_Kids    010-20986            Unknown        PASS      Unknown
# 13  GUSTO_Kids    010-21050            Unknown        PASS      Unknown
# 14  GUSTO_Kids    010-22116            Unknown        PASS      Unknown
# 15  GUSTO_Kids    020-08071            Unknown        PASS      Unknown
# 16  GUSTO_Kids    020-66156            Unknown        PASS      Unknown
# 17  GUSTO_Kids    010-20300            Unknown        PASS      Unknown
# 18  GUSTO_Kids    010-21800            Unknown        PASS      Unknown
# 19  GUSTO_Kids    019-30305            Unknown        PASS      Unknown
# 20  GUSTO_Kids    020-04324            Unknown        PASS      Unknown
# 21  GUSTO_Kids    020-50177            Unknown        PASS      Unknown
# 22  GUSTO_Kids    010-20620            Unknown        PASS      Unknown
# 23  GUSTO_Kids    010-21488            Unknown        PASS      Unknown
# 24  GUSTO_Kids    020-04271            Unknown        PASS      Unknown
# 25  GUSTO_Kids    010-21266            Unknown        PASS      Unknown
# 26  GUSTO_Kids    020-00033            Unknown        PASS      Unknown
# 27  GUSTO_Kids    020-50006            Unknown        PASS      Unknown
# 28  GUSTO_Kids    010-21897            Unknown        PASS      Unknown
# 29  GUSTO_Kids    010-20332            Unknown        PASS      Unknown
# 30  GUSTO_Kids    010-21833            Unknown        PASS      Unknown
# ⋮   ⋮             ⋮                    ⋮              ⋮         ⋮
# 936 GUSTO_Kids    020-50166            Unknown        PASS      Unknown
# 937 GUSTO_Kids    020-74144            Unknown        PASS      Unknown
# 938 GUSTO_Kids    020-00050            Unknown        PASS      Unknown
# 939 GUSTO_Kids    020-06006            Unknown        PASS      Unknown
# 940 GUSTO_Kids    010-10016            Unknown        PASS      Unknown
# 941 GUSTO_Kids    010-20978            Unknown        PASS      Unknown
# 942 GUSTO_Kids    020-66037            Unknown        PASS      Unknown
# 943 GUSTO_Kids    020-74044            Unknown        PASS      Unknown
# 944 GUSTO_Kids    010-21934            Unknown        PASS      Unknown
# 945 GUSTO_Kids    020-74070            Unknown        PASS      Unknown
# 946 GUSTO_Kids    020-74126            Unknown        PASS      Unknown
# 947 GUSTO_Kids    020-66155            Unknown        PASS      Unknown
# 948 GUSTO_Kids    020-74093            Unknown        PASS      Unknown
# 949 GUSTO_Kids    019-30332            Unknown        PASS      Unknown
# 950 GUSTO_Kids    010-21851            Unknown        PASS      Unknown
# 951 GUSTO_Kids    010-21784            Unknown        PASS      Unknown
# 952 GUSTO_Kids    020-66027            Unknown        PASS      Unknown
# 953 GUSTO_Kids    010-21797            Unknown        PASS      Unknown
# 954 GUSTO_Kids    010-20426            Unknown        PASS      Unknown
# 955 GUSTO_Kids    020-08039            Unknown        PASS      Unknown
# 956 GUSTO_Kids    020-50026            Unknown        PASS      Unknown
# 957 GUSTO_Kids    020-04149            Unknown        PASS      Unknown
# 958 GUSTO_Kids    010-20923            Unknown        PASS      Unknown
# 959 GUSTO_Kids    020-18007            Unknown        PASS      Unknown
# 960 GUSTO_Kids    020-50019            Unknown        PASS      Unknown
# 961 GUSTO_Kids    010-20031            Unknown        PASS      Unknown
# 962 GUSTO_Kids    010-14064            Unknown        PASS      Unknown
# 963 GUSTO_Kids    010-20002            Unknown        PASS      Unknown
# 964 GUSTO_Kids    010-21279            Unknown        PASS      Unknown
# 965 GUSTO_Kids    020-06012            Unknown        PASS      Unknown

# %%
meta$hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot

# %%
prev_df %>%
    group_by(extraction_kit) %>%
    summarise(prev = sum(get("Bradyrhizobium sp. SK17")) / n())
# Out:
#   extraction_kit                                 prev
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit 0.8851381
# 2 Chemagic DNA Blood Kit (Perkin Elmer, MA)      0.9990385
# 3 Maxwell RSC Blood DNA Kit (AS1400)             0.9947966
# 4 QIAamp DNA Blood Mini Kit                      0.6404321
# 5 QIAsymphony DSP DNA Midi Kit                   1.0000000
# 6 QIAsymphony DSP DNA Mini Kit (192)             0.9663300
# 7 Unknown                                        0.5644567

# %%
full_species_df %>%
    group_by(taxa) %>%
    summarise(n_diff = sum(diff_prev)) %>%
    filter(n_diff == 1)
# Out:
#   taxa                        n_diff
# 1 Altererythrobacter sp. B11  1
# 2 Bradyrhizobium erythrophlei 1
# 3 Bradyrhizobium sp. SK17     1

# %% [markdown]
# ### Correlation filter

# %%
load_parse_data <- function(n_subset, rank, human, rel_a) {
    # Load data
    to_retain <- fread("data/samples_above_95_reads.txt")$npm_research_id
    df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>% 
        filter(npm_research_id %in% to_retain)
    meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)
    
    # Get metadata subset
    meta_filt <- subset_metadata(meta, 9999)

    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    df_filt3 <- remove_low_freq_taxa(df_filt2, frac_presence = 0.05)
    df_filt4 <- remove_empty_rows(df_filt3)
    print(ncol(df_filt4))
    if (rel_a) {
        RA_df <- otu_to_RA(df_filt4)
        return(RA_df)
    } else {
        return(df_filt4)
    }
    
}

# %%
species_df <- load_parse_data(9999, "S", "Homo sapiens", rel_a = F)
species_RA <- load_parse_data(9999, "S", "Homo sapiens", rel_a = T)
# genus_RA <- load_parse_data(9999, "G", "Homo", rel_a = T)
# Out:
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] 1793
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] 1793

# %%
# genus_c <- full_genus_res[["contaminants"]]
# genus_nc <- full_genus_res[["non_contaminants"]]

# species_c <- full_species_res[["contaminants"]]
# species_nc <- full_species_res[["non_contaminants"]]

# %%
# genus_n_nc <- length(genus_nc)
# species_n_nc <- length(species_nc)

# print(str_glue("{genus_n_nc}/{ncol(genus_RA)} genus after differential prevalence decontamination"))
# print(str_glue("{species_n_nc}/{ncol(species_RA)} species after differential prevalence decontamination"))

# %% [markdown]
# ### Identify read/RA thresholds

# %%
long_df <- species_df %>%
    pivot_longer(!npm_research_id, names_to = "taxon", values_to = "read_count") 
long_RA <- species_RA %>%
    pivot_longer(!npm_research_id, names_to = "taxon", values_to = "rel_a")

# %% [markdown]
# #### Read thresholds ~ percentile

# %%
quantiles <- foreach (perc = seq(90, 100, by = 0.1)) %dopar% {
    quant <- quantile(long_df$read_count, perc / 100)
    return(tibble(perc = perc, quant = quant))
}
stopImplicitCluster()

read_q_df <- bind_rows(quantiles)

# %%
read_q_df %>% filter(quant != 0, quant != 1)
# Out:
#     perc  quant
# 1   90.0  3
# 2   90.1  3
# 3   90.2  4
# 4   90.3  4
# 5   90.4  4
# 6   90.5  4
# 7   90.6  4
# 8   90.7  4
# 9   90.8  4
# 10  90.9  4
# 11  91.0  4
# 12  91.1  4
# 13  91.2  4
# 14  91.3  4
# 15  91.4  4
# 16  91.5  4
# 17  91.6  4
# 18  91.7  5
# 19  91.8  5
# 20  91.9  5
# 21  92.0  5
# 22  92.1  5
# 23  92.2  5
# 24  92.3  5
# 25  92.4  5
# 26  92.5  5
# 27  92.6  5
# 28  92.7  6
# 29  92.8  6
# 30  92.9  6
# ⋮   ⋮     ⋮
# 72   97.1      22.000
# 73   97.2      24.000
# 74   97.3      25.000
# 75   97.4      26.000
# 76   97.5      28.000
# 77   97.6      30.000
# 78   97.7      32.000
# 79   97.8      34.000
# 80   97.9      36.000
# 81   98.0      39.000
# 82   98.1      42.000
# 83   98.2      46.000
# 84   98.3      49.000
# 85   98.4      54.000
# 86   98.5      59.000
# 87   98.6      66.000
# 88   98.7      73.000
# 89   98.8      81.000
# 90   98.9      92.000
# 91   99.0     105.000
# 92   99.1     122.000
# 93   99.2     143.000
# 94   99.3     171.000
# 95   99.4     210.000
# 96   99.5     268.000
# 97   99.6     360.000
# 98   99.7     526.000
# 99   99.8     915.000
# 100  99.9    2194.425
# 101 100.0 1594156.000

# %%
read_q_df %>%
    ggplot(aes(x = perc, y = quant)) +
    geom_line() +
    ylim(0, 50) +
    xlim(80, 99.9) +
    labs(x = "Percentile read count", y = "Quantile")
# Out:
# Warning message:
# “Removed 17 row(s) containing missing values (geom_path).”
# plot without title

# %% [markdown]
# #### RA thresholds ~ percentile

# %%
quantiles <- foreach (perc = seq(91, 100, 0.5)) %dopar% {
    quant <- quantile(long_RA$rel_a, perc / 100)
    return(tibble(perc = perc, quant = quant))
}

stopImplicitCluster()
q_df <- bind_rows(quantiles)

# %%
q_df %>%
    ggplot(aes(x = perc, y = log(quant, base = 10))) +
    geom_line()
# Out:
# plot without title

# %%
min_samples <- 100
# threshold_df <- tibble()

# for (perc in seq(95, 100, 0.5)) {
#     read_threshold <- quantile(long_RA$rel_a, perc / 100)
#     full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens", read_threshold = read_threshold, min_samples = min_samples)
#     full_species_res <- parse_decontamination_results(full_species_df)
# #     fwrite(full_species_df, str_glue("results/decontamination/RA_thresholds/diff_prev_results.9999.S.RA.perc{perc}_t{read_threshold}_minsamples{min_samples}.csv"))
#     fwrite(tibble(non_contaminants = full_species_res[["non_contaminants"]]), str_glue("results/decontamination/RA_thresholds/prevalence.noncontam.S.n9999.RA.perc{perc}_t{read_threshold}_minsamples{min_samples}.txt"))
#     threshold_df <- threshold_df %>% bind_rows(tibble(perc = perc, read_threshold = read_threshold, n_nc = length(full_species_res[["non_contaminants"]])))
# }

# %%
# threshold_df

# %%
threshold_df2 <- tibble()

## For RA ##
# for (read_threshold in c(0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5)) {
#     full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens", read_threshold = read_threshold, min_samples = min_samples)
#     full_species_res <- parse_decontamination_results(full_species_df)
# #     fwrite(full_species_df, str_glue("results/decontamination/RA_thresholds/diff_prev_results.9999.S.RA.perc_{read_threshold}.csv"))
#     fwrite(tibble(non_contaminants = full_species_res[["non_contaminants"]]), str_glue("results/decontamination/RA_thresholds/prevalence.noncontam.S.n9999.RA.perc{perc}_t{read_threshold}_minsamples{min_samples}.txt"))
#     threshold_df2 <- threshold_df2 %>% bind_rows(tibble(read_threshold = read_threshold, n_nc = length(full_species_res[["non_contaminants"]])))
# }


## For reads ##
for (read_threshold in c(0, 1, 2, 3, 4, 5, 10, 20, 30, 50, 100)) {
    full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens", read_threshold = read_threshold, min_samples = min_samples)
    full_species_res <- parse_decontamination_results(full_species_df)
#     fwrite(full_species_df, str_glue("results/decontamination/RA_thresholds/diff_prev_results.9999.S.perc_{read_threshold}.csv"))
    fwrite(tibble(non_contaminants = full_species_res[["non_contaminants"]]), str_glue("results/decontamination/RA_thresholds/prevalence.noncontam.S.n9999.perc_t{read_threshold}_minsamples{min_samples}.txt"))
    threshold_df2 <- threshold_df2 %>% bind_rows(tibble(read_threshold = read_threshold, n_nc = length(full_species_res[["non_contaminants"]])))
}
# Out:
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# 1792 / 5199 taxa are present in 0.05 of samples
# 0/8728 samples removed due to having no reads of interest
# [1] "site_supplying_sample"
# After pruning, site_supplying_sample has 6 levels
# [1] "extraction_kit"
# After pruning, extraction_kit has 6 levels
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels

# %%
threshold_df2
# Out:
#    read_threshold n_nc
# 1    0            2
# 2    1            0
# 3    2            0
# 4    3            0
# 5    4            0
# 6    5            0
# 7   10            0
# 8   20            0
# 9   30            0
# 10  50            0
# 11 100            0
