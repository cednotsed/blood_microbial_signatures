# %% [markdown]
# # Identication of putative contaminant taxa

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(foreach)
require(tidyverse)
require(ggplot2)
require(data.table)
# Out:
# Loading required package: foreach
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::accumulate() masks foreach::accumulate()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ purrr::when()       masks foreach::when()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
load_data <- function(file_path) {
    df <- as.data.frame(fread(file_path)) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}


load_metadata <- function(file_path, df) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% df$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}


subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}


retrieve_rows_from_meta <- function(df, meta) {
    return(df %>% filter(npm_research_id %in% meta$npm_research_id)) 
}


remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}


remove_low_freq_taxa <- function(df, frac_presence) {
    n_original <- ncol(df[, colnames(df) != "npm_research_id"])
    PA_df <- apply(df[, 2:ncol(df)], 2, function(x) {ifelse(x > 0, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    n_new <- length(to_keep) - 1
    print(str_glue("{n_new} / {n_original} taxa are present in {frac_presence} of samples"))
    return(df %>% select(all_of(to_keep)))
}


otu_to_RA <- function(df) {
    rownames(df) <- df$npm_research_id
    RA_df <- t(apply(df[, colnames(df) != "npm_research_id"], 1, function(x) {x / sum(x)}))
    
    return(as.data.frame(RA_df))
}


get_metadata_plots <- function(meta, meta_cols) {
    meta <- as.matrix(meta)
    meta <- as_tibble(meta, rownames = "sample")

    plots <- list()
    
    for (column in meta_cols) {
        plt <- meta %>%
            mutate(across(everything(), as.character)) %>%
            select(all_of(column)) %>%
            group_by_at(column) %>%
            summarise(n = n()) %>%
            ggplot(aes_string(x = column, y = "n", fill = column)) +
                geom_bar(stat = "identity") +
                theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
                geom_text(aes_string(label = "n"))
        plots[[column]] <- plt
    }
    
    return(plots)
}


get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id", "extraction_kit")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


print_group_freqs <- function(meta, meta_cols) {
    for (col in meta_cols) {
        tmp <- tibble(data.frame(meta)) %>%
            group_by(get(col)) %>%
            summarise(n = n())
        print(col)
        print(tmp)
    }
}


get_batch_prevalence <- function(x) {sum(x) / length(x)}


remove_low_read_samples <- function(df) {
    to_retain <- fread("data/samples_above_10_reads.txt")$npm_research_id
    return(df %>% filter(npm_research_id %in% to_retain))
}


remove_empty_rows <- function(df) {
    df_filt <- df %>% 
        rowwise(npm_research_id) %>% 
        mutate(total = sum(across(everything()))) %>%
        filter(total != 0) %>%
        select(-total)
    
    n_original <- nrow(df)
    n_removed <- n_original - nrow(df_filt)
    
    print(str_glue("{n_removed}/{n_original} samples removed due to having no reads of interest"))
    
    return(as.data.frame(df_filt))
}

# %% [markdown]
# #### Test for differential prevalence

# %%
run_diff_prev <- function(dat, metadat, meta_cols, read_threshold, prev_threshold, min_samples) {
    morsels <- foreach (column = meta_cols) %do% {
        print(column)
        # Remove levels with < x samples
        tmp <- tibble(data.frame(metadat)) %>%
                group_by(get(column)) %>%
                summarise(n = n())

        # Vector of group levels to keep
        to_keep <- tmp[tmp$n >= min_samples, "get(column)"]$`get(column)`
        to_keep <- to_keep[to_keep != "Unknown"]
        n_levels <- length(to_keep)

        if (n_levels < 2) {
            print(str_glue("After pruning, {column} has < 2 levels"))
        } else {
            print(str_glue("After pruning, {column} has {n_levels} levels"))
        }

        # Remove rows in metadata
        metadat_filt <- metadat %>% filter(get(column) %in% to_keep)

        # Retrieve rows
        dat_filt <- retrieve_rows_from_meta(dat, metadat_filt)
        metadat_filt <- metadat_filt %>% filter(npm_research_id %in% dat_filt$npm_research_id)

        # Convert abundance table to presence absence table
        prev_filt <- dat_filt[, colnames(dat_filt) != "npm_research_id"]
        prev_filt[prev_filt < read_threshold] <- 0
        prev_filt[prev_filt >= read_threshold] <- 1
        prev_filt$npm_research_id <- dat_filt$npm_research_id
        
        taxa_vec <- colnames(prev_filt)
        taxa_vec <- taxa_vec[taxa_vec != "npm_research_id"]

        crumbs <- foreach (taxon = taxa_vec) %do% {
            prev_stats <- prev_filt %>% 
                left_join(metadat_filt, by = "npm_research_id") %>%
                group_by_at(c(column)) %>%
                summarise(sum = sum(get(taxon))) %>%
                mutate(batch_n = as.vector(table(metadat_filt[, column])),
                       prevalence = sum / as.vector(table(metadat_filt[, column])))

            max_prev <- max(prev_stats$prevalence)
            min_prev <- min(prev_stats$prevalence)
            fold_diff <- max_prev / min_prev
            max_level <- pull(prev_stats, column)[which(prev_stats$prevalence == max(prev_stats$prevalence))][1]
            min_level <- pull(prev_stats, column)[which(prev_stats$prevalence == min(prev_stats$prevalence))][1]
            diff_prev <- ifelse(fold_diff > prev_threshold, T, F)

            crumb <- tibble(taxa = taxon, meta_col = column,
                   max_level = max_level, min_level = min_level, 
                   max_prev = max_prev, min_prev = min_prev,
                   fold_diff = fold_diff,
                   diff_prev = diff_prev)
            
            crumb <- distinct(crumb, taxa, .keep_all = T)

            return(crumb)
        }
        
        morsel <- bind_rows(crumbs)
        return(morsel)
    }

    result_df <- bind_rows(morsels)
    return(result_df)
}

# %% [markdown]
# #### Diff. prevalence decontamination procedure

# %%
decontaminate <- function(rank, n_subset, n, human) {
    # Load data and remove low microbial read samples
    to_retain <- fread("data/samples_above_95_reads.txt")$npm_research_id
    df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>% 
        filter(npm_research_id %in% to_retain)
    meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)
    
    # Get metadata subset
    meta_filt <- subset_metadata(meta, n) %>%
        filter(site_supplying_sample == "PRISM")

    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    df_filt3 <- remove_low_freq_taxa(df_filt2, frac_presence = 0.05)
    df_filt4 <- remove_empty_rows(df_filt3)

    # Get metadata columns of interest
    meta_cols <- get_meta_cols(meta_filt)
    
#     # Print group freqs
#     print_group_freqs(meta_filt, meta_cols)
    
    # Differential prevalence
    res <- run_diff_prev(df_filt4, meta_filt, meta_cols, read_threshold = 1, prev_threshold = 2 , min_samples = 5)
    
    return(res)
}


parse_decontamination_results <- function(decontam_res) {
    non_contaminants <- decontam_res %>%     
        group_by(taxa) %>%
        summarise(n_diff = sum(diff_prev)) %>%
        filter(n_diff == 0)
    non_contaminants <- non_contaminants$taxa

    contaminants <- decontam_res %>%
        group_by(taxa) %>%
        summarise(n_diff = sum(diff_prev)) %>%
        filter(n_diff > 0)
    contaminants <- contaminants$taxa
    
    return(list(non_contaminants = non_contaminants, contaminants = contaminants))
}

# %% [markdown]
# #### Rarefy decontamination procedure

# %%
rarefy_decontaminate <- function(rank, human, breaks) {
    morsels <- foreach (n = breaks) %do% {
        res <- decontaminate(rank, 9999, n, human)
        res_list <- parse_decontamination_results(res)
        morsel <- tibble(non_contaminants = res_list[["non_contaminants"]], n = n)
        return(morsel)
    }

    nc_df <- bind_rows(morsels)
    return(nc_df)
}

# %% [markdown]
# #### Visualise

# %%
diff_prev_heatmap <- function(nc) {
    plt <- nc %>% 
        mutate(n = as.factor(n)) %>%
        ggplot(aes(x = n, y = non_contaminants)) +
        geom_tile(color = "black") +
        scale_x_discrete(breaks = breaks) +
        theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
        labs(x = "No. of samples", y = "Non-contaminant taxa")

        return(plt)
}

# %% [markdown]
# ### Main for diff. prevalence decontamination

# %%
breaks <- c(100, 200, 400, 800, 1300)
# breaks <- c(100, 200, 400)
# breaks <- c(9999)
breaks

species_nc_df <- rarefy_decontaminate("S", "Homo sapiens", breaks)
genus_nc_df <- rarefy_decontaminate("G", "Homo", breaks)
# Out:
# [1]  100  200  400  800 1300
# 2124 / 5199 taxa are present in 0.05 of samples
# 0/100 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 4 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 4 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 5 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 4 levels
# 2138 / 5199 taxa are present in 0.05 of samples
# 0/200 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 4 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 5 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 4 levels
# 2147 / 5199 taxa are present in 0.05 of samples
# 0/400 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 7 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 6 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 6 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 5 levels
# 2151 / 5199 taxa are present in 0.05 of samples
# 0/800 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 9 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels
# 2154 / 5199 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 9 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels
# 717 / 1492 taxa are present in 0.05 of samples
# 0/100 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 5 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 4 levels
# 736 / 1492 taxa are present in 0.05 of samples
# 0/200 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 6 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 6 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 5 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 4 levels
# 731 / 1492 taxa are present in 0.05 of samples
# 0/400 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 8 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 6 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 7 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 5 levels
# 729 / 1492 taxa are present in 0.05 of samples
# 0/800 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 8 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 7 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 5 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels
# 728 / 1492 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 9 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels

# %%
diff_prev_heatmap(species_nc_df)
ggsave("results/decontamination/non_contaminant_species_heatmap.png", dpi = 300, width = 5, height = 10)
# Out:
# plot without title

# %%
diff_prev_heatmap(genus_nc_df)
ggsave("results/decontamination/PRISM_only/non_contaminant_genus_heatmap.png", dpi = 300, width = 5, height = 10)
# Out:
# plot without title

# %%
full_genus_df <- decontaminate("G", 9999, 9999, "Homo")
full_genus_res <- parse_decontamination_results(full_genus_df)
fwrite(full_genus_df, str_glue("results/decontamination/diff_prev_raw/diff_prev_results.PRISM_only.G.csv"))

full_species_df <- decontaminate("S", 9999, 9999, "Homo sapiens")
full_species_res <- parse_decontamination_results(full_species_df)
fwrite(full_species_df, str_glue("results/decontamination/diff_prev_raw/diff_prev_results.PRISM_only.S.csv"))

fwrite(tibble(non_contaminants = full_genus_res[["non_contaminants"]]), str_glue("results/decontamination/PRISM_only/prevalence.noncontam.G.n9999.txt"))
fwrite(tibble(contaminants = full_genus_res[["contaminants"]]), str_glue("results/decontamination/PRISM_only/prevalence.contam.G.n9999.txt"))

fwrite(tibble(non_contaminants = full_species_res[["non_contaminants"]]), str_glue("results/decontamination/PRISM_only/prevalence.noncontam.S.n9999.txt"))
fwrite(tibble(contaminants = full_species_res[["contaminants"]]), str_glue("results/decontamination/PRISM_only/prevalence.contam.S.n9999.txt"))
# Out:
# 728 / 1492 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 9 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels
# 2154 / 5199 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] "instrument_id"
# After pruning, instrument_id has 5 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 9 levels
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 9 levels
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 8 levels
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 6 levels

# %% [markdown]
# ### Correlation filter

# %%
load_parse_RA <- function(n_subset, rank, human) {
    # Load data
    to_retain <- fread("data/samples_above_95_reads.txt")$npm_research_id
    df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.{rank}.tsv")) %>% 
        filter(npm_research_id %in% to_retain)
    meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)
    
    # Get metadata subset
    meta_filt <- subset_metadata(meta, 9999) %>%
        filter(site_supplying_sample == "PRISM")

    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    df_filt3 <- remove_low_freq_taxa(df_filt2, frac_presence = 0.05)
    df_filt4 <- remove_empty_rows(df_filt3)
    print(ncol(df_filt4))
    RA_df <- otu_to_RA(df_filt4)
    
    return(RA_df)
}

# %%
corr_decontam <- function(RA_df, non_contaminants, contaminants) {
    nc_list <- foreach (non_contaminant_taxon = non_contaminants) %do% {
        morsel <- tibble()
        for (contaminant_taxon in contaminants) {
            spearman_test <- cor.test(RA_df[ ,contaminant_taxon], RA_df[, non_contaminant_taxon])
            rho <- spearman_test$estimate
#             p_val <- spearman_test$p.value
#             p_adj <- p.adjust(p_val, method = "BH", n = length(length(non_contaminants) * length(contaminants)))
    #         print(str_glue("{non_contaminant_taxon} has correlation of {rho} with {contaminant_taxon}, p = {p_adj}"))
            morsel <- morsel %>% bind_rows(tibble(non_contaminant_taxon = non_contaminant_taxon, 
                                           contaminant_taxon = contaminant_taxon,
                                           rho = rho))
        }

        return(morsel)
    }

    corr_df <- bind_rows(nc_list)  
    return(corr_df)
}

# %%
species_RA <- load_parse_RA(9999, "S", "Homo sapiens")
genus_RA <- load_parse_RA(9999, "G", "Homo")
# Out:
# 2154 / 5199 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] 2155
# 728 / 1492 taxa are present in 0.05 of samples
# 0/1248 samples removed due to having no reads of interest
# [1] 729

# %%
genus_c <- full_genus_res[["contaminants"]]
genus_nc <- full_genus_res[["non_contaminants"]]

species_c <- full_species_res[["contaminants"]]
species_nc <- full_species_res[["non_contaminants"]]

species_corr <- corr_decontam(species_RA, species_nc, species_c)
genus_corr <- corr_decontam(genus_RA, genus_nc, genus_c)

# %%
genus_n_nc <- length(genus_nc)
species_n_nc <- length(species_nc)

print(str_glue("{genus_n_nc}/{ncol(genus_RA)} genus after differential prevalence decontamination"))
print(str_glue("{species_n_nc}/{ncol(species_RA)} species after differential prevalence decontamination"))
# Out:
# 272/728 genus after differential prevalence decontamination
# 672/2154 species after differential prevalence decontamination

# %% [markdown]
# #### Visualise number of taxa retained by correlation threshold

# %%
get_corr_dist <- function(corr_df, non_contaminants) {
    rho_df <- tibble()
    for (i in seq(0, 1, 0.05)) {
        filtered_corr <- corr_df %>% 
            filter(rho > i)

        n_retained <- length(non_contaminants) - length(unique(filtered_corr$non_contaminant_taxon))
        morsel <- tibble(rho = i, n_retained = n_retained)
        rho_df <- rho_df %>% bind_rows(morsel)
    }
    
    rho_plt <- rho_df %>%
        ggplot(aes(x = rho, y = n_retained)) +
        geom_point() +
        labs(y = "No. of taxa retained", x = "Rho threshold")
    print(rho_plt)
    return(rho_df)
}

# %%
genus_corr_dist <- get_corr_dist(genus_corr, genus_nc)
genus_corr_dist

ggsave("results/decontamination/PRISM_only/genus_rho_threshold_plot.png", dpi = 300)
# Out:
#    rho  n_retained
# 1  0.00   0
# 2  0.05   0
# 3  0.10   1
# 4  0.15   1
# 5  0.20   2
# 6  0.25   4
# 7  0.30   8
# 8  0.35  25
# 9  0.40  45
# 10 0.45  63
# 11 0.50  98
# 12 0.55 142
# 13 0.60 183
# 14 0.65 220
# 15 0.70 230
# 16 0.75 243
# 17 0.80 254
# 18 0.85 259
# 19 0.90 262
# 20 0.95 266
# 21 1.00 272
# Saving 6.67 x 6.67 in image
# plot without title

# %%
species_corr_dist <- get_corr_dist(species_corr, species_nc)
species_corr_dist

ggsave("results/decontamination/species_rho_threshold_plot.png", dpi = 300)
# Out:
#    rho  n_retained
# 1  0.00   0
# 2  0.05   0
# 3  0.10   0
# 4  0.15   0
# 5  0.20   2
# 6  0.25  19
# 7  0.30  56
# 8  0.35 105
# 9  0.40 154
# 10 0.45 227
# 11 0.50 278
# 12 0.55 340
# 13 0.60 406
# 14 0.65 478
# 15 0.70 513
# 16 0.75 545
# 17 0.80 578
# 18 0.85 601
# 19 0.90 630
# 20 0.95 650
# 21 1.00 672
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# #### Save contaminant and non-contaminant taxa

# %%
get_filtered_taxa <- function(corr_df, nc, corr_t) {
    to_remove <- corr_df %>% 
        filter(rho > corr_t) %>%
        distinct(non_contaminant_taxon) %>%
        rename(to_remove = non_contaminant_taxon)
    to_keep <- tibble(non_contaminants = nc) %>% 
        filter(!(non_contaminants %in% to_remove$to_remove))
    return(list(to_remove = to_remove, to_keep = to_keep))
}

# %%
corr_t <- 0.7
species_corr_res <- get_filtered_taxa(species_corr, species_nc, corr_t)
genus_corr_res <- get_filtered_taxa(genus_corr, genus_nc, corr_t)

species_corr_res
genus_corr_res
# Out:
# $to_remove
# # A tibble: 159 × 1
#    to_remove
#    <chr>
#  1 Achromobacter denitrificans
#  2 Achromobacter insolitus
#  3 Achromobacter sp. AONIH1
#  4 Achromobacter sp. MFA1 R4
#  5 Achromobacter spanius
#  6 Achromobacter xylosoxidans
#  7 Acidovorax sp. KKS102
#  8 Agrobacterium tumefaciens
#  9 Agrococcus carbonis
# 10 Aminobacter aminovorans
# # … with 149 more rows
#
# $to_keep
# # A tibble: 513 × 1
#    non_contaminants
#    <chr>
#  1 Acidiphilium multivorum
#  2 Acidisphaera sp. G45-3
#  3 Acidovorax avenae
#  4 Acidovorax carolinensis
#  5 Acidovorax cattleyae
#  6 Acidovorax citrulli
#  7 Acidovorax sp. JS42
#  8 Actinoalloteichus hymeniacidonis
#  9 Actinoplanes friuliensis
# 10 Actinoplanes missouriensis
# # … with 503 more rows
# $to_remove
# # A tibble: 42 × 1
#    to_remove
#    <chr>
#  1 Achromobacter
#  2 Actinomyces
#  3 Agrococcus
#  4 Agromyces
#  5 Beijerinckia
#  6 Bifidobacterium
#  7 Burkholderia
#  8 Caulobacter
#  9 Chelativorans
# 10 Clavibacter
# # … with 32 more rows
#
# $to_keep
# # A tibble: 230 × 1
#    non_contaminants
#    <chr>
#  1 Acetobacter
#  2 Acidiphilium
#  3 Acidipropionibacterium
#  4 Acidisphaera
#  5 Acidovorax
#  6 Acinetobacter
#  7 Actinoalloteichus
#  8 Actinoplanes
#  9 Actinopolymorpha
# 10 Actinosynnema
# # … with 220 more rows

# %%
fwrite(species_corr_res[["to_keep"]], 
       str_glue("results/decontamination/PRISM_only/prevalence.corr.noncontam.S.n9999.txt"))
fwrite(species_corr_res[["to_remove"]], 
       str_glue("results/decontamination/PRISM_only/prevalence.corr.contam.S.n9999.txt"))

fwrite(genus_corr_res[["to_keep"]], 
       str_glue("results/decontamination/PRISM_only/prevalence.corr.noncontam.G.n9999.txt"))
fwrite(genus_corr_res[["to_remove"]], 
       str_glue("results/decontamination/PRISM_only/prevalence.corr.contam.G.n9999.txt"))

# %%
genus_corr_res[["to_keep"]]
species_corr_res[["to_keep"]]

print(str_glue("{genus_n_nc}/{ncol(genus_RA)} genus after differential prevalence decontamination"))
print(str_glue("{species_n_nc}/{ncol(species_RA)} species after differential prevalence decontamination"))
# Out:
#     non_contaminants
# 1   Acetobacter
# 2   Acidiphilium
# 3   Acidipropionibacterium
# 4   Acidisphaera
# 5   Acidovorax
# 6   Acinetobacter
# 7   Actinoalloteichus
# 8   Actinoplanes
# 9   Actinopolymorpha
# 10  Actinosynnema
# 11  Aeromicrobium
# 12  Aeromonas
# 13  Afipia
# 14  Agrobacterium
# 15  Alcanivorax
# 16  Alicycliphilus
# 17  Alkalilimnicola
# 18  Alloactinosynnema
# 19  Allokutzneria
# 20  Altererythrobacter
# 21  Aminobacter
# 22  Amycolatopsis
# 23  Anaeromyxobacter
# 24  Aromatoleum
# 25  Arthrobacter
# 26  Asticcacaulis
# 27  Aureimonas
# 28  Azoarcus
# 29  Azorhizobium
# 30  Azospira
# ⋮   ⋮
# 201 Sinorhizobium
# 202 Solimonas
# 203 Sorangium
# 204 Sphingobacterium
# 205 Sphingobium
# 206 Sphingorhabdus
# 207 Sphingosinicella
# 208 Stappia
# 209 Starkeya
# 210 Stenotrophomonas
# 211 Steroidobacter
# 212 Streptomyces
# 213 Streptosporangium
# 214 Sulfitobacter
# 215 Sulfuricaulis
# 216 Synechococcus
# 217 Tateyamaria
# 218 Tessaracoccus
# 219 Thauera
# 220 Thioalkalivibrio
# 221 Thiohalobacter
# 222 Thiomonas
# 223 Tistrella
# 224 Tsukamurella
# 225 Variibacter
# 226 Variovorax
# 227 Verminephrobacter
# 228 Vogesella
# 229 Wenzhouxiangella
# 230 Yangia
#     non_contaminants
# 1   Acidiphilium multivorum
# 2   Acidisphaera sp. G45-3
# 3   Acidovorax avenae
# 4   Acidovorax carolinensis
# 5   Acidovorax cattleyae
# 6   Acidovorax citrulli
# 7   Acidovorax sp. JS42
# 8   Actinoalloteichus hymeniacidonis
# 9   Actinoplanes friuliensis
# 10  Actinoplanes missouriensis
# 11  Actinoplanes sp. N902-109
# 12  Actinopolymorpha singaporensis
# 13  Aeromonas hydrophila
# 14  Aeromonas schubertii
# 15  Aeromonas sp. ASNIH3
# 16  Afipia sp. GAS231
# 17  Agrobacterium fabrum
# 18  Agrobacterium rhizogenes
# 19  Agrobacterium sp. RAC06
# 20  Agrobacterium vitis
# 21  Agromyces aureus
# 22  Alcanivorax pacificus
# 23  Alcanivorax sp. N3-2A
# 24  Alicycliphilus denitrificans
# 25  Alkalilimnicola ehrlichii
# 26  Alloactinosynnema sp. L-07
# 27  Allokutzneria albata
# 28  Alphaproteobacteria bacterium WS11
# 29  Altererythrobacter atlanticus
# 30  Altererythrobacter sp. B11
# ⋮   ⋮
# 484 Streptosporangium roseum
# 485 Streptosporangium sp. 'caverna'
# 486 Sulfuricaulis limicola
# 487 Tateyamaria omphalii
# 488 Thauera aromatica
# 489 Thauera chlorobenzoica
# 490 Thauera hydrothermalis
# 491 Thauera sp. K11
# 492 Thauera sp. MZ1T
# 493 Thioalkalivibrio sulfidiphilus
# 494 Thiohalobacter thiocyanaticus
# 495 Tistrella mobilis
# 496 Tsukamurella paurometabola
# 497 Tsukamurella tyrosinosolvens
# 498 Variibacter gotjawalensis
# 499 Variovorax boronicumulans
# 500 Variovorax paradoxus
# 501 Variovorax sp. HW608
# 502 Variovorax sp. PMC12
# 503 Verminephrobacter eiseniae
# 504 Vogesella sp. LIG4
# 505 Wenzhouxiangella marina
# 506 Xanthomonas arboricola
# 507 Xanthomonas cassavae
# 508 Xanthomonas citri
# 509 Xanthomonas translucens
# 510 Xanthomonas vesicatoria
# 511 Yangia pacifica
# 512 Yangia sp. CCB-MM3
# 513 Zoogloeaceae bacteirum Par-f-2
