# %% [markdown]
# # Identication of putative contaminant taxa

# %%
# tempdir <- function() {return("~/.Rtmp")}

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(tidyverse)
require(ggplot2)
require(data.table)
require(ANCOMBC)
require(phyloseq)
# Out:
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: ANCOMBC
#
# Loading required package: phyloseq

# %% [markdown]
# ### Create Phyloseq object

# %% [markdown]
# #### Load abundance matrix

# %%
load_data <- function(file_path) {
    df <- fread(file_path) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}

df_to_phy <- function(df) {
    df <- as.matrix(df, rownames=1)
    df <- otu_table(df, taxa_are_rows = F)
    return(df)
}

df <- load_data(str_glue("data/temp_files_9999/07_abundance_matrix/abundance_matrix.subset_9999.S.tsv"))

# %% [markdown]
# #### Load metadata

# %%
load_metadata <- function(file_path, df) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% df$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "")
    return(meta)
}

meta_to_phy <- function(meta) {
    meta <- sample_data(meta_filt %>% column_to_rownames("npm_research_id"))
    return(meta)
}

meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)

# %% [markdown]
# #### Get metadata subsets

# %%
subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}

meta_filt <- subset_metadata(meta, 10)

# %% [markdown]
# #### Retrieve rows in abundance matrix

# %%
retrieve_rows_from_meta <- function(df, meta) {
    return(df %>% filter(npm_research_id %in% meta$npm_research_id)) 
}

df_filt <- retrieve_rows_from_meta(df, meta_filt)

# %% [markdown]
# #### Remove human and unclassified reads

# %%
remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}

df_filt2 <- remove_cols(df_filt, c("Homo sapiens", "unclassified"))

# %% [markdown]
# #### Remove taxa present in <~x% of samples

# %%
remove_low_freq_taxa <- function(df) {
    n_original <- ncol(df)
    frac_presence <- 0.05
    PA_df <- apply(df[, 2:ncol(df)], 2, function(x) {ifelse(x > 0, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    print(str_glue("{length(to_keep)} / {n_original} taxa are present in {frac_presence} of samples"))
    return(df %>% select(all_of(to_keep)))
}

df_filt3 <- remove_low_freq_taxa(df_filt2)
# Out:
# 1576 / 5200 taxa are present in 0.05 of samples

# %% [markdown]
# #### Plot metadata barcharts

# %%
get_metadata_plots <- function(meta, meta_cols) {
    meta <- as.matrix(meta)
    meta <- as_tibble(meta, rownames = "sample")

    plots <- list()
    
    for (column in meta_cols) {
        plt <- meta %>%
            mutate(across(everything(), as.character)) %>%
            select(all_of(column)) %>%
            group_by_at(column) %>%
            summarise(n = n()) %>%
            ggplot(aes_string(x = column, y = "n", fill = column)) +
                geom_bar(stat = "identity") +
                theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
                geom_text(aes_string(label = "n"))
        plots[[column]] <- plt
    }
    
    return(plots)
}

# %%
get_meta_cols <- function(meta) {
    meta_cols <- colnames(meta)[grep("kit|flow_cell|instrument_id|site_supplying", colnames(meta))]
    to_exclude <- c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id")
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}

meta_cols <- get_meta_cols(meta)

# %%
print_group_freqs <- function(meta, meta_cols) {
    for (col in meta_cols) {
        tmp <- tibble(data.frame(meta)) %>%
            group_by(get(col)) %>%
            summarise(n = n())
        print(col)
        print(tmp)
    }
}

print_group_freqs(meta_filt, meta_cols)
# Out:
# [1] "site_supplying_sample"
# # A tibble: 7 × 2
#   `get(col)`     n
#   <chr>      <int>
# 1 GUSTO         10
# 2 HELIOS        10
# 3 MEC           10
# 4 PRISM         10
# 5 SERI          10
# 6 SSMP          10
# 7 TTSH          10
# [1] "extraction_kit"
# # A tibble: 6 × 2
#   `get(col)`                                         n
#   <chr>                                          <int>
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit    10
# 2 Chemagic DNA Blood Kit (Perkin Elmer, MA)          8
# 3 Maxwell RSC Blood DNA Kit (AS1400)                10
# 4 QIAamp DNA Blood Mini Kit                         10
# 5 QIAsymphony DSP DNA Midi Kit                      10
# 6 Unknown                                           22
# [1] "instrument_id"
# # A tibble: 6 × 2
#   `get(col)`     n
#   <chr>      <int>
# 1 NG001         10
# 2 NG002          6
# 3 NG003          6
# 4 NG004          8
# 5 NG005          7
# 6 Unknown       33
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# # A tibble: 19 × 2
#    `get(col)`     n
#    <chr>      <int>
#  1 20293078       1
#  2 20304523       2
#  3 20305982       2
#  4 20314080       1
#  5 20319700       2
#  6 20324969       2
#  7 20331242       1
#  8 20336598       3
#  9 20340298       5
# 10 20340301       1
# 11 20363558       6
# 12 20364059       1
# 13 20371255       2
# 14 20374156       1
# 15 20382082       1
# 16 20392970       3
# 17 20392972       1
# 18 20396095       2
# 19 Unknown       33
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# # A tibble: 16 × 2
#    `get(col)`     n
#    <chr>      <int>
#  1 20298588       3
#  2 20314829       1
#  3 20314832       3
#  4 20316938       1
#  5 20331251       2
#  6 20336632       3
#  7 20340313       2
#  8 20345691       4
#  9 20354529       1
# 10 20364085       6
# 11 20374150       4
# 12 20382958       1
# 13 20392975       3
# 14 20393199       2
# 15 20397673       1
# 16 Unknown       33
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# # A tibble: 18 × 2
#    `get(col)`     n
#    <chr>      <int>
#  1 20285695       3
#  2 20291660       1
#  3 20303896       2
#  4 20309873       2
#  5 20320784       3
#  6 20324724       3
#  7 20337254       1
#  8 20344239       5
#  9 20348434       1
# 10 20350208       3
# 11 20356806       4
# 12 20356807       1
# 13 20357599       1
# 14 20363360       3
# 15 20365297       1
# 16 20368191       2
# 17 20377556       1
# 18 Unknown       33
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# # A tibble: 18 × 2
#    `get(col)`     n
#    <chr>      <int>
#  1 20300585       3
#  2 20305231       1
#  3 20315909       3
#  4 20320911       1
#  5 20331193       2
#  6 20331198       4
#  7 20340288       3
#  8 20345688       2
#  9 20355393       1
# 10 20364080       1
# 11 20364081       1
# 12 20364082       1
# 13 20371249       5
# 14 20376900       2
# 15 20382943       1
# 16 20385639       3
# 17 20392969       3
# 18 Unknown       33
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# # A tibble: 20 × 2
#    `get(col)`     n
#    <chr>      <int>
#  1 20285943       3
#  2 20294379       1
#  3 20302809       1
#  4 20302937       2
#  5 20308248       1
#  6 20316761       1
#  7 20316762       1
#  8 20328452       4
#  9 20335773       1
# 10 20335774       3
# 11 20347583       8
# 12 20347589       1
# 13 20350041       1
# 14 20350042       2
# 15 20358945       1
# 16 20367079       2
# 17 20367085       1
# 18 20393560       2
# 19 20394822       1
# 20 Unknown       33

# %% [markdown]
# ### Run ANCOM-BC

# %%
run_ancom_bc <- function(phy_fn, meta_fn, meta_cols, n_samples, max_iter) {
    result_df <- tibble()

    for (column in meta_cols) {
        print(column)
#         column <- "extraction_kit"
        # Remove levels with < x samples
        tmp <- tibble(data.frame(meta_fn)) %>%
            group_by(get(column)) %>%
            summarise(n = n())
        
        print(tmp)

        # Vector of group levels to keep
        to_keep <- tmp[tmp$n >= n_samples, "get(column)"]$`get(column)`
        to_keep <- to_keep[to_keep != "Unknown"]
        
        print(length(to_keep))

        # Retrieve groupings
        var_values <- sample_data(phy_fn)[[column]]

        # Prune groups
        phy_subset <- prune_samples(var_values %in% to_keep, phy_fn)
        n_filt <- nrow(phy_subset)
        print(str_glue("There are {n_filt} samples after pruning metadata levels"))
        
        out <- ancombc(phyloseq = phy_subset, formula = column,
                      p_adj_method = "BH", zero_cut = 1, lib_cut = 0,
                      group = column, struc_zero = FALSE, neg_lb = FALSE,
                      tol = 1e-5, max_iter = max_iter, conserve = FALSE,
                      alpha = 0.05, global = TRUE)
        
        morsel <- out$res_global %>% mutate(meta_col = column)
        
        result_df <- result_df %>% bind_rows(morsel)
    }
    
    return(result_df %>% rownames_to_column("taxa"))
}

# %% [markdown]
# #### Decontamination procedure for each subset

# %%
# decontaminate <- function(n) {
    # Load data
#     df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.S.tsv"))
    df <- load_data(str_glue("data/temp_files_9999/07_abundance_matrix/abundance_matrix.subset_9999.S.tsv"))
    meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)
    
    # Get metadata subset
    meta_filt <- subset_metadata(meta, 9999)

    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c("Homo sapiens", "unclassified"))
    df_filt3 <- remove_low_freq_taxa(df_filt2)

    # Get metadata columns of interest
    meta_cols <- get_meta_cols(meta_filt)
    
    # Create phyloseq object
    phy <- phyloseq(df_to_phy(df_filt3), meta_to_phy(meta_filt))

    # Print batch levels and frequencies
#     print_group_freqs(meta_filt, meta_cols)

    # Run ANCOM-BC
    result_df <- run_ancom_bc(phy, meta_filt, meta_cols, n_samples = 3, max_iter = 100)
    result_df
    
#     return(non_contaminants)
#     }
# Out:
# 1747 / 5200 taxa are present in 0.05 of samples
# [1] "site_supplying_sample"
# # A tibble: 7 × 2
#   `get(column)`     n
#   <chr>         <int>
# 1 GUSTO           968
# 2 HELIOS         2285
# 3 MEC            2787
# 4 PRISM          1248
# 5 SERI           1436
# 6 SSMP             63
# 7 TTSH            919
# [1] 7
#
# [1] "extraction_kit"
# # A tibble: 7 × 2
#   `get(column)`                                      n
#   <chr>                                          <int>
# 1 abGENIX Whole Blood Genomic DNA Extraction Kit  2281
# 2 Chemagic DNA Blood Kit (Perkin Elmer, MA)       1040
# 3 Maxwell RSC Blood DNA Kit (AS1400)              2117
# 4 QIAamp DNA Blood Mini Kit                        919
# 5 QIAsymphony DSP DNA Midi Kit                     968
# 6 QIAsymphony DSP DNA Mini Kit (192)               670
# 7 Unknown                                         1711
# [1] 6
#
# [1] "instrument_id"
# # A tibble: 6 × 2
#   `get(column)`     n
#   <chr>         <int>
# 1 NG001          1335
# 2 NG002          1221
# 3 NG003          1282
# 4 NG004          1516
# 5 NG005          1638
# 6 Unknown        2714
# [1] 5
#
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot"
# # A tibble: 34 × 2
#    `get(column)`     n
#    <chr>         <int>
#  1 20235982         20
#  2 20293078         46
#  3 20304523        238
#  4 20305232         10
#  5 20305982        148
#  6 20314080        197
#  7 20314082        329
#  8 20319700        186
#  9 20322799         19
# 10 20324969        342
# # … with 24 more rows
# [1] 33
#
# [1] "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"
# # A tibble: 34 × 2
#    `get(column)`     n
#    <chr>         <int>
#  1 20277312          8
#  2 20295428         11
#  3 20298588        193
#  4 20305983         10
#  5 20314829        231
#  6 20314830        204
#  7 20314832        314
#  8 20316938         70
#  9 20316939        146
# 10 20325219          5
# # … with 24 more rows
# [1] 33
#
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot"
# # A tibble: 29 × 2
#    `get(column)`     n
#    <chr>         <int>
#  1 20265537         38
#  2 20285695        179
#  3 20286254         10
#  4 20290688         10
#  5 20291660        234
#  6 20303896        344
#  7 20309873        222
#  8 20315030        138
#  9 20315031         10
# 10 20320784        331
# # … with 19 more rows
# [1] 28
#
# [1] "hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot"
# # A tibble: 33 × 2
#    `get(column)`     n
#    <chr>         <int>
#  1 20295412         10
#  2 20300585        164
#  3 20305231        133
#  4 20305612          9
#  5 20307071         10
#  6 20308845        152
#  7 20311423        208
#  8 20315909        267
#  9 20320911        246
# 10 20329385        136
# # … with 23 more rows
# [1] 32
#
# [1] "hiseq_xtm_flow_cell_v2_5_lot"
# # A tibble: 36 × 2
#    `get(column)`     n
#    <chr>         <int>
#  1 20285943        174
#  2 20294378         10
#  3 20294379        265
#  4 20302809        146
#  5 20302932         48
#  6 20302937        329
#  7 20308245         65
#  8 20308248        164
#  9 20316761        157
# 10 20316762        153
# # … with 26 more rows
# [1] 35
#       taxa                                          W          p_val
# 1     Paraburkholderia fungorum...1                  2369.5949  0.000000e+00
# 2     Paraburkholderia xenovorans...2                1431.8126 6.262869e-306
# 3     Paraburkholderia hospita...3                    660.2795 4.593525e-139
# 4     Ralstonia pickettii...4                        3803.0451  0.000000e+00
# 5     Ralstonia insidiosa...5                       11006.3824  0.000000e+00
# 6     Ralstonia mannitolilytica...6                  4609.9584  0.000000e+00
# 7     Ralstonia solanacearum...7                     5302.4572  0.000000e+00
# 8     Burkholderia cepacia...8                       4335.3477  0.000000e+00
# 9     Burkholderia sp. LA-2-3-30-S1-D2...9           2308.2847  0.000000e+00
# 10    Burkholderia metallica...10                    1130.0050 1.343308e-240
# 11    Burkholderia contaminans...11                  2846.8788  0.000000e+00
# 12    Burkholderia gladioli...12                     9847.3649  0.000000e+00
# 13    Burkholderia thailandensis...13                 729.6536 4.833906e-154
# 14    Burkholderia sp. OLGA172...14                  1222.5535 1.258281e-260
# 15    Bordetella genomosp. 8...15                    1835.6105  0.000000e+00
# 16    Bordetella genomosp. 13...16                  14540.9158  0.000000e+00
# 17    Acidovorax sp. RAC01...17                      3324.5010  0.000000e+00
# 18    Acidovorax sp. 1608163...18                    3620.3009  0.000000e+00
# 19    Diaphorobacter polyhydroxybutyrativorans...19   929.3545 3.383759e-197
# 20    Massilia sp. WG5...20                          8254.7258  0.000000e+00
# 21    Aromatoleum aromaticum...21                    4071.0045  0.000000e+00
# 22    Bradyrhizobium sp. SK17...22                  58167.3505  0.000000e+00
# 23    Bradyrhizobium sp. BTAi1...23                 46329.7238  0.000000e+00
# 24    Bradyrhizobium erythrophlei...24              35114.9066  0.000000e+00
# 25    Bradyrhizobium icense...25                    36656.2486  0.000000e+00
# 26    Bradyrhizobium diazoefficiens...26            46012.8786  0.000000e+00
# 27    Bradyrhizobium sp. WSM471...27                10420.0661  0.000000e+00
# 28    Bradyrhizobium ottawaense...28                26795.8880  0.000000e+00
# 29    Rhodopseudomonas palustris...29               97958.7439  0.000000e+00
# 30    Oligotropha carboxidovorans...30              30202.0768  0.000000e+00
# ⋮     ⋮                                             ⋮          ⋮
# 13939 Corynebacterium provencense...13939           7367.846   0
# 13940 Corynebacterium glutamicum...13940            8200.992   0
# 13941 Corynebacterium falsenii...13941              6171.133   0
# 13942 Kitasatospora albolonga...13942               4768.064   0
# 13943 Trueperella pyogenes...13943                  8182.139   0
# 13944 Gordonibacter pamelaeae...13944               7645.546   0
# 13945 Deinococcus sp. S14-83...13945                5823.598   0
# 13946 Chlorobaculum limnaeum...13946                7838.732   0
# 13947 Gluconobacter albidus...13947                 5706.178   0
# 13948 Acetobacter ghanensis...13948                 6582.644   0
# 13949 Citrobacter koseri...13949                    5088.732   0
# 13950 Adlercreutzia equolifaciens...13950           5976.559   0
# 13951 Chlorobium phaeobacteroides...13951           6001.430   0
# 13952 Aquaspirillum sp. LM1...13952                 5439.753   0
# 13953 Acinetobacter bereziniae...13953              7144.056   0
# 13954 Pectobacterium parmentieri...13954            7895.328   0
# 13955 Acidihalobacter ferrooxidans...13955          4915.455   0
# 13956 Bifidobacterium choerinum...13956             7063.347   0
# 13957 Stenotrophomonas sp. SAU14A_NAIMI4_8...13957  4801.020   0
# 13958 Desulfovibrio desulfuricans...13958           6822.081   0
# 13959 Corynebacterium epidermidicanis...13959       6587.287   0
# 13960 Sulfuricella denitrificans...13960            7495.815   0
# 13961 Asaia bogorensis...13961                      5794.385   0
# 13962 Caldilinea aerophila...13962                  5996.758   0
# 13963 Kosakonia cowanii...13963                     6236.103   0
# 13964 Synechococcus sp. PCC 7336...13964            6824.469   0
# 13965 Granulicella tundricola...13965               5915.935   0
# 13966 Granulosicoccus antarcticus...13966           6159.157   0
# 13967 Candidatus Nitrospira inopinata...13967       6802.590   0
# 13968 Lactococcus lactis...13968                    5313.937   0
#       q_val         diff_abn meta_col
# 1      0.000000e+00 TRUE     site_supplying_sample
# 2     8.064137e-306 TRUE     site_supplying_sample
# 3     4.828594e-139 TRUE     site_supplying_sample
# 4      0.000000e+00 TRUE     site_supplying_sample
# 5      0.000000e+00 TRUE     site_supplying_sample
# 6      0.000000e+00 TRUE     site_supplying_sample
# 7      0.000000e+00 TRUE     site_supplying_sample
# 8      0.000000e+00 TRUE     site_supplying_sample
# 9      0.000000e+00 TRUE     site_supplying_sample
# 10    1.571995e-240 TRUE     site_supplying_sample
# 11     0.000000e+00 TRUE     site_supplying_sample
# 12     0.000000e+00 TRUE     site_supplying_sample
# 13    5.162079e-154 TRUE     site_supplying_sample
# 14    1.513057e-260 TRUE     site_supplying_sample
# 15     0.000000e+00 TRUE     site_supplying_sample
# 16     0.000000e+00 TRUE     site_supplying_sample
# 17     0.000000e+00 TRUE     site_supplying_sample
# 18     0.000000e+00 TRUE     site_supplying_sample
# 19    3.775108e-197 TRUE     site_supplying_sample
# 20     0.000000e+00 TRUE     site_supplying_sample
# 21     0.000000e+00 TRUE     site_supplying_sample
# 22     0.000000e+00 TRUE     site_supplying_sample
# 23     0.000000e+00 TRUE     site_supplying_sample
# 24     0.000000e+00 TRUE     site_supplying_sample
# 25     0.000000e+00 TRUE     site_supplying_sample
# 26     0.000000e+00 TRUE     site_supplying_sample
# 27     0.000000e+00 TRUE     site_supplying_sample
# 28     0.000000e+00 TRUE     site_supplying_sample
# 29     0.000000e+00 TRUE     site_supplying_sample
# 30     0.000000e+00 TRUE     site_supplying_sample
# ⋮     ⋮             ⋮        ⋮
# 13939 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13940 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13941 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13942 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13943 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13944 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13945 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13946 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13947 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13948 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13949 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13950 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13951 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13952 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13953 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13954 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13955 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13956 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13957 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13958 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13959 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13960 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13961 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13962 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13963 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13964 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13965 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13966 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13967 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot
# 13968 0             TRUE     hiseq_xtm_flow_cell_v2_5_lot

# %%
result_df <- fread("results/decontamination/ANCOMBC_decontamination_results.n9706.100821.csv")
result_df %>%
    separate(taxa, into = c("taxa", NA), remove = T, sep = "\\.\\.") %>%
    pivot_wider(names_from = meta_col, values_from = diff_abn, id_cols = taxa)

result_df %>%
    separate(taxa, into = c("taxa", NA), remove = T, sep = "\\.\\.") %>%
    ggplot(aes(x = meta_col, y = taxa, fill = diff_abn)) +
    geom_tile() +
    theme(axis.text.y = element_blank(),
          axis.text.x = element_text(angle = 45, hjust = 1)) +
    labs(x = "Batch Info", y = "Species", fill = "Contaminant?")
# Out:
# Warning message:
# “Expected 2 pieces. Additional pieces discarded in 8 rows [143, 1889, 3635, 5381, 7127, 8873, 10619, 12365].”
#      taxa                                     site_supplying_sample
# 1    Paraburkholderia fungorum                TRUE
# 2    Paraburkholderia xenovorans              TRUE
# 3    Paraburkholderia hospita                 TRUE
# 4    Ralstonia pickettii                      TRUE
# 5    Ralstonia insidiosa                      TRUE
# 6    Ralstonia mannitolilytica                TRUE
# 7    Ralstonia solanacearum                   TRUE
# 8    Burkholderia cepacia                     TRUE
# 9    Burkholderia sp. LA-2-3-30-S1-D2         TRUE
# 10   Burkholderia metallica                   TRUE
# 11   Burkholderia contaminans                 TRUE
# 12   Burkholderia gladioli                    TRUE
# 13   Burkholderia thailandensis               TRUE
# 14   Burkholderia sp. OLGA172                 TRUE
# 15   Bordetella genomosp. 8                   TRUE
# 16   Bordetella genomosp. 13                  TRUE
# 17   Acidovorax sp. RAC01                     TRUE
# 18   Acidovorax sp. 1608163                   TRUE
# 19   Diaphorobacter polyhydroxybutyrativorans TRUE
# 20   Massilia sp. WG5                         TRUE
# 21   Aromatoleum aromaticum                   TRUE
# 22   Bradyrhizobium sp. SK17                  TRUE
# 23   Bradyrhizobium sp. BTAi1                 TRUE
# 24   Bradyrhizobium erythrophlei              TRUE
# 25   Bradyrhizobium icense                    TRUE
# 26   Bradyrhizobium diazoefficiens            TRUE
# 27   Bradyrhizobium sp. WSM471                TRUE
# 28   Bradyrhizobium ottawaense                TRUE
# 29   Rhodopseudomonas palustris               TRUE
# 30   Oligotropha carboxidovorans              TRUE
# ⋮    ⋮                                        ⋮
# 1717 Corynebacterium provencense              TRUE
# 1718 Corynebacterium glutamicum               TRUE
# 1719 Corynebacterium falsenii                 TRUE
# 1720 Kitasatospora albolonga                  TRUE
# 1721 Trueperella pyogenes                     TRUE
# 1722 Gordonibacter pamelaeae                  TRUE
# 1723 Deinococcus sp. S14-83                   TRUE
# 1724 Chlorobaculum limnaeum                   TRUE
# 1725 Gluconobacter albidus                    TRUE
# 1726 Acetobacter ghanensis                    TRUE
# 1727 Citrobacter koseri                       TRUE
# 1728 Adlercreutzia equolifaciens              TRUE
# 1729 Chlorobium phaeobacteroides              TRUE
# 1730 Aquaspirillum sp. LM1                    TRUE
# 1731 Acinetobacter bereziniae                 TRUE
# 1732 Pectobacterium parmentieri               TRUE
# 1733 Acidihalobacter ferrooxidans             TRUE
# 1734 Bifidobacterium choerinum                TRUE
# 1735 Stenotrophomonas sp. SAU14A_NAIMI4_8     TRUE
# 1736 Desulfovibrio desulfuricans              TRUE
# 1737 Corynebacterium epidermidicanis          TRUE
# 1738 Sulfuricella denitrificans               TRUE
# 1739 Asaia bogorensis                         TRUE
# 1740 Caldilinea aerophila                     TRUE
# 1741 Kosakonia cowanii                        TRUE
# 1742 Synechococcus sp. PCC 7336               TRUE
# 1743 Granulicella tundricola                  TRUE
# 1744 Granulosicoccus antarcticus              TRUE
# 1745 Candidatus Nitrospira inopinata          TRUE
# 1746 Lactococcus lactis                       TRUE
#      extraction_kit instrument_id
# 1    TRUE            TRUE
# 2    TRUE           FALSE
# 3    TRUE           FALSE
# 4    TRUE            TRUE
# 5    TRUE            TRUE
# 6    TRUE            TRUE
# 7    TRUE            TRUE
# 8    TRUE           FALSE
# 9    TRUE           FALSE
# 10   TRUE           FALSE
# 11   TRUE           FALSE
# 12   TRUE           FALSE
# 13   TRUE           FALSE
# 14   TRUE           FALSE
# 15   TRUE            TRUE
# 16   TRUE           FALSE
# 17   TRUE            TRUE
# 18   TRUE            TRUE
# 19   TRUE           FALSE
# 20   TRUE           FALSE
# 21   TRUE           FALSE
# 22   TRUE           FALSE
# 23   TRUE            TRUE
# 24   TRUE            TRUE
# 25   TRUE            TRUE
# 26   TRUE            TRUE
# 27   TRUE            TRUE
# 28   TRUE            TRUE
# 29   TRUE            TRUE
# 30   TRUE            TRUE
# ⋮    ⋮              ⋮
# 1717 TRUE           FALSE
# 1718 TRUE           FALSE
# 1719 TRUE           FALSE
# 1720 TRUE           FALSE
# 1721 TRUE           FALSE
# 1722 TRUE           FALSE
# 1723 TRUE           FALSE
# 1724 TRUE           FALSE
# 1725 TRUE           FALSE
# 1726 TRUE           FALSE
# 1727 TRUE           FALSE
# 1728 TRUE           FALSE
# 1729 TRUE           FALSE
# 1730 TRUE           FALSE
# 1731 TRUE           FALSE
# 1732 TRUE           FALSE
# 1733 TRUE           FALSE
# 1734 TRUE           FALSE
# 1735 TRUE           FALSE
# 1736 TRUE           FALSE
# 1737 TRUE           FALSE
# 1738 TRUE            TRUE
# 1739 TRUE           FALSE
# 1740 TRUE           FALSE
# 1741 TRUE           FALSE
# 1742 TRUE            TRUE
# 1743 TRUE           FALSE
# 1744 TRUE           FALSE
# 1745 TRUE           FALSE
# 1746 TRUE           FALSE
#      hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot
# 1    TRUE
# 2    TRUE
# 3    TRUE
# 4    TRUE
# 5    TRUE
# 6    TRUE
# 7    TRUE
# 8    TRUE
# 9    TRUE
# 10   TRUE
# 11   TRUE
# 12   TRUE
# 13   TRUE
# 14   TRUE
# 15   TRUE
# 16   TRUE
# 17   TRUE
# 18   TRUE
# 19   TRUE
# 20   TRUE
# 21   TRUE
# 22   TRUE
# 23   TRUE
# 24   TRUE
# 25   TRUE
# 26   TRUE
# 27   TRUE
# 28   TRUE
# 29   TRUE
# 30   TRUE
# ⋮    ⋮
# 1717 TRUE
# 1718 TRUE
# 1719 TRUE
# 1720 TRUE
# 1721 TRUE
# 1722 TRUE
# 1723 TRUE
# 1724 TRUE
# 1725 TRUE
# 1726 TRUE
# 1727 TRUE
# 1728 TRUE
# 1729 TRUE
# 1730 TRUE
# 1731 TRUE
# 1732 TRUE
# 1733 TRUE
# 1734 TRUE
# 1735 TRUE
# 1736 TRUE
# 1737 TRUE
# 1738 TRUE
# 1739 TRUE
# 1740 TRUE
# 1741 TRUE
# 1742 TRUE
# 1743 TRUE
# 1744 TRUE
# 1745 TRUE
# 1746 TRUE
#      hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot
# 1    TRUE
# 2    TRUE
# 3    TRUE
# 4    TRUE
# 5    TRUE
# 6    TRUE
# 7    TRUE
# 8    TRUE
# 9    TRUE
# 10   TRUE
# 11   TRUE
# 12   TRUE
# 13   TRUE
# 14   TRUE
# 15   TRUE
# 16   TRUE
# 17   TRUE
# 18   TRUE
# 19   TRUE
# 20   TRUE
# 21   TRUE
# 22   TRUE
# 23   TRUE
# 24   TRUE
# 25   TRUE
# 26   TRUE
# 27   TRUE
# 28   TRUE
# 29   TRUE
# 30   TRUE
# ⋮    ⋮
# 1717 TRUE
# 1718 TRUE
# 1719 TRUE
# 1720 TRUE
# 1721 TRUE
# 1722 TRUE
# 1723 TRUE
# 1724 TRUE
# 1725 TRUE
# 1726 TRUE
# 1727 TRUE
# 1728 TRUE
# 1729 TRUE
# 1730 TRUE
# 1731 TRUE
# 1732 TRUE
# 1733 TRUE
# 1734 TRUE
# 1735 TRUE
# 1736 TRUE
# 1737 TRUE
# 1738 TRUE
# 1739 TRUE
# 1740 TRUE
# 1741 TRUE
# 1742 TRUE
# 1743 TRUE
# 1744 TRUE
# 1745 TRUE
# 1746 TRUE
#      hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot
# 1    TRUE
# 2    TRUE
# 3    TRUE
# 4    TRUE
# 5    TRUE
# 6    TRUE
# 7    TRUE
# 8    TRUE
# 9    TRUE
# 10   TRUE
# 11   TRUE
# 12   TRUE
# 13   TRUE
# 14   TRUE
# 15   TRUE
# 16   TRUE
# 17   TRUE
# 18   TRUE
# 19   TRUE
# 20   TRUE
# 21   TRUE
# 22   TRUE
# 23   TRUE
# 24   TRUE
# 25   TRUE
# 26   TRUE
# 27   TRUE
# 28   TRUE
# 29   TRUE
# 30   TRUE
# ⋮    ⋮
# 1717 TRUE
# 1718 TRUE
# 1719 TRUE
# 1720 TRUE
# 1721 TRUE
# 1722 TRUE
# 1723 TRUE
# 1724 TRUE
# 1725 TRUE
# 1726 TRUE
# 1727 TRUE
# 1728 TRUE
# 1729 TRUE
# 1730 TRUE
# 1731 TRUE
# 1732 TRUE
# 1733 TRUE
# 1734 TRUE
# 1735 TRUE
# 1736 TRUE
# 1737 TRUE
# 1738 TRUE
# 1739 TRUE
# 1740 TRUE
# 1741 TRUE
# 1742 TRUE
# 1743 TRUE
# 1744 TRUE
# 1745 TRUE
# 1746 TRUE
#      hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot
# 1    TRUE
# 2    TRUE
# 3    TRUE
# 4    TRUE
# 5    TRUE
# 6    TRUE
# 7    TRUE
# 8    TRUE
# 9    TRUE
# 10   TRUE
# 11   TRUE
# 12   TRUE
# 13   TRUE
# 14   TRUE
# 15   TRUE
# 16   TRUE
# 17   TRUE
# 18   TRUE
# 19   TRUE
# 20   TRUE
# 21   TRUE
# 22   TRUE
# 23   TRUE
# 24   TRUE
# 25   TRUE
# 26   TRUE
# 27   TRUE
# 28   TRUE
# 29   TRUE
# 30   TRUE
# ⋮    ⋮
# 1717 TRUE
# 1718 TRUE
# 1719 TRUE
# 1720 TRUE
# 1721 TRUE
# 1722 TRUE
# 1723 TRUE
# 1724 TRUE
# 1725 TRUE
# 1726 TRUE
# 1727 TRUE
# 1728 TRUE
# 1729 TRUE
# 1730 TRUE
# 1731 TRUE
# 1732 TRUE
# 1733 TRUE
# 1734 TRUE
# 1735 TRUE
# 1736 TRUE
# 1737 TRUE
# 1738 TRUE
# 1739 TRUE
# 1740 TRUE
# 1741 TRUE
# 1742 TRUE
# 1743 TRUE
# 1744 TRUE
# 1745 TRUE
# 1746 TRUE
#      hiseq_xtm_flow_cell_v2_5_lot
# 1    TRUE
# 2    TRUE
# 3    TRUE
# 4    TRUE
# 5    TRUE
# 6    TRUE
# 7    TRUE
# 8    TRUE
# 9    TRUE
# 10   TRUE
# 11   TRUE
# 12   TRUE
# 13   TRUE
# 14   TRUE
# 15   TRUE
# 16   TRUE
# 17   TRUE
# 18   TRUE
# 19   TRUE
# 20   TRUE
# 21   TRUE
# 22   TRUE
# 23   TRUE
# 24   TRUE
# 25   TRUE
# 26   TRUE
# 27   TRUE
# 28   TRUE
# 29   TRUE
# 30   TRUE
# ⋮    ⋮
# 1717 TRUE
# 1718 TRUE
# 1719 TRUE
# 1720 TRUE
# 1721 TRUE
# 1722 TRUE
# 1723 TRUE
# 1724 TRUE
# 1725 TRUE
# 1726 TRUE
# 1727 TRUE
# 1728 TRUE
# 1729 TRUE
# 1730 TRUE
# 1731 TRUE
# 1732 TRUE
# 1733 TRUE
# 1734 TRUE
# 1735 TRUE
# 1736 TRUE
# 1737 TRUE
# 1738 TRUE
# 1739 TRUE
# 1740 TRUE
# 1741 TRUE
# 1742 TRUE
# 1743 TRUE
# 1744 TRUE
# 1745 TRUE
# 1746 TRUE
# Warning message:
# “Expected 2 pieces. Additional pieces discarded in 8 rows [143, 1889, 3635, 5381, 7127, 8873, 10619, 12365].”
# plot without title

# %%
# fwrite(result_df, "results/decontamination/ANCOMBC_decontamination_results.n9706.100821.csv")

# %%
dawdawdawdwadwa####################################################
# Out:
# Error in eval(expr, envir, enclos): object 'dawdawdawdwadwa' not found
# Traceback:

# %% [markdown]
# ### Explore metadata

# %%
n_subset <- 100

# Load data
df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.S.tsv"))

# Retain relevant metadata
meta <- parse_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)

# Get metadata columns of interest
meta_cols <- get_meta_cols(meta)

meta <- as.matrix(meta)
meta <- as_tibble(meta, rownames = "sample")

plots <- list()

for (column in meta_cols) {
    plt <- meta %>%
        mutate(across(everything(), as.character)) %>%
        select(all_of(column)) %>%
        group_by_at(column) %>%
        summarise(n = n()) %>%
        ggplot(aes_string(x = column, y = "n", fill = column)) +
            geom_bar(stat = "identity") +
            theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
            geom_text(aes_string(label = "n"))
    plots[[column]] <- plt
}

plots

# %% [markdown]
# ### MAIN

# %%
# nc_list <- list()

# for (i in c(100)) {
#     nc_list[[str_glue("subset_{i}")]] <- decontaminate(i)
# }

# nc_list

# %% [markdown]
# ### Sanity check

# %%
# Reduce(intersect, nc_list)

# %%
plot_sanity_plot <- function(X, Y, tax) {
    print(tax)
    temp_plt <- cbind(X, Y) %>%
        mutate(log_abundance = log(get(tax) + 0.0001)) %>%
        ggplot(aes(x = site_supplying_sample, y = get(tax), fill = site_supplying_sample)) + 
        geom_point() +
        geom_boxplot(alpha = 0.5) +
        labs(x = "Source cohort", y = paste(tax, "% abundance")) +
        theme(legend.position = "none",
          axis.text.x = element_text(angle = 45, hjust = 1),
          text = element_text(size = 15))
    return(temp_plt)
}

# %%
# Load data
taxon <- "Cutibacterium acnes"
df <- load_data(str_glue("data/temp_files_{n_subset}/07_abundance_matrix/abundance_matrix.subset_{n_subset}.S.tsv"))

# Remove homo and unclassified
col_to_exclude <- colnames(df)[grepl("Homo|unclassified", colnames(df))]
df <- remove_cols(df, col_to_exclude)

# Retain relevant metadata
meta <- parse_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df)

# Normalise to RA
normalise <- function(df) {
    RA_df <- t(apply(df, 1, function(x) {x / sum(x) * 100}))
    return(as_tibble(RA_df))
}

species_df_RA <- normalise(df)

plot_sanity_plot(df, meta, taxon)
print(str_glue("Max no. of reads = {max(df[, taxon])}"))
print(str_glue("Mean no. of reads = {mean(df[, taxon])}"))

# %%
l1 <- tibble(l1)

fwrite(l1, str_glue("/home/projects/14001280/PROJECTS/blood_microbiome/results/decontamination/decontaminated_list.n{n_subset}.csv"))
