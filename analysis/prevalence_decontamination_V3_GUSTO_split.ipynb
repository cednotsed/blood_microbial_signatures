# %% [markdown]
# # Identication of putative contaminant taxa

# %%
setwd("/mnt/c/Users/Cedric/Desktop/git_repos/blood_microbiome")
require(foreach)
require(tidyverse)
require(ggplot2)
require(data.table)
require(doParallel)
require(compositions)
require(VennDiagram)
registerDoParallel(cores=9)
# Out:
# Loading required package: foreach
#
# Loading required package: tidyverse
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::accumulate() masks foreach::accumulate()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ purrr::when()       masks foreach::when()
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: doParallel
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: compositions
#
# Welcome to compositions, a package for compositional data analysis.
# Find an intro with "? compositions"
#
#
#
# Attaching package: ‘compositions’
#
#
# The following objects are masked from ‘package:stats’:
#
#     anova, cor, cov, dist, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %*%, norm, scale, scale.default
#
#
# Loading required package: VennDiagram
#
# Loading required package: grid
#
# Loading required package: futile.logger

# %% [markdown]
# ### Data processing functions

# %%
load_data <- function(file_path) {
    df <- as.data.frame(fread(file_path)) %>%
        separate(sample, into = c(NA, "npm_research_id"), sep = "\\.")
    return(df)
}


load_metadata <- function(file_path, df) {
    meta <- fread(file_path, na.strings=c("", NA))
    meta <- meta %>% 
        filter(npm_research_id %in% df$npm_research_id) %>%
        select(-removal_requested_by_supplier) %>%
        replace(is.na(.), "unknown")
    return(meta)
}


subset_metadata <- function(meta, n_subset) {
    meta <- as.data.frame(meta)
    cohorts <- unique(meta$site_supplying_sample)
    subset_vec <- c()

    for (i in cohorts) {
        ids <- meta$npm_research_id[meta$site_supplying_sample == i]
        
        if (length(ids) > n_subset) {
            subset_ids <- sample(ids, n_subset)
            subset_vec <- c(subset_vec, subset_ids)
        } else {
            subset_vec <- c(subset_vec, ids)
        }
    }

    meta_sub <- meta %>%
      filter(npm_research_id %in% subset_vec) 
    return(meta_sub)
}


retrieve_rows_from_meta <- function(df, meta) {
    return(df %>% filter(npm_research_id %in% meta$npm_research_id)) 
}


remove_cols <- function(df, col_to_exclude) {
    return(df %>% select(-all_of(col_to_exclude)))
}


remove_low_freq_taxa <- function(df, frac_presence) {
    n_original <- ncol(df[, colnames(df) != "npm_research_id"])
    PA_df <- apply(df[, 2:ncol(df)], 2, function(x) {ifelse(x > 0, T, F)})
    frac_df <- apply(PA_df, 2, function(x) {sum(x) / nrow(PA_df)})
    to_keep <- names(frac_df[frac_df > frac_presence])
    to_keep <- c("npm_research_id", to_keep)
    n_new <- length(to_keep) - 1
    print(str_glue("{n_new} / {n_original} taxa are present in {frac_presence} of samples"))
    return(df %>% select(all_of(to_keep)))
}


otu_to_RA <- function(df) {
    mat <- as.matrix(df[, colnames(df) != "npm_research_id"])
    RA_df <- as.data.frame(mat / rowSums(mat))
    RA_df <- add_column(RA_df, df$npm_research_id, .before = 1)
    colnames(RA_df)[1] <- "npm_research_id"
    
    return(RA_df)
}


get_meta_cols <- function(meta, meta_regex, to_exclude) {
    meta_cols <- colnames(meta)[grep(meta_regex, colnames(meta))]
    meta_cols <- meta_cols[!(meta_cols %in% to_exclude)]
    return(meta_cols)
}


otu_to_PA <- function(df, read_threshold) {
    prev_read <- df %>%
        column_to_rownames("npm_research_id")
    
    prev_read[prev_read <= read_threshold] <- 0
    prev_read[prev_read > read_threshold] <- 1

    return(prev_read)
}


RA_to_PA <- function(RA_df, PA_threshold) {
    prev_RA <- RA_df %>% column_to_rownames("npm_research_id")
    prev_RA[prev_RA <= PA_threshold] <- 0
    prev_RA[prev_RA > PA_threshold] <- 1
    
    return(prev_RA)
}


RA_to_clr <- function(df) {
    mat <- df[, colnames(df) != "npm_research_id"]
    clr_df <- clr(mat)
    return(cbind(data.frame(npm_research_id = df$npm_research_id), as.data.frame(clr_df, check.names = F)))
}


filter_taxa_by_presence <- function(prev_df, presence_t) {
    taxa_counts <- apply(prev_df, 2, sum)
    to_keep <- names(taxa_counts)[taxa_counts > presence_t]
    return(prev_df %>% select(all_of(to_keep)))
}

# %% [markdown]
# ### Decontamination functions

# %%
filter_batch_levels <- function(dat, metadat, column) {
    # Remove levels with < x samples
    tmp <- tibble(data.frame(metadat)) %>%
            group_by(get(column)) %>%
            summarise(n = n())

    # Vector of group levels to keep
    to_keep <- tmp[tmp$n >= min_samples, "get(column)"]$`get(column)`
    to_keep <- to_keep[to_keep != "Unknown"]
    n_levels <- length(to_keep)

    if (n_levels < 2) {
        print(str_glue("After pruning, {column} has < 2 levels"))
    } else {
        print(str_glue("After pruning, {column} has {n_levels} levels"))
    }

    # Remove rows in metadata
    dat_meta <- dat %>%
        left_join(metadat, by = "npm_research_id") %>%
        filter(get(column) %in% to_keep)

    return(dat_meta)
}


get_taxon_diff_prev <- function(dat_meta, column, taxon) {
    prev_stats <- dat_meta %>%
        group_by_at(c(column)) %>%
        summarise(prevalence = sum(get(taxon)) / n())

    max_prev <- max(prev_stats$prevalence)
    min_prev <- min(prev_stats$prevalence)
    fold_diff <- max_prev / min_prev
    max_level <- pull(prev_stats, column)[which(prev_stats$prevalence == max(prev_stats$prevalence))][1]
    min_level <- pull(prev_stats, column)[which(prev_stats$prevalence == min(prev_stats$prevalence))][1]

    crumb <- tibble(taxa = taxon, meta_col = column,
           max_level = max_level, min_level = min_level, 
           max_prev = max_prev, min_prev = min_prev,
           fold_diff = fold_diff)

    crumb <- distinct(crumb, taxa, .keep_all = T)

    return(crumb)
}

get_diff_prev <- function(dat, metadat, meta_cols, taxa_vec, prev_threshold, min_samples) {
    morsels <- foreach (column = meta_cols) %do% {
        dat_meta <- filter_batch_levels(dat, metadat, column)
        
        crumbs <- foreach (taxon = taxa_vec) %dopar% {
            get_taxon_diff_prev(dat_meta, column, taxon)
        }
        
        stopImplicitCluster()
        
        morsel <- bind_rows(crumbs)
        return(morsel)
    }

    result_df <- bind_rows(morsels)
    return(result_df)
}


preprocess_data <- function(df, meta_filt, RA_threshold, read_threshold, presence_t) {
    # Filter data
    df_filt <- retrieve_rows_from_meta(df, meta_filt)
    df_filt2 <- remove_cols(df_filt, c(human, "unclassified"))
    RA_df <- otu_to_RA(df_filt2)
    prev_RA <- RA_to_PA(RA_df, RA_threshold)
    prev_read <- otu_to_PA(df_filt2, read_threshold)
    prev_df <- as.data.frame(prev_read & prev_RA)
    prev_df <- filter_taxa_by_presence(prev_df, presence_t = presence_t) # Remove taxa that are not present in any samples
    prev_df <- prev_df %>% rownames_to_column("npm_research_id")
    return(prev_df)
}

decontaminate <- function(df, meta_filt, meta_cols, human, RA_threshold, read_threshold, presence_t, min_samples, taxa_vec = NA) {
    # Preprocess df
    prev_df <- preprocess_data(df, meta_filt, RA_threshold, read_threshold, presence_t)
    
    # Get list of taxa
    if (is.na(taxa_vec)) {
        taxa_vec <- colnames(prev_df)
        taxa_vec <- taxa_vec[taxa_vec != "npm_research_id"]
    }

    # Differential prevalence
    res <- get_diff_prev(prev_df, meta_filt, meta_cols, taxa_vec, min_samples = min_samples)

    return(res)
}

# %% [markdown]
# ### Run decontamination

# %%
human <- "Homo sapiens"
RA_threshold <- 0.005
read_threshold <- 10
presence_t <- 0
min_samples <- 100

# Load data and remove low microbial read samples
to_retain <- fread("data/samples_above_100_microbial_reads.txt")$npm_research_id

df <- load_data(str_glue("data/taxonomic_profiles/07_abundance_matrix/abundance_matrix.S.pipeline2_210322.tsv")) %>% 
    filter(npm_research_id %in% to_retain)

meta <- load_metadata("data/SG10K_Health_metadata.n10714.16March2021.parsed.csv", df) %>% 
    filter(npm_research_id %in% to_retain)

# Get metadata columns of interest
meta_cols <- get_meta_cols(meta, 
                           meta_regex = "kit|flow_cell|site_supplying", 
                           to_exclude = c("library_prep_kit", "hiseq_xtm_flow_cell_v2_5_id"))

# Remove GUSTO Kids cohort
gusto_meta <- meta %>%
    filter(site_supplying_sample == "GUSTO")

gusto_only <- df %>%
    filter(npm_research_id %in% gusto_meta$npm_research_id)
no_gusto <- df %>%
    filter(!(npm_research_id %in% gusto_meta$npm_research_id))

# Get abundance matrix of non-zero taxa
df_zeroed <- preprocess_data(df, meta, RA_threshold, read_threshold, presence_t)
# fwrite(df_zeroed, str_glue("results/decontamination/prevalence_RA{RA_threshold}_read{read_threshold}.csv"))

# %%
# Run decontamination
decon_raw <- decontaminate(no_gusto, meta_filt = meta, meta_cols = meta_cols, 
                           human = human, RA_threshold = RA_threshold, read_threshold = read_threshold, 
                           presence_t = presence_t, min_samples = min_samples)
decon_raw_gusto <- decontaminate(gusto_only, meta_filt = meta, meta_cols = meta_cols, 
                                 human = human, RA_threshold = RA_threshold, read_threshold = read_threshold, 
                                 presence_t = presence_t, min_samples = min_samples)
# Out:
# After pruning, site_supplying_sample has 6 levels
# After pruning, extraction_kit has 6 levels
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels
# After pruning, site_supplying_sample has 6 levels
# After pruning, extraction_kit has 6 levels
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_1of_2__lot has 20 levels
# After pruning, hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot has 19 levels
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_1_of_2__lot has 19 levels
# After pruning, hiseq_xtm_pe_cluster_kit_cbottm_v2__box_2_of_2__lot has 23 levels
# After pruning, hiseq_xtm_flow_cell_v2_5_lot has 19 levels

# %%
decon_raw
# Out:
#      taxa                                         meta_col
# 1    Sphingobium sp. YG1                          site_supplying_sample
# 2    Sphingobium sp. RAC03                        site_supplying_sample
# 3    Sphingobium sp. TKS                          site_supplying_sample
# 4    Sphingobium sp. Cam5-1                       site_supplying_sample
# 5    Sphingobium sp. KCTC 72723                   site_supplying_sample
# 6    Sphingobium sp. PAMC28499                    site_supplying_sample
# 7    Sphingobium sp. MI1205                       site_supplying_sample
# 8    Sphingobium sp. SYK-6                        site_supplying_sample
# 9    Sphingobium sp. CAP-1                        site_supplying_sample
# 10   Sphingobium yanoikuyae                       site_supplying_sample
# 11   Sphingobium baderi                           site_supplying_sample
# 12   Sphingobium cloacae                          site_supplying_sample
# 13   Sphingobium hydrophobicum                    site_supplying_sample
# 14   Sphingobium herbicidovorans                  site_supplying_sample
# 15   Sphingobium amiense                          site_supplying_sample
# 16   Sphingomonas sp. LM7                         site_supplying_sample
# 17   Sphingomonas sp. Cra20                       site_supplying_sample
# 18   Sphingomonas sp. CL5.1                       site_supplying_sample
# 19   Sphingomonas sp. IC081                       site_supplying_sample
# 20   Sphingomonas sp. XS-10                       site_supplying_sample
# 21   Sphingomonas sp. FARSPH                      site_supplying_sample
# 22   Sphingomonas sp. LK11                        site_supplying_sample
# 23   Sphingomonas sp. DH-S5                       site_supplying_sample
# 24   Sphingomonas sp. NBWT7                       site_supplying_sample
# 25   Sphingomonas sp. MM-1                        site_supplying_sample
# 26   Sphingomonas sp. AP4-R1                      site_supplying_sample
# 27   Sphingomonas sp. AAP5                        site_supplying_sample
# 28   Sphingomonas sp. LMO-1                       site_supplying_sample
# 29   Sphingomonas sp. NIC1                        site_supplying_sample
# 30   Sphingomonas sp. C8-2                        site_supplying_sample
# ⋮    ⋮                                            ⋮
# 5214 Aggregatibacter sp. 2125159857               hiseq_xtm_flow_cell_v2_5_lot
# 5215 Empedobacter stercoris                       hiseq_xtm_flow_cell_v2_5_lot
# 5216 Fannyhessea vaginae                          hiseq_xtm_flow_cell_v2_5_lot
# 5217 Frischella perrara                           hiseq_xtm_flow_cell_v2_5_lot
# 5218 Leptotrichia sp. oral taxon 498              hiseq_xtm_flow_cell_v2_5_lot
# 5219 Rickettsia endosymbiont of Ixodes scapularis hiseq_xtm_flow_cell_v2_5_lot
# 5220 Streptococcus marmotae                       hiseq_xtm_flow_cell_v2_5_lot
# 5221 Rickettsia endosymbiont of Bemisia tabaci    hiseq_xtm_flow_cell_v2_5_lot
# 5222 Streptococcus koreensis                      hiseq_xtm_flow_cell_v2_5_lot
# 5223 Rickettsia australis                         hiseq_xtm_flow_cell_v2_5_lot
# 5224 Rickettsia amblyommatis                      hiseq_xtm_flow_cell_v2_5_lot
# 5225 Rickettsia canadensis                        hiseq_xtm_flow_cell_v2_5_lot
# 5226 Rickettsia asiatica                          hiseq_xtm_flow_cell_v2_5_lot
# 5227 Aggregatibacter segnis                       hiseq_xtm_flow_cell_v2_5_lot
# 5228 Streptococcus sp. LPB0220                    hiseq_xtm_flow_cell_v2_5_lot
# 5229 Ligilactobacillus ruminis                    hiseq_xtm_flow_cell_v2_5_lot
# 5230 Rickettsia monacensis                        hiseq_xtm_flow_cell_v2_5_lot
# 5231 Treponema sp. OMZ 804                        hiseq_xtm_flow_cell_v2_5_lot
# 5232 Streptococcus sp. I-G2                       hiseq_xtm_flow_cell_v2_5_lot
# 5233 Hepatitis B virus                            hiseq_xtm_flow_cell_v2_5_lot
# 5234 Rickettsia felis                             hiseq_xtm_flow_cell_v2_5_lot
# 5235 Paracoccus haeundaensis                      hiseq_xtm_flow_cell_v2_5_lot
# 5236 Rickettsia helvetica                         hiseq_xtm_flow_cell_v2_5_lot
# 5237 Rickettsia rhipicephali                      hiseq_xtm_flow_cell_v2_5_lot
# 5238 Rickettsia endosymbiont of Ixodes pacificus  hiseq_xtm_flow_cell_v2_5_lot
# 5239 Woolly monkey hepatitis B virus              hiseq_xtm_flow_cell_v2_5_lot
# 5240 Torque teno virus 2                          hiseq_xtm_flow_cell_v2_5_lot
# 5241 Bacillus sp. TK-2                            hiseq_xtm_flow_cell_v2_5_lot
# 5242 Rickettsia massiliae                         hiseq_xtm_flow_cell_v2_5_lot
# 5243 Capuchin monkey hepatitis B virus            hiseq_xtm_flow_cell_v2_5_lot
#      max_level min_level max_prev     min_prev     fold_diff
# 1    MEC       PRISM     0.6639883126 0.0000000000      Inf
# 2    MEC       HELIOS    0.2322863404 0.0000000000      Inf
# 3    MEC       HELIOS    0.0288531775 0.0000000000      Inf
# 4    MEC       HELIOS    0.0029218408 0.0000000000      Inf
# 5    MEC       HELIOS    0.0032870709 0.0000000000      Inf
# 6    HELIOS    MEC       0.0004376368 0.0000000000      Inf
# 7    MEC       HELIOS    0.0065741417 0.0000000000      Inf
# 8    MEC       HELIOS    0.0014609204 0.0000000000      Inf
# 9    MEC       HELIOS    0.0029218408 0.0000000000      Inf
# 10   MEC       PRISM     0.6190650110 0.0008012821 772.5931
# 11   MEC       PRISM     0.2753834916 0.0000000000      Inf
# 12   MEC       HELIOS    0.0051132213 0.0000000000      Inf
# 13   MEC       HELIOS    0.0010956903 0.0000000000      Inf
# 14   MEC       HELIOS    0.0043827611 0.0000000000      Inf
# 15   MEC       HELIOS    0.0003652301 0.0000000000      Inf
# 16   MEC       SERI      0.6632578524 0.0000000000      Inf
# 17   MEC       SERI      0.6643535427 0.0000000000      Inf
# 18   MEC       SERI      0.6479181885 0.0000000000      Inf
# 19   MEC       PRISM     0.3582907232 0.0000000000      Inf
# 20   MEC       PRISM     0.6274653031 0.0000000000      Inf
# 21   MEC       PRISM     0.5894813733 0.0000000000      Inf
# 22   MEC       PRISM     0.4956172389 0.0000000000      Inf
# 23   MEC       PRISM     0.3363769175 0.0000000000      Inf
# 24   MEC       PRISM     0.2841490139 0.0000000000      Inf
# 25   MEC       PRISM     0.3951789627 0.0000000000      Inf
# 26   MEC       PRISM     0.3816654492 0.0000000000      Inf
# 27   MEC       PRISM     0.4956172389 0.0000000000      Inf
# 28   MEC       PRISM     0.1515704894 0.0000000000      Inf
# 29   MEC       PRISM     0.1355003652 0.0000000000      Inf
# 30   MEC       HELIOS    0.0003652301 0.0000000000      Inf
# ⋮    ⋮         ⋮         ⋮            ⋮            ⋮
# 5214 20347589  20285943  0.002403846  0            Inf
# 5215 20285943  20285943  0.000000000  0            NaN
# 5216 20350042  20285943  0.002096436  0            Inf
# 5217 20285943  20285943  0.000000000  0            NaN
# 5218 20350042  20285943  0.002096436  0            Inf
# 5219 20285943  20285943  0.000000000  0            NaN
# 5220 20285943  20285943  0.000000000  0            NaN
# 5221 20393560  20285943  0.003787879  0            Inf
# 5222 20285943  20285943  0.000000000  0            NaN
# 5223 20285943  20285943  0.000000000  0            NaN
# 5224 20285943  20285943  0.000000000  0            NaN
# 5225 20285943  20285943  0.000000000  0            NaN
# 5226 20285943  20285943  0.000000000  0            NaN
# 5227 20347589  20285943  0.002403846  0            Inf
# 5228 20285943  20285943  0.000000000  0            NaN
# 5229 20285943  20285943  0.000000000  0            NaN
# 5230 20285943  20285943  0.000000000  0            NaN
# 5231 20350042  20285943  0.002096436  0            Inf
# 5232 20285943  20285943  0.000000000  0            NaN
# 5233 20358945  20285943  0.003169572  0            Inf
# 5234 20285943  20285943  0.000000000  0            NaN
# 5235 20350042  20285943  0.002096436  0            Inf
# 5236 20285943  20285943  0.000000000  0            NaN
# 5237 20285943  20285943  0.000000000  0            NaN
# 5238 20285943  20285943  0.000000000  0            NaN
# 5239 20285943  20285943  0.000000000  0            NaN
# 5240 20350042  20285943  0.002096436  0            Inf
# 5241 20285943  20285943  0.000000000  0            NaN
# 5242 20285943  20285943  0.000000000  0            NaN
# 5243 20285943  20285943  0.000000000  0            NaN

# %%
decon_raw_gusto
# Out:
#      taxa                           meta_col                     max_level
# 1    Sphingobium yanoikuyae         site_supplying_sample        GUSTO
# 2    Sphingomonas sp. LM7           site_supplying_sample        GUSTO
# 3    Sphingomonas sp. Cra20         site_supplying_sample        GUSTO
# 4    Sphingomonas sp. LK11          site_supplying_sample        GUSTO
# 5    Sphingomonas sp. AAP5          site_supplying_sample        GUSTO
# 6    Sphingomonas sp. NIC1          site_supplying_sample        GUSTO
# 7    Sphingomonas hengshuiensis     site_supplying_sample        GUSTO
# 8    Sphingomonas koreensis         site_supplying_sample        GUSTO
# 9    Sphingomonas melonis           site_supplying_sample        GUSTO
# 10   Sphingomonas paucimobilis      site_supplying_sample        GUSTO
# 11   Sphingomonas taxi              site_supplying_sample        GUSTO
# 12   Bradyrhizobium sp. PSBB068     site_supplying_sample        GUSTO
# 13   Bradyrhizobium sp. SK17        site_supplying_sample        GUSTO
# 14   Bradyrhizobium sp. CCBAU 53421 site_supplying_sample        GUSTO
# 15   Bradyrhizobium sp. CCBAU 51753 site_supplying_sample        GUSTO
# 16   Bradyrhizobium sp. 6(2017)     site_supplying_sample        GUSTO
# 17   Bradyrhizobium diazoefficiens  site_supplying_sample        GUSTO
# 18   Bradyrhizobium betae           site_supplying_sample        GUSTO
# 19   Bradyrhizobium genosp. L       site_supplying_sample        GUSTO
# 20   Rhodopseudomonas palustris     site_supplying_sample        GUSTO
# 21   Nitrobacter hamburgensis       site_supplying_sample        GUSTO
# 22   Methylobacterium currus        site_supplying_sample        GUSTO
# 23   Methylobacterium sp. C1        site_supplying_sample        GUSTO
# 24   Methylobacterium sp. 17Sr1-43  site_supplying_sample        GUSTO
# 25   Methylobacterium sp. WL1       site_supplying_sample        GUSTO
# 26   Methylobacterium terrae        site_supplying_sample        GUSTO
# 27   Methylobacterium radiotolerans site_supplying_sample        GUSTO
# 28   Methylobacterium aquaticum     site_supplying_sample        GUSTO
# 29   Methylobacterium indicum       site_supplying_sample        GUSTO
# 30   Methylobacterium mesophilicum  site_supplying_sample        GUSTO
# ⋮    ⋮                              ⋮                            ⋮
# 2260 Prevotella sp. oral taxon 299  hiseq_xtm_flow_cell_v2_5_lot 20328452
# 2261 Alistipes megaguti             hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2262 Human betaherpesvirus 6B       hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2263 Fusobacterium hwasookii        hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2264 Staphylococcus arlettae        hiseq_xtm_flow_cell_v2_5_lot 20316761
# 2265 Gardnerella leopoldii          hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2266 Streptococcus pseudoporcinus   hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2267 Megasphaera elsdenii           hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2268 Capnocytophaga sputigena       hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2269 Streptococcus infantarius      hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2270 Aerococcus christensenii       hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2271 Acidaminococcus intestini      hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2272 Corynebacterium sp. NML98-0116 hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2273 Prevotella scopos              hiseq_xtm_flow_cell_v2_5_lot 20328452
# 2274 Streptococcus dysgalactiae     hiseq_xtm_flow_cell_v2_5_lot 20347583
# 2275 Campylobacter hominis          hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2276 Fannyhessea vaginae            hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2277 Haemophilus sp. oral taxon 036 hiseq_xtm_flow_cell_v2_5_lot 20328452
# 2278 Lactobacillus paragasseri      hiseq_xtm_flow_cell_v2_5_lot 20347583
# 2279 Staphylococcus sp. M0911       hiseq_xtm_flow_cell_v2_5_lot 20316761
# 2280 Ligilactobacillus ruminis      hiseq_xtm_flow_cell_v2_5_lot 20347583
# 2281 Streptococcus pasteurianus     hiseq_xtm_flow_cell_v2_5_lot 20347583
# 2282 Ureaplasma urealyticum         hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2283 Staphylococcus argenteus       hiseq_xtm_flow_cell_v2_5_lot 20316761
# 2284 Cruoricaptor ignavus           hiseq_xtm_flow_cell_v2_5_lot 20328452
# 2285 Primate erythroparvovirus 1    hiseq_xtm_flow_cell_v2_5_lot 20316761
# 2286 Human betaherpesvirus 5        hiseq_xtm_flow_cell_v2_5_lot 20335902
# 2287 Human alphaherpesvirus 2       hiseq_xtm_flow_cell_v2_5_lot 20328452
# 2288 Streptococcus sp. FDAARGOS_522 hiseq_xtm_flow_cell_v2_5_lot 20335774
# 2289 Lactobacillus phage Lv-1       hiseq_xtm_flow_cell_v2_5_lot 20316761
#      min_level max_prev    min_prev    fold_diff
# 1    GUSTO     0.003102378 0.003102378 1
# 2    GUSTO     0.021716649 0.021716649 1
# 3    GUSTO     0.020682523 0.020682523 1
# 4    GUSTO     0.016546019 0.016546019 1
# 5    GUSTO     0.001034126 0.001034126 1
# 6    GUSTO     0.001034126 0.001034126 1
# 7    GUSTO     0.011375388 0.011375388 1
# 8    GUSTO     0.002068252 0.002068252 1
# 9    GUSTO     0.002068252 0.002068252 1
# 10   GUSTO     0.010341262 0.010341262 1
# 11   GUSTO     0.001034126 0.001034126 1
# 12   GUSTO     0.521199586 0.521199586 1
# 13   GUSTO     0.806618407 0.806618407 1
# 14   GUSTO     0.355739400 0.355739400 1
# 15   GUSTO     0.081695967 0.081695967 1
# 16   GUSTO     0.270941055 0.270941055 1
# 17   GUSTO     0.002068252 0.002068252 1
# 18   GUSTO     0.034126163 0.034126163 1
# 19   GUSTO     0.009307135 0.009307135 1
# 20   GUSTO     0.015511892 0.015511892 1
# 21   GUSTO     0.001034126 0.001034126 1
# 22   GUSTO     0.448810755 0.448810755 1
# 23   GUSTO     0.223371251 0.223371251 1
# 24   GUSTO     0.486039297 0.486039297 1
# 25   GUSTO     0.474663909 0.474663909 1
# 26   GUSTO     0.435367115 0.435367115 1
# 27   GUSTO     0.359875905 0.359875905 1
# 28   GUSTO     0.475698035 0.475698035 1
# 29   GUSTO     0.426059979 0.426059979 1
# 30   GUSTO     0.468459152 0.468459152 1
# ⋮    ⋮         ⋮           ⋮           ⋮
# 2260 20316761  0.002242152 0           Inf
# 2261 20316761  0.004310345 0           Inf
# 2262 20316761  0.014925373 0           Inf
# 2263 20316761  0.004310345 0           Inf
# 2264 20316761  0.000000000 0           NaN
# 2265 20316761  0.059701493 0           Inf
# 2266 20316761  0.004310345 0           Inf
# 2267 20316761  0.014925373 0           Inf
# 2268 20316761  0.004310345 0           Inf
# 2269 20316761  0.004310345 0           Inf
# 2270 20316761  0.014925373 0           Inf
# 2271 20316761  0.014925373 0           Inf
# 2272 20316761  0.004310345 0           Inf
# 2273 20316761  0.002242152 0           Inf
# 2274 20316761  0.008771930 0           Inf
# 2275 20316761  0.004310345 0           Inf
# 2276 20316761  0.029850746 0           Inf
# 2277 20316761  0.002242152 0           Inf
# 2278 20316761  0.008771930 0           Inf
# 2279 20316761  0.000000000 0           NaN
# 2280 20316761  0.017543860 0           Inf
# 2281 20316761  0.008771930 0           Inf
# 2282 20316761  0.012931034 0           Inf
# 2283 20316761  0.000000000 0           NaN
# 2284 20316761  0.002242152 0           Inf
# 2285 20316761  0.000000000 0           NaN
# 2286 20316761  0.014925373 0           Inf
# 2287 20316761  0.002242152 0           Inf
# 2288 20316761  0.004310345 0           Inf
# 2289 20316761  0.000000000 0           NaN

# %%
morsels <- foreach(max_prev_t = c(0.25, 0.5, 0.75)) %do% {
    crumbs <- foreach(fold_diff_t = c(2, 5, 10)) %do% {
        no_gusto_contam <- decon_raw %>%
            mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
            filter(max_prev > max_prev_t, diff_abn) %>%
            distinct(taxa)

        gusto_contams <- decon_raw_gusto %>%
            mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
            filter(max_prev > max_prev_t, diff_abn) %>%
            distinct(taxa)

        temp_contam <- bind_rows(no_gusto_contam, gusto_contams) %>%
            distinct(taxa)
        
        tibble(max_prev = max_prev_t, fold_diff = fold_diff_t, n_contam = length(temp_contam$taxa))
    }
    
    return(bind_rows(crumbs))
}

bind_rows(morsels)
# Out:
#   max_prev fold_diff n_contam
# 1 0.25      2        160
# 2 0.25      5        160
# 3 0.25     10        160
# 4 0.50      2        124
# 5 0.50      5        124
# 6 0.50     10        124
# 7 0.75      2         91
# 8 0.75      5         88
# 9 0.75     10         87

# %%
max_prev_t <- 0.25
fold_diff_t <- 2

no_gusto_contam <- decon_raw %>%
    mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
    filter(max_prev > max_prev_t, diff_abn) %>%
    distinct(taxa)

gusto_contams <- decon_raw_gusto %>%
    mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
    filter(max_prev > max_prev_t, diff_abn) %>%
    distinct(taxa)

contam <- bind_rows(no_gusto_contam, gusto_contams) %>%
    distinct(taxa)
contam

nc <- colnames(df_zeroed)
nc <- nc[!(nc %in% contam$taxa)]
nc <- tibble(taxa = nc[nc != "npm_research_id"])
# Out:
#     taxa
# 1   Sphingobium sp. YG1
# 2   Sphingobium yanoikuyae
# 3   Sphingobium baderi
# 4   Sphingomonas sp. LM7
# 5   Sphingomonas sp. Cra20
# 6   Sphingomonas sp. CL5.1
# 7   Sphingomonas sp. IC081
# 8   Sphingomonas sp. XS-10
# 9   Sphingomonas sp. FARSPH
# 10  Sphingomonas sp. LK11
# 11  Sphingomonas sp. DH-S5
# 12  Sphingomonas sp. NBWT7
# 13  Sphingomonas sp. MM-1
# 14  Sphingomonas sp. AP4-R1
# 15  Sphingomonas sp. AAP5
# 16  Sphingomonas hengshuiensis
# 17  Sphingomonas koreensis
# 18  Sphingomonas sanxanigenens
# 19  Sphingomonas alpina
# 20  Sphingomonas melonis
# 21  Sphingomonas paucimobilis
# 22  Sphingomonas taxi
# 23  Sphingomonas panacisoli
# 24  Sphingomonas panacis
# 25  Novosphingobium sp. ABRDHK2
# 26  Sphingosinithalassobacter sp. zrk23
# 27  Sphingosinithalassobacter sp. CS137
# 28  Bradyrhizobium sp. BTAi1
# 29  Bradyrhizobium sp. PSBB068
# 30  Bradyrhizobium sp. CCBAU 051011
# ⋮   ⋮
# 131 Methylobacterium phyllosphaerae
# 132 Methylobacterium sp. 4-46
# 133 Methylobacterium nodulans
# 134 Rhizobium oryzihabitans
# 135 Achromobacter denitrificans
# 136 Delftia acidovorans
# 137 Delftia tsuruhatensis
# 138 Massilia oculi
# 139 Microbacterium sp. 10M-3C3
# 140 Methylobacterium sp. 17Sr1-1
# 141 Methylobacterium sp. AMS5
# 142 Bosea sp. RAC05
# 143 Phreatobacter cathodiphilus
# 144 Achromobacter spanius
# 145 Achromobacter sp. AONIH1
# 146 Leifsonia shinshuensis
# 147 Methylobacterium sp. DM1
# 148 Massilia sp. LPB0304
# 149 Microbacterium lemovicicum
# 150 Bradyrhizobium sp.
# 151 Phreatobacter stygius
# 152 Microbacterium oleivorans
# 153 Methylobacterium sp. C1
# 154 Methylobacterium radiotolerans
# 155 Phyllobacterium sp. 628
# 156 Stenotrophomonas maltophilia
# 157 Methylobacterium sp. XJLW
# 158 Methylorubrum zatmanii
# 159 Toxoplasma gondii
# 160 Prevotella copri

# %%
df_zeroed %>%
    left_join(meta) %>%
    group_by(site_supplying_sample) %>%
    summarise(sum = sum(get("Toxoplasma gondii")))
# Out:
# Joining, by = "npm_research_id"
#   site_supplying_sample sum
# 1 GUSTO                 34
# 2 HELIOS                 0
# 3 MEC                   24
# 4 PRISM                  0
# 5 SERI                   0
# 6 SSMP                   3
# 7 TTSH                   0

# %%
decon_raw %>%
    mutate(diff_abn = ifelse(fold_diff > fold_diff_t, T, F)) %>%
    filter(max_prev > max_prev_t, diff_abn) %>%
    filter(grepl("Toxo", taxa))
# Out:
#      taxa meta_col max_level min_level max_prev min_prev fold_diff diff_abn

# %%
sum(df_zeroed$`Toxoplasma gondii`)
# Out:
# [1] 61

# %%
contam$taxa[!(contam$taxa %in% contam_no_split$taxa)]
# Out:
# Error in contam$taxa %in% contam_no_split$taxa: object 'contam_no_split' not found
# Traceback:
#
# 1. contam$taxa %in% contam_no_split$taxa

# %%
contam_no_split <- read.csv("results/decontamination/diff_prev_V3/contaminants.RA0.005.read_threshold10.max_prev0.25.fold_diff2.txt")
# contam_no_split

sum(contam$taxa %in% contam_no_split$taxa)

# %%
length(contam$taxa)
length(nc$taxa)

# %% [markdown]
# #### Determine how many taxa were not analysable

# %%
not_analysable <- decon_raw %>%
    group_by(taxa) %>%
    summarise(max_max_prev = max(max_prev)) %>%
    filter(max_max_prev <= 0.25)

sum(not_analysable$taxa %in% nc$taxa)

# %%
fwrite(decon_raw, str_glue("results/decontamination/diff_prev_V3/decon_V3_raw.RA{RA_threshold}.read_threshold{read_threshold}.csv"))
fwrite(decon_raw_gusto, str_glue("results/decontamination/diff_prev_V3/decon_V3_raw.GUSTO_only.RA{RA_threshold}.read_threshold{read_threshold}.csv"))
fwrite(contam, str_glue("results/decontamination/diff_prev_V3/contaminants.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))
fwrite(nc, str_glue("results/decontamination/diff_prev_V3/noncontaminants.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.txt"))

# %% [markdown]
# ### Sanity check

# %%
# taxon <- "Alcaligenes faecalis"
# taxon <- "Stenotrophomonas maltophilia"
# column <- "extraction_kit"
# # column <- "hiseq_xtm_sbs_kit_300_cycles_v2__box_2_of_2__lot"

# for (taxon in c( "Alcaligenes faecalis", "Moraxella osloensis", "Lactobacillus crispatus")) {
#     df_zeroed %>% 
#         left_join(meta) %>%
#         group_by_at(c(column)) %>%
#         summarise(prevalence = sum(get(taxon)) / n()) %>%
#         filter(get(column) != "Unknown") %>%
#         ggplot(aes(x = get(column), y = prevalence)) +
#             geom_bar(stat = "identity") +
#             theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
#         ylim(0, 1) +
#         labs(x = column, y = "Prevalence", title = taxon)
#     ggsave(str_glue("results/decontamination/diff_prev_V3/{taxon}.{column}.batch_prevalence.png"), dpi = 300)
# }

# %% [markdown]
# #### Query taxa that have overall prevalence > x

# %%
prevalence_t <- 0.1
prev_stats <- apply(df_zeroed[, 2:ncol(df_zeroed)], 2, sum) / nrow(df_zeroed)
overall_prev <- data.frame(taxa = names(prev_stats), prevalence = as.vector(prev_stats))
prevalent_taxa <- overall_prev %>% filter(prevalence > prevalence_t)
prevalent_taxa <- prevalent_taxa$taxa
length(prevalent_taxa)

# %%
sum(contam$taxa %in% prevalent_taxa)

# %%
overall_prev %>% arrange(desc(prevalence))

# %% [markdown]
# #### Positive and negative controls

# %%
# pos_control <- read.csv("data/reported_controls/damgaard_2015_positive.txt")$positive_controls
# torque_tenos <- (overall_prev %>% filter(grepl("torque teno", taxa, ignore.case = T)))$taxa
# herpes <- (overall_prev %>% filter(grepl("herpes", taxa, ignore.case = T)))$taxa
# pos_control <- c(pos_control, 
#                  "Escherichia coli",
#                  "Pasteurella multocida", 
#                  "Bartonella henselae", "Bartonella clarridgeiae", 
#                  "Enterococcus faecalis", "Cutibacterium acnes", "Staphylococcus epidermis", "Actinomyces viscosus",
#                  "Streptococcus agalactiae",
#                  "Yersinia enterocolitica",
#                  "Leclercia adecarboxylata",
#                  "Streptococcus pneumoniae",
#                  torque_tenos,
#                  herpes
#                  )
# neg_control1 <- read.csv("data/reported_controls/asmp_parsed_negative.txt")$taxa
# neg_control2 <- read.csv("data/reported_controls/chng_2020_parsed_negative.txt")$taxa
# neg_control3 <- read.csv("data/reported_controls/caregiver_parsed_negative.txt")$taxa

# intersection <- Reduce(intersect, list(neg_control1, neg_control2, neg_control3))
# union <- unique(c(neg_control1, neg_control2, neg_control3))

# # At least 2 studies
# all_neg <- table(c(neg_control1, neg_control2, neg_control3))
# semi_union <- names(all_neg[all_neg >= 2])

# pos_not_intersect <- pos_control[!(pos_control %in% intersection)]
# pos_not_union <- pos_control[!(pos_control %in% union)]
# pos_not_semi <- pos_control[!(pos_control %in% semi_union)]

# print(length(intersection))
# print(length(union))
# print(length(semi_union))
# print(length(pos_control))
# print(length(pos_not_intersect))
# print(length(pos_not_union))

# %%
# tibble(intersection)

# %% [markdown]
# #### Plot venn diagrams of controls

# %%
# venn_list1 <- list(nc = nc$taxa,
#                   contam = contam$taxa, 
#                   pos_not_semi = pos_not_semi)

# venn_list2 <- list(nc = nc$taxa,
#                   contam = contam$taxa, 
#                   semi_union = semi_union)

# # ggVennDiagram(venn_list1, category.names = c("Non-contaminants", "Contaminants", "Found in blood")) +
# #     scale_fill_gradient(low = "#F4FAFE", high = "#4981BF") +
# #     scale_color_manual(values = "black")
# #     theme(legend.position = "none")

# # ggVennDiagram(venn_list2, category.names = c("Non-contaminants", "Contaminants", "Common contaminants (union)")) +
# #     scale_fill_gradient(low = "#F4FAFE", high = "#4981BF") +
# #     theme(legend.position = "none")

# venn.diagram(venn_list1, 
#              filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_pos_controls.png"),
# #              category.names = c("Identified non-contaminants", "Identified contaminants", "Found in blood"),
#              category.names = c("", "", ""),
#              print.mode = c("raw"),
#              fill = c("#999999", "#E69F00", "#66a182")
#              )

# venn.diagram(venn_list2, 
#              filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_neg_controls.png"),
# #              category.names = c("Identified non-contaminants", "Identified contaminants", "Common contaminants (union)"),
#              category.names = c("", "", ""),
#              print.mode = c("raw"),
#              fill = c("#999999", "#E69F00", "#f8766d")
#              )

# # filename = str_glue("results/decontamination/diff_prev_V3/decontamination_results_pos_controls.png"),

# %%
# # venn_list1 <- list(asmp = neg_control1,
# #                   caregiver = neg_control3, 
# #                   hospital = neg_control2,
# #                   prevalent = prevalent_taxa)

# # venn.diagram(venn_list1, 
# #              filename = str_glue("results/decontamination/diff_prev_V3/negative_controls_venn.png"),
# #              category.names = c("ASMP", "Caregiver", "Hospital", str_glue(">{prevalence_t} prevalence")),
# #              print.mode = c("raw", "percent")
# #              )

# # venn_list2 <- list(intersection = intersection,
# #                   pos_control = pos_control,
# #                   prevalent = prevalent_taxa)

# # venn.diagram(venn_list2, 
# #              filename = str_glue("results/decontamination/diff_prev_V3/pos_intersection_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
# #              category.names = c("Negative (intersect)", "Positive", str_glue(">{prevalence_t} prevalence")),
# #              print.mode = c("raw", "percent")
# #              )

# # venn_list3 <- list(union = union,
# #                   pos_control = pos_control,
# #                   prevalent = prevalent_taxa)

# # venn.diagram(venn_list3, 
# #              filename = str_glue("results/decontamination/diff_prev_V3/pos_union_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
# #              category.names = c("Negative (union)", "Positive", str_glue(">{prevalence_t} prevalence")),
# #              print.mode = c("raw", "percent"),
# #              height = 5000, width = 5000
# #              )

# venn_list4 <- list(asmp = neg_control1,
#                   caregiver = neg_control3, 
#                   hospital = neg_control2)

# venn.diagram(venn_list4, 
#              filename = str_glue("results/decontamination/diff_prev_V3/negative_controls_venn.RA{RA_threshold}.read_threshold{read_threshold}.max_prev{max_prev_t}.fold_diff{fold_diff_t}.png"),
#              category.names = c("ASMP", "Caregiver", "Hospital"),
#              print.mode = c("raw", "percent")
#              )
